# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/Casos_por_cidades.csv'

df = pd.read_csv(url)
print(len(df))
print(df.head())
 

df2 = df.sort_values(by='last_available_confirmed', ascending=False)
df3 = df2[:15].reset_index(drop=True)
print(df3)


#for i in range(15):
#print(df2.loc[['city', 'last_available_confirmed']])
# Out:
# 5524
#              city  city_ibge_code        date  epidemiological_week  \
# 0       São Paulo       3550308.0  2020-08-18                    34
# 1        Brasília       5300108.0  2020-08-18                    34
# 2  Rio de Janeiro       3304557.0  2020-08-18                    34
# 3        Salvador       2927408.0  2020-08-18                    34
# 4       Fortaleza       2304400.0  2020-08-18                    34
#
#    estimated_population_2019  is_last  is_repeated  last_available_confirmed  \
# 0                 12252023.0    False         True                    236163
# 1                  3015268.0    False         True                    120321
# 2                  6718903.0    False         True                     80899
# 3                  2872347.0    False         True                     68087
# 4                  2669342.0    False         True                     44974
#
#    last_available_confirmed_per_100k_inhabitants last_available_date  \
# 0                                     1927.54290          2020-08-17
# 1                                     3990.39157          2020-08-16
# 2                                     1204.05072          2020-08-17
# 3                                     2370.43087          2020-08-17
# 4                                     1684.83469          2020-08-17
#
#    last_available_death_rate  last_available_deaths  order_for_place  \
# 0                     0.0450                  10625              176
# 1                     0.0150                   1807              165
# 2                     0.1091                   8830              166
# 3                     0.0319                   2174              159
# 4                     0.0836                   3758              156
#
#   place_type state  new_confirmed  new_deaths
# 0       city    SP              0           0
# 1       city    DF              0           0
# 2       city    RJ              0           0
# 3       city    BA              0           0
# 4       city    CE              0           0
#               city  city_ibge_code        date  epidemiological_week  \
# 0        São Paulo       3550308.0  2020-08-18                    34
# 1         Brasília       5300108.0  2020-08-18                    34
# 2   Rio de Janeiro       3304557.0  2020-08-18                    34
# 3         Salvador       2927408.0  2020-08-18                    34
# 4        Fortaleza       2304400.0  2020-08-18                    34
# 5           Manaus       1302603.0  2020-08-18                    34
# 6          Aracaju       2800308.0  2020-08-18                    34
# 7        Boa Vista       1400100.0  2020-08-18                    34
# 8           Recife       2611606.0  2020-08-18                    34
# 9            Belém       1501402.0  2020-08-18                    34
# 10  Belo Horizonte       3106200.0  2020-08-18                    34
# 11         Goiânia       5208707.0  2020-08-18                    34
# 12     Porto Velho       1100205.0  2020-08-18                    34
# 13          Maceió       2704302.0  2020-08-18                    34
# 14     João Pessoa       2507507.0  2020-08-18                    34
#
#     estimated_population_2019  is_last  is_repeated  last_available_confirmed  \
# 0                  12252023.0    False         True                    236163
# 1                   3015268.0    False         True                    120321
# 2                   6718903.0    False         True                     80899
# 3                   2872347.0    False         True                     68087
# 4                   2669342.0    False         True                     44974
# 5                   2182763.0    False         True                     39563
# 6                    657013.0    False         True                     31777
# 7                    399213.0    False         True                     29978
# 8                   1645727.0    False         True                     29718
# 9                   1492745.0    False         True                     29262
# 10                  2512070.0    False         True                     28462
# 11                  1516113.0    False         True                     26216
# 12                   529544.0    False         True                     25006
# 13                  1018948.0    False         True                     24909
# 14                   809015.0    False         True                     24597
#
#     last_available_confirmed_per_100k_inhabitants last_available_date  \
# 0                                      1927.54290          2020-08-17
# 1                                      3990.39157          2020-08-16
# 2                                      1204.05072          2020-08-17
# 3                                      2370.43087          2020-08-17
# 4                                      1684.83469          2020-08-17
# 5                                      1812.51927          2020-08-17
# 6                                      4836.58619          2020-08-17
# 7                                      7509.27450          2020-08-17
# 8                                      1805.76730          2020-08-17
# 9                                      1960.28123          2020-08-17
# 10                                     1133.00983          2020-08-17
# 11                                     1729.15871          2020-08-17
# 12                                     4722.17606          2020-08-17
# 13                                     2444.58010          2020-08-17
# 14                                     3040.36390          2020-08-17
#
#     last_available_death_rate  last_available_deaths  order_for_place  \
# 0                      0.0450                  10625              176
# 1                      0.0150                   1807              165
# 2                      0.1091                   8830              166
# 3                      0.0319                   2174              159
# 4                      0.0836                   3758              156
# 5                      0.0546                   2159              159
# 6                      0.0201                    640              158
# 7                      0.0148                    444              151
# 8                      0.0747                   2220              160
# 9                      0.0709                   2074              154
# 10                     0.0284                    808              156
# 11                     0.0246                    645              160
# 12                     0.0243                    608              151
# 13                     0.0322                    803              164
# 14                     0.0310                    762              154
#
#    place_type state  new_confirmed  new_deaths
# 0        city    SP              0           0
# 1        city    DF              0           0
# 2        city    RJ              0           0
# 3        city    BA              0           0
# 4        city    CE              0           0
# 5        city    AM              0           0
# 6        city    SE              0           0
# 7        city    RR              0           0
# 8        city    PE              0           0
# 9        city    PA              0           0
# 10       city    MG              0           0
# 11       city    GO              0           0
# 12       city    RO              0           0
# 13       city    AL              0           0
# 14       city    PB              0           0

# %%
print('Ultimos casos confirmados \n')

print(df3.loc[:, ['city', 'last_available_confirmed']])
# Out:
# Ultimos casos confirmados
#
#               city  last_available_confirmed
# 0        São Paulo                    236163
# 1         Brasília                    120321
# 2   Rio de Janeiro                     80899
# 3         Salvador                     68087
# 4        Fortaleza                     44974
# 5           Manaus                     39563
# 6          Aracaju                     31777
# 7        Boa Vista                     29978
# 8           Recife                     29718
# 9            Belém                     29262
# 10  Belo Horizonte                     28462
# 11         Goiânia                     26216
# 12     Porto Velho                     25006
# 13          Maceió                     24909
# 14     João Pessoa                     24597
