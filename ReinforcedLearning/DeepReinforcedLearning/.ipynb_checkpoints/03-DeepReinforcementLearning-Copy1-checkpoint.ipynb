# %% [markdown]
# # <font color='blue'>Data Science Academy - Deep Learning II</font>

# %% [markdown]
# # Deep Reinforcement Learning
#
# O objetivo de Deep Reinforcement Learning é encontrar uma Função de Aproximação que permita resolver ambientes complexos, lidando com o problema da generalização.
#
# Tudo começou em 2013, com o Deep Mind (que mais tarde seria comprado pelo Google para se tornar o braço de pesquisa em Deep Learning):
#
# https://arxiv.org/abs/1312.5602
#
# https://www.cs.toronto.edu/~vmnih/docs/dqn.pdf

# %% [markdown]
# ## Reinforcement Learning
#
# Considere o jogo Breakout. Neste jogo você controla uma pá na parte inferior da tela e tem que saltar a bola de volta para limpar todos os tijolos na metade superior da tela. Cada vez que você bate em um tijolo, ele desaparece e sua pontuação aumenta - você recebe uma recompensa.
#
# Suponha que você queira ensinar uma rede neural a jogar este jogo. A entrada em sua rede seria imagens de tela, e a saída seria de três ações: esquerda, direita ou fogo (para iniciar a bola). Teria sentido tratá-lo como um problema de classificação - para cada tela de jogo você deve decidir, se você deve mover para a esquerda, direita ou pressionar o fogo. Parece simples? Claro, mas então você precisa de exemplos de treinamento, e muitos deles. Claro que você poderia gravar sessões de jogos usando jogadores experientes, mas isso não é realmente como aprendemos. Não precisamos de alguém para nos contar um milhão de vezes que se movem para escolher em cada tela. Nós apenas precisamos de feedback ocasional que fizemos a coisa certa e podemos descobrir todos os outros nós mesmos.
#
# Esta é a tarefa que o aprendizado de reforço tenta resolver. O aprendizado de reforço situa-se entre a aprendizagem supervisionada e não supervisionada. No aprendizado supervisionado, usamos um rótulo alvo para cada exemplo de treinamento e na aprendizagem sem supervisão não tem rótulos. No aprendizado por reforço, temos rótulos dispersos e atrasados, as recompensas. Com base apenas nas recompensas, o agente deve aprender a comportar-se no ambiente.
#
# <img src="images/breakout.png">
#
# Embora a ideia seja bastante intuitiva, na prática há inúmeros desafios. Por exemplo, quando você bate em um tijolo e ganha uma recompensa no jogo Breakout, muitas vezes não tem nada a ver com as ações (movimentos de remo) que você fez antes de obter a recompensa. Todo o trabalho duro já foi feito, quando você colocou a pá corretamente e saltou a bola de volta. Isso é chamado de problema de atribuição de crédito - ou seja, qual das ações anteriores foi responsável por receber a recompensa e até que ponto.
#
# Depois de ter descoberto uma estratégia para coletar um certo número de recompensas, você deve ficar com ela ou experimentar alguma coisa que possa resultar em recompensas ainda maiores? No jogo Breakout acima, uma estratégia simples é mover-se para a margem esquerda e esperar lá. Quando lançado, a bola tende a voar para a esquerda com mais frequência do que a direita e você conseguirá marcar com facilidade cerca de 10 pontos antes de morrer. Você ficará satisfeito com isso ou quer mais? Isso é chamado de dilema explore-exploit - você deve explorar a estratégia de trabalho conhecida ou explorar outras estratégias possivelmente melhores?
#
# O aprendizado por reforço é um modelo importante de como nós (e todos os animais em geral) aprendemos. Elogios de nossos pais, notas na escola, salário no trabalho - estes são exemplos de recompensas. Problemas de atribuição de crédito e dilemas explore-exploit surgem todos os dias, tanto nos negócios como nos relacionamentos. É por isso que é importante estudar este problema, e os jogos formam uma sandbox maravilhosa para experimentar novas abordagens.

# %% [markdown]
# ## Markov Decision Process
#
# Agora, a questão é como você formaliza um problema de aprendizado por reforço, para que você possa raciocinar sobre ele? O método mais comum é representá-lo como um Processo de Decisão Markov.
#
# Suponha que você seja um agente, situado em um ambiente (por exemplo, o jogo Breakout). O ambiente está em certo estado (por exemplo, localização da pá, localização e direção da bola, existência de cada tijolo e assim por diante). O agente pode executar certas ações no ambiente (por exemplo, mover a pá para a esquerda ou para a direita). Essas ações às vezes resultam em uma recompensa (por exemplo, aumento na pontuação). As ações transformam o ambiente e conduzem a um novo estado, onde o agente pode executar outra ação, e assim por diante. As regras sobre como você escolhe essas ações são chamadas de política. O ambiente em geral é estocástico, o que significa que o próximo estado pode ser um pouco aleatório (por exemplo, quando você perde uma bola e lança uma nova, vai para uma direção aleatória).
#
# <img src="images/mdp.png">
#
# O conjunto de estados e ações, juntamente com as regras para a transição de um estado para outro, compõem um processo de decisão Markov. Um episódio deste processo (por exemplo, um jogo) forma uma sequência finita de estados, ações e recompensas:
#
# <img src="images/mdp2.png">
#
# Aqui si representa o estado, ai é a ação e ri + 1 é a recompensa depois de executar a ação. O episódio termina com o estado do terminal sn (por exemplo, "game over"). Um processo de decisão de Markov baseia-se na suposição de Markov, que a probabilidade de o próximo estado si + 1 depende apenas do estado atual si e da ação ai, mas não de estados ou ações anteriores.

# %% [markdown]
# ## Discounted Future Reward
#
# Para se comportar bem a longo prazo, precisamos levar em conta não só as recompensas imediatas, mas também as recompensas futuras que vamos conseguir. Como devemos fazer isso?
#
# Dada uma série do processo de decisão de Markov, podemos calcular facilmente a recompensa total de um episódio:
#
# <img src="images/reward1.png">
#
# Dado que, a recompensa futura total a partir do ponto de tempo a seguir pode ser expressa como:
#
# <img src="images/reward2.png">
#
# Mas porque o nosso ambiente é estocástico, nunca podemos ter certeza, se conseguirmos as mesmas recompensas na próxima vez que realizarmos as mesmas ações. Quanto mais no futuro nós vamos, mais pode divergir. Por esse motivo, é comum usar uma recompensa futura com desconto em vez disso:
#
# <img src="images/reward3.png">
#
# Aqui γ é o fator de desconto entre 0 e 1 - quanto mais no futuro a recompensa é, menos levamos em consideração. É fácil de ver, que a recompensa futura com desconto no tempo passo t pode ser expressa em termos da mesma coisa no tempo passo t + 1:
#
# <img src="images/reward4.png">
#
# Se definimos o fator de desconto γ = 0, nossa estratégia será míope e confiamos apenas nas recompensas imediatas. Se quisermos equilibrar entre recompensas imediatas e futuras, devemos definir fator de desconto para algo como γ = 0.9. Se o nosso ambiente for determinista e as mesmas ações sempre resultarão nas mesmas recompensas, então podemos definir o fator de desconto γ = 1.
#
# Uma boa estratégia para um agente seria sempre escolher uma ação que maximize a recompensa futura (descontada).

# %% [markdown]
# ## Play Game com Agente Baseado em IA
#
# <img src="images/catch-game.jpg">
#
# Catch é um jogo de arcade muito simples, que você provavelmente já jogou. Os frutos estão caindo do topo da tela e o jogador precisa pegá-los com um cesto. Para cada fruta capturada, o jogador recebe um ponto. Para cada fruta perdida, o jogador perde um ponto. Nosso objetivo aqui é permitir que o computador jogue este game por si só.
#
# Ao jogar Catch, o jogador deve decidir entre 3 possíveis ações. O jogador pode mover a cesta para a esquerda, para a direita ou ficar na posição. A base para esta decisão é o estado atual do jogo, a posição do fruto e a posição do cesto, ambos visíveis na tela. Nosso objetivo é, portanto, criar um modelo que, dado o conteúdo da tela do jogo, escolha a ação que leva à maior pontuação possível.
#
# Esta tarefa poderia ser enquadrada como um problema de classificação simples. Poderíamos coletar dados de treinamento, permitindo que jogadores humanos experientes jogassem muitos jogos e, em seguida, treinassem um modelo para escolher a ação "correta" que espelha os jogadores experientes. Não é assim que os humanos aprendem no entanto. Os seres humanos podem aprender um jogo sem orientação. Isso é muito útil. Imagine que você teria que contratar um monte de especialistas para realizar uma tarefa milhares de vezes toda vez que você queria aprender algo tão simples como Catch. Seria muito caro e muito lento. Aqui, usaremos Deep Reinforcement Learning, onde o modelo aprende da experiência, em vez de dados de treinamento rotulados.

# %%
# Imports
import numpy as np
import json
import matplotlib.pyplot as plt
import time
from PIL import Image
from IPython import display
import seaborn
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import sgd

# %matplotlib inline
seaborn.set()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Preparando o Game
#
# No jogo, frutas, representadas por azulejos brancos, caem do topo. O objetivo é pegar os frutos com um basket (representado por azulejos brancos). Se você pegar uma fruta, você obtém um ponto (sua pontuação sobe por um), se você perder uma fruta, perdeu um (sua pontuação diminui).
#
# Não se preocupe muito com os detalhes da implementação, o foco aqui deve ser na IA, e não no jogo. Apenas certifique-se de executar esta célula para que ela seja definida.

# %%
class Catch(object):
    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()

    def _update_state(self, action):
        """
        Input: ações e estados
        Ouput: novos estados e recompensas
        """
        state = self.state
        if action == 0:  # left
            action = -1
        elif action == 1:  # stay
            action = 0
        else:
            action = 1  # right
        f0, f1, basket = state[0]
        new_basket = min(max(1, basket + action), self.grid_size-1)
        f0 += 1
        out = np.asarray([f0, f1, new_basket])
        out = out[np.newaxis]

        assert len(out.shape) == 2
        self.state = out

    def _draw_state(self):
        im_size = (self.grid_size,)*2
        state = self.state[0]
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1  # desenha fruta
        canvas[-1, state[2]-1:state[2] + 2] = 1  # desenha basket
        return canvas
        
    def _get_reward(self):
        fruit_row, fruit_col, basket = self.state[0]
        if fruit_row == self.grid_size-1:
            if abs(fruit_col - basket) <= 1:
                return 1
            else:
                return -1
        else:
            return 0

    def _is_over(self):
        if self.state[0, 0] == self.grid_size-1:
            return True
        else:
            return False

    def observe(self):
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over

    def reset(self):
        n = np.random.randint(0, self.grid_size-1, size=1)
        m = np.random.randint(1, self.grid_size-2, size=1)
        self.state = np.asarray([0, n, m])[np.newaxis]

# %% [markdown]
# Além de definir o jogo, precisamos definir algumas variáveis e funções auxiliares. Execute as células abaixo para defini-las.

# %%
# O último time frame faz o controle do quadro em que estamos
last_frame_time = 0

# Traduz as ações para palavras humanas legíveis
translate_action = ["Left","Stay","Right","Create Ball","End Test"]

# Tamanho do campo de jogo
grid_size = 10

# %%
def display_screen(action,points,input_t):
    # Renderiza a tela do jogo
    global last_frame_time
    print("Action %s, Points: %d" % (translate_action[action],points))
    
    # Somente mostra a tela do jogo se não for game over
    if("End" not in translate_action[action]):
        plt.imshow(input_t.reshape((grid_size,)*2), interpolation='none', cmap='gray')
        display.clear_output(wait=True)
        display.display(plt.gcf())
    last_frame_time = set_max_fps(last_frame_time)
    
    
def set_max_fps(last_frame_time,FPS = 1):
    current_milli_time = lambda: int(round(time.time() * 1000))
    sleep_time = 1./FPS - (current_milli_time() - last_frame_time)
    if sleep_time > 0:
        time.sleep(sleep_time)
    return current_milli_time()

# %% [markdown]
# ## Deep Reinforcement Learning
#
# Agora vamos a parte emocionante.

# %% [markdown]
# ## Q-Learning
#
# No Q-learning, definimos uma função Q(s, a) que representa a recompensa futura máxima com desconto quando executamos a ação a no estado s e continuamos de forma óptima a partir desse ponto.
#
# Uma boa maneira de entender Q-learning é comparar jogar Catch com jogar xadrez. Em ambos os jogos, você recebe um estado s (xadrez: posições das figuras no tabuleiro, Catch: localização do fruto e do cesto), no qual você deve tomar uma ação a (xadrez: mova uma figura, Catch: move o cesto à esquerda, à direita ou fica onde você está). Como resultado, haverá alguma recompensa e um novo estado s '. O problema tanto com Catch quanto com o xadrez é que as recompensas não aparecerão imediatamente após você ter tomado a ação. Em Catch, você só ganha recompensas quando os frutos caem na cesta ou caem no chão, e no xadrez você só ganha uma recompensa quando ganha ou perde o jogo. As recompensas são _sparsely distributed_, na maioria das vezes, r será 0. Quando há uma recompensa, nem sempre é resultado da ação tomada imediatamente antes. Algumas ações tomadas muito antes podem ter causado a vitória. Determinar qual ação é responsável pela recompensa é muitas vezes referido como _credit assignment problem_.
#
# Como as recompensas são atrasadas, os bons jogadores de xadrez não escolhem suas peças apenas pela recompensa imediata, mas pela recompensa futura esperada. Eles não só pensam sobre se eles podem eliminar uma figura de oponentes no próximo movimento, mas como tomar uma determinada ação agora irá ajudá-los a longo prazo.
#
# No Q-learning, escolhemos nossa ação com base na maior recompensa futura esperada. Enquanto no estado s, estimamos a recompensa futura para cada ação possível a. Assumimos que depois de terem feito uma ação e mudado para o próximo estado s', tudo funciona perfeitamente. Como em finanças, nós descontamos recompensas futuras, já que elas são incertas.
#
# A recompensa futura esperada Q(s, a) dado um estado s e uma ação a é, portanto, a recompensa r que segue diretamente de um mais a recompensa futura esperada Q(s', a') se a ação ideal a' for tomada em o seguinte estado s', descontado pelo fator de desconto gama.
#
# Q(s,a) = r + gamma * max Q(s’,a’)
#
# Os bons jogadores de xadrez são muito bons na estimativa de recompensas futuras em sua cabeça. Em outras palavras, sua função Q (s, a) é muito precisa. A maioria das práticas de xadrez gira em torno do desenvolvimento de uma melhor função Q. Os jogadores examinam muitos jogos antigos para saber como os movimentos específicos se desenrolaram no passado e a probabilidade de uma determinada ação levar a vitória.
#
# Mas como podemos estimar uma boa função Q? É aqui que as redes neurais entram em jogo.
#
#
# ## Como Treinar o Agente
#
# Ao jogar, geramos muitas experiências consistindo no estado inicial s, na ação tomada a, na recompensa ganha r e no estado que seguiu s'. Essas experiências são nossos dados de treinamento. Podemos enquadrar o problema de estimar Q(s, a) como um simples problema de regressão. Dado um vetor de entrada consistindo de s e uma rede neural é suposto prever o valor de Q(s, a) igual ao alvo: r + gama * max Q(s', a'). Se for bom prever Q(s, a) para diferentes estados s e ações a, temos uma boa aproximação de Q. Observe que Q(s', a') é também uma predição da rede neural que estamos treinando.
#
# Dado um lote de experiências < s, a, r, s’ >, o processo de treinamento então é o seguinte:
#
# 1. Para cada ação possível a' (esquerda, direita, permanência), preveja a recompensa futura esperada Q(s', a') usando a rede neural
# 2. Escolha o valor mais alto das três predições max Q(s', a')
# 3. Calcule r + gama * max Q (s', a'). Este é o valor alvo da rede neural.
# 4. Treina a rede neural usando a função de perda 1/2(predicted_Q(s,a) - target)^2
#
# Durante a jogabilidade, todas as experiências são armazenadas em uma memória de repetição. Esta é a classe abaixo.
#
# A função de lembrança simplesmente salva uma experiência em uma lista. A função get_batch executa os passos 1 a 3 da lista acima e retorna uma entrada e um vetor de destino. O treinamento real é feito em uma função discutida abaixo.

# %%
class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        """
        Setup
        max_memory: o número máximo de experiências que queremos armazenar
        memory: uma lista de experiências
        discount: o fator de desconto para a experiência futura
        
        Na memória, a informação se o jogo terminou no estado é armazenada separadamente em uma matriz aninhada
        [...
        [experience, game_over]
        [experience, game_over]
        ...]
        """
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        # Salvando o estado na memória
        self.memory.append([states, game_over])
        
        # Nós não queremos armazenar memórias infinitas, então, se tivermos demais, 
        # simplesmente excluímos o mais antigo
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        
        # Quantas experiências temos?
        len_memory = len(self.memory)
        
        # Calcule o número de ações que podem ser tomadas no jogo
        num_actions = model.output_shape[-1]
        
        # Dimensões do campo de jogo
        env_dim = self.memory[0][0][0].shape[1]
        
        # Queremos retornar um vetor de entrada e destino com entradas de um estado observado...
        inputs = np.zeros((min(len_memory, batch_size), env_dim))
        
        # ...e target r + gamma * max Q(s’,a’)
        # Observe que nosso alvo é uma matriz, com possíveis campos não só para a ação realizada, mas também 
        # para as outras ações possíveis. As ações não tomam o mesmo valor que a previsão de não afetá-las.
        targets = np.zeros((inputs.shape[0], num_actions))
        
        # Nós desenhamos estados para aprender aleatoriamente
        for i, idx in enumerate(np.random.randint(0, len_memory, size=inputs.shape[0])):

            state_t, action_t, reward_t, state_tp1 = self.memory[idx][0]
            
            # Também precisamos saber se o jogo terminou nesse estado
            game_over = self.memory[idx][1]

            # Adicione o estado s à entrada
            inputs[i:i+1] = state_t
            
            # Primeiro, preenchemos os valores-alvo com as previsões do modelo. 
            # Eles não serão afetados pelo treinamento (uma vez que a perda de treinamento para eles é 0)
            targets[i] = model.predict(state_t)[0]
            
            """
            Se o jogo acabou, a recompensa esperada Q (s, a) deve ser a recompensa final r.
            Ou então o target value é r + gamma * max Q(s’,a’)
            """
            Q_sa = np.max(model.predict(state_tp1)[0])
            
            # Se o jogo acabou, a recompensa é a recompensa final.
            if game_over:  
                targets[i, action_t] = reward_t
            else:
                # r + gamma * max Q(s’,a’)
                targets[i, action_t] = reward_t + self.discount * Q_sa
        return inputs, targets

# %% [markdown]
# ## Definindo o Modelo
#
# Agora é hora de definir o modelo que irá aprender Q. Estamos usando o Keras como frontend para Tensorflow ou Theano. Nosso modelo de linha de base é uma rede muito simples de 3 camadas densas. Você pode brincar com modelos mais complexos e ver se você pode melhorar o desempenho.

# %%
def baseline_model(grid_size,num_actions,hidden_size):
    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    model.compile(sgd(lr = .1), "mse")
    return model

# %% [markdown]
# ## Parâmetros
#
# Antes de começar a treinar, precisamos definir alguns parâmetros. Você também pode experimentar com esses.

# %%
# Parâmetros
epsilon = .1      # Exploração
num_actions = 3   # [move_left, stay, move_right]
max_memory = 500  # Número máximo de experiências que estamos armazenando
hidden_size = 100 # Tamanho das camadas ocultas
batch_size = 1    # Número de experiências que usamos para treinar por lote
grid_size = 10    # Tamanho do campo de jogo

# %%
# Modelo
model = baseline_model(grid_size,num_actions,hidden_size)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 20,503
# Trainable params: 20,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define environment/game
env = Catch(grid_size)

# Inicializa o objeto de repetição da experiência
exp_replay = ExperienceReplay(max_memory=max_memory)

# %% [markdown]
# ## Treinando o Modelo
#
# O treinamento é relativamente direto. Nós deixamos o modelo jogar o jogo. Enquanto joga, ele gera dados de treinamento na forma de experiências. Usamos esses dados de treinamento para treinar nosso estimador Q.

# %%
def train(model, epochs, verbose = 1):
    win_cnt = 0
    win_hist = []
    
    for e in range(epochs):
        loss = 0.
        env.reset()
        game_over = False
        input_t = env.observe()
        
        while not game_over:
            
            # O aluno está atuando na última tela de jogo observada
            # input_t é um vetor que contém a representação da tela do jogo
            input_tm1 = input_t
            
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, num_actions, size=1)
            else:
                q = model.predict(input_tm1)
                # Escolhemos a ação com a maior recompensa esperada
                action = np.argmax(q[0])

            # Aplicar ação, obter recompensas e novo estado
            input_t, reward, game_over = env.act(action)

            if reward == 1:
                win_cnt += 1        
            
            # Experiência 
            exp_replay.remember([input_tm1, action, reward, input_t], game_over)    
            
            # Carregar lote de experiências
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)
  
            # Modelo de trem sobre experiências
            batch_loss = model.train_on_batch(inputs, targets)
            
            loss += batch_loss
        if verbose > 0:
            print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win count {}".format(e, epochs, loss, win_cnt))
        win_hist.append(win_cnt)
    return win_hist

# %% [markdown]
# ## Playing Vários Games
#
# Para se tornar um bom jogador, nosso modelo precisa jogar _many_ games. Descobri que, após cerca de 4.000 jogos, tornou-se um jogador decente. Por causa de um notebook legível, desabilitamos a saída do treinador aqui. Veja a seção sobre avaliação do progresso abaixo para um gráfico.

# %%
# Número de jogos jogados no treinamento. O modelo precisa de cerca de 4.000 jogos até que ele jogue bem
epoch = 5000 

# Treinando o Modelo
hist = train(model, epoch, verbose=1)
print("Treinamento Concluído!")
# Out:
# Epoch 000/5000 | Loss 0.0284 | Win count 0
# Epoch 001/5000 | Loss 0.5250 | Win count 0
# Epoch 002/5000 | Loss 0.1903 | Win count 0
# Epoch 003/5000 | Loss 0.1171 | Win count 0
# Epoch 004/5000 | Loss 0.2811 | Win count 1
# Epoch 005/5000 | Loss 0.4200 | Win count 1
# Epoch 006/5000 | Loss 0.5790 | Win count 2
# Epoch 007/5000 | Loss 0.2553 | Win count 2
# Epoch 008/5000 | Loss 0.0910 | Win count 2
# Epoch 009/5000 | Loss 0.0435 | Win count 3
# Epoch 010/5000 | Loss 0.0582 | Win count 3
# Epoch 011/5000 | Loss 0.4210 | Win count 3
# Epoch 012/5000 | Loss 0.3586 | Win count 3
# Epoch 013/5000 | Loss 0.0707 | Win count 4
# Epoch 014/5000 | Loss 0.0326 | Win count 5
# Epoch 015/5000 | Loss 0.4302 | Win count 6
# Epoch 016/5000 | Loss 0.2011 | Win count 6
# Epoch 017/5000 | Loss 0.0165 | Win count 6
# Epoch 018/5000 | Loss 1.1626 | Win count 6
# Epoch 019/5000 | Loss 0.5546 | Win count 6
# Epoch 020/5000 | Loss 0.6953 | Win count 6
# Epoch 021/5000 | Loss 0.4430 | Win count 7
# Epoch 022/5000 | Loss 0.0413 | Win count 7
# Epoch 023/5000 | Loss 1.0202 | Win count 7
# Epoch 024/5000 | Loss 0.7253 | Win count 7
# Epoch 025/5000 | Loss 0.4306 | Win count 7
# Epoch 026/5000 | Loss 0.3412 | Win count 7
# Epoch 027/5000 | Loss 0.4330 | Win count 8
# Epoch 028/5000 | Loss 0.6168 | Win count 8
# Epoch 029/5000 | Loss 0.0486 | Win count 8
# Epoch 030/5000 | Loss 0.2357 | Win count 8
# Epoch 031/5000 | Loss 0.4680 | Win count 8
# Epoch 032/5000 | Loss 0.5421 | Win count 8
# Epoch 033/5000 | Loss 0.1558 | Win count 8
# Epoch 034/5000 | Loss 0.8041 | Win count 8
# Epoch 035/5000 | Loss 0.3851 | Win count 8
# Epoch 036/5000 | Loss 0.3301 | Win count 8
# Epoch 037/5000 | Loss 0.0282 | Win count 9
# Epoch 038/5000 | Loss 0.0051 | Win count 9
# Epoch 039/5000 | Loss 0.2999 | Win count 9
# Epoch 040/5000 | Loss 0.4811 | Win count 9
# Epoch 041/5000 | Loss 0.7592 | Win count 9
# Epoch 042/5000 | Loss 0.2537 | Win count 9
# Epoch 043/5000 | Loss 0.2288 | Win count 10
# Epoch 044/5000 | Loss 0.1156 | Win count 11
# Epoch 045/5000 | Loss 0.0544 | Win count 11
# Epoch 046/5000 | Loss 0.5715 | Win count 11
# Epoch 047/5000 | Loss 0.3106 | Win count 11
# Epoch 048/5000 | Loss 0.6287 | Win count 12
# Epoch 049/5000 | Loss 0.1075 | Win count 12
# Epoch 050/5000 | Loss 0.4523 | Win count 12
# Epoch 051/5000 | Loss 0.2310 | Win count 13
# Epoch 052/5000 | Loss 0.5399 | Win count 13
# Epoch 053/5000 | Loss 0.2786 | Win count 14
# Epoch 054/5000 | Loss 0.3102 | Win count 14
# Epoch 055/5000 | Loss 0.7374 | Win count 14
# Epoch 056/5000 | Loss 0.0275 | Win count 15
# Epoch 057/5000 | Loss 0.0193 | Win count 16
# Epoch 058/5000 | Loss 0.4075 | Win count 16
# Epoch 059/5000 | Loss 0.8616 | Win count 17
# Epoch 060/5000 | Loss 0.2772 | Win count 18
# Epoch 061/5000 | Loss 0.7423 | Win count 18
# Epoch 062/5000 | Loss 0.0179 | Win count 19
# Epoch 063/5000 | Loss 0.4917 | Win count 19
# Epoch 064/5000 | Loss 0.5632 | Win count 19
# Epoch 065/5000 | Loss 0.0370 | Win count 20
# Epoch 066/5000 | Loss 0.0441 | Win count 20
# Epoch 067/5000 | Loss 0.0531 | Win count 21
# Epoch 068/5000 | Loss 0.4520 | Win count 22
# Epoch 069/5000 | Loss 0.5553 | Win count 22
# Epoch 070/5000 | Loss 0.8862 | Win count 22
# Epoch 071/5000 | Loss 0.4127 | Win count 23
# Epoch 072/5000 | Loss 0.2960 | Win count 23
# Epoch 073/5000 | Loss 0.3161 | Win count 23
# Epoch 074/5000 | Loss 0.2235 | Win count 23
# Epoch 075/5000 | Loss 0.3617 | Win count 24
# Epoch 076/5000 | Loss 0.1927 | Win count 25
# Epoch 077/5000 | Loss 0.2308 | Win count 25
# Epoch 078/5000 | Loss 0.3525 | Win count 25
# Epoch 079/5000 | Loss 0.8149 | Win count 25
# Epoch 080/5000 | Loss 0.4273 | Win count 25
# Epoch 081/5000 | Loss 0.1413 | Win count 26
# Epoch 082/5000 | Loss 0.0701 | Win count 27
# Epoch 083/5000 | Loss 0.1528 | Win count 27
# Epoch 084/5000 | Loss 1.2033 | Win count 28
# Epoch 085/5000 | Loss 0.1699 | Win count 28
# Epoch 086/5000 | Loss 0.5755 | Win count 28
# Epoch 087/5000 | Loss 0.2082 | Win count 28
# Epoch 088/5000 | Loss 0.8298 | Win count 29
# Epoch 089/5000 | Loss 0.0230 | Win count 29
# Epoch 090/5000 | Loss 0.7775 | Win count 30
# Epoch 091/5000 | Loss 0.1218 | Win count 31
# Epoch 092/5000 | Loss 0.1309 | Win count 31
# Epoch 093/5000 | Loss 0.6752 | Win count 31
# Epoch 094/5000 | Loss 0.9687 | Win count 32
# Epoch 095/5000 | Loss 0.3986 | Win count 32
# Epoch 096/5000 | Loss 0.2474 | Win count 32
# Epoch 097/5000 | Loss 0.3370 | Win count 33
# Epoch 098/5000 | Loss 0.2929 | Win count 34
# Epoch 099/5000 | Loss 0.3316 | Win count 34
# Epoch 100/5000 | Loss 0.1084 | Win count 34
# Epoch 101/5000 | Loss 1.0688 | Win count 34
# Epoch 102/5000 | Loss 0.0520 | Win count 34
# Epoch 103/5000 | Loss 0.3281 | Win count 35
# Epoch 104/5000 | Loss 0.5600 | Win count 35
# Epoch 105/5000 | Loss 0.1348 | Win count 35
# Epoch 106/5000 | Loss 0.2886 | Win count 36
# Epoch 107/5000 | Loss 0.0324 | Win count 36
# Epoch 108/5000 | Loss 0.4025 | Win count 37
# Epoch 109/5000 | Loss 0.0223 | Win count 38
# Epoch 110/5000 | Loss 0.1997 | Win count 38
# Epoch 111/5000 | Loss 0.1651 | Win count 39
# Epoch 112/5000 | Loss 0.0278 | Win count 39
# Epoch 113/5000 | Loss 0.0370 | Win count 40
# Epoch 114/5000 | Loss 0.9262 | Win count 41
# Epoch 115/5000 | Loss 0.1965 | Win count 41
# Epoch 116/5000 | Loss 0.0137 | Win count 42
# Epoch 117/5000 | Loss 0.3538 | Win count 43
# Epoch 118/5000 | Loss 0.0565 | Win count 43
# Epoch 119/5000 | Loss 0.1789 | Win count 43
# Epoch 120/5000 | Loss 0.3169 | Win count 43
# Epoch 121/5000 | Loss 0.0294 | Win count 44
# Epoch 122/5000 | Loss 0.1140 | Win count 44
# Epoch 123/5000 | Loss 0.1387 | Win count 44
# Epoch 124/5000 | Loss 0.7594 | Win count 45
# Epoch 125/5000 | Loss 0.7014 | Win count 45
# Epoch 126/5000 | Loss 0.0388 | Win count 45
# Epoch 127/5000 | Loss 0.2529 | Win count 46
# Epoch 128/5000 | Loss 0.0424 | Win count 47
# Epoch 129/5000 | Loss 0.5098 | Win count 47
# Epoch 130/5000 | Loss 0.3567 | Win count 48
# Epoch 131/5000 | Loss 0.0232 | Win count 48
# Epoch 132/5000 | Loss 0.0174 | Win count 49
# Epoch 133/5000 | Loss 0.0480 | Win count 49
# Epoch 134/5000 | Loss 0.3195 | Win count 50
# Epoch 135/5000 | Loss 0.0418 | Win count 50
# Epoch 136/5000 | Loss 0.0841 | Win count 51
# Epoch 137/5000 | Loss 0.3151 | Win count 52
# Epoch 138/5000 | Loss 0.0348 | Win count 53
# Epoch 139/5000 | Loss 0.0302 | Win count 54
# Epoch 140/5000 | Loss 0.4209 | Win count 54
# Epoch 141/5000 | Loss 0.2912 | Win count 54
# Epoch 142/5000 | Loss 0.2453 | Win count 54
# Epoch 143/5000 | Loss 0.2532 | Win count 54
# Epoch 144/5000 | Loss 0.0323 | Win count 55
# Epoch 145/5000 | Loss 0.0929 | Win count 55
# Epoch 146/5000 | Loss 0.0502 | Win count 56
# Epoch 147/5000 | Loss 0.6336 | Win count 57
# Epoch 148/5000 | Loss 0.2701 | Win count 57
# Epoch 149/5000 | Loss 0.1241 | Win count 58
# Epoch 150/5000 | Loss 0.5267 | Win count 59
# Epoch 151/5000 | Loss 0.0590 | Win count 59
# Epoch 152/5000 | Loss 0.1581 | Win count 59
# Epoch 153/5000 | Loss 0.6705 | Win count 59
# Epoch 154/5000 | Loss 0.0866 | Win count 59
# Epoch 155/5000 | Loss 0.0460 | Win count 59
# Epoch 156/5000 | Loss 0.0344 | Win count 59
# Epoch 157/5000 | Loss 0.0967 | Win count 59
# Epoch 158/5000 | Loss 0.6792 | Win count 59
# Epoch 159/5000 | Loss 0.0333 | Win count 60
# Epoch 160/5000 | Loss 0.2614 | Win count 60
# Epoch 161/5000 | Loss 0.1396 | Win count 60
# Epoch 162/5000 | Loss 0.3975 | Win count 60
# Epoch 163/5000 | Loss 0.3792 | Win count 61
# Epoch 164/5000 | Loss 1.4741 | Win count 62
# Epoch 165/5000 | Loss 0.1980 | Win count 63
# Epoch 166/5000 | Loss 0.4036 | Win count 63
# Epoch 167/5000 | Loss 0.7516 | Win count 64
# Epoch 168/5000 | Loss 0.0699 | Win count 64
# Epoch 169/5000 | Loss 0.6569 | Win count 64
# Epoch 170/5000 | Loss 0.3802 | Win count 64
# Epoch 171/5000 | Loss 0.3267 | Win count 64
# Epoch 172/5000 | Loss 0.5880 | Win count 64
# Epoch 173/5000 | Loss 0.0514 | Win count 64
# Epoch 174/5000 | Loss 0.0647 | Win count 64
# Epoch 175/5000 | Loss 0.0138 | Win count 65
# Epoch 176/5000 | Loss 0.4280 | Win count 65
# Epoch 177/5000 | Loss 0.1144 | Win count 65
# Epoch 178/5000 | Loss 0.0511 | Win count 66
# Epoch 179/5000 | Loss 0.1355 | Win count 67
# Epoch 180/5000 | Loss 0.5357 | Win count 67
# Epoch 181/5000 | Loss 0.0401 | Win count 68
# Epoch 182/5000 | Loss 0.4996 | Win count 68
# Epoch 183/5000 | Loss 0.1008 | Win count 68
# Epoch 184/5000 | Loss 0.3188 | Win count 68
# Epoch 185/5000 | Loss 0.2241 | Win count 69
# Epoch 186/5000 | Loss 0.3252 | Win count 70
# Epoch 187/5000 | Loss 0.4769 | Win count 71
# Epoch 188/5000 | Loss 0.0183 | Win count 72
# Epoch 189/5000 | Loss 1.3267 | Win count 72
# Epoch 190/5000 | Loss 0.5135 | Win count 72
# Epoch 191/5000 | Loss 0.0795 | Win count 72
# Epoch 192/5000 | Loss 0.3296 | Win count 72
# Epoch 193/5000 | Loss 0.1285 | Win count 73
# Epoch 194/5000 | Loss 0.6250 | Win count 73
# Epoch 195/5000 | Loss 1.0432 | Win count 73
# Epoch 196/5000 | Loss 0.0991 | Win count 73
# Epoch 197/5000 | Loss 0.5043 | Win count 73
# Epoch 198/5000 | Loss 0.2319 | Win count 74
# Epoch 199/5000 | Loss 0.4223 | Win count 74
# Epoch 200/5000 | Loss 0.1481 | Win count 75
# Epoch 201/5000 | Loss 0.1205 | Win count 75
# Epoch 202/5000 | Loss 0.7203 | Win count 75
# Epoch 203/5000 | Loss 0.3147 | Win count 76
# Epoch 204/5000 | Loss 0.7811 | Win count 77
# Epoch 205/5000 | Loss 0.1055 | Win count 77
# Epoch 206/5000 | Loss 0.2589 | Win count 77
# Epoch 207/5000 | Loss 0.3534 | Win count 78
# Epoch 208/5000 | Loss 0.1454 | Win count 78
# Epoch 209/5000 | Loss 0.0196 | Win count 78
# Epoch 210/5000 | Loss 0.3392 | Win count 78
# Epoch 211/5000 | Loss 0.6067 | Win count 79
# Epoch 212/5000 | Loss 0.0929 | Win count 80
# Epoch 213/5000 | Loss 0.1062 | Win count 80
# Epoch 214/5000 | Loss 0.1069 | Win count 80
# Epoch 215/5000 | Loss 0.9773 | Win count 80
# Epoch 216/5000 | Loss 0.1269 | Win count 80
# Epoch 217/5000 | Loss 0.9783 | Win count 80
# Epoch 218/5000 | Loss 0.1739 | Win count 80
# Epoch 219/5000 | Loss 1.0555 | Win count 80
# Epoch 220/5000 | Loss 0.8740 | Win count 81
# Epoch 221/5000 | Loss 0.4272 | Win count 81
# Epoch 222/5000 | Loss 0.0531 | Win count 82
# Epoch 223/5000 | Loss 0.0280 | Win count 83
# Epoch 224/5000 | Loss 0.4119 | Win count 83
# Epoch 225/5000 | Loss 0.1445 | Win count 84
# Epoch 226/5000 | Loss 0.7330 | Win count 84
# Epoch 227/5000 | Loss 0.0782 | Win count 84
# Epoch 228/5000 | Loss 0.3730 | Win count 85
# Epoch 229/5000 | Loss 0.5437 | Win count 85
# Epoch 230/5000 | Loss 0.2532 | Win count 86
# Epoch 231/5000 | Loss 0.4094 | Win count 87
# Epoch 232/5000 | Loss 0.1308 | Win count 87
# Epoch 233/5000 | Loss 1.0124 | Win count 87
# Epoch 234/5000 | Loss 0.5090 | Win count 87
# Epoch 235/5000 | Loss 0.4047 | Win count 88
# Epoch 236/5000 | Loss 0.4769 | Win count 88
# Epoch 237/5000 | Loss 0.2050 | Win count 89
# Epoch 238/5000 | Loss 0.1193 | Win count 90
# Epoch 239/5000 | Loss 0.2897 | Win count 90
# Epoch 240/5000 | Loss 0.1540 | Win count 90
# Epoch 241/5000 | Loss 0.6630 | Win count 91
# Epoch 242/5000 | Loss 0.0683 | Win count 92
# Epoch 243/5000 | Loss 0.2151 | Win count 93
# Epoch 244/5000 | Loss 0.6256 | Win count 94
# Epoch 245/5000 | Loss 0.6867 | Win count 94
# Epoch 246/5000 | Loss 0.8223 | Win count 95
# Epoch 247/5000 | Loss 0.2442 | Win count 95
# Epoch 248/5000 | Loss 0.0202 | Win count 95
# Epoch 249/5000 | Loss 0.2747 | Win count 95
# Epoch 250/5000 | Loss 0.0284 | Win count 95
# Epoch 251/5000 | Loss 0.1624 | Win count 95
# Epoch 252/5000 | Loss 0.0131 | Win count 96
# Epoch 253/5000 | Loss 0.2307 | Win count 97
# Epoch 254/5000 | Loss 0.2312 | Win count 98
# Epoch 255/5000 | Loss 0.5821 | Win count 98
# Epoch 256/5000 | Loss 0.5319 | Win count 98
# Epoch 257/5000 | Loss 0.1706 | Win count 99
# Epoch 258/5000 | Loss 0.1411 | Win count 100
# Epoch 259/5000 | Loss 0.0474 | Win count 100
# Epoch 260/5000 | Loss 1.0939 | Win count 100
# Epoch 261/5000 | Loss 0.1562 | Win count 100
# Epoch 262/5000 | Loss 0.5763 | Win count 101
# Epoch 263/5000 | Loss 0.4122 | Win count 102
# Epoch 264/5000 | Loss 0.4244 | Win count 103
# Epoch 265/5000 | Loss 0.2706 | Win count 103
# Epoch 266/5000 | Loss 0.8517 | Win count 103
# Epoch 267/5000 | Loss 0.7135 | Win count 103
# Epoch 268/5000 | Loss 0.2711 | Win count 103
# Epoch 269/5000 | Loss 0.1149 | Win count 103
# Epoch 270/5000 | Loss 0.1593 | Win count 104
# Epoch 271/5000 | Loss 0.1632 | Win count 104
# Epoch 272/5000 | Loss 0.0546 | Win count 105
# Epoch 273/5000 | Loss 0.0641 | Win count 105
# Epoch 274/5000 | Loss 0.0413 | Win count 106
# Epoch 275/5000 | Loss 0.1468 | Win count 106
# Epoch 276/5000 | Loss 0.0432 | Win count 106
# Epoch 277/5000 | Loss 0.0512 | Win count 106
# Epoch 278/5000 | Loss 0.4233 | Win count 106
# Epoch 279/5000 | Loss 0.7599 | Win count 107
# Epoch 280/5000 | Loss 0.4924 | Win count 107
# Epoch 281/5000 | Loss 0.2747 | Win count 108
# Epoch 282/5000 | Loss 0.3675 | Win count 108
# Epoch 283/5000 | Loss 1.5227 | Win count 109
# Epoch 284/5000 | Loss 0.2540 | Win count 109
# Epoch 285/5000 | Loss 0.2307 | Win count 109
# Epoch 286/5000 | Loss 0.0530 | Win count 109
# Epoch 287/5000 | Loss 0.0854 | Win count 109
# Epoch 288/5000 | Loss 0.0337 | Win count 109
# Epoch 289/5000 | Loss 0.7539 | Win count 109
# Epoch 290/5000 | Loss 0.0208 | Win count 109
# Epoch 291/5000 | Loss 0.0149 | Win count 110
# Epoch 292/5000 | Loss 0.2862 | Win count 110
# Epoch 293/5000 | Loss 0.0132 | Win count 111
# Epoch 294/5000 | Loss 0.0645 | Win count 112
# Epoch 295/5000 | Loss 0.0162 | Win count 112
# Epoch 296/5000 | Loss 0.0913 | Win count 112
# Epoch 297/5000 | Loss 0.0442 | Win count 113
# Epoch 298/5000 | Loss 0.2624 | Win count 114
# Epoch 299/5000 | Loss 0.0453 | Win count 114
# Epoch 300/5000 | Loss 1.5254 | Win count 114
# Epoch 301/5000 | Loss 0.5032 | Win count 114
# Epoch 302/5000 | Loss 0.1484 | Win count 115
# Epoch 303/5000 | Loss 0.1726 | Win count 116
# Epoch 304/5000 | Loss 0.7926 | Win count 116
# Epoch 305/5000 | Loss 0.5171 | Win count 116
# Epoch 306/5000 | Loss 0.3103 | Win count 116
# Epoch 307/5000 | Loss 0.1901 | Win count 117
# Epoch 308/5000 | Loss 0.6824 | Win count 117
# Epoch 309/5000 | Loss 0.5989 | Win count 118
# Epoch 310/5000 | Loss 0.0813 | Win count 118
# Epoch 311/5000 | Loss 0.5485 | Win count 119
# Epoch 312/5000 | Loss 0.0539 | Win count 120
# Epoch 313/5000 | Loss 0.1618 | Win count 120
# Epoch 314/5000 | Loss 0.6020 | Win count 120
# Epoch 315/5000 | Loss 0.1993 | Win count 120
# Epoch 316/5000 | Loss 0.8078 | Win count 121
# Epoch 317/5000 | Loss 0.0458 | Win count 122
# Epoch 318/5000 | Loss 0.4700 | Win count 122
# Epoch 319/5000 | Loss 0.5237 | Win count 122
# Epoch 320/5000 | Loss 0.6442 | Win count 122
# Epoch 321/5000 | Loss 0.0357 | Win count 122
# Epoch 322/5000 | Loss 0.6164 | Win count 123
# Epoch 323/5000 | Loss 0.0976 | Win count 124
# Epoch 324/5000 | Loss 0.3725 | Win count 125
# Epoch 325/5000 | Loss 0.4169 | Win count 125
# Epoch 326/5000 | Loss 0.0294 | Win count 126
# Epoch 327/5000 | Loss 0.1816 | Win count 127
# Epoch 328/5000 | Loss 0.6057 | Win count 128
# Epoch 329/5000 | Loss 0.0488 | Win count 128
# Epoch 330/5000 | Loss 0.3786 | Win count 129
# Epoch 331/5000 | Loss 0.1207 | Win count 130
# Epoch 332/5000 | Loss 0.1976 | Win count 131
# Epoch 333/5000 | Loss 0.7276 | Win count 132
# Epoch 334/5000 | Loss 0.0819 | Win count 132
# Epoch 335/5000 | Loss 0.7730 | Win count 132
# Epoch 336/5000 | Loss 0.0842 | Win count 133
# Epoch 337/5000 | Loss 0.3364 | Win count 133
# Epoch 338/5000 | Loss 0.0972 | Win count 133
# Epoch 339/5000 | Loss 0.3976 | Win count 133
# Epoch 340/5000 | Loss 0.5393 | Win count 134
# Epoch 341/5000 | Loss 0.0465 | Win count 134
# Epoch 342/5000 | Loss 0.2553 | Win count 135
# Epoch 343/5000 | Loss 0.0431 | Win count 135
# Epoch 344/5000 | Loss 0.8841 | Win count 135
# Epoch 345/5000 | Loss 0.4096 | Win count 136
# Epoch 346/5000 | Loss 0.8792 | Win count 137
# Epoch 347/5000 | Loss 0.0487 | Win count 138
# Epoch 348/5000 | Loss 0.3409 | Win count 139
# Epoch 349/5000 | Loss 0.1172 | Win count 140
# Epoch 350/5000 | Loss 0.0364 | Win count 140
# Epoch 351/5000 | Loss 0.2081 | Win count 141
# Epoch 352/5000 | Loss 0.0459 | Win count 142
# Epoch 353/5000 | Loss 0.5088 | Win count 142
# Epoch 354/5000 | Loss 0.3729 | Win count 143
# Epoch 355/5000 | Loss 0.0519 | Win count 144
# Epoch 356/5000 | Loss 0.1107 | Win count 144
# Epoch 357/5000 | Loss 0.2569 | Win count 144
# Epoch 358/5000 | Loss 0.0483 | Win count 145
# Epoch 359/5000 | Loss 0.4241 | Win count 146
# Epoch 360/5000 | Loss 1.1334 | Win count 147
# Epoch 361/5000 | Loss 0.1857 | Win count 147
# Epoch 362/5000 | Loss 0.0685 | Win count 147
# Epoch 363/5000 | Loss 0.2341 | Win count 148
# Epoch 364/5000 | Loss 0.0129 | Win count 149
# Epoch 365/5000 | Loss 0.0498 | Win count 149
# Epoch 366/5000 | Loss 0.1667 | Win count 149
# Epoch 367/5000 | Loss 0.1196 | Win count 149
# Epoch 368/5000 | Loss 0.1035 | Win count 149
# Epoch 369/5000 | Loss 0.4914 | Win count 150
# Epoch 370/5000 | Loss 0.0575 | Win count 150
# Epoch 371/5000 | Loss 0.2008 | Win count 150
# Epoch 372/5000 | Loss 0.0152 | Win count 151
# Epoch 373/5000 | Loss 0.0702 | Win count 152
# Epoch 374/5000 | Loss 0.2483 | Win count 153
# Epoch 375/5000 | Loss 0.1341 | Win count 154
# Epoch 376/5000 | Loss 0.5525 | Win count 154
# Epoch 377/5000 | Loss 0.1135 | Win count 155
# Epoch 378/5000 | Loss 0.0809 | Win count 156
# Epoch 379/5000 | Loss 0.0634 | Win count 156
# Epoch 380/5000 | Loss 0.1668 | Win count 157
# Epoch 381/5000 | Loss 0.0270 | Win count 157
# Epoch 382/5000 | Loss 0.1902 | Win count 158
# Epoch 383/5000 | Loss 0.0443 | Win count 158
# Epoch 384/5000 | Loss 0.6381 | Win count 158
# Epoch 385/5000 | Loss 0.1073 | Win count 159
# Epoch 386/5000 | Loss 0.0303 | Win count 159
# Epoch 387/5000 | Loss 0.4558 | Win count 160
# Epoch 388/5000 | Loss 0.0205 | Win count 161
# Epoch 389/5000 | Loss 0.1117 | Win count 162
# Epoch 390/5000 | Loss 0.7721 | Win count 163
# Epoch 391/5000 | Loss 0.0437 | Win count 164
# Epoch 392/5000 | Loss 0.0248 | Win count 165
# Epoch 393/5000 | Loss 0.4655 | Win count 165
# Epoch 394/5000 | Loss 0.0839 | Win count 165
# Epoch 395/5000 | Loss 0.0769 | Win count 166
# Epoch 396/5000 | Loss 0.0402 | Win count 166
# Epoch 397/5000 | Loss 0.1699 | Win count 166
# Epoch 398/5000 | Loss 0.6392 | Win count 167
# Epoch 399/5000 | Loss 0.0741 | Win count 167
# Epoch 400/5000 | Loss 0.0067 | Win count 167
# Epoch 401/5000 | Loss 0.0248 | Win count 168
# Epoch 402/5000 | Loss 0.9552 | Win count 168
# Epoch 403/5000 | Loss 0.0284 | Win count 168
# Epoch 404/5000 | Loss 0.0348 | Win count 169
# Epoch 405/5000 | Loss 0.1143 | Win count 170
# Epoch 406/5000 | Loss 0.0073 | Win count 171
# Epoch 407/5000 | Loss 0.6615 | Win count 172
# Epoch 408/5000 | Loss 0.0671 | Win count 172
# Epoch 409/5000 | Loss 0.1050 | Win count 172
# Epoch 410/5000 | Loss 0.0752 | Win count 172
# Epoch 411/5000 | Loss 0.0329 | Win count 173
# Epoch 412/5000 | Loss 0.0509 | Win count 173
# Epoch 413/5000 | Loss 0.4048 | Win count 174
# Epoch 414/5000 | Loss 0.1163 | Win count 174
# Epoch 415/5000 | Loss 0.2037 | Win count 174
# Epoch 416/5000 | Loss 0.4658 | Win count 175
# Epoch 417/5000 | Loss 0.2791 | Win count 175
# Epoch 418/5000 | Loss 0.9807 | Win count 175
# Epoch 419/5000 | Loss 0.2006 | Win count 175
# Epoch 420/5000 | Loss 0.1181 | Win count 175
# Epoch 421/5000 | Loss 0.0663 | Win count 175
# Epoch 422/5000 | Loss 0.0888 | Win count 175
# Epoch 423/5000 | Loss 0.9289 | Win count 175
# Epoch 424/5000 | Loss 0.3549 | Win count 175
# Epoch 425/5000 | Loss 1.0223 | Win count 175
# Epoch 426/5000 | Loss 0.1706 | Win count 175
# Epoch 427/5000 | Loss 0.7381 | Win count 175
# Epoch 428/5000 | Loss 0.0633 | Win count 175
# Epoch 429/5000 | Loss 0.0300 | Win count 176
# Epoch 430/5000 | Loss 0.3265 | Win count 176
# Epoch 431/5000 | Loss 0.7952 | Win count 176
# Epoch 432/5000 | Loss 0.2796 | Win count 177
# Epoch 433/5000 | Loss 0.0715 | Win count 178
# Epoch 434/5000 | Loss 0.5471 | Win count 179
# Epoch 435/5000 | Loss 0.0506 | Win count 179
# Epoch 436/5000 | Loss 0.0816 | Win count 179
# Epoch 437/5000 | Loss 0.1191 | Win count 180
# Epoch 438/5000 | Loss 0.0783 | Win count 181
# Epoch 439/5000 | Loss 0.3084 | Win count 181
# Epoch 440/5000 | Loss 0.9476 | Win count 181
# Epoch 441/5000 | Loss 0.7431 | Win count 182
# Epoch 442/5000 | Loss 0.1872 | Win count 183
# Epoch 443/5000 | Loss 0.1863 | Win count 183
# Epoch 444/5000 | Loss 0.0999 | Win count 184
# Epoch 445/5000 | Loss 0.4683 | Win count 184
# Epoch 446/5000 | Loss 0.1086 | Win count 184
# Epoch 447/5000 | Loss 0.3329 | Win count 184
# Epoch 448/5000 | Loss 0.4610 | Win count 185
# Epoch 449/5000 | Loss 0.1347 | Win count 186
# Epoch 450/5000 | Loss 0.6575 | Win count 187
# Epoch 451/5000 | Loss 0.7670 | Win count 187
# Epoch 452/5000 | Loss 0.0886 | Win count 187
# Epoch 453/5000 | Loss 0.1318 | Win count 187
# Epoch 454/5000 | Loss 0.0990 | Win count 187
# Epoch 455/5000 | Loss 0.6164 | Win count 187
# Epoch 456/5000 | Loss 0.0688 | Win count 188
# Epoch 457/5000 | Loss 0.0621 | Win count 188
# Epoch 458/5000 | Loss 0.0751 | Win count 188
# Epoch 459/5000 | Loss 0.1299 | Win count 189
# Epoch 460/5000 | Loss 0.6311 | Win count 189
# Epoch 461/5000 | Loss 0.1872 | Win count 190
# Epoch 462/5000 | Loss 0.0736 | Win count 190
# Epoch 463/5000 | Loss 0.4074 | Win count 191
# Epoch 464/5000 | Loss 0.0488 | Win count 191
# Epoch 465/5000 | Loss 0.0514 | Win count 191
# Epoch 466/5000 | Loss 0.1892 | Win count 192
# Epoch 467/5000 | Loss 0.2233 | Win count 193
# Epoch 468/5000 | Loss 0.0603 | Win count 194
# Epoch 469/5000 | Loss 0.3771 | Win count 194
# Epoch 470/5000 | Loss 1.1075 | Win count 194
# Epoch 471/5000 | Loss 0.1854 | Win count 195
# Epoch 472/5000 | Loss 0.1886 | Win count 196
# Epoch 473/5000 | Loss 0.3827 | Win count 196
# Epoch 474/5000 | Loss 0.1959 | Win count 196
# Epoch 475/5000 | Loss 0.1876 | Win count 197
# Epoch 476/5000 | Loss 0.3795 | Win count 198
# Epoch 477/5000 | Loss 0.3384 | Win count 199
# Epoch 478/5000 | Loss 0.3624 | Win count 200
# Epoch 479/5000 | Loss 0.1311 | Win count 201
# Epoch 480/5000 | Loss 1.1139 | Win count 201
# Epoch 481/5000 | Loss 0.0458 | Win count 201
# Epoch 482/5000 | Loss 0.0267 | Win count 202
# Epoch 483/5000 | Loss 0.1197 | Win count 202
# Epoch 484/5000 | Loss 0.2762 | Win count 202
# Epoch 485/5000 | Loss 0.0735 | Win count 203
# Epoch 486/5000 | Loss 0.5729 | Win count 203
# Epoch 487/5000 | Loss 0.1036 | Win count 204
# Epoch 488/5000 | Loss 0.2637 | Win count 204
# Epoch 489/5000 | Loss 0.0336 | Win count 205
# Epoch 490/5000 | Loss 0.0977 | Win count 205
# Epoch 491/5000 | Loss 0.3860 | Win count 205
# Epoch 492/5000 | Loss 0.0945 | Win count 205
# Epoch 493/5000 | Loss 0.0651 | Win count 205
# Epoch 494/5000 | Loss 0.1284 | Win count 206
# Epoch 495/5000 | Loss 0.6233 | Win count 207
# Epoch 496/5000 | Loss 0.0804 | Win count 208
# Epoch 497/5000 | Loss 0.2168 | Win count 209
# Epoch 498/5000 | Loss 0.2187 | Win count 210
# Epoch 499/5000 | Loss 0.4507 | Win count 210
# Epoch 500/5000 | Loss 0.2985 | Win count 211
# Epoch 501/5000 | Loss 0.0671 | Win count 212
# Epoch 502/5000 | Loss 0.0484 | Win count 213
# Epoch 503/5000 | Loss 0.0994 | Win count 214
# Epoch 504/5000 | Loss 0.2659 | Win count 215
# Epoch 505/5000 | Loss 0.3313 | Win count 215
# Epoch 506/5000 | Loss 0.0929 | Win count 215
# Epoch 507/5000 | Loss 0.0106 | Win count 215
# Epoch 508/5000 | Loss 0.0369 | Win count 215
# Epoch 509/5000 | Loss 0.0955 | Win count 215
# Epoch 510/5000 | Loss 0.0474 | Win count 215
# Epoch 511/5000 | Loss 0.2346 | Win count 215
# Epoch 512/5000 | Loss 0.0619 | Win count 215
# Epoch 513/5000 | Loss 0.0893 | Win count 216
# Epoch 514/5000 | Loss 0.3482 | Win count 217
# Epoch 515/5000 | Loss 0.3540 | Win count 217
# Epoch 516/5000 | Loss 0.2924 | Win count 217
# Epoch 517/5000 | Loss 0.0676 | Win count 217
# Epoch 518/5000 | Loss 0.2103 | Win count 217
# Epoch 519/5000 | Loss 0.0541 | Win count 217
# Epoch 520/5000 | Loss 0.3496 | Win count 218
# Epoch 521/5000 | Loss 0.0673 | Win count 218
# Epoch 522/5000 | Loss 0.1001 | Win count 218
# Epoch 523/5000 | Loss 0.0355 | Win count 218
# Epoch 524/5000 | Loss 0.2744 | Win count 218
# Epoch 525/5000 | Loss 0.2360 | Win count 219
# Epoch 526/5000 | Loss 0.3428 | Win count 220
# Epoch 527/5000 | Loss 0.1952 | Win count 220
# Epoch 528/5000 | Loss 0.1780 | Win count 220
# Epoch 529/5000 | Loss 0.1298 | Win count 220
# Epoch 530/5000 | Loss 0.5746 | Win count 220
# Epoch 531/5000 | Loss 0.1915 | Win count 221
# Epoch 532/5000 | Loss 0.0480 | Win count 222
# Epoch 533/5000 | Loss 0.0678 | Win count 223
# Epoch 534/5000 | Loss 0.0568 | Win count 223
# Epoch 535/5000 | Loss 0.1714 | Win count 224
# Epoch 536/5000 | Loss 0.0499 | Win count 225
# Epoch 537/5000 | Loss 0.0381 | Win count 226
# Epoch 538/5000 | Loss 0.0616 | Win count 227
# Epoch 539/5000 | Loss 0.2554 | Win count 228
# Epoch 540/5000 | Loss 0.6701 | Win count 228
# Epoch 541/5000 | Loss 0.0499 | Win count 228
# Epoch 542/5000 | Loss 0.7484 | Win count 228
# Epoch 543/5000 | Loss 0.1764 | Win count 228
# Epoch 544/5000 | Loss 0.0281 | Win count 228
# Epoch 545/5000 | Loss 0.0290 | Win count 229
# Epoch 546/5000 | Loss 0.0804 | Win count 230
# Epoch 547/5000 | Loss 0.0537 | Win count 230
# Epoch 548/5000 | Loss 0.2317 | Win count 230
# Epoch 549/5000 | Loss 0.3755 | Win count 230
# Epoch 550/5000 | Loss 0.1703 | Win count 230
# Epoch 551/5000 | Loss 0.3853 | Win count 230
# Epoch 552/5000 | Loss 0.1446 | Win count 230
# Epoch 553/5000 | Loss 0.0709 | Win count 231
# Epoch 554/5000 | Loss 0.2277 | Win count 232
# Epoch 555/5000 | Loss 0.1294 | Win count 232
# Epoch 556/5000 | Loss 0.6185 | Win count 232
# Epoch 557/5000 | Loss 0.0217 | Win count 233
# Epoch 558/5000 | Loss 0.3206 | Win count 234
# Epoch 559/5000 | Loss 0.2216 | Win count 234
# Epoch 560/5000 | Loss 0.2425 | Win count 234
# Epoch 561/5000 | Loss 0.2035 | Win count 235
# Epoch 562/5000 | Loss 1.3272 | Win count 236
# Epoch 563/5000 | Loss 0.2933 | Win count 236
# Epoch 564/5000 | Loss 0.3794 | Win count 237
# Epoch 565/5000 | Loss 0.0746 | Win count 238
# Epoch 566/5000 | Loss 0.0908 | Win count 238
# Epoch 567/5000 | Loss 0.0793 | Win count 239
# Epoch 568/5000 | Loss 0.1424 | Win count 239
# Epoch 569/5000 | Loss 0.0488 | Win count 240
# Epoch 570/5000 | Loss 0.9531 | Win count 241
# Epoch 571/5000 | Loss 0.4426 | Win count 242
# Epoch 572/5000 | Loss 0.2732 | Win count 242
# Epoch 573/5000 | Loss 0.2413 | Win count 243
# Epoch 574/5000 | Loss 0.0732 | Win count 244
# Epoch 575/5000 | Loss 0.0725 | Win count 244
# Epoch 576/5000 | Loss 0.0821 | Win count 245
# Epoch 577/5000 | Loss 0.4320 | Win count 245
# Epoch 578/5000 | Loss 0.1240 | Win count 246
# Epoch 579/5000 | Loss 0.2737 | Win count 247
# Epoch 580/5000 | Loss 0.0475 | Win count 247
# Epoch 581/5000 | Loss 0.1841 | Win count 247
# Epoch 582/5000 | Loss 0.2658 | Win count 248
# Epoch 583/5000 | Loss 0.0932 | Win count 249
# Epoch 584/5000 | Loss 0.4107 | Win count 249
# Epoch 585/5000 | Loss 0.6716 | Win count 250
# Epoch 586/5000 | Loss 0.0556 | Win count 251
# Epoch 587/5000 | Loss 0.1120 | Win count 251
# Epoch 588/5000 | Loss 0.0375 | Win count 252
# Epoch 589/5000 | Loss 0.1562 | Win count 253
# Epoch 590/5000 | Loss 0.2195 | Win count 253
# Epoch 591/5000 | Loss 1.2132 | Win count 253
# Epoch 592/5000 | Loss 0.0226 | Win count 254
# Epoch 593/5000 | Loss 0.1203 | Win count 255
# Epoch 594/5000 | Loss 0.0982 | Win count 255
# Epoch 595/5000 | Loss 0.3043 | Win count 256
# Epoch 596/5000 | Loss 0.1807 | Win count 257
# Epoch 597/5000 | Loss 0.0842 | Win count 257
# Epoch 598/5000 | Loss 0.0648 | Win count 257
# Epoch 599/5000 | Loss 0.2402 | Win count 257
# Epoch 600/5000 | Loss 0.2643 | Win count 258
# Epoch 601/5000 | Loss 0.1277 | Win count 258
# Epoch 602/5000 | Loss 0.2125 | Win count 259
# Epoch 603/5000 | Loss 0.1583 | Win count 260
# Epoch 604/5000 | Loss 0.0858 | Win count 260
# Epoch 605/5000 | Loss 0.5044 | Win count 260
# Epoch 606/5000 | Loss 0.4438 | Win count 260
# Epoch 607/5000 | Loss 0.0888 | Win count 260
# Epoch 608/5000 | Loss 0.7085 | Win count 260
# Epoch 609/5000 | Loss 0.0409 | Win count 260
# Epoch 610/5000 | Loss 0.0658 | Win count 261
# Epoch 611/5000 | Loss 0.0833 | Win count 262
# Epoch 612/5000 | Loss 0.2621 | Win count 262
# Epoch 613/5000 | Loss 0.1768 | Win count 262
# Epoch 614/5000 | Loss 0.1428 | Win count 262
# Epoch 615/5000 | Loss 0.1950 | Win count 262
# Epoch 616/5000 | Loss 0.1664 | Win count 263
# Epoch 617/5000 | Loss 0.1048 | Win count 264
# Epoch 618/5000 | Loss 0.2839 | Win count 264
# Epoch 619/5000 | Loss 0.2108 | Win count 264
# Epoch 620/5000 | Loss 0.1265 | Win count 264
# Epoch 621/5000 | Loss 0.2019 | Win count 265
# Epoch 622/5000 | Loss 0.0644 | Win count 266
# Epoch 623/5000 | Loss 0.1185 | Win count 267
# Epoch 624/5000 | Loss 0.1679 | Win count 268
# Epoch 625/5000 | Loss 0.2861 | Win count 269
# Epoch 626/5000 | Loss 0.1316 | Win count 270
# Epoch 627/5000 | Loss 0.5390 | Win count 270
# Epoch 628/5000 | Loss 0.0664 | Win count 270
# Epoch 629/5000 | Loss 0.8903 | Win count 270
# Epoch 630/5000 | Loss 0.0866 | Win count 270
# Epoch 631/5000 | Loss 0.0800 | Win count 270
# Epoch 632/5000 | Loss 0.2091 | Win count 270
# Epoch 633/5000 | Loss 0.0556 | Win count 270
# Epoch 634/5000 | Loss 0.1087 | Win count 271
# Epoch 635/5000 | Loss 0.2398 | Win count 271
# Epoch 636/5000 | Loss 0.1001 | Win count 272
# Epoch 637/5000 | Loss 0.0538 | Win count 273
# Epoch 638/5000 | Loss 0.0127 | Win count 274
# Epoch 639/5000 | Loss 0.1098 | Win count 275
# Epoch 640/5000 | Loss 0.0382 | Win count 275
# Epoch 641/5000 | Loss 0.1179 | Win count 276
# Epoch 642/5000 | Loss 0.1907 | Win count 277
# Epoch 643/5000 | Loss 0.7319 | Win count 277
# Epoch 644/5000 | Loss 0.1012 | Win count 278
# Epoch 645/5000 | Loss 0.0184 | Win count 278
# Epoch 646/5000 | Loss 0.1467 | Win count 279
# Epoch 647/5000 | Loss 0.0692 | Win count 279
# Epoch 648/5000 | Loss 0.1024 | Win count 280
# Epoch 649/5000 | Loss 0.2276 | Win count 280
# Epoch 650/5000 | Loss 0.1112 | Win count 281
# Epoch 651/5000 | Loss 0.1267 | Win count 282
# Epoch 652/5000 | Loss 0.1456 | Win count 282
# Epoch 653/5000 | Loss 0.2032 | Win count 283
# Epoch 654/5000 | Loss 0.1623 | Win count 283
# Epoch 655/5000 | Loss 0.2908 | Win count 284
# Epoch 656/5000 | Loss 0.3564 | Win count 285
# Epoch 657/5000 | Loss 0.1715 | Win count 286
# Epoch 658/5000 | Loss 0.1232 | Win count 287
# Epoch 659/5000 | Loss 0.1223 | Win count 288
# Epoch 660/5000 | Loss 0.0429 | Win count 288
# Epoch 661/5000 | Loss 0.4076 | Win count 288
# Epoch 662/5000 | Loss 0.4578 | Win count 288
# Epoch 663/5000 | Loss 0.1768 | Win count 288
# Epoch 664/5000 | Loss 0.0918 | Win count 289
# Epoch 665/5000 | Loss 0.1407 | Win count 289
# Epoch 666/5000 | Loss 0.5019 | Win count 289
# Epoch 667/5000 | Loss 0.0845 | Win count 289
# Epoch 668/5000 | Loss 0.0538 | Win count 290
# Epoch 669/5000 | Loss 0.0697 | Win count 290
# Epoch 670/5000 | Loss 0.4578 | Win count 290
# Epoch 671/5000 | Loss 0.0319 | Win count 290
# Epoch 672/5000 | Loss 0.3936 | Win count 291
# Epoch 673/5000 | Loss 0.0071 | Win count 292
# Epoch 674/5000 | Loss 0.2999 | Win count 292
# Epoch 675/5000 | Loss 0.1342 | Win count 293
# Epoch 676/5000 | Loss 0.1566 | Win count 294
# Epoch 677/5000 | Loss 0.1672 | Win count 295
# Epoch 678/5000 | Loss 0.1710 | Win count 295
# Epoch 679/5000 | Loss 0.1195 | Win count 296
# Epoch 680/5000 | Loss 0.0505 | Win count 297
# Epoch 681/5000 | Loss 0.0840 | Win count 298
# Epoch 682/5000 | Loss 0.1931 | Win count 299
# Epoch 683/5000 | Loss 0.5878 | Win count 300
# Epoch 684/5000 | Loss 0.2316 | Win count 300
# Epoch 685/5000 | Loss 0.0599 | Win count 300
# Epoch 686/5000 | Loss 0.2245 | Win count 300
# Epoch 687/5000 | Loss 0.1159 | Win count 300
# Epoch 688/5000 | Loss 0.1105 | Win count 301
# Epoch 689/5000 | Loss 0.0175 | Win count 301
# Epoch 690/5000 | Loss 0.1795 | Win count 301
# Epoch 691/5000 | Loss 0.0922 | Win count 301
# Epoch 692/5000 | Loss 0.7607 | Win count 302
# Epoch 693/5000 | Loss 0.0654 | Win count 302
# Epoch 694/5000 | Loss 0.1025 | Win count 302
# Epoch 695/5000 | Loss 0.4990 | Win count 302
# Epoch 696/5000 | Loss 0.2280 | Win count 303
# Epoch 697/5000 | Loss 0.0900 | Win count 304
# Epoch 698/5000 | Loss 0.0608 | Win count 304
# Epoch 699/5000 | Loss 0.0474 | Win count 305
# Epoch 700/5000 | Loss 0.9507 | Win count 306
# Epoch 701/5000 | Loss 0.1700 | Win count 306
# Epoch 702/5000 | Loss 0.1422 | Win count 306
# Epoch 703/5000 | Loss 0.1412 | Win count 307
# Epoch 704/5000 | Loss 0.1329 | Win count 308
# Epoch 705/5000 | Loss 0.2416 | Win count 309
# Epoch 706/5000 | Loss 0.0897 | Win count 309
# Epoch 707/5000 | Loss 0.1906 | Win count 309
# Epoch 708/5000 | Loss 0.0916 | Win count 310
# Epoch 709/5000 | Loss 0.0150 | Win count 310
# Epoch 710/5000 | Loss 0.2657 | Win count 310
# Epoch 711/5000 | Loss 0.1286 | Win count 311
# Epoch 712/5000 | Loss 0.2230 | Win count 311
# Epoch 713/5000 | Loss 0.1574 | Win count 312
# Epoch 714/5000 | Loss 0.1492 | Win count 312
# Epoch 715/5000 | Loss 0.0471 | Win count 312
# Epoch 716/5000 | Loss 0.2377 | Win count 313
# Epoch 717/5000 | Loss 0.3074 | Win count 314
# Epoch 718/5000 | Loss 0.2528 | Win count 314
# Epoch 719/5000 | Loss 0.3471 | Win count 314
# Epoch 720/5000 | Loss 0.6823 | Win count 314
# Epoch 721/5000 | Loss 0.2309 | Win count 315
# Epoch 722/5000 | Loss 0.4911 | Win count 316
# Epoch 723/5000 | Loss 0.1907 | Win count 317
# Epoch 724/5000 | Loss 0.5349 | Win count 317
# Epoch 725/5000 | Loss 0.0560 | Win count 317
# Epoch 726/5000 | Loss 0.0609 | Win count 318
# Epoch 727/5000 | Loss 0.1379 | Win count 319
# Epoch 728/5000 | Loss 0.2037 | Win count 320
# Epoch 729/5000 | Loss 0.1085 | Win count 320
# Epoch 730/5000 | Loss 0.1776 | Win count 321
# Epoch 731/5000 | Loss 0.3922 | Win count 322
# Epoch 732/5000 | Loss 0.1426 | Win count 322
# Epoch 733/5000 | Loss 0.2731 | Win count 323
# Epoch 734/5000 | Loss 0.1606 | Win count 324
# Epoch 735/5000 | Loss 0.1651 | Win count 324
# Epoch 736/5000 | Loss 0.7094 | Win count 324
# Epoch 737/5000 | Loss 0.1692 | Win count 325
# Epoch 738/5000 | Loss 0.1744 | Win count 326
# Epoch 739/5000 | Loss 0.0127 | Win count 327
# Epoch 740/5000 | Loss 0.0662 | Win count 328
# Epoch 741/5000 | Loss 0.2556 | Win count 328
# Epoch 742/5000 | Loss 0.1595 | Win count 328
# Epoch 743/5000 | Loss 0.1228 | Win count 328
# Epoch 744/5000 | Loss 0.2573 | Win count 328
# Epoch 745/5000 | Loss 0.0886 | Win count 329
# Epoch 746/5000 | Loss 0.0544 | Win count 330
# Epoch 747/5000 | Loss 0.1201 | Win count 331
# Epoch 748/5000 | Loss 0.0613 | Win count 332
# Epoch 749/5000 | Loss 0.1023 | Win count 333
# Epoch 750/5000 | Loss 0.0562 | Win count 334
# Epoch 751/5000 | Loss 0.0594 | Win count 334
# Epoch 752/5000 | Loss 0.1500 | Win count 335
# Epoch 753/5000 | Loss 0.3366 | Win count 336
# Epoch 754/5000 | Loss 0.0708 | Win count 336
# Epoch 755/5000 | Loss 0.0814 | Win count 337
# Epoch 756/5000 | Loss 0.0867 | Win count 337
# Epoch 757/5000 | Loss 0.2809 | Win count 337
# Epoch 758/5000 | Loss 0.5725 | Win count 338
# Epoch 759/5000 | Loss 0.0905 | Win count 339
# Epoch 760/5000 | Loss 0.0301 | Win count 340
# Epoch 761/5000 | Loss 0.1290 | Win count 341
# Epoch 762/5000 | Loss 0.2480 | Win count 341
# Epoch 763/5000 | Loss 0.0968 | Win count 341
# Epoch 764/5000 | Loss 0.1199 | Win count 342
# Epoch 765/5000 | Loss 0.1086 | Win count 343
# Epoch 766/5000 | Loss 0.0895 | Win count 343
# Epoch 767/5000 | Loss 0.0386 | Win count 344
# Epoch 768/5000 | Loss 0.0573 | Win count 345
# Epoch 769/5000 | Loss 0.0194 | Win count 346
# Epoch 770/5000 | Loss 0.0264 | Win count 347
# Epoch 771/5000 | Loss 0.0620 | Win count 348
# Epoch 772/5000 | Loss 0.0589 | Win count 349
# Epoch 773/5000 | Loss 0.0403 | Win count 350
# Epoch 774/5000 | Loss 0.1818 | Win count 350
# Epoch 775/5000 | Loss 0.0917 | Win count 350
# Epoch 776/5000 | Loss 0.0294 | Win count 350
# Epoch 777/5000 | Loss 0.3067 | Win count 351
# Epoch 778/5000 | Loss 0.4112 | Win count 352
# Epoch 779/5000 | Loss 0.0333 | Win count 353
# Epoch 780/5000 | Loss 0.0505 | Win count 354
# Epoch 781/5000 | Loss 0.0912 | Win count 355
# Epoch 782/5000 | Loss 0.3175 | Win count 356
# Epoch 783/5000 | Loss 0.0905 | Win count 357
# Epoch 784/5000 | Loss 0.1549 | Win count 358
# Epoch 785/5000 | Loss 0.1378 | Win count 358
# Epoch 786/5000 | Loss 0.1422 | Win count 359
# Epoch 787/5000 | Loss 0.0640 | Win count 360
# Epoch 788/5000 | Loss 0.0904 | Win count 361
# Epoch 789/5000 | Loss 0.5158 | Win count 362
# Epoch 790/5000 | Loss 0.0307 | Win count 363
# Epoch 791/5000 | Loss 0.2288 | Win count 364
# Epoch 792/5000 | Loss 0.1258 | Win count 365
# Epoch 793/5000 | Loss 0.1568 | Win count 365
# Epoch 794/5000 | Loss 0.0625 | Win count 366
# Epoch 795/5000 | Loss 0.0503 | Win count 366
# Epoch 796/5000 | Loss 0.0532 | Win count 367
# Epoch 797/5000 | Loss 0.0178 | Win count 367
# Epoch 798/5000 | Loss 0.1696 | Win count 367
# Epoch 799/5000 | Loss 0.0346 | Win count 368
# Epoch 800/5000 | Loss 0.0456 | Win count 369
# Epoch 801/5000 | Loss 0.0782 | Win count 370
# Epoch 802/5000 | Loss 0.0256 | Win count 370
# Epoch 803/5000 | Loss 0.9751 | Win count 370
# Epoch 804/5000 | Loss 0.5718 | Win count 370
# Epoch 805/5000 | Loss 0.0978 | Win count 371
# Epoch 806/5000 | Loss 0.1395 | Win count 372
# Epoch 807/5000 | Loss 0.5443 | Win count 372
# Epoch 808/5000 | Loss 0.0453 | Win count 373
# Epoch 809/5000 | Loss 0.5786 | Win count 373
# Epoch 810/5000 | Loss 0.0242 | Win count 373
# Epoch 811/5000 | Loss 0.0823 | Win count 373
# Epoch 812/5000 | Loss 0.0123 | Win count 374
# Epoch 813/5000 | Loss 0.0926 | Win count 374
# Epoch 814/5000 | Loss 0.1987 | Win count 374
# Epoch 815/5000 | Loss 0.1521 | Win count 375
# Epoch 816/5000 | Loss 0.1958 | Win count 376
# Epoch 817/5000 | Loss 0.4410 | Win count 376
# Epoch 818/5000 | Loss 0.1615 | Win count 376
# Epoch 819/5000 | Loss 0.2627 | Win count 376
# Epoch 820/5000 | Loss 0.2994 | Win count 377
# Epoch 821/5000 | Loss 0.0577 | Win count 378
# Epoch 822/5000 | Loss 0.2083 | Win count 378
# Epoch 823/5000 | Loss 0.3655 | Win count 378
# Epoch 824/5000 | Loss 0.0548 | Win count 378
# Epoch 825/5000 | Loss 0.1687 | Win count 379
# Epoch 826/5000 | Loss 0.1022 | Win count 379
# Epoch 827/5000 | Loss 0.3365 | Win count 380
# Epoch 828/5000 | Loss 0.0936 | Win count 380
# Epoch 829/5000 | Loss 0.0483 | Win count 380
# Epoch 830/5000 | Loss 0.0861 | Win count 381
# Epoch 831/5000 | Loss 0.0496 | Win count 382
# Epoch 832/5000 | Loss 0.0699 | Win count 383
# Epoch 833/5000 | Loss 0.1691 | Win count 384
# Epoch 834/5000 | Loss 0.2467 | Win count 384
# Epoch 835/5000 | Loss 0.8012 | Win count 385
# Epoch 836/5000 | Loss 0.3423 | Win count 385
# Epoch 837/5000 | Loss 0.5982 | Win count 385
# Epoch 838/5000 | Loss 0.0789 | Win count 385
# Epoch 839/5000 | Loss 0.5133 | Win count 386
# Epoch 840/5000 | Loss 0.1560 | Win count 386
# Epoch 841/5000 | Loss 0.0110 | Win count 387
# Epoch 842/5000 | Loss 0.0598 | Win count 388
# Epoch 843/5000 | Loss 0.2402 | Win count 389
# Epoch 844/5000 | Loss 0.0801 | Win count 390
# Epoch 845/5000 | Loss 0.1269 | Win count 391
# Epoch 846/5000 | Loss 0.7555 | Win count 391
# Epoch 847/5000 | Loss 0.2451 | Win count 391
# Epoch 848/5000 | Loss 0.0465 | Win count 392
# Epoch 849/5000 | Loss 0.0989 | Win count 392
# Epoch 850/5000 | Loss 0.1511 | Win count 393
# Epoch 851/5000 | Loss 0.0918 | Win count 394
# Epoch 852/5000 | Loss 0.2152 | Win count 395
# Epoch 853/5000 | Loss 0.1927 | Win count 396
# Epoch 854/5000 | Loss 1.8202 | Win count 397
# Epoch 855/5000 | Loss 0.4676 | Win count 398
# Epoch 856/5000 | Loss 0.0672 | Win count 399
# Epoch 857/5000 | Loss 0.2409 | Win count 400
# Epoch 858/5000 | Loss 0.3541 | Win count 401
# Epoch 859/5000 | Loss 0.4994 | Win count 401
# Epoch 860/5000 | Loss 0.5919 | Win count 401
# Epoch 861/5000 | Loss 1.0713 | Win count 402
# Epoch 862/5000 | Loss 0.1033 | Win count 403
# Epoch 863/5000 | Loss 0.0999 | Win count 404
# Epoch 864/5000 | Loss 0.0505 | Win count 405
# Epoch 865/5000 | Loss 0.8013 | Win count 405
# Epoch 866/5000 | Loss 0.0269 | Win count 405
# Epoch 867/5000 | Loss 0.4642 | Win count 406
# Epoch 868/5000 | Loss 0.0895 | Win count 407
# Epoch 869/5000 | Loss 0.2233 | Win count 408
# Epoch 870/5000 | Loss 0.1558 | Win count 409
# Epoch 871/5000 | Loss 0.0341 | Win count 410
# Epoch 872/5000 | Loss 0.0936 | Win count 411
# Epoch 873/5000 | Loss 0.0589 | Win count 411
# Epoch 874/5000 | Loss 0.8034 | Win count 412
# Epoch 875/5000 | Loss 0.1932 | Win count 413
# Epoch 876/5000 | Loss 0.1068 | Win count 414
# Epoch 877/5000 | Loss 0.0193 | Win count 415
# Epoch 878/5000 | Loss 0.2751 | Win count 416
# Epoch 879/5000 | Loss 0.0687 | Win count 417
# Epoch 880/5000 | Loss 0.0095 | Win count 418
# Epoch 881/5000 | Loss 0.2844 | Win count 418
# Epoch 882/5000 | Loss 0.2283 | Win count 419
# Epoch 883/5000 | Loss 0.0638 | Win count 420
# Epoch 884/5000 | Loss 0.0588 | Win count 420
# Epoch 885/5000 | Loss 0.0550 | Win count 421
# Epoch 886/5000 | Loss 0.1525 | Win count 422
# Epoch 887/5000 | Loss 0.0729 | Win count 422
# Epoch 888/5000 | Loss 0.0882 | Win count 423
# Epoch 889/5000 | Loss 0.0690 | Win count 424
# Epoch 890/5000 | Loss 0.0210 | Win count 424
# Epoch 891/5000 | Loss 0.0397 | Win count 425
# Epoch 892/5000 | Loss 0.1903 | Win count 426
# Epoch 893/5000 | Loss 0.0308 | Win count 427
# Epoch 894/5000 | Loss 0.0385 | Win count 428
# Epoch 895/5000 | Loss 0.6174 | Win count 429
# Epoch 896/5000 | Loss 0.0344 | Win count 430
# Epoch 897/5000 | Loss 0.0686 | Win count 430
# Epoch 898/5000 | Loss 0.0962 | Win count 431
# Epoch 899/5000 | Loss 0.0943 | Win count 432
# Epoch 900/5000 | Loss 0.0448 | Win count 432
# Epoch 901/5000 | Loss 0.0908 | Win count 433
# Epoch 902/5000 | Loss 0.3656 | Win count 434
# Epoch 903/5000 | Loss 0.1081 | Win count 434
# Epoch 904/5000 | Loss 0.0297 | Win count 435
# Epoch 905/5000 | Loss 0.0851 | Win count 436
# Epoch 906/5000 | Loss 0.1025 | Win count 437
# Epoch 907/5000 | Loss 0.0652 | Win count 438
# Epoch 908/5000 | Loss 0.0692 | Win count 439
# Epoch 909/5000 | Loss 0.0978 | Win count 440
# Epoch 910/5000 | Loss 0.0957 | Win count 441
# Epoch 911/5000 | Loss 0.2167 | Win count 442
# Epoch 912/5000 | Loss 0.0132 | Win count 443
# Epoch 913/5000 | Loss 0.1528 | Win count 444
# Epoch 914/5000 | Loss 0.9090 | Win count 445
# Epoch 915/5000 | Loss 0.0426 | Win count 446
# Epoch 916/5000 | Loss 0.0277 | Win count 447
# Epoch 917/5000 | Loss 0.0872 | Win count 447
# Epoch 918/5000 | Loss 0.0149 | Win count 448
# Epoch 919/5000 | Loss 0.2025 | Win count 449
# Epoch 920/5000 | Loss 0.1259 | Win count 450
# Epoch 921/5000 | Loss 0.0474 | Win count 451
# Epoch 922/5000 | Loss 0.0672 | Win count 452
# Epoch 923/5000 | Loss 0.1621 | Win count 452
# Epoch 924/5000 | Loss 0.1198 | Win count 452
# Epoch 925/5000 | Loss 0.0985 | Win count 453
# Epoch 926/5000 | Loss 0.0465 | Win count 453
# Epoch 927/5000 | Loss 0.0624 | Win count 454
# Epoch 928/5000 | Loss 0.2261 | Win count 454
# Epoch 929/5000 | Loss 0.1466 | Win count 455
# Epoch 930/5000 | Loss 0.0683 | Win count 456
# Epoch 931/5000 | Loss 0.2138 | Win count 457
# Epoch 932/5000 | Loss 0.0772 | Win count 458
# Epoch 933/5000 | Loss 0.1035 | Win count 459
# Epoch 934/5000 | Loss 0.1188 | Win count 460
# Epoch 935/5000 | Loss 0.0671 | Win count 461
# Epoch 936/5000 | Loss 0.6727 | Win count 461
# Epoch 937/5000 | Loss 0.0970 | Win count 462
# Epoch 938/5000 | Loss 0.1949 | Win count 463
# Epoch 939/5000 | Loss 0.0894 | Win count 464
# Epoch 940/5000 | Loss 0.0395 | Win count 464
# Epoch 941/5000 | Loss 0.0518 | Win count 465
# Epoch 942/5000 | Loss 0.0626 | Win count 466
# Epoch 943/5000 | Loss 0.0466 | Win count 466
# Epoch 944/5000 | Loss 0.0765 | Win count 466
# Epoch 945/5000 | Loss 0.0621 | Win count 467
# Epoch 946/5000 | Loss 0.0186 | Win count 468
# Epoch 947/5000 | Loss 0.0815 | Win count 469
# Epoch 948/5000 | Loss 0.0886 | Win count 470
# Epoch 949/5000 | Loss 0.0181 | Win count 471
# Epoch 950/5000 | Loss 0.0414 | Win count 471
# Epoch 951/5000 | Loss 0.0216 | Win count 472
# Epoch 952/5000 | Loss 0.1712 | Win count 472
# Epoch 953/5000 | Loss 0.1626 | Win count 472
# Epoch 954/5000 | Loss 0.0615 | Win count 473
# Epoch 955/5000 | Loss 0.0690 | Win count 474
# Epoch 956/5000 | Loss 0.0774 | Win count 475
# Epoch 957/5000 | Loss 0.1777 | Win count 476
# Epoch 958/5000 | Loss 0.0235 | Win count 476
# Epoch 959/5000 | Loss 0.0518 | Win count 477
# Epoch 960/5000 | Loss 0.0378 | Win count 478
# Epoch 961/5000 | Loss 0.0257 | Win count 478
# Epoch 962/5000 | Loss 0.1302 | Win count 479
# Epoch 963/5000 | Loss 0.0274 | Win count 480
# Epoch 964/5000 | Loss 0.1038 | Win count 481
# Epoch 965/5000 | Loss 0.2514 | Win count 481
# Epoch 966/5000 | Loss 0.0109 | Win count 482
# Epoch 967/5000 | Loss 0.0871 | Win count 483
# Epoch 968/5000 | Loss 0.0810 | Win count 483
# Epoch 969/5000 | Loss 1.1571 | Win count 484
# Epoch 970/5000 | Loss 0.1562 | Win count 484
# Epoch 971/5000 | Loss 0.2500 | Win count 484
# Epoch 972/5000 | Loss 0.1057 | Win count 485
# Epoch 973/5000 | Loss 0.0140 | Win count 485
# Epoch 974/5000 | Loss 0.0894 | Win count 486
# Epoch 975/5000 | Loss 0.0940 | Win count 487
# Epoch 976/5000 | Loss 0.1585 | Win count 488
# Epoch 977/5000 | Loss 0.0264 | Win count 489
# Epoch 978/5000 | Loss 0.0837 | Win count 489
# Epoch 979/5000 | Loss 0.0295 | Win count 490
# Epoch 980/5000 | Loss 0.0462 | Win count 490
# Epoch 981/5000 | Loss 0.0548 | Win count 491
# Epoch 982/5000 | Loss 0.0577 | Win count 492
# Epoch 983/5000 | Loss 0.0321 | Win count 492
# Epoch 984/5000 | Loss 0.0296 | Win count 493
# Epoch 985/5000 | Loss 0.0399 | Win count 494
# Epoch 986/5000 | Loss 0.0269 | Win count 495
# Epoch 987/5000 | Loss 0.0145 | Win count 495
# Epoch 988/5000 | Loss 0.0088 | Win count 496
# Epoch 989/5000 | Loss 0.5787 | Win count 497
# Epoch 990/5000 | Loss 0.0857 | Win count 497
# Epoch 991/5000 | Loss 0.0177 | Win count 498
# Epoch 992/5000 | Loss 0.1485 | Win count 499
# Epoch 993/5000 | Loss 0.0434 | Win count 500
# Epoch 994/5000 | Loss 0.0554 | Win count 501
# Epoch 995/5000 | Loss 0.8988 | Win count 502
# Epoch 996/5000 | Loss 0.1304 | Win count 503
# Epoch 997/5000 | Loss 0.0750 | Win count 504
# Epoch 998/5000 | Loss 0.0725 | Win count 505
# Epoch 999/5000 | Loss 0.1232 | Win count 506
# Epoch 1000/5000 | Loss 0.1109 | Win count 507
# Epoch 1001/5000 | Loss 0.3757 | Win count 508
# Epoch 1002/5000 | Loss 0.0456 | Win count 509
# Epoch 1003/5000 | Loss 0.0962 | Win count 510
# Epoch 1004/5000 | Loss 0.0856 | Win count 511
# Epoch 1005/5000 | Loss 0.0286 | Win count 512
# Epoch 1006/5000 | Loss 0.0815 | Win count 513
# Epoch 1007/5000 | Loss 0.1236 | Win count 513
# Epoch 1008/5000 | Loss 0.2271 | Win count 514
# Epoch 1009/5000 | Loss 0.0538 | Win count 515
# Epoch 1010/5000 | Loss 0.0733 | Win count 515
# Epoch 1011/5000 | Loss 0.0840 | Win count 516
# Epoch 1012/5000 | Loss 0.0260 | Win count 517
# Epoch 1013/5000 | Loss 0.0444 | Win count 518
# Epoch 1014/5000 | Loss 0.0994 | Win count 519
# Epoch 1015/5000 | Loss 0.0908 | Win count 519
# Epoch 1016/5000 | Loss 0.0534 | Win count 519
# Epoch 1017/5000 | Loss 0.0308 | Win count 519
# Epoch 1018/5000 | Loss 0.0708 | Win count 520
# Epoch 1019/5000 | Loss 0.1589 | Win count 521
# Epoch 1020/5000 | Loss 0.0827 | Win count 522
# Epoch 1021/5000 | Loss 0.0290 | Win count 522
# Epoch 1022/5000 | Loss 0.1524 | Win count 523
# Epoch 1023/5000 | Loss 0.0622 | Win count 524
# Epoch 1024/5000 | Loss 0.0750 | Win count 524
# Epoch 1025/5000 | Loss 0.3230 | Win count 524
# Epoch 1026/5000 | Loss 0.0649 | Win count 525
# Epoch 1027/5000 | Loss 0.1935 | Win count 525
# Epoch 1028/5000 | Loss 0.3043 | Win count 526
# Epoch 1029/5000 | Loss 0.1444 | Win count 527
# Epoch 1030/5000 | Loss 0.1202 | Win count 527
# Epoch 1031/5000 | Loss 0.0274 | Win count 528
# Epoch 1032/5000 | Loss 0.0486 | Win count 529
# Epoch 1033/5000 | Loss 0.0432 | Win count 530
# Epoch 1034/5000 | Loss 0.0484 | Win count 531
# Epoch 1035/5000 | Loss 0.2716 | Win count 532
# Epoch 1036/5000 | Loss 0.0618 | Win count 533
# Epoch 1037/5000 | Loss 0.0335 | Win count 534
# Epoch 1038/5000 | Loss 0.0813 | Win count 534
# Epoch 1039/5000 | Loss 0.0555 | Win count 535
# Epoch 1040/5000 | Loss 0.0335 | Win count 536
# Epoch 1041/5000 | Loss 0.0225 | Win count 536
# Epoch 1042/5000 | Loss 0.0516 | Win count 537
# Epoch 1043/5000 | Loss 0.3062 | Win count 538
# Epoch 1044/5000 | Loss 0.0702 | Win count 539
# Epoch 1045/5000 | Loss 0.0545 | Win count 540
# Epoch 1046/5000 | Loss 0.0824 | Win count 540
# Epoch 1047/5000 | Loss 0.1156 | Win count 541
# Epoch 1048/5000 | Loss 0.1074 | Win count 542
# Epoch 1049/5000 | Loss 0.1053 | Win count 543
# Epoch 1050/5000 | Loss 0.2717 | Win count 543
# Epoch 1051/5000 | Loss 0.1391 | Win count 544
# Epoch 1052/5000 | Loss 0.0576 | Win count 545
# Epoch 1053/5000 | Loss 0.0296 | Win count 545
# Epoch 1054/5000 | Loss 0.5877 | Win count 546
# Epoch 1055/5000 | Loss 0.1317 | Win count 547
# Epoch 1056/5000 | Loss 0.0400 | Win count 548
# Epoch 1057/5000 | Loss 0.1566 | Win count 549
# Epoch 1058/5000 | Loss 0.1508 | Win count 549
# Epoch 1059/5000 | Loss 0.1660 | Win count 550
# Epoch 1060/5000 | Loss 0.0794 | Win count 550
# Epoch 1061/5000 | Loss 0.0937 | Win count 550
# Epoch 1062/5000 | Loss 0.5698 | Win count 551
# Epoch 1063/5000 | Loss 0.0520 | Win count 552
# Epoch 1064/5000 | Loss 0.1394 | Win count 553
# Epoch 1065/5000 | Loss 0.0363 | Win count 553
# Epoch 1066/5000 | Loss 0.1250 | Win count 554
# Epoch 1067/5000 | Loss 0.1292 | Win count 555
# Epoch 1068/5000 | Loss 0.1536 | Win count 555
# Epoch 1069/5000 | Loss 0.1161 | Win count 556
# Epoch 1070/5000 | Loss 0.2297 | Win count 557
# ...
# Epoch 4661/5000 | Loss 0.5691 | Win count 3865
# Epoch 4662/5000 | Loss 0.1035 | Win count 3865
# Epoch 4663/5000 | Loss 0.0458 | Win count 3866
# Epoch 4664/5000 | Loss 0.0180 | Win count 3867
# Epoch 4665/5000 | Loss 0.0058 | Win count 3868
# Epoch 4666/5000 | Loss 0.0025 | Win count 3869
# Epoch 4667/5000 | Loss 0.0789 | Win count 3870
# Epoch 4668/5000 | Loss 0.0039 | Win count 3871
# Epoch 4669/5000 | Loss 0.0423 | Win count 3872
# Epoch 4670/5000 | Loss 0.1064 | Win count 3873
# Epoch 4671/5000 | Loss 0.1874 | Win count 3874
# Epoch 4672/5000 | Loss 0.0274 | Win count 3875
# Epoch 4673/5000 | Loss 0.0297 | Win count 3876
# Epoch 4674/5000 | Loss 0.0794 | Win count 3877
# Epoch 4675/5000 | Loss 0.0087 | Win count 3878
# Epoch 4676/5000 | Loss 0.0537 | Win count 3879
# Epoch 4677/5000 | Loss 0.0244 | Win count 3880
# Epoch 4678/5000 | Loss 0.1680 | Win count 3881
# Epoch 4679/5000 | Loss 0.0257 | Win count 3882
# Epoch 4680/5000 | Loss 0.0564 | Win count 3883
# Epoch 4681/5000 | Loss 0.0132 | Win count 3884
# Epoch 4682/5000 | Loss 0.0252 | Win count 3885
# Epoch 4683/5000 | Loss 0.0335 | Win count 3886
# Epoch 4684/5000 | Loss 0.0143 | Win count 3887
# Epoch 4685/5000 | Loss 0.0153 | Win count 3888
# Epoch 4686/5000 | Loss 0.0471 | Win count 3889
# Epoch 4687/5000 | Loss 0.0081 | Win count 3889
# Epoch 4688/5000 | Loss 0.0075 | Win count 3890
# Epoch 4689/5000 | Loss 0.0074 | Win count 3891
# Epoch 4690/5000 | Loss 0.0131 | Win count 3892
# Epoch 4691/5000 | Loss 0.0101 | Win count 3893
# Epoch 4692/5000 | Loss 0.0043 | Win count 3894
# Epoch 4693/5000 | Loss 0.0043 | Win count 3895
# Epoch 4694/5000 | Loss 0.0032 | Win count 3896
# Epoch 4695/5000 | Loss 0.0519 | Win count 3897
# Epoch 4696/5000 | Loss 0.0038 | Win count 3898
# Epoch 4697/5000 | Loss 0.0062 | Win count 3899
# Epoch 4698/5000 | Loss 0.0092 | Win count 3900
# Epoch 4699/5000 | Loss 0.0107 | Win count 3901
# Epoch 4700/5000 | Loss 0.2164 | Win count 3902
# Epoch 4701/5000 | Loss 0.0190 | Win count 3903
# Epoch 4702/5000 | Loss 0.0086 | Win count 3904
# Epoch 4703/5000 | Loss 0.0087 | Win count 3905
# Epoch 4704/5000 | Loss 0.0906 | Win count 3906
# Epoch 4705/5000 | Loss 0.1324 | Win count 3907
# Epoch 4706/5000 | Loss 0.0039 | Win count 3908
# Epoch 4707/5000 | Loss 0.0466 | Win count 3909
# Epoch 4708/5000 | Loss 0.0017 | Win count 3910
# Epoch 4709/5000 | Loss 0.0049 | Win count 3911
# Epoch 4710/5000 | Loss 0.0157 | Win count 3912
# Epoch 4711/5000 | Loss 0.0076 | Win count 3913
# Epoch 4712/5000 | Loss 0.0547 | Win count 3914
# Epoch 4713/5000 | Loss 0.0087 | Win count 3915
# Epoch 4714/5000 | Loss 0.0119 | Win count 3916
# Epoch 4715/5000 | Loss 0.0187 | Win count 3917
# Epoch 4716/5000 | Loss 0.0066 | Win count 3918
# Epoch 4717/5000 | Loss 0.0049 | Win count 3919
# Epoch 4718/5000 | Loss 0.0072 | Win count 3920
# Epoch 4719/5000 | Loss 0.0180 | Win count 3921
# Epoch 4720/5000 | Loss 0.0082 | Win count 3922
# Epoch 4721/5000 | Loss 0.0226 | Win count 3923
# Epoch 4722/5000 | Loss 0.0060 | Win count 3924
# Epoch 4723/5000 | Loss 0.0041 | Win count 3925
# Epoch 4724/5000 | Loss 0.0054 | Win count 3926
# Epoch 4725/5000 | Loss 0.0052 | Win count 3927
# Epoch 4726/5000 | Loss 0.0048 | Win count 3928
# Epoch 4727/5000 | Loss 0.0033 | Win count 3929
# Epoch 4728/5000 | Loss 0.0030 | Win count 3930
# Epoch 4729/5000 | Loss 0.0036 | Win count 3931
# Epoch 4730/5000 | Loss 0.0047 | Win count 3931
# Epoch 4731/5000 | Loss 0.0107 | Win count 3931
# Epoch 4732/5000 | Loss 0.0102 | Win count 3932
# Epoch 4733/5000 | Loss 0.0037 | Win count 3933
# Epoch 4734/5000 | Loss 0.0092 | Win count 3934
# Epoch 4735/5000 | Loss 0.0027 | Win count 3935
# Epoch 4736/5000 | Loss 0.0027 | Win count 3936
# Epoch 4737/5000 | Loss 0.0769 | Win count 3937
# Epoch 4738/5000 | Loss 0.0264 | Win count 3938
# Epoch 4739/5000 | Loss 0.0079 | Win count 3939
# Epoch 4740/5000 | Loss 0.0082 | Win count 3940
# Epoch 4741/5000 | Loss 0.0059 | Win count 3941
# Epoch 4742/5000 | Loss 0.0013 | Win count 3942
# Epoch 4743/5000 | Loss 0.0106 | Win count 3943
# Epoch 4744/5000 | Loss 0.0183 | Win count 3944
# Epoch 4745/5000 | Loss 0.0046 | Win count 3945
# Epoch 4746/5000 | Loss 0.0315 | Win count 3946
# Epoch 4747/5000 | Loss 0.0035 | Win count 3947
# Epoch 4748/5000 | Loss 0.0037 | Win count 3948
# Epoch 4749/5000 | Loss 0.0077 | Win count 3948
# Epoch 4750/5000 | Loss 0.0189 | Win count 3949
# Epoch 4751/5000 | Loss 0.0031 | Win count 3950
# Epoch 4752/5000 | Loss 0.0080 | Win count 3951
# Epoch 4753/5000 | Loss 0.0056 | Win count 3952
# Epoch 4754/5000 | Loss 0.0037 | Win count 3953
# Epoch 4755/5000 | Loss 0.0045 | Win count 3954
# Epoch 4756/5000 | Loss 0.0034 | Win count 3955
# Epoch 4757/5000 | Loss 0.2766 | Win count 3956
# Epoch 4758/5000 | Loss 0.1430 | Win count 3957
# Epoch 4759/5000 | Loss 0.0158 | Win count 3958
# Epoch 4760/5000 | Loss 0.0079 | Win count 3959
# Epoch 4761/5000 | Loss 0.0147 | Win count 3960
# Epoch 4762/5000 | Loss 0.0551 | Win count 3961
# Epoch 4763/5000 | Loss 0.0043 | Win count 3961
# Epoch 4764/5000 | Loss 0.0261 | Win count 3962
# Epoch 4765/5000 | Loss 0.0223 | Win count 3962
# Epoch 4766/5000 | Loss 0.0160 | Win count 3962
# Epoch 4767/5000 | Loss 0.0073 | Win count 3963
# Epoch 4768/5000 | Loss 0.0101 | Win count 3964
# Epoch 4769/5000 | Loss 0.0070 | Win count 3965
# Epoch 4770/5000 | Loss 0.0534 | Win count 3966
# Epoch 4771/5000 | Loss 0.0112 | Win count 3967
# Epoch 4772/5000 | Loss 0.0112 | Win count 3968
# Epoch 4773/5000 | Loss 0.0056 | Win count 3969
# Epoch 4774/5000 | Loss 0.0062 | Win count 3970
# Epoch 4775/5000 | Loss 0.3981 | Win count 3971
# Epoch 4776/5000 | Loss 0.3018 | Win count 3972
# Epoch 4777/5000 | Loss 0.0057 | Win count 3973
# Epoch 4778/5000 | Loss 0.0762 | Win count 3974
# Epoch 4779/5000 | Loss 0.1661 | Win count 3975
# Epoch 4780/5000 | Loss 0.0157 | Win count 3976
# Epoch 4781/5000 | Loss 0.0047 | Win count 3977
# Epoch 4782/5000 | Loss 0.0047 | Win count 3978
# Epoch 4783/5000 | Loss 0.0212 | Win count 3979
# Epoch 4784/5000 | Loss 0.0635 | Win count 3980
# Epoch 4785/5000 | Loss 0.0067 | Win count 3981
# Epoch 4786/5000 | Loss 0.1613 | Win count 3982
# Epoch 4787/5000 | Loss 0.1244 | Win count 3982
# Epoch 4788/5000 | Loss 0.0917 | Win count 3983
# Epoch 4789/5000 | Loss 0.1087 | Win count 3984
# Epoch 4790/5000 | Loss 0.0281 | Win count 3985
# Epoch 4791/5000 | Loss 0.0117 | Win count 3986
# Epoch 4792/5000 | Loss 0.0119 | Win count 3987
# Epoch 4793/5000 | Loss 0.0206 | Win count 3988
# Epoch 4794/5000 | Loss 0.0162 | Win count 3989
# Epoch 4795/5000 | Loss 0.0094 | Win count 3990
# Epoch 4796/5000 | Loss 0.0023 | Win count 3991
# Epoch 4797/5000 | Loss 0.0073 | Win count 3992
# Epoch 4798/5000 | Loss 0.0036 | Win count 3993
# Epoch 4799/5000 | Loss 0.0576 | Win count 3994
# Epoch 4800/5000 | Loss 0.0110 | Win count 3995
# Epoch 4801/5000 | Loss 0.0653 | Win count 3996
# Epoch 4802/5000 | Loss 0.0082 | Win count 3997
# Epoch 4803/5000 | Loss 0.0179 | Win count 3998
# Epoch 4804/5000 | Loss 0.0627 | Win count 3999
# Epoch 4805/5000 | Loss 0.0046 | Win count 4000
# Epoch 4806/5000 | Loss 0.0082 | Win count 4001
# Epoch 4807/5000 | Loss 0.0131 | Win count 4002
# Epoch 4808/5000 | Loss 0.0093 | Win count 4002
# Epoch 4809/5000 | Loss 0.0030 | Win count 4003
# Epoch 4810/5000 | Loss 0.0057 | Win count 4004
# Epoch 4811/5000 | Loss 0.0080 | Win count 4005
# Epoch 4812/5000 | Loss 0.0066 | Win count 4006
# Epoch 4813/5000 | Loss 0.0170 | Win count 4007
# Epoch 4814/5000 | Loss 0.0144 | Win count 4007
# Epoch 4815/5000 | Loss 0.0123 | Win count 4008
# Epoch 4816/5000 | Loss 0.0096 | Win count 4008
# Epoch 4817/5000 | Loss 0.0132 | Win count 4009
# Epoch 4818/5000 | Loss 0.0569 | Win count 4010
# Epoch 4819/5000 | Loss 0.0058 | Win count 4011
# Epoch 4820/5000 | Loss 0.0039 | Win count 4012
# Epoch 4821/5000 | Loss 0.0074 | Win count 4013
# Epoch 4822/5000 | Loss 0.0091 | Win count 4014
# Epoch 4823/5000 | Loss 0.0384 | Win count 4015
# Epoch 4824/5000 | Loss 0.0074 | Win count 4016
# Epoch 4825/5000 | Loss 0.0116 | Win count 4017
# Epoch 4826/5000 | Loss 0.0087 | Win count 4018
# Epoch 4827/5000 | Loss 0.0115 | Win count 4019
# Epoch 4828/5000 | Loss 0.0010 | Win count 4020
# Epoch 4829/5000 | Loss 0.0028 | Win count 4021
# Epoch 4830/5000 | Loss 0.0055 | Win count 4022
# Epoch 4831/5000 | Loss 0.0038 | Win count 4023
# Epoch 4832/5000 | Loss 0.0024 | Win count 4024
# Epoch 4833/5000 | Loss 0.0439 | Win count 4025
# Epoch 4834/5000 | Loss 0.0101 | Win count 4026
# Epoch 4835/5000 | Loss 0.0043 | Win count 4027
# Epoch 4836/5000 | Loss 0.0058 | Win count 4028
# Epoch 4837/5000 | Loss 0.0027 | Win count 4029
# Epoch 4838/5000 | Loss 0.0643 | Win count 4030
# Epoch 4839/5000 | Loss 0.0326 | Win count 4031
# Epoch 4840/5000 | Loss 0.0050 | Win count 4032
# Epoch 4841/5000 | Loss 0.0128 | Win count 4033
# Epoch 4842/5000 | Loss 0.0202 | Win count 4034
# Epoch 4843/5000 | Loss 0.0258 | Win count 4034
# Epoch 4844/5000 | Loss 0.0014 | Win count 4035
# Epoch 4845/5000 | Loss 0.0014 | Win count 4036
# Epoch 4846/5000 | Loss 0.0022 | Win count 4037
# Epoch 4847/5000 | Loss 0.0160 | Win count 4038
# Epoch 4848/5000 | Loss 0.0054 | Win count 4039
# Epoch 4849/5000 | Loss 0.0018 | Win count 4040
# Epoch 4850/5000 | Loss 0.0089 | Win count 4041
# Epoch 4851/5000 | Loss 0.0195 | Win count 4042
# Epoch 4852/5000 | Loss 0.0074 | Win count 4043
# Epoch 4853/5000 | Loss 0.0065 | Win count 4044
# Epoch 4854/5000 | Loss 0.0120 | Win count 4045
# Epoch 4855/5000 | Loss 0.0035 | Win count 4046
# Epoch 4856/5000 | Loss 0.0057 | Win count 4046
# Epoch 4857/5000 | Loss 0.0043 | Win count 4047
# Epoch 4858/5000 | Loss 0.0042 | Win count 4048
# Epoch 4859/5000 | Loss 0.0525 | Win count 4049
# Epoch 4860/5000 | Loss 0.0665 | Win count 4050
# Epoch 4861/5000 | Loss 0.0411 | Win count 4051
# Epoch 4862/5000 | Loss 0.0027 | Win count 4052
# Epoch 4863/5000 | Loss 0.0116 | Win count 4053
# Epoch 4864/5000 | Loss 0.0022 | Win count 4054
# Epoch 4865/5000 | Loss 0.0390 | Win count 4055
# Epoch 4866/5000 | Loss 0.0063 | Win count 4056
# Epoch 4867/5000 | Loss 0.0182 | Win count 4057
# Epoch 4868/5000 | Loss 0.0026 | Win count 4058
# Epoch 4869/5000 | Loss 0.0065 | Win count 4059
# Epoch 4870/5000 | Loss 0.0060 | Win count 4060
# Epoch 4871/5000 | Loss 0.0175 | Win count 4061
# Epoch 4872/5000 | Loss 0.0028 | Win count 4062
# Epoch 4873/5000 | Loss 0.0097 | Win count 4063
# Epoch 4874/5000 | Loss 0.0018 | Win count 4064
# Epoch 4875/5000 | Loss 0.0048 | Win count 4065
# Epoch 4876/5000 | Loss 0.0049 | Win count 4066
# Epoch 4877/5000 | Loss 0.0123 | Win count 4067
# Epoch 4878/5000 | Loss 0.0118 | Win count 4068
# Epoch 4879/5000 | Loss 0.0128 | Win count 4068
# Epoch 4880/5000 | Loss 0.0056 | Win count 4069
# Epoch 4881/5000 | Loss 0.0047 | Win count 4070
# Epoch 4882/5000 | Loss 0.0061 | Win count 4071
# Epoch 4883/5000 | Loss 0.0039 | Win count 4072
# Epoch 4884/5000 | Loss 0.0773 | Win count 4073
# Epoch 4885/5000 | Loss 0.0012 | Win count 4074
# Epoch 4886/5000 | Loss 0.0085 | Win count 4075
# Epoch 4887/5000 | Loss 0.0047 | Win count 4076
# Epoch 4888/5000 | Loss 0.0038 | Win count 4077
# Epoch 4889/5000 | Loss 0.0049 | Win count 4078
# Epoch 4890/5000 | Loss 0.0041 | Win count 4079
# Epoch 4891/5000 | Loss 0.0038 | Win count 4080
# Epoch 4892/5000 | Loss 0.0018 | Win count 4081
# Epoch 4893/5000 | Loss 0.0012 | Win count 4082
# Epoch 4894/5000 | Loss 0.0017 | Win count 4082
# Epoch 4895/5000 | Loss 0.6022 | Win count 4083
# Epoch 4896/5000 | Loss 0.0899 | Win count 4084
# Epoch 4897/5000 | Loss 0.0208 | Win count 4085
# Epoch 4898/5000 | Loss 0.0354 | Win count 4086
# Epoch 4899/5000 | Loss 0.0107 | Win count 4087
# Epoch 4900/5000 | Loss 0.0152 | Win count 4087
# Epoch 4901/5000 | Loss 0.0279 | Win count 4087
# Epoch 4902/5000 | Loss 0.0099 | Win count 4088
# Epoch 4903/5000 | Loss 0.0738 | Win count 4089
# Epoch 4904/5000 | Loss 0.0186 | Win count 4090
# Epoch 4905/5000 | Loss 0.1546 | Win count 4091
# Epoch 4906/5000 | Loss 0.0332 | Win count 4092
# Epoch 4907/5000 | Loss 0.0055 | Win count 4093
# Epoch 4908/5000 | Loss 0.1306 | Win count 4093
# Epoch 4909/5000 | Loss 0.0616 | Win count 4094
# Epoch 4910/5000 | Loss 0.0163 | Win count 4095
# Epoch 4911/5000 | Loss 0.1422 | Win count 4096
# Epoch 4912/5000 | Loss 0.0264 | Win count 4097
# Epoch 4913/5000 | Loss 0.0093 | Win count 4098
# Epoch 4914/5000 | Loss 0.0099 | Win count 4099
# Epoch 4915/5000 | Loss 0.0182 | Win count 4100
# Epoch 4916/5000 | Loss 0.1504 | Win count 4101
# Epoch 4917/5000 | Loss 0.0140 | Win count 4102
# Epoch 4918/5000 | Loss 0.0224 | Win count 4103
# Epoch 4919/5000 | Loss 0.0109 | Win count 4104
# Epoch 4920/5000 | Loss 0.0078 | Win count 4105
# Epoch 4921/5000 | Loss 0.0699 | Win count 4106
# Epoch 4922/5000 | Loss 0.0143 | Win count 4107
# Epoch 4923/5000 | Loss 0.0141 | Win count 4108
# Epoch 4924/5000 | Loss 0.0202 | Win count 4109
# Epoch 4925/5000 | Loss 0.0030 | Win count 4110
# Epoch 4926/5000 | Loss 0.0159 | Win count 4111
# Epoch 4927/5000 | Loss 0.0127 | Win count 4112
# Epoch 4928/5000 | Loss 0.0704 | Win count 4113
# Epoch 4929/5000 | Loss 0.0553 | Win count 4114
# Epoch 4930/5000 | Loss 0.0095 | Win count 4115
# Epoch 4931/5000 | Loss 0.0063 | Win count 4116
# Epoch 4932/5000 | Loss 0.0073 | Win count 4117
# Epoch 4933/5000 | Loss 0.0373 | Win count 4118
# Epoch 4934/5000 | Loss 0.0069 | Win count 4119
# Epoch 4935/5000 | Loss 0.0624 | Win count 4120
# Epoch 4936/5000 | Loss 0.0082 | Win count 4121
# Epoch 4937/5000 | Loss 0.0135 | Win count 4122
# Epoch 4938/5000 | Loss 0.1926 | Win count 4123
# Epoch 4939/5000 | Loss 0.0115 | Win count 4124
# Epoch 4940/5000 | Loss 0.0025 | Win count 4125
# Epoch 4941/5000 | Loss 0.0076 | Win count 4126
# Epoch 4942/5000 | Loss 0.0311 | Win count 4127
# Epoch 4943/5000 | Loss 0.0138 | Win count 4128
# Epoch 4944/5000 | Loss 0.3866 | Win count 4129
# Epoch 4945/5000 | Loss 0.0326 | Win count 4130
# Epoch 4946/5000 | Loss 0.0285 | Win count 4131
# Epoch 4947/5000 | Loss 0.0051 | Win count 4132
# Epoch 4948/5000 | Loss 0.0121 | Win count 4133
# Epoch 4949/5000 | Loss 0.0073 | Win count 4134
# Epoch 4950/5000 | Loss 0.0088 | Win count 4135
# Epoch 4951/5000 | Loss 0.0082 | Win count 4136
# Epoch 4952/5000 | Loss 0.0631 | Win count 4137
# Epoch 4953/5000 | Loss 0.0106 | Win count 4138
# Epoch 4954/5000 | Loss 0.0021 | Win count 4139
# Epoch 4955/5000 | Loss 0.0137 | Win count 4139
# Epoch 4956/5000 | Loss 0.0062 | Win count 4140
# Epoch 4957/5000 | Loss 0.0093 | Win count 4141
# Epoch 4958/5000 | Loss 0.0060 | Win count 4142
# Epoch 4959/5000 | Loss 0.0043 | Win count 4143
# Epoch 4960/5000 | Loss 0.0140 | Win count 4143
# Epoch 4961/5000 | Loss 0.0035 | Win count 4144
# Epoch 4962/5000 | Loss 0.0217 | Win count 4145
# Epoch 4963/5000 | Loss 0.0141 | Win count 4146
# Epoch 4964/5000 | Loss 0.0364 | Win count 4147
# Epoch 4965/5000 | Loss 0.0353 | Win count 4148
# Epoch 4966/5000 | Loss 0.0411 | Win count 4149
# Epoch 4967/5000 | Loss 0.0185 | Win count 4150
# Epoch 4968/5000 | Loss 0.0560 | Win count 4151
# Epoch 4969/5000 | Loss 0.0059 | Win count 4151
# Epoch 4970/5000 | Loss 0.0088 | Win count 4152
# Epoch 4971/5000 | Loss 0.1692 | Win count 4153
# Epoch 4972/5000 | Loss 0.1466 | Win count 4154
# Epoch 4973/5000 | Loss 0.0177 | Win count 4155
# Epoch 4974/5000 | Loss 0.0233 | Win count 4156
# Epoch 4975/5000 | Loss 0.0027 | Win count 4156
# Epoch 4976/5000 | Loss 0.0066 | Win count 4157
# Epoch 4977/5000 | Loss 0.0036 | Win count 4158
# Epoch 4978/5000 | Loss 0.0024 | Win count 4159
# Epoch 4979/5000 | Loss 0.0176 | Win count 4160
# Epoch 4980/5000 | Loss 0.0072 | Win count 4161
# Epoch 4981/5000 | Loss 0.0092 | Win count 4162
# Epoch 4982/5000 | Loss 0.0131 | Win count 4163
# Epoch 4983/5000 | Loss 0.0033 | Win count 4164
# Epoch 4984/5000 | Loss 0.0146 | Win count 4165
# Epoch 4985/5000 | Loss 0.0321 | Win count 4166
# Epoch 4986/5000 | Loss 0.0036 | Win count 4167
# Epoch 4987/5000 | Loss 0.0038 | Win count 4168
# Epoch 4988/5000 | Loss 0.0018 | Win count 4169
# Epoch 4989/5000 | Loss 0.0076 | Win count 4170
# Epoch 4990/5000 | Loss 0.0025 | Win count 4170
# Epoch 4991/5000 | Loss 0.0023 | Win count 4171
# Epoch 4992/5000 | Loss 0.0071 | Win count 4171
# Epoch 4993/5000 | Loss 0.0020 | Win count 4172
# Epoch 4994/5000 | Loss 0.0073 | Win count 4173
# Epoch 4995/5000 | Loss 0.0046 | Win count 4174
# Epoch 4996/5000 | Loss 0.0041 | Win count 4175
# Epoch 4997/5000 | Loss 0.0199 | Win count 4176
# Epoch 4998/5000 | Loss 0.0052 | Win count 4177
# Epoch 4999/5000 | Loss 0.0050 | Win count 4178
# Treinamento Concluído!

# %% [markdown]
# ## Testando o Modelo
#
# Agora que temos um ótimo jogador Catch à mão, queremos vê-lo em ação! A função de teste é muito semelhante à função do trem. Só que nos testes não salvamos as experiências e treinamos nelas. Mas agora podemos usar as funções de renderização definidas acima para assistir nosso modelo de jogo!

# %%
def test(model):
    global last_frame_time
    plt.ion()
    env = Catch(grid_size)
    c = 0
    last_frame_time = 0
    points = 0
    
    for e in range(10):
        loss = 0.
        env.reset()
        game_over = False
        input_t = env.observe()
        c += 1
        while not game_over:
            input_tm1 = input_t
            q = model.predict(input_tm1)
            action = np.argmax(q[0])
            input_t, reward, game_over = env.act(action)
            points += reward
            display_screen(action,points,input_t)
            c += 1

# %%
test(model)

# %% [markdown]
# ## Avaliando o Progresso
#
# Essa demo é bastante impressionante, hein? Antes de terminar esta pequena excursão, vamos ter um olhar mais atento sobre o modo como nosso modelo realmente aprendeu. Mais cedo, salvamos a história das vitórias. Agora, podemos traçar a média móvel da diferença, ou seja, quantas vitórias adicionais marcaram o modelo por jogo extra. 1 vitória extra por jogo significa que o modelo ganha cada jogo (pega todas as frutas), 0 significa que ela perde todas elas. Como você pode ver, o modelo se aproxima de uma taxa de vitória de 100% ao longo do tempo. Após 4000 peças, o modelo ganha de forma relativamente consistente. As quedas aleatórias no desempenho são provavelmente devido ao epsilon de escolha aleatória que são feitas de tempos em tempos. Um modelo melhor se aproximaria de 100% mais rápido.

# %%
def moving_average_diff(a, n=100):
    diff = np.diff(a)
    ret = np.cumsum(diff, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

plt.plot(moving_average_diff(hist))
plt.ylabel('Média de Vitórias Por Game')
plt.show()

# %% [markdown]
# ### Referências:
#
# Desmystifying Deep Reinforcement Learning
# https://www.intelnervana.com/demystifying-deep-reinforcement-learning/
#
# Deep Reinforcement Learning Stanford
# http://rll.berkeley.edu/deeprlcourse/
#
# Deep Mind
# https://deepmind.com/blog/deep-reinforcement-learning/

# %% [markdown]
# # Fim
