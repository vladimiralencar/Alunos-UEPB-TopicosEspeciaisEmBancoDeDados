# %% [markdown]
# # Redes Neurais

# %% [markdown]
# ## Neurolab

# %% [markdown]
# https://pythonhosted.org/neurolab/

# %% [markdown]
# https://code.google.com/archive/p/neurolab/

# %% [markdown]
# https://pypi.python.org/pypi/neurolab

# %%
#!pip install neurolab

# %%
import neurolab as nl
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Criando datasets de treino
x = np.linspace(-10,10, 60)
y = np.cos(x) * 0.9
size = len(x)
x_train = x.reshape(size,1)
y_train = y.reshape(size,1)

# %%
# ?nl.net.newff

# %%
# ?nl.train.train_gd

# %%
def gerar_rede_neural(num_camadas, camadas):
    net = nl.net.newff([[-10, 10]],camadas)
    train_net = nl.train.train_gd(net, x_train, y_train, epochs = 1000, show = 100)
    outp = net.sim(x_train)
    
    # Plot 
    plt.subplot(2, 1, 1)
    plt.plot(train_net)
    plt.xlabel('Epochs')
    plt.ylabel('Squared error')
    x2 = np.linspace(-10.0,10.0,150)
    y2 = net.sim(x2.reshape(x2.size,1)).reshape(x2.size)
    y3 = outp.reshape(size)
    plt.subplot(2, 1, 2)

    plt.suptitle([num_camadas ,'Camadas Ocultas'])
    plt.plot(x2, y2, '-',x , y, '.', x, y3, 'p')
    plt.legend(['Y previsto', 'Y observado'])
    plt.show()

# %% [markdown]
# ## Criando 4 redes com 0, 1, 2, e 3 camadas e randomizando a inicialização

# %%
d = [[1,1],[45,1],[45,45,1],[45,45,45,1]]
camadas = d[0]
num_camadas_ocultas = 0
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 12.647981800494856;
# Epoch: 200; Error: 12.647981800494856;
# Epoch: 300; Error: 12.647981800494856;
# Epoch: 400; Error: 12.647981800494856;
# Epoch: 500; Error: 12.647981800494856;
# Epoch: 600; Error: 12.647981800494856;
# Epoch: 700; Error: 12.647981800494856;
# Epoch: 800; Error: 12.647981800494856;
# Epoch: 900; Error: 12.647981800494856;
# Epoch: 1000; Error: 12.647981800494856;
# The maximum number of train epochs is reached

# %%
camadas = d[1]
num_camadas_ocultas = 1
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 2.5108493358156116;
# Epoch: 200; Error: 1.3897306290792573;
# Epoch: 300; Error: 0.9844946848810888;
# Epoch: 400; Error: 1.7243065705153857;
# Epoch: 500; Error: 0.9207066578277867;
# Epoch: 600; Error: 2.1448774396948456;
# Epoch: 700; Error: 1.9392544244701124;
# Epoch: 800; Error: 4.985802010905254;
# Epoch: 900; Error: 5.045681039561211;
# Epoch: 1000; Error: 1.6850572237571997;
# The maximum number of train epochs is reached

# %%
camadas = d[2]
num_camadas_ocultas = 2
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 1.8835527827938874;
# Epoch: 200; Error: 0.9267956220597725;
# Epoch: 300; Error: 0.7594219744493798;
# Epoch: 400; Error: 1.6307725730593732;
# Epoch: 500; Error: 0.6223135111747159;
# Epoch: 600; Error: 0.4238403744904352;
# Epoch: 700; Error: 0.47563627199742414;
# Epoch: 800; Error: 0.4002260533094808;
# Epoch: 900; Error: 0.2114344129014976;
# Epoch: 1000; Error: 0.23641822592863046;
# The maximum number of train epochs is reached

# %%
camadas = d[3]
num_camadas_ocultas = 3
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 0.29515490258378274;
# Epoch: 200; Error: 0.6878088151707122;
# Epoch: 300; Error: 0.2115730288528892;
# Epoch: 400; Error: 0.15604965949460892;
# Epoch: 500; Error: 0.15181820347562364;
# Epoch: 600; Error: 0.04550573275871483;
# Epoch: 700; Error: 0.07314094963017764;
# Epoch: 800; Error: 0.02763519734556777;
# Epoch: 900; Error: 0.03394097462220715;
# Epoch: 1000; Error: 0.03496326407505142;
# The maximum number of train epochs is reached

# %% [markdown]
# ---
