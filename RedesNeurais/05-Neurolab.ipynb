# %% [markdown]
# # Redes Neurais

# %% [markdown]
# ## Neurolab

# %% [markdown]
# https://pythonhosted.org/neurolab/

# %% [markdown]
# https://code.google.com/archive/p/neurolab/

# %% [markdown]
# https://pypi.python.org/pypi/neurolab

# %%
#!pip install neurolab

# %%
import neurolab as nl
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Criando datasets de treino
x = np.linspace(-10,10, 60)
y = np.cos(x) * 0.9
size = len(x)
x_train = x.reshape(size,1)
y_train = y.reshape(size,1)

# %%
# ?nl.net.newff

# %%
# ?nl.train.train_gd

# %%
def gerar_rede_neural(num_camadas, camadas):
    net = nl.net.newff([[-10, 10]],camadas)
    train_net = nl.train.train_gd(net, x_train, y_train, epochs = 1000, show = 100)
    outp = net.sim(x_train)
    
    # Plot 
    plt.subplot(2, 1, 1)
    plt.plot(train_net)
    plt.xlabel('Epochs')
    plt.ylabel('Squared error')
    x2 = np.linspace(-10.0,10.0,150)
    y2 = net.sim(x2.reshape(x2.size,1)).reshape(x2.size)
    y3 = outp.reshape(size)
    plt.subplot(2, 1, 2)

    plt.suptitle([num_camadas ,'Camadas Ocultas'])
    plt.plot(x2, y2, '-',x , y, '.', x, y3, 'p')
    plt.legend(['Y previsto', 'Y observado'])
    plt.show()

# %% [markdown]
# ## Criando 4 redes com 0, 1, 2, e 3 camadas e randomizando a inicialização

# %%
d = [[1,1],[45,1],[45,45,1],[45,45,45,1]]
camadas = d[0]
num_camadas_ocultas = 0
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 12.647981800494856;
# Epoch: 200; Error: 12.647981800494856;
# Epoch: 300; Error: 12.647981800494856;
# Epoch: 400; Error: 12.647981800494856;
# Epoch: 500; Error: 12.647981800494856;
# Epoch: 600; Error: 12.647981800494856;
# Epoch: 700; Error: 12.647981800494856;
# Epoch: 800; Error: 12.647981800494856;
# Epoch: 900; Error: 12.647981800494856;
# Epoch: 1000; Error: 12.647981800494856;
# The maximum number of train epochs is reached

# %%
camadas = d[1]
num_camadas_ocultas = 1
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 1.0483208723410775;
# Epoch: 200; Error: 1.3810208853794916;
# Epoch: 300; Error: 2.321098195769998;
# Epoch: 400; Error: 1.061809616368253;
# Epoch: 500; Error: 2.521199758798342;
# Epoch: 600; Error: 2.028963971787265;
# Epoch: 700; Error: 0.8382334055667494;
# Epoch: 800; Error: 5.821727397371747;
# Epoch: 900; Error: 3.071743818740513;
# Epoch: 1000; Error: 0.886875711102179;
# The maximum number of train epochs is reached

# %%
camadas = d[2]
num_camadas_ocultas = 2
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 3.5281015271361515;
# Epoch: 200; Error: 0.41373353977358884;
# Epoch: 300; Error: 1.3515615224991047;
# Epoch: 400; Error: 0.8591699159096028;
# Epoch: 500; Error: 0.40740917093029305;
# Epoch: 600; Error: 0.4684904467174042;
# Epoch: 700; Error: 0.3771993727520498;
# Epoch: 800; Error: 0.2867724603471464;
# Epoch: 900; Error: 0.257978567288308;
# Epoch: 1000; Error: 0.15629900887670667;
# The maximum number of train epochs is reached

# %%
camadas = d[3]
num_camadas_ocultas = 3
gerar_rede_neural(num_camadas_ocultas, camadas)
# Out:
# Epoch: 100; Error: 2.6437341694929897;
# Epoch: 200; Error: 0.34577684795502733;
# Epoch: 300; Error: 0.20848058578299472;
# Epoch: 400; Error: 0.19312172252303236;
# Epoch: 500; Error: 0.12071709467620013;
# Epoch: 600; Error: 0.041930190373094874;
# Epoch: 700; Error: 0.04796098332035554;
# Epoch: 800; Error: 0.03871850410013994;
# Epoch: 900; Error: 0.02503444571549844;
# Epoch: 1000; Error: 0.017199870254959608;
# The maximum number of train epochs is reached

# %% [markdown]
# ---
