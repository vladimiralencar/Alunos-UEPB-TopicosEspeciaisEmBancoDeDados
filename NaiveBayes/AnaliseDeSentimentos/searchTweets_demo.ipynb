# %% [markdown]
# ## Demo de Busca com Twiiter

# %%
#!pip install twitter

# %%
# -*- coding: UTF-8 -*-
import twitter


CONSUMER_KEY = '7Q5yEwrYLAUkYLXna0ZGTfefD'
CONSUMER_SECRET = '5A1xx6c0wvIqZFgF6kn0bPAfPo7ERhXgAslBJeKZ66JPVY10uc'
OAUTH_TOKEN = '2904474861-SuqqjBrphTNAI1rGHAecrQf5wT4ByauhEKjPdXC'
OAUTH_TOKEN_SECRET = 'YKXb7UjHUiLAZ04r6KOTjm9s6lrx7GZcRGA9fqJTPxMHw'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# 

WORLD_WOE_ID = 1
US_WOE_ID = 23424977
BR_WOE_ID = 23424768 # ("Brazil" - Country)
CG_WOE_ID=12580269 # Campina Grande
PB_WO_ID= 2344858 # Paraiba 

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
br_trends = twitter_api.trends.place(_id=BR_WOE_ID)
pb_trends = twitter_api.trends.place(_id=BR_WOE_ID)
cg_trends = twitter_api.trends.place(_id=BR_WOE_ID)

pb_trends_set = set([trend['name'] 
                        for trend in pb_trends[0]['trends']])

cg_trends_set = set([trend['name'] 
                        for trend in cg_trends[0]['trends']])


world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 


br_trends_set = set([trend['name'] 
                     for trend in br_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)


# print world_trends_set
# print us_trends_set

#f = open('trends10.txt', 'w+')

print 
print ("------------------------------")
print ("Top 20 World Trends")

#f.writelines("Top 20 World Trends")

for i in range(0,20) :
    #s = str(i+1) + ": " +  world_trends_set.pop()
    print   (i+1, ": " , world_trends_set.pop())
    #f.writelines(s)

print 
print ("------------------------------")
print ("Top 20 Brazil Trends")

for i in range(0,20) :
    print (i+1, ": " , br_trends_set.pop())

print ("------------------------------")
print ("Top 20 Paraiba-Brazil Trends")

for i in range(0,20) :
    print (i+1, ": " , pb_trends_set.pop())
    
print ("------------------------------")
print ("Top 10 Campina Grande-Paraiba-Brazil Trends")

for i in range(0,10) :
    print (i+1, ": " , cg_trends_set.pop())


#f.close()
# Out:
# ------------------------------
# Top 20 World Trends
# 1 :  #حراك_ال_مره_في_قطر
# 2 :  #Winx
# 3 :  #さいとー家結婚式
# 4 :  Emilia Pardo Bazán
# 5 :  #saturdaymorning
# 6 :  #FRENZ_JP
# 7 :  #TarıkAkan
# 8 :  #نقل_كليه_الاقتصاد
# 9 :  #GareebKalyanMela
# 10 :  友軍艦隊
# 11 :  #My4WordTurnOn
# 12 :  #USMuslimDialogue
# 13 :  #GloboNoRock
# 14 :  #لله_در_الشعب_لقنهم_الدرس
# 15 :  #ReadyForCAPTUR
# 16 :  Viva México
# 17 :  #niunamas
# 18 :  #KoreaSS
# 19 :  #كلمه_حق_في_السعوديه
# 20 :  #ExplainTVShowsBadly
# ------------------------------
# Top 20 Brazil Trends
# 1 :  NICOLE ATÉ O FIM
# 2 :  #TooMuchToAsk
# 3 :  Marcelo Rezende
# 4 :  #GloboNoRock
# 5 :  #FIVBMensGCC
# 6 :  Vanderlei
# 7 :  #oquemefazrir
# 8 :  QUE NOITE
# 9 :  Bowie
# 10 :  #GoodLuckShawn
# 11 :  #copadoscampeoes
# 12 :  #DepoisDas11NoRIR
# 13 :  Baia
# 14 :  UNIDOS POR MARCOS HARTER
# 15 :  #AusvsBra
# 16 :  #sextou
# 17 :  #DiaDoCliente
# 18 :  SOPHIA JOVEM DO ANO
# 19 :  Gisele
# 20 :  Minerato
# ------------------------------
# Top 20 Paraiba-Brazil Trends
# 1 :  NICOLE ATÉ O FIM
# 2 :  #TooMuchToAsk
# 3 :  Marcelo Rezende
# 4 :  #GloboNoRock
# 5 :  #FIVBMensGCC
# 6 :  Vanderlei
# 7 :  #oquemefazrir
# 8 :  QUE NOITE
# 9 :  Bowie
# 10 :  #GoodLuckShawn
# 11 :  #copadoscampeoes
# 12 :  #DepoisDas11NoRIR
# 13 :  Baia
# 14 :  UNIDOS POR MARCOS HARTER
# 15 :  #AusvsBra
# 16 :  #sextou
# 17 :  #DiaDoCliente
# 18 :  SOPHIA JOVEM DO ANO
# 19 :  Gisele
# 20 :  Minerato
# ------------------------------
# Top 10 Campina Grande-Paraiba-Brazil Trends
# 1 :  NICOLE ATÉ O FIM
# 2 :  #TooMuchToAsk
# 3 :  Marcelo Rezende
# 4 :  #GloboNoRock
# 5 :  #FIVBMensGCC
# 6 :  Vanderlei
# 7 :  #oquemefazrir
# 8 :  QUE NOITE
# 9 :  Bowie
# 10 :  #GoodLuckShawn

# %%
# procurar por termos

# %%
#!pip install twitter

# %%
from twitter import *
query = twitter_api.search.tweets(q = "North Korea")

#-----------------------------------------------------------------------
# Tempo da query
#-----------------------------------------------------------------------
print ("Search complete (%.3f seconds)" % (query["search_metadata"]["completed_in"]))

#-----------------------------------------------------------------------
# Loop dos resultados
#-----------------------------------------------------------------------
for result in query["statuses"]:
    print ("(%s) @%s %s" % (result["created_at"], result["user"]["screen_name"], result["text"]))
# Out:
# Search complete (0.048 seconds)
# (Sat Sep 16 08:04:02 +0000 2017) @LumpyAsia Mattis' message: US is not intimidated by North Korea  https://t.co/G7LRYL4tit via @WTOP https://t.co/LvmWavrHD5
# (Sat Sep 16 08:03:57 +0000 2017) @TooDistantLover WOW, you are all up in North Korea business while "police state" oppression, aggression, and killing is rampant in… https://t.co/9S0blLSf9z
# (Sat Sep 16 08:03:47 +0000 2017) @JessicaDexter5 RT @BBCBreaking: North Korea fires missile from Pyongyang, media reports say, as Japan warns residents to take shelter https://t.co/zz4T3yb…
# (Sat Sep 16 08:03:45 +0000 2017) @basalmeida Washington should switch from threats to dialogue on North Korea – Chinese envoy to US https://t.co/puXw3QaQmZ
# (Sat Sep 16 08:03:39 +0000 2017) @Wakye4Wakye RT @naoyafujiwara: JアラートではなくてAアラート＝安倍アラート。
#
# 朝7時の安倍チャンネル＝NHKニュースは安倍アラートから始まります（大笑）。
#
# 北朝鮮がミサイル発射、北海道上空から太平洋へ　Jアラートが発動
#
# https://t.co/dx29drHpqo
# (Sat Sep 16 08:03:38 +0000 2017) @MD_87_90 RT @MD_87_90: @nytimes Shinzo Abe only wants to reform the Constitution of #Japan by stoking anxiety over #North #Korea. It is clear that i…
# (Sat Sep 16 08:03:38 +0000 2017) @__gracemartin RT @JTSHEEPS35: Love how America is dealing with 3 hurricanes North Korea is on the brink of war yet the UK is stressing over which flavour…
# (Sat Sep 16 08:03:36 +0000 2017) @MD_87_90 RT @nytimes: Why doesn’t Japan shoot down North Korea’s missiles? It’s constrained by its Constitution and its capabilities. https://t.co/U…
# (Sat Sep 16 08:03:32 +0000 2017) @seminalahoor RT @kaveh20092009: How #Iran Is More Dangerous Than North Korea via @forbes https://t.co/ap7C49OZDh
# #IranDeal

# %%
query = twitter_api.search.tweets(q = "febre amarela", result_type='recent', lang='pt', count=200)

#-----------------------------------------------------------------------
# Tempo da query
#-----------------------------------------------------------------------
print ("Search complete (%.3f seconds)" % (query["search_metadata"]["completed_in"]))

#-----------------------------------------------------------------------
# Loop dos resultados
#-----------------------------------------------------------------------
for result in query["statuses"]:
    print ("(%s) @%s %s" % (result["created_at"], result["user"]["screen_name"], result["text"]))
# Out:
# Search complete (0.071 seconds)
# (Sat Sep 16 02:22:05 +0000 2017) @pantzcarol RT @agencia_fiocruz: Estudo da @fiocruz avalia duração de imunidade de vacina para #febreamarela https://t.co/4wWif589Ie https://t.co/vIhEq…
# (Sat Sep 16 00:37:40 +0000 2017) @paolamendess_ Dps que tomei vacina da febre amarela minha amigdalite nunca mais atacou, obrigada Deus
# (Sat Sep 16 00:33:11 +0000 2017) @PareciaMasNfoi @OPratesDaNora Febre da amarela
# (Sat Sep 16 00:17:12 +0000 2017) @Alinemedeiros1 RT @carloseduardo12: Também disponíveis vacinas para febre amarela , DTP, hepatite A, antitetânica, dTpa e HPV. Não deixem de levar seus fi…
# (Fri Sep 15 21:27:18 +0000 2017) @mrvieira19 RT @revistasaude: Não é só com a febre amarela que você deve se preocupar! https://t.co/DRFNiYR4rY
# (Fri Sep 15 20:57:51 +0000 2017) @kekaenf Mães com idade de 15 a 26 anos amamentando podem tomar a vacina contra Hpv...mas nao podem tomar contra febre amarela...ok
# (Fri Sep 15 20:41:57 +0000 2017) @cidadedejundiai Amanhã é dia de multivacinação Apesar do desconforto é a maneira de prevenir muitas doenças, inclusive febre amarela https://t.co/TtqsjS8gtD
# (Wed Sep 13 22:02:51 +0000 2017) @enfermagemnovid Febre Amarela - Transmissão, Tratamento e Prevenção https://t.co/pakBDrToFL #relacionadosàsaúde
# (Wed Sep 13 21:52:45 +0000 2017) @obhennig Trocando de canais e febre amarela #SupernaturalDay https://t.co/vMSByw20HA
# (Wed Sep 13 21:45:32 +0000 2017) @lovepornsites Febre amarela: Governo federal reconhece situação de emergência em cidades mineiras https://t.co/VMko1qp4uk https://t.co/yc0AYTZRXN
# (Wed Sep 13 21:41:25 +0000 2017) @Houis_Love @HuntersPlantao Fico em descisa entre febre amarela e acho q "um dia de cão " #SupernaturalDay
# (Wed Sep 13 21:38:28 +0000 2017) @thesteeph @HuntersPlantao febre amarela, pé de coelho.. #SupernaturalDay
# (Wed Sep 13 21:23:51 +0000 2017) @tatimrqs Descobri que meu plano de saúde cobre vacina de febre amarela em clínica particular, já tomei já tenho o certificado internacional 🙌🏻
# (Wed Sep 13 21:13:53 +0000 2017) @ThasBertonceli1 Minha mãe não para d falar no meu ouvido, só pq eu não quis tomar a vacina da febre amarela
# (Wed Sep 13 21:13:09 +0000 2017) @bunkibum A epidemia de cólera em Lisboa acabou em novembro de 1856 só para depois surgir a febre amarela em agosto do ano a seguir rip
# (Wed Sep 13 21:10:15 +0000 2017) @demil5605 RT @coelhoko: Twitter, o único vacinado contra a febre Amarela https://t.co/cvpSnpw2OK
# (Wed Sep 13 20:46:57 +0000 2017) @cczniteroirj RT @saudeniteroi: Febre Amarela: já se vacinou? Niterói tem ainda + de 130 mil doses disponíveis p/ vacinação. De seg a sex, 8h às 16h http…
# (Wed Sep 13 19:47:51 +0000 2017) @VIPIMUNE Isabella Ballalai, presidente da Sbim Nacional, esclarece dúvidas quanto ao esquema de vacinação contra Febre... https://t.co/bwxqMHQBWI
# (Wed Sep 13 19:18:12 +0000 2017) @thaiismaarques Pra ir pra festinha da minha best @OnePretender tomei até a vacina da febre amarela! So um tsunami pra n me fazer ir mesmo. Bjss amg❤️
# (Wed Sep 13 19:11:00 +0000 2017) @CarvalhoNylza Vacina da febre amarela não foi nadinha, agora da HPV.... Meu irmão.......
# (Wed Sep 13 18:55:55 +0000 2017) @PHortolandia UBS Nova Hortolândia terá doses contra Febre Amarela, neste sábado (16/09) https://t.co/yYzrgFWyte
# (Wed Sep 13 18:14:01 +0000 2017) @MartynnaAstolfi Fiz a vacina da febre amarela, que dorzinha chata
# (Wed Sep 13 18:07:21 +0000 2017) @sadbriann Estudar na UFRJ é louco, tava andando pelo CCS e ganhei uma injeção de febre amarela ????
# (Wed Sep 13 17:27:27 +0000 2017) @jpavanello Tomei vacina da febre amarela e fiquei 3 dias com dor muscular... hj é que to bem... #PQP
# (Wed Sep 13 16:53:28 +0000 2017) @CarvalhoNylza Vou pro curso mal desse jeito e ainda vou ter que tomar vacina da febre amarela 😩🖕🏻
# (Wed Sep 13 15:56:05 +0000 2017) @oxentecami Tomei vacina de HPV e meu braço ta doendo demais!!! Por que da febre amarela não doeu? 🤦🏻‍♀️
# (Wed Sep 13 15:44:54 +0000 2017) @Wildlovatika Sempre quando tem ação social e tem a vacina da febre amarela eu tô resfriada INFERNOOOOOOOOOOOO
# (Wed Sep 13 15:44:07 +0000 2017) @SPVirologia Na última década assistimos a uma emergência sem precedentes de epidemias causadas por arbovirus: Febre Amarela em Angola, Zika no Brasil
# (Wed Sep 13 15:38:23 +0000 2017) @_Strawberrybull Que tristeza, tomei uma antitetânica e uma vacina pra febre amarela, não doeu, mas eu chorei tanto, fazia tempo q não ficava tão nervouser

# %%
#query = twitter_api.search.tweets(q = "", result_type='recent', lang='pt', count=20)

query = twitter_api.search.tweets(q = "north korea", result_type='recent', lang='pt', count=50)

#-----------------------------------------------------------------------
# Tempo da query
#-----------------------------------------------------------------------
print ("Search complete (%.3f seconds)" % (query["search_metadata"]["completed_in"]))

#-----------------------------------------------------------------------
# Loop dos resultados
#-----------------------------------------------------------------------
for result in query["statuses"]:
    print ("(%s) @%s %s" % (result["created_at"], result["user"]["screen_name"], result["text"]))
# Out:
# Search complete (0.197 seconds)
# (Sat Sep 16 05:09:37 +0000 2017) @GAZETAdoBRASIL1 Olha só  o que tem de regalo a ser dado por Tio Sam ao gorducho idiota da North Korea !A China agradecerá e incorpo… https://t.co/jwT7uYBhyM
# (Sat Sep 16 01:30:00 +0000 2017) @VICEBRASIL Guia VICE para a Coreia do Norte.
# https://t.co/vppKiNC5Zg https://t.co/AfukRmUxop
# (Sat Sep 16 00:25:32 +0000 2017) @andreaugfonseca RT @ThiagoKrause2: A Coreia do Norte parece ser o mais próximo que a realidade já chegou de 1984. Terrível.
# https://t.co/z6gZRE6wqk
# (Fri Sep 15 23:15:05 +0000 2017) @Econom_Digital Coreia do Norte pode driblar sanções da ONU com Bitcoin: Opinião - Cointelegraph (Notícias Bitcoin &amp; Ethereum…… https://t.co/hBhw7Yms7u
# (Fri Sep 15 21:58:11 +0000 2017) @StoneGearYT Gostei de um vídeo @YouTube https://t.co/YKWlZTaD4V North Korea !!! Coreia do Norte lança míssil sobre o Japão e desafia
# (Fri Sep 15 19:32:30 +0000 2017) @psi_14 https://t.co/aWgSMkd26B Esperem, vocês querem ver que é o Dennis Rodman que vai salvar o planeta!!?
# (Fri Sep 15 18:12:31 +0000 2017) @MicaelFFerreira TERCEIRA GUERRA MUNDIAL EMINENTE!
# Mais num míssil foi lançado hoje pelo ditador COMUNISTA da Coreia do Norte em... https://t.co/zkhoowCz7A
# (Fri Sep 15 17:17:03 +0000 2017) @oliveiraEdeson RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 16:27:03 +0000 2017) @RenanBTC Coreia do Norte pode driblar sanções da ONU com Bitcoin: Opinião https://t.co/C4Le3mrmrt #Bitcoin_Regulation… https://t.co/GzaC5Mn1hc
# (Fri Sep 15 15:45:04 +0000 2017) @Rodrickkkkkkkk RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 15:28:50 +0000 2017) @marciasuian falei north korea para o meu tweet ficar mais chique
# (Fri Sep 15 15:28:27 +0000 2017) @marciasuian alguém stop a north korea
# (Fri Sep 15 14:58:07 +0000 2017) @PPericlesgmf RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 14:57:47 +0000 2017) @Ramblin007 Opp o pp p https://t.co/r1AMDOCGsz
# (Fri Sep 15 14:41:20 +0000 2017) @LakeEmerald1 RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 14:23:50 +0000 2017) @felipettZ017 RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 14:21:20 +0000 2017) @httpiuri RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 14:19:43 +0000 2017) @chicodocentro RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 14:17:25 +0000 2017) @ricanani RT @PolitzOficial: Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# http…
# (Fri Sep 15 14:16:38 +0000 2017) @PolitzOficial Coreia do Sul ameaça destruir a do Norte:
#
# "Podemos destruir tanto o país que será impossível eles se recuperarem"
#
# https://t.co/IvZk3eY3N9
# (Fri Sep 15 13:16:09 +0000 2017) @luciaguimaraes Comando e controle.
# Assustador exame da Coreia do Norte, onde só Kim-que teme ajuda externa a golpe-aperta o botão.
# https://t.co/dtiKVZwpdw
# (Fri Sep 15 11:02:10 +0000 2017) @akikorossella Ahia https://t.co/bDzpwr0igh
# (Fri Sep 15 09:03:01 +0000 2017) @rldigital RT @StellaMendonca: "Ñ estamos olhando aniquilação total, a saber, Coréia do Norte. Mas, c\ disse, temos opções p\ fazê-lo ":Jim Mattis htt…
# (Fri Sep 15 09:00:08 +0000 2017) @StellaMendonca "Ñ estamos olhando aniquilação total, a saber, Coréia do Norte. Mas, c\ disse, temos opções p\ fazê-lo ":Jim Mattis https://t.co/jMOUDRYKrG
# (Fri Sep 15 08:02:34 +0000 2017) @Zonavelha Gostei de um vídeo do @YouTube https://t.co/MW5QQjrrAi North Korea fires ballistic missile over Japan
# (Thu Sep 14 23:09:18 +0000 2017) @LanceLibra A Coreia do Norte lançou há poucas horas atrás, mais um "iPhone" e mais uma vez teve como plateia do evento... https://t.co/JWG2w2b1Wp
# (Thu Sep 14 23:06:28 +0000 2017) @supra1Bqteam PolticsNewz: #NorthKorea 'fires unidentified missile' https://t.co/dR86ljkN5M https://t.co/ifwIKPS7F4
# (Thu Sep 14 22:57:50 +0000 2017) @RicardoPF Esse gordinho coreano tá doido para fazer uma cagada...
#
# North Korea Launches Another Missile, Escalating Crisis https://t.co/8zpR1SsZfE
# (Thu Sep 14 22:50:11 +0000 2017) @marinainflames olha o míssiiiiiiiiiil
#
# aaaaaaaaaaah!!!!!!
#
# é mentiraaaaaaaaaa
#
# aaaaaaaaaaah...
#
# https://t.co/DXUm7Vn6gg
# (Thu Sep 14 22:48:14 +0000 2017) @honeyykim o ditador da north korea ameaçou o japão e já começou com os mísseis lá
# esse desgraçado também ameaçou seul e os eu… https://t.co/LAEyd2e5R3
# (Thu Sep 14 22:47:00 +0000 2017) @supra1Bqteam PolticsNewz: #NorthKorea 'fires unidentified missile' https://t.co/dR86ljkN5M https://t.co/VnHmr0eWWo
# (Thu Sep 14 22:42:07 +0000 2017) @nobrejoao Brasil: "lady gaga cancela show no Rock in Rio"
#
# North Korea: hmm, segura aqui meu drink
# (Thu Sep 14 22:37:29 +0000 2017) @Paraymo1 As ações desse louco vão terminar em guerra.
# https://t.co/rQcD97kFsB

# %%
len(query['statuses'])
# Out:
# 50

# %%
print(query["statuses"][0])

# %%
query

# %%
type(query.keys)

# %%
query.popitem()

# %%
query.values()

# %% [markdown]
# # Análise de Sentimentos

# %%
def sentiment_analysis(query):
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query, count = 1000)
    
    print("Análise de Sentimentos: ", query)
 
    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positivo tweets: {0:.0f} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    
    # picking neutral tweets from tweets
    neutraltweets = [tweet for tweet in tweets if tweet['sentiment'] == 'neutral']
    
    # percentage of negative tweets
    print("Negativo tweets: {0:.0f} % ".format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    print("Neutros tweets: {0:.0f} % ".format(100* (len(tweets) - len(ntweets) - len(ptweets)) /len(tweets)))
 
    # printing first 5 positive tweets
    print("\n\nPositivos tweets:")
    for tweet in ptweets[:10]:
        print(tweet['text'])
 
    # printing first 5 negative tweets
    print("\n\nNegativos tweets:")
    for tweet in ntweets[:10]:
        print(tweet['text'])
        
    # printing first 5 neutral tweets
    print("\n\nNeutros tweets:")
    for tweet in neutraltweets[:10]:
        print(tweet['text'])
        
    return ptweets, ntweets, neutraltweets
