# %% [markdown]
# # Vetorização de palavras

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()
data_corpus = ["carro ótimo", 
               "Julia tem um carro",
               "carro carro bom ótimo"]
X = vectorizer.fit_transform(data_corpus) 
print(X.toarray())
print(vectorizer.get_feature_names())
# Out:
# [[0 1 0 0 0 1]
#  [0 1 1 1 1 0]
#  [1 2 0 0 0 1]]
# ['bom', 'carro', 'julia', 'tem', 'um', 'ótimo']

# %%
txt = vectorizer.inverse_transform(X)
fo
print (txt)
# Out:
# [array(['carro', 'ótimo'], dtype='<U5'), array(['carro', 'julia', 'tem', 'um'], dtype='<U5'), array(['carro', 'ótimo', 'bom'], dtype='<U5')]
