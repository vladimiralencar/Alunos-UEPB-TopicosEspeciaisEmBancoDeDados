# %% [markdown]
# ### Aula-04-17-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Noite

# %% [markdown]
# # DataFrames - Estatística Descritiva

# %%
url = 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/datasets/covid19-Agosto-2021.csv'
url
# Out:
# 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/datasets/covid19-Agosto-2021.csv'

# %% [markdown]
# ## Dados Covid Referentes ao dia 11-Agosto-2021

# %%
import pandas as pd

# %%
df = pd.read_csv(url)
print(len(df))
df.head()
# Out:
# 5616
#    epidemiological_week        date  order_for_place state          city  \
# 0                202132  2021-08-11              501    AC    Acrelândia
# 1                202132  2021-08-11              468    AC  Assis Brasil
# 2                202132  2021-08-11              460    AC     Brasiléia
# 3                202132  2021-08-11              491    AC        Bujari
# 4                202132  2021-08-11              461    AC      Capixaba
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       1200013.0       city                      1772
# 1       1200054.0       city                      1793
# 2       1200104.0       city                      2975
# 3       1200138.0       city                      1139
# 4       1200179.0       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                    11439.63848              0
# ...

# %%
df.columns
# Out:
# Index(['epidemiological_week', 'date', 'order_for_place', 'state', 'city',
#        'city_ibge_code', 'place_type', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated'],
#       dtype='object')

# %%
atributos = df.columns
atributos
# Out:
# Index(['epidemiological_week', 'date', 'order_for_place', 'state', 'city',
#        'city_ibge_code', 'place_type', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated'],
#       dtype='object')

# %%
df = df [ atributos[3:-2]  ]
df.head()
# Out:
#   state          city  city_ibge_code place_type  last_available_confirmed  \
# 0    AC    Acrelândia       1200013.0       city                      1772
# 1    AC  Assis Brasil       1200054.0       city                      1793
# 2    AC     Brasiléia       1200104.0       city                      2975
# 3    AC        Bujari       1200138.0       city                      1139
# 4    AC      Capixaba       1200179.0       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                    11439.63848              0
# 1                                    23798.77887              0
# 2                                    11141.48753              0
# 3                                    10930.90211              0
# 4                                     5604.59694              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5616 entries, 0 to 5615
# Data columns (total 11 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   state                                          5616 non-null   object
#  1   city                                           5589 non-null   object
#  2   city_ibge_code                                 5597 non-null   float64
#  3   place_type                                     5616 non-null   object
#  4   last_available_confirmed                       5616 non-null   int64
#  5   last_available_confirmed_per_100k_inhabitants  5597 non-null   float64
#  6   new_confirmed                                  5616 non-null   int64
#  7   last_available_deaths                          5616 non-null   int64
#  8   new_deaths                                     5616 non-null   int64
# ...

# %%
df.head()
# Out:
#   state          city  city_ibge_code place_type  last_available_confirmed  \
# 0    AC    Acrelândia       1200013.0       city                      1772
# 1    AC  Assis Brasil       1200054.0       city                      1793
# 2    AC     Brasiléia       1200104.0       city                      2975
# 3    AC        Bujari       1200138.0       city                      1139
# 4    AC      Capixaba       1200179.0       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                    11439.63848              0
# 1                                    23798.77887              0
# 2                                    11141.48753              0
# 3                                    10930.90211              0
# 4                                     5604.59694              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# ...

# %%
df.place_type.unique()
# Out:
# array(['city', 'state'], dtype=object)

# %%
dfe = df[ df.place_type == 'state'].reset_index(drop=True)
dfe
# Out:
#    state city  city_ibge_code place_type  last_available_confirmed  \
# 0     AC  NaN            12.0      state                     87468
# 1     AL  NaN            27.0      state                    232128
# 2     AM  NaN            13.0      state                    420524
# 3     AP  NaN            16.0      state                    121868
# 4     BA  NaN            29.0      state                   1205316
# 5     CE  NaN            23.0      state                    924654
# 6     DF  NaN            53.0      state                    456791
# 7     ES  NaN            32.0      state                    548895
# 8     GO  NaN            52.0      state                    771414
# 9     MA  NaN            21.0      state                    341669
# 10    MG  NaN            31.0      state                   2007665
# 11    MS  NaN            50.0      state                    361313
# 12    MT  NaN            51.0      state                    501972
# ...

# %%
del dfe['city']

# %%
del dfe['place_type']

# %%
dfe
# Out:
#    state  city_ibge_code  last_available_confirmed  \
# 0     AC            12.0                     87468
# 1     AL            27.0                    232128
# 2     AM            13.0                    420524
# 3     AP            16.0                    121868
# 4     BA            29.0                   1205316
# 5     CE            23.0                    924654
# 6     DF            53.0                    456791
# 7     ES            32.0                    548895
# 8     GO            52.0                    771414
# 9     MA            21.0                    341669
# 10    MG            31.0                   2007665
# 11    MS            50.0                    361313
# 12    MT            51.0                    501972
# 13    PA            15.0                    576949
# 14    PB            25.0                    426198
# 15    PE            26.0                    597338
# 16    PI            22.0                    312661
# ...

# %%
dfe.to_csv('covid_estados_12_ago_2021.csv', index=False)

# %%
# !cat covid_estados_12_ago_2021.csv
# Out:
# state,city_ibge_code,last_available_confirmed,last_available_confirmed_per_100k_inhabitants,new_confirmed,last_available_deaths,new_deaths,last_available_death_rate,estimated_population
# AC,12.0,87468,9778.75166,45,1805,1,0.0206,894470.0
# AL,27.0,232128,6926.00393,208,5923,9,0.0255,3351543.0
# AM,13.0,420524,9994.12032,350,13605,9,0.0324,4207714.0
# AP,16.0,121868,14141.54307,44,1931,1,0.0158,861773.0
# BA,29.0,1205316,8072.7717299999995,1040,26046,23,0.0216,14930634.0
# CE,23.0,924654,10064.69613,592,23775,34,0.0257,9187103.0
# DF,53.0,456791,14951.513,662,9772,12,0.0214,3055149.0
# ES,32.0,548895,13506.10179,789,12019,13,0.0219,4064052.0
# GO,52.0,771414,10844.30537,2848,21584,73,0.027999999999999997,7113540.0
# MA,21.0,341669,4802.3655,589,9783,17,0.0286,7114598.0
# MG,31.0,2007665,9428.90383,4654,51502,140,0.0257,21292666.0
# MS,50.0,361313,12860.88744,0,9113,0,0.0252,2809394.0
# MT,51.0,501972,14235.413559999999,1432,13087,31,0.0261,3526220.0
# ...

# %%
dfe.head()
# Out:
#   state  city_ibge_code  last_available_confirmed  \
# 0    AC            12.0                     87468
# 1    AL            27.0                    232128
# 2    AM            13.0                    420524
# 3    AP            16.0                    121868
# 4    BA            29.0                   1205316
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                     9778.75166             45
# 1                                     6926.00393            208
# 2                                     9994.12032            350
# 3                                    14141.54307             44
# 4                                     8072.77173           1040
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   1805           1                     0.0206
# 1                   5923           9                     0.0255
# 2                  13605           9                     0.0324
# ...

# %%
dfe.sort_values(by='last_available_confirmed', ascending=False)
# Out:
#    state  city_ibge_code  last_available_confirmed  \
# 25    SP            35.0                   4138421
# 10    MG            31.0                   2007665
# 17    PR            41.0                   1407021
# 22    RS            43.0                   1385669
# 4     BA            29.0                   1205316
# 23    SC            42.0                   1128471
# 18    RJ            33.0                   1067809
# 5     CE            23.0                    924654
# 8     GO            52.0                    771414
# 15    PE            26.0                    597338
# 13    PA            15.0                    576949
# 7     ES            32.0                    548895
# 12    MT            51.0                    501972
# 6     DF            53.0                    456791
# 14    PB            25.0                    426198
# 2     AM            13.0                    420524
# 19    RN            24.0                    361518
# ...

# %%
ds = dfe.sort_values(by='last_available_confirmed', ascending=False)
ds.head()
# Out:
#    state  city_ibge_code  last_available_confirmed  \
# 25    SP            35.0                   4138421
# 10    MG            31.0                   2007665
# 17    PR            41.0                   1407021
# 22    RS            43.0                   1385669
# 4     BA            29.0                   1205316
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 25                                     8940.33405           8701
# 10                                     9428.90383           4654
# 17                                    12217.07517           2117
# 22                                    12130.54605           1815
# 4                                      8072.77173           1040
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 25                 141664         387                     0.0342
# 10                  51502         140                     0.0257
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

sns.barplot(x='last_available_confirmed', y='state', data=ds)
# Out:
# <AxesSubplot:xlabel='last_available_confirmed', ylabel='state'>

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='last_available_confirmed', y='state', data=ds, palette='Oranges_r')
# Out:
# <AxesSubplot:xlabel='last_available_confirmed', ylabel='state'>

# %%
dfe.head()
# Out:
#   state  city_ibge_code  last_available_confirmed  \
# 0    AC            12.0                     87468
# 1    AL            27.0                    232128
# 2    AM            13.0                    420524
# 3    AP            16.0                    121868
# 4    BA            29.0                   1205316
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                     9778.75166             45
# 1                                     6926.00393            208
# 2                                     9994.12032            350
# 3                                    14141.54307             44
# 4                                     8072.77173           1040
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   1805           1                     0.0206
# 1                   5923           9                     0.0255
# 2                  13605           9                     0.0324
# ...

# %%
ds = dfe.sort_values(by='last_available_deaths', ascending=False)
ds.head()
# Out:
#    state  city_ibge_code  last_available_confirmed  \
# 25    SP            35.0                   4138421
# 18    RJ            33.0                   1067809
# 10    MG            31.0                   2007665
# 17    PR            41.0                   1407021
# 22    RS            43.0                   1385669
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 25                                     8940.33405           8701
# 18                                     6148.78141           4037
# 10                                     9428.90383           4654
# 17                                    12217.07517           2117
# 22                                    12130.54605           1815
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 25                 141664         387                     0.0342
# 18                  60266         130                     0.0564
# ...

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='last_available_deaths', y='state', data=ds, palette='Oranges_r')
# Out:
# <AxesSubplot:xlabel='last_available_deaths', ylabel='state'>

# %%
dfc = df[ df.place_type == 'city'].reset_index(drop=True)
print(len(dfc))
dfc.head()
# Out:
# 5589
#   state          city  city_ibge_code place_type  last_available_confirmed  \
# 0    AC    Acrelândia       1200013.0       city                      1772
# 1    AC  Assis Brasil       1200054.0       city                      1793
# 2    AC     Brasiléia       1200104.0       city                      2975
# 3    AC        Bujari       1200138.0       city                      1139
# 4    AC      Capixaba       1200179.0       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                    11439.63848              0
# 1                                    23798.77887              0
# 2                                    11141.48753              0
# 3                                    10930.90211              0
# 4                                     5604.59694              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# ...

# %%
pd.options.display.float_format = "{:,.0f}".format
dfc.describe()
# Out:
#        city_ibge_code  last_available_confirmed  \
# count           5,570                     5,589
# mean        3,253,591                     3,558
# std           984,910                    18,156
# min         1,100,015                         0
# 25%         2,512,126                       418
# 50%         3,146,280                       915
# 75%         4,119,190                     2,269
# max         5,300,108                   914,177
#
#        last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# count                                          5,570          5,589
# mean                                           9,292              0
# std                                            4,546              5
# min                                              179              0
# 25%                                            5,941              0
# 50%                                            8,850              0
# ...

# %%
dfc.describe().T
# Out:
#                                                count      mean     std  \
# city_ibge_code                                 5,570 3,253,591 984,910
# last_available_confirmed                       5,589     3,558  18,156
# last_available_confirmed_per_100k_inhabitants  5,570     9,292   4,546
# new_confirmed                                  5,589         0       5
# last_available_deaths                          5,589        99     737
# new_deaths                                     5,589         0       0
# last_available_death_rate                      5,589         0       0
# estimated_population                           5,570    38,017 222,893
#
#                                                     min       25%       50%  \
# city_ibge_code                                1,100,015 2,512,126 3,146,280
# last_available_confirmed                              0       418       915
# last_available_confirmed_per_100k_inhabitants       179     5,941     8,850
# ...

# %%
ds = dfc.sort_values(by='last_available_confirmed', ascending=False)
ds.head()
# Out:
#      state            city  city_ibge_code place_type  \
# 5369    SP       São Paulo       3,550,308       city
# 3673    RJ  Rio de Janeiro       3,304,557       city
# 806     DF        Brasília       5,300,108       city
# 679     CE       Fortaleza       2,304,400       city
# 539     BA        Salvador       2,927,408       city
#
#       last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 5369                    914177                                          7,417
# 3673                    412601                                          6,115
# 806                     401413                                         13,139
# 679                     254593                                          9,476
# 539                     232254                                          8,046
#
#       new_confirmed  last_available_deaths  new_deaths  \
# 5369              0                  35728           0
# 3673              0                  30849           0
# ...

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='last_available_confirmed', y='city', data=ds[:15], palette='Oranges_r')
# Out:
# <AxesSubplot:xlabel='last_available_confirmed', ylabel='city'>

# %%
ds = dfc.sort_values(by='last_available_deaths', ascending=False)
ds.head()
# Out:
#      state            city  city_ibge_code place_type  \
# 5369    SP       São Paulo       3,550,308       city
# 3673    RJ  Rio de Janeiro       3,304,557       city
# 679     CE       Fortaleza       2,304,400       city
# 162     AM          Manaus       1,302,603       city
# 806     DF        Brasília       5,300,108       city
#
#       last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 5369                    914177                                          7,417
# 3673                    412601                                          6,115
# 679                     254593                                          9,476
# 162                     199885                                          9,006
# 806                     401413                                         13,139
#
#       new_confirmed  last_available_deaths  new_deaths  \
# 5369              0                  35728           0
# 3673              0                  30849           0
# ...

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='last_available_deaths', y='city', data=ds[:15], palette='Reds_r')
# Out:
# <AxesSubplot:xlabel='last_available_deaths', ylabel='city'>

# %%
ds = dfc.sort_values(by='last_available_confirmed', ascending=False)
ds.head()
# Out:
#      state            city  city_ibge_code place_type  \
# 5369    SP       São Paulo       3,550,308       city
# 3673    RJ  Rio de Janeiro       3,304,557       city
# 806     DF        Brasília       5,300,108       city
# 679     CE       Fortaleza       2,304,400       city
# 539     BA        Salvador       2,927,408       city
#
#       last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 5369                    914177                                          7,417
# 3673                    412601                                          6,115
# 806                     401413                                         13,139
# 679                     254593                                          9,476
# 539                     232254                                          8,046
#
#       new_confirmed  last_available_deaths  new_deaths  \
# 5369              0                  35728           0
# 3673              0                  30849           0
# ...

# %%
ds[ ['state', 'city', 'last_available_confirmed'] ][:20].reset_index(drop=True)
# Out:
#    state            city  last_available_confirmed
# 0     SP       São Paulo                    914177
# 1     RJ  Rio de Janeiro                    412601
# 2     DF        Brasília                    401413
# 3     CE       Fortaleza                    254593
# 4     BA        Salvador                    232254
# 5     MG  Belo Horizonte                    226544
# 6     PR        Curitiba                    206619
# 7     AM          Manaus                    199885
# 8     GO         Goiânia                    177466
# 9     RS    Porto Alegre                    168459
# 10    PE          Recife                    147525
# 11    MS    Campo Grande                    129806
# 12    SE         Aracaju                    126884
# 13    PA           Belém                    105287
# 14    SP        Campinas                    105014
# 15    SC       Joinville                    104549
# 16    PI        Teresina                    103730
# ...

# %%
ds[ ds.city.str.contains('Campina Grande') ].reset_index(drop=True)
# Out:
#   state                   city  city_ibge_code place_type  \
# 0    PB         Campina Grande       2,504,009       city
# 1    PR  Campina Grande do Sul       4,104,006       city
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                     41599                                         10,102
# 1                      5712                                         13,075
#
#    new_confirmed  last_available_deaths  new_deaths  \
# 0              0                   1068           0
# 1              2                    147           0
#
#    last_available_death_rate  estimated_population
# 0                          0               411,807
# 1                          0                43,685

# %% [markdown]
# ## Valores Nulos

# %%
dfc.isna().sum()
# Out:
# state                                             0
# city                                              0
# city_ibge_code                                   19
# place_type                                        0
# last_available_confirmed                          0
# last_available_confirmed_per_100k_inhabitants    19
# new_confirmed                                     0
# last_available_deaths                             0
# new_deaths                                        0
# last_available_death_rate                         0
# estimated_population                             19
# dtype: int64

# %%
dfc[ dfc.city_ibge_code.isna()  ]
# Out:
#      state                    city  city_ibge_code place_type  \
# 57      AL  Importados/Indefinidos             nan       city
# 367     BA  Importados/Indefinidos             nan       city
# 698     CE  Importados/Indefinidos             nan       city
# 807     DF  Importados/Indefinidos             nan       city
# 841     ES  Importados/Indefinidos             nan       city
# 994     GO  Importados/Indefinidos             nan       city
# 1698    MG  Importados/Indefinidos             nan       city
# 2333    MT  Importados/Indefinidos             nan       city
# 2480    PA  Importados/Indefinidos             nan       city
# 2657    PB  Importados/Indefinidos             nan       city
# 2872    PE  Importados/Indefinidos             nan       city
# 3353    PR  Importados/Indefinidos             nan       city
# 3633    RJ  Importados/Indefinidos             nan       city
# 3748    RN  Importados/Indefinidos             nan       city
# ...

# %%
print(len(dfc))
dfc = dfc[ ~ dfc.city_ibge_code.isna()  ]
print(len(dfc))
dfc.head()
# Out:
# 5570
# 5570
#   state          city  city_ibge_code place_type  last_available_confirmed  \
# 0    AC    Acrelândia       1,200,013       city                      1772
# 1    AC  Assis Brasil       1,200,054       city                      1793
# 2    AC     Brasiléia       1,200,104       city                      2975
# 3    AC        Bujari       1,200,138       city                      1139
# 4    AC      Capixaba       1,200,179       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                         11,440              0
# 1                                         23,799              0
# 2                                         11,141              0
# 3                                         10,931              0
# 4                                          5,605              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# ...

# %%
dfc.isna().sum()
# Out:
# state                                            0
# city                                             0
# city_ibge_code                                   0
# place_type                                       0
# last_available_confirmed                         0
# last_available_confirmed_per_100k_inhabitants    0
# new_confirmed                                    0
# last_available_deaths                            0
# new_deaths                                       0
# last_available_death_rate                        0
# estimated_population                             0
# dtype: int64

# %%
dfc.head()
# Out:
#   state          city  city_ibge_code place_type  last_available_confirmed  \
# 0    AC    Acrelândia       1,200,013       city                      1772
# 1    AC  Assis Brasil       1,200,054       city                      1793
# 2    AC     Brasiléia       1,200,104       city                      2975
# 3    AC        Bujari       1,200,138       city                      1139
# 4    AC      Capixaba       1,200,179       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                         11,440              0
# 1                                         23,799              0
# 2                                         11,141              0
# 3                                         10,931              0
# 4                                          5,605              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# ...

# %%
# !ls estados*
# Out:
# estados_2010.dbf  estados_2010.shp  estados_2010.shx

# %%
#!pip install geopandas

# %%
#!pip install mapclassify

# %%
import geopandas as gpd

df = gpd.read_file('estados_2010.shp')
df.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...

# %%
type(df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
df2 = df.copy()

# %%
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
dfe.head()
# Out:
#   state  city_ibge_code  last_available_confirmed  \
# 0    AC              12                     87468
# 1    AL              27                    232128
# 2    AM              13                    420524
# 3    AP              16                    121868
# 4    BA              29                   1205316
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          9,779             45
# 1                                          6,926            208
# 2                                          9,994            350
# 3                                         14,142             44
# 4                                          8,073           1040
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   1805           1                          0
# 1                   5923           9                          0
# 2                  13605           9                          0
# ...

# %%
df.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...

# %%
df.sigla.values
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
dfe.state.values
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %% [markdown]
# # Join de Dataframes

# %%
d = df.merge(dfe, left_on='sigla', right_on='state')
d.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry state  city_ibge_code  \
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...    AC              12
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...    AL              27
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...    AM              13
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...    AP              16
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...    BA              29
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                     87468                                          9,779
# 1                    232128                                          6,926
# ...

# %%
type(d)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
d.plot(column='last_available_confirmed', figsize=(12,8), cmap='Blues', legend=True)
# Out:
# <AxesSubplot:>

# %%
d.plot(column='last_available_deaths', figsize=(12,8), cmap='Oranges', legend=True)
# Out:
# <AxesSubplot:>

# %%
##

# %%
#!pip install geopandas==0.3.0
#pip install pyshp==1.2.10
#!pip install shapely

# %%
# !ls
# Out:
# arquivo-dsc.txt
# Aula-01-05-agosto-2021-Python-Fundamentos.ipynb
# Aula-01-05-Agosto-2021-Python-Fundamentos-Noite.ipynb
# Aula01-23-marco-2021-Noite.ipynb
# Aula-01-23-marco-2021-Python-Fundamentos-Manha.ipynb
# Aula-01-Setembro-2020-Numpy-Noite.ipynb
# Aula-01-setembro-2020-Numpy-Turma-Manha.ipynb
# Aula-02-10-Agosto-2021-Dicionarios-DataFrames-Noite.ipynb
# Aula-02-10-Agosto-2021-Python-Fundamentos-Dicionarios-DataFrames.ipynb
# Aula-02-25-marco-2021-Python-Fundamentos-Manha.ipynb
# Aula-02-25-marco-2021-Python-Fundamentos-Noite.ipynb
# Aula-03-06-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-NOITE-2021.ipynb
# Aula-03-06-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Manha-2021.ipynb
# Aula-03-12-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Manha-2021.ipynb
# Aula-03-12-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Manha.ipynb
# ...

# %%
dfc.head()
# Out:
#   state          city  city_ibge_code place_type  last_available_confirmed  \
# 0    AC    Acrelândia       1,200,013       city                      1772
# 1    AC  Assis Brasil       1,200,054       city                      1793
# 2    AC     Brasiléia       1,200,104       city                      2975
# 3    AC        Bujari       1,200,138       city                      1139
# 4    AC      Capixaba       1,200,179       city                       673
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                         11,440              0
# 1                                         23,799              0
# 2                                         11,141              0
# 3                                         10,931              0
# 4                                          5,605              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# ...

# %%
casos = dfc.last_available_confirmed.value_counts()
casos
# Out:
# 207     11
# 287     11
# 302     10
# 254     10
# 363     10
#         ..
# 678      1
# 682      1
# 2735     1
# 2739     1
# 4098     1
# Name: last_available_confirmed, Length: 2949, dtype: int64

# %%
casos = casos.to_frame().reset_index()
casos
# Out:
#       index  last_available_confirmed
# 0       207                        11
# 1       287                        11
# 2       302                        10
# 3       254                        10
# 4       363                        10
# ...     ...                       ...
# 2944    678                         1
# 2945    682                         1
# 2946   2735                         1
# 2947   2739                         1
# 2948   4098                         1
#
# [2949 rows x 2 columns]

# %%
casos.columns = ['Numero de Casos', "Numero de Cidades"]
casos
# Out:
#       Numero de Casos  Numero de Cidades
# 0                 207                 11
# 1                 287                 11
# 2                 302                 10
# 3                 254                 10
# 4                 363                 10
# ...               ...                ...
# 2944              678                  1
# 2945              682                  1
# 2946             2735                  1
# 2947             2739                  1
# 2948             4098                  1
#
# [2949 rows x 2 columns]

# %%
casos_o = casos.sort_values(by='Numero de Casos', ascending=False)
casos_o.head(10)
# Out:
#       Numero de Casos  Numero de Cidades
# 1890           914177                  1
# 2228           412601                  1
# 1639           401413                  1
# 2322           254593                  1
# 1917           232254                  1
# 2777           226544                  1
# 2214           206619                  1
# 1747           199885                  1
# 1713           177466                  1
# 1194           168459                  1

# %%
casos_o = casos.sort_values(by='Numero de Casos', ascending=True)
casos_o.head(20)
# Out:
#       Numero de Casos  Numero de Cidades
# 2457               10                  1
# 2043               15                  1
# 2471               22                  1
# 1490               24                  1
# 1641               25                  1
# 2040               27                  1
# 1643               29                  1
# 1645               33                  1
# 1492               36                  1
# 2485               38                  1
# 2031               39                  1
# 840                41                  2
# 1493               44                  1
# 1647               45                  1
# 1648               49                  1
# 750                50                  2
# 864                52                  2
# 1649               53                  1
# 2481               54                  1
# 2036               55                  1

# %%
plt.figure(figsize=(12,8))

sns.barplot(y='Numero de Cidades', x = 'Numero de Casos', data=casos_o[:35], palette='RdBu')
# Out:
# <AxesSubplot:xlabel='Numero de Casos', ylabel='Numero de Cidades'>

# %%
casos_o = casos.sort_values(by='Numero de Casos', ascending=True)
casos_o.head(20)
# Out:
#       Numero de Casos  Numero de Cidades
# 2457               10                  1
# 2043               15                  1
# 2471               22                  1
# 1490               24                  1
# 1641               25                  1
# 2040               27                  1
# 1643               29                  1
# 1645               33                  1
# 1492               36                  1
# 2485               38                  1
# 2031               39                  1
# 840                41                  2
# 1493               44                  1
# 1647               45                  1
# 1648               49                  1
# 750                50                  2
# 864                52                  2
# 1649               53                  1
# 2481               54                  1
# 2036               55                  1

# %%
plt.figure(figsize=(12,8))

sns.barplot(y='Numero de Cidades', x = 'Numero de Casos', data=casos_o[:15], palette='RdBu')
# Out:
# <AxesSubplot:xlabel='Numero de Casos', ylabel='Numero de Cidades'>

# %% [markdown]
# # Dataframe de Salarios

# %%
url = 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/salarios.csv'
url
# Out:
# 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/salarios.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(url)
len(df)
# Out:
# 32182

# %%
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $88968.00
# 1              $80778.00
# 2              $80778.00
# 3              $84780.00
# 4             $104736.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32182 entries, 0 to 32181
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32181 non-null  object
#  1   Position Title          32181 non-null  object
#  2   Department              32181 non-null  object
#  3   Employee Annual Salary  32181 non-null  object
# dtypes: object(4)
# memory usage: 1005.8+ KB

# %%
df['salario'] = df['Employee Annual Salary'].apply(lambda x : str(x))
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary     salario
# 0              $88968.00   $88968.00
# 1              $80778.00   $80778.00
# 2              $80778.00   $80778.00
# 3              $84780.00   $84780.00
# 4             $104736.00  $104736.00

# %%
df['salario'] = df['salario'].apply(lambda x : x.replace('$', ''))
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary    salario
# 0              $88968.00   88968.00
# 1              $80778.00   80778.00
# 2              $80778.00   80778.00
# 3              $84780.00   84780.00
# 4             $104736.00  104736.00

# %%
df.salario.max(), df.salario.min()
# Out:
# ('nan', '0.96')

# %% [markdown]
# ## Python - O valor nulo (NULL)
# Nulo = nan, Nan, NAN

# %%
import numpy as np
np.nan
# Out:
# nan

# %%
df['salario'] = df['salario'].apply(lambda x : np.nan if x == 'nan' else x )
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary    salario
# 0              $88968.00   88968.00
# 1              $80778.00   80778.00
# 2              $80778.00   80778.00
# 3              $84780.00   84780.00
# 4             $104736.00  104736.00

# %%
df['salario'] = df['salario'].apply(lambda x : float(x) )
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary  salario
# 0              $88968.00   88,968
# 1              $80778.00   80,778
# 2              $80778.00   80,778
# 3              $84780.00   84,780
# 4             $104736.00  104,736

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32182 entries, 0 to 32181
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32181 non-null  object
#  1   Position Title          32181 non-null  object
#  2   Department              32181 non-null  object
#  3   Employee Annual Salary  32181 non-null  object
#  4   salario                 32181 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 1.2+ MB

# %%
df.salario.sum()
# Out:
# 2547690152.24

# %%
df.describe().T
# Out:
#          count   mean    std  min    25%    50%    75%     max
# salario 32,181 79,168 24,462    1 69,888 83,616 91,764 260,004

# %%
260004 * 5.3 / 13
# Out:
# 106001.63076923076

# %%
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary  salario
# 0              $88968.00   88,968
# 1              $80778.00   80,778
# 2              $80778.00   80,778
# 3              $84780.00   84,780
# 4             $104736.00  104,736

# %%
df.Department.unique()
# Out:
# array(['WATER MGMNT', 'POLICE', 'GENERAL SERVICES', 'CITY COUNCIL',
#        'STREETS & SAN', 'AVIATION', 'FIRE', 'FAMILY & SUPPORT', 'IPRA',
#        'PUBLIC LIBRARY', 'DoIT', 'BUSINESS AFFAIRS', 'OEMC', 'TRANSPORTN',
#        'HEALTH', "MAYOR'S OFFICE", 'LAW', 'FINANCE', 'CULTURAL AFFAIRS',
#        'COMMUNITY DEVELOPMENT', 'BUILDINGS', 'ANIMAL CONTRL',
#        'CITY CLERK', 'BOARD OF ELECTION', 'INSPECTOR GEN', 'TREASURER',
#        'DISABILITIES', 'HUMAN RESOURCES', 'PROCUREMENT',
#        'HUMAN RELATIONS', 'BOARD OF ETHICS', 'POLICE BOARD',
#        'BUDGET & MGMT', 'ADMIN HEARNG', 'LICENSE APPL COMM', nan],
#       dtype=object)

# %%
len(df.Department.unique())
# Out:
# 36

# %%
dfg = df.groupby(['Department']).sum().reset_index()
dfg
# Out:
#                Department       salario
# 0            ADMIN HEARNG     2,898,456
# 1           ANIMAL CONTRL     3,699,370
# 2                AVIATION    96,467,503
# 3       BOARD OF ELECTION     6,252,156
# 4         BOARD OF ETHICS       750,852
# 5           BUDGET & MGMT     3,776,940
# 6               BUILDINGS    24,127,022
# 7        BUSINESS AFFAIRS    12,889,272
# 8              CITY CLERK     5,439,045
# 9            CITY COUNCIL    22,367,892
# 10  COMMUNITY DEVELOPMENT    17,754,150
# 11       CULTURAL AFFAIRS     6,091,348
# 12           DISABILITIES     2,109,660
# 13                   DoIT    10,136,460
# 14       FAMILY & SUPPORT    26,951,553
# 15                FINANCE    39,085,897
# 16                   FIRE   457,971,614
# 17       GENERAL SERVICES    75,486,488
# 18                 HEALTH    44,719,992
# 19        HUMAN RELATIONS     1,513,356
# 20        HUMAN RESOURCES     4,889,112
# 21          INSPECTOR GEN     4,416,264
# ...

# %%
dfgo = dfg.sort_values(by='salario', ascending=False).reset_index(drop=True)
dfgo
# Out:
#                Department       salario
# 0                  POLICE 1,106,657,381
# 1                    FIRE   457,971,614
# 2             WATER MGMNT   155,110,588
# 3           STREETS & SAN   146,821,191
# 4              TRANSPORTN    98,344,398
# 5                AVIATION    96,467,503
# 6        GENERAL SERVICES    75,486,488
# 7                    OEMC    63,379,954
# 8          PUBLIC LIBRARY    52,663,130
# 9                  HEALTH    44,719,992
# 10                FINANCE    39,085,897
# 11                    LAW    30,989,159
# 12       FAMILY & SUPPORT    26,951,553
# 13              BUILDINGS    24,127,022
# 14           CITY COUNCIL    22,367,892
# 15  COMMUNITY DEVELOPMENT    17,754,150
# 16       BUSINESS AFFAIRS    12,889,272
# 17                   DoIT    10,136,460
# 18         MAYOR'S OFFICE     8,120,517
# 19                   IPRA     7,358,004
# 20            PROCUREMENT     6,303,888
# 21      BOARD OF ELECTION     6,252,156
# ...

# %%
sns.barplot(y='Department', x='salario', data=dfgo[:15], palette="Blues_r")
# Out:
# <AxesSubplot:xlabel='salario', ylabel='Department'>

# %%
cargos = df['Position Title'].unique()
len(cargos)
# Out:
# 1095

# %%
cargos = list(cargos)
print(cargos)
# Out:
# ['WATER RATE TAKER', 'POLICE OFFICER', 'CHIEF CONTRACT EXPEDITER', 'CIVIL ENGINEER IV', 'ASST TO THE ALDERMAN', 'GENERAL LABORER - DSS', 'ELECTRICAL MECHANIC', 'FIRE ENGINEER', 'FOSTER GRANDPARENT', 'CLERK III', 'INVESTIGATOR - IPRA II', 'FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC', 'FIREFIGHTER/PARAMEDIC', 'ENGINEERING TECHNICIAN VI', 'FIREFIGHTER-EMT', 'LIEUTENANT', 'CROSSING GUARD', 'ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT', 'PARAMEDIC', 'MOTOR TRUCK DRIVER', 'LIBRARY ASSOCIATE - HOURLY', 'SENIOR PROGRAMMER/ANALYST', 'ENGINEERING TECHNICIAN V', 'SUPERVISING TRAFFIC CONTROL AIDE', 'SANITATION LABORER', 'AMBULANCE COMMANDER', 'POOL MOTOR TRUCK DRIVER', 'SEWER BRICKLAYER', 'TREE TRIMMER', 'TRAFFIC SIGNAL REPAIRMAN', 'PERSONAL COMPUTER OPERATOR III', 'SENIOR COMPANION', 'SENIOR ENVIRONMENTAL INSPECTOR', 'PLUMBER', 'CIVIL ENGINEER II', 'POLICE OFFICER (ASSIGNED AS EVIDENCE TECHNICIAN)', 'CONSTRUCTION LABORER', 'DIVISION SUPERINTENDENT', 'ADMINISTRATIVE ASST', 'COMMUNICABLE DISEASE C
# ...

# %%
print(len(df))
df2 = df.dropna()
print(len(df2))
# Out:
# 32182
# 32181

# %%
ds = df2 [ df2['Position Title'].str.contains('POLICE OFFICER') ]
ds
# Out:
#                         Name  Position Title Department  \
# 1          AARON,  JEFFERY M  POLICE OFFICER     POLICE
# 2             AARON,  KARINA  POLICE OFFICER     POLICE
# 9           ABBATE,  TERRY M  POLICE OFFICER     POLICE
# 13           ABDALLAH,  ZAID  POLICE OFFICER     POLICE
# 14     ABDELHADI,  ABDALMAHD  POLICE OFFICER     POLICE
# ...                      ...             ...        ...
# 32172       ZWIT,  JEFFREY J  POLICE OFFICER     POLICE
# 32174          ZYDEK,  BRYAN  POLICE OFFICER     POLICE
# 32177     ZYGOWICZ,  PETER J  POLICE OFFICER     POLICE
# 32178      ZYMANTAS,  MARK E  POLICE OFFICER     POLICE
# 32179    ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE
#
#       Employee Annual Salary  salario
# 1                  $80778.00   80,778
# 2                  $80778.00   80,778
# 9                  $86520.00   86,520
# 13                 $69684.00   69,684
# 14                 $80778.00   80,778
# ...                      ...      ...
# ...

# %%
ds.describe().T
# Out:
#          count   mean    std    min    25%    50%    75%     max
# salario 10,634 83,175 10,371 46,200 80,778 83,616 89,718 110,370

# %%
83175 * 5.3 / 13
# Out:
# 33909.807692307695

# %%
ds = df2 [ df2['Position Title'].str.contains('FIREFIGHTER/PARAMEDIC') ]
ds
# Out:
#                         Name         Position Title Department  \
# 17       ABDOLLAHZADEH,  ALI  FIREFIGHTER/PARAMEDIC       FIRE
# 707       ANDERSON,  JACOB P  FIREFIGHTER/PARAMEDIC       FIRE
# 718      ANDERSON JR,  ROY T  FIREFIGHTER/PARAMEDIC       FIRE
# 1249        BAILEY,  MICHAEL  FIREFIGHTER/PARAMEDIC       FIRE
# 1577          BARRY,  JOHN M  FIREFIGHTER/PARAMEDIC       FIRE
# ...                      ...                    ...        ...
# 32035      ZELLER,  DANIEL J  FIREFIGHTER/PARAMEDIC       FIRE
# 32040       ZENDEJAS,  RUBEN  FIREFIGHTER/PARAMEDIC       FIRE
# 32092            ZIMO,  JOHN  FIREFIGHTER/PARAMEDIC       FIRE
# 32098  ZIOLKOWSKI,  THOMAS P  FIREFIGHTER/PARAMEDIC       FIRE
# 32125        ZORNIAK,  ROMAN  FIREFIGHTER/PARAMEDIC       FIRE
#
#       Employee Annual Salary  salario
# 17                 $87720.00   87,720
# 707                $87720.00   87,720
# 718                $97728.00   97,728
# 1249               $90798.00   90,798
# ...

# %%
ds.describe().T
# Out:
#          count   mean   std    min    25%    50%    75%     max
# salario    269 87,078 6,797 71,604 87,720 87,720 90,798 101,634
