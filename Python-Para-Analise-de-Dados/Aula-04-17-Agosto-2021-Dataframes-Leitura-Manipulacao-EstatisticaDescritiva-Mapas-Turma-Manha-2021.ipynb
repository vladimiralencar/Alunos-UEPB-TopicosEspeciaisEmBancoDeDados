# %% [markdown]
# #### Aula-04-17-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-Manha-2021

# %% [markdown]
# # Aluno: xxxx - Matrícula: xxxx

# %%
import pandas as pd

df = pd.DataFrame()
df['Matricula'] = [123, 567]
df
# Out:
#    Matricula
# 0        123
# 1        567

# %%
# !ls
# Out:
# Aula-01-05-Agosto-2021-Python-Fundamentos-Noite.ipynb
# Aula-01-05-agosto-2021-Python-Fundamentos.ipynb
# Aula-01-23-marco-2021-Python-Fundamentos-Manha.ipynb
# Aula-01-Setembro-2020-Numpy-Noite.ipynb
# Aula-01-setembro-2020-Numpy-Turma-Manha.ipynb
# Aula-02-10-Agosto-2021-Dicionarios-DataFrames-Noite.ipynb
# Aula-02-10-Agosto-2021-Python-Fundamentos-Dicionarios-DataFrames.ipynb
# Aula-02-25-marco-2021-Python-Fundamentos-Manha.ipynb
# Aula-02-25-marco-2021-Python-Fundamentos-Noite.ipynb
# Aula-03-06-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-NOITE-2021.ipynb
# Aula-03-06-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Manha-2021.ipynb
# Aula-03-12-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Manha-2021.ipynb
# Aula-03-12-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Manha.ipynb
# Aula-03-12-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Turma-Noite.ipynb
# Aula-04-08-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-MANHA-2021.ipynb
# Aula-04-08-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-NOITE-2021.ipynb
# Aula-04-17-Agosto-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-Manha-2021.ipynb
# Aula-04-DataFrames-Numpy-Python-25-Agosto-2020-Noite.ipynb
# Aula-04-Dataframes-Numpy-Python-25-Agosto-2020.ipynb
# Aula-05-08-Abril-2021-Numpy-Arrays-Turma-MANHA-2021.ipynb
# Aula-06-13-Abril-2021-Numpy-Turma-NOITE-2021.ipynb
# Aula-COPIA-03-06-Abril-2021-Dataframes-Leitura-Manipulacao-EstatisticaDescritiva-Mapas-Turma-NOITE-2021-Copy1.ipynb
# Aula01-23-marco-2021-Noite.ipynb
# Casos_por_cidades.csv
# DataAcquisitionPipeline.png
# IoT-Traffic
# Olympics2020Medals.csv
# README.md
# TSLA.csv
# Untitled.ipynb
# arquivo-dsc.txt
# binary.csv
# car.csv
# car.data
# covid-python_py.ipynb
# covid19-05-abril-2021.csv
# covid19-10-Agosto-2021.csv
# covid19-6-abril-2021-NOITE.csv
# covid_estados_12_ago_2021.csv
# datasets
# estados_2010.dbf
# estados_2010.shp
# estados_2010.shx
# iris.csv
# mapa_br_covid.csv
# nomes.txt
# python_covid.py
# raw.githubusercontent.com
# salarios.csv
# t.txt
# teste.txt
# texas.html
# tic-tac-toe.data
# tic-tac-toe.names
# tweets.json

# %%
df['Nome'] = ['Daniel', "Amanda"]
df
# Out:
#    Matricula    Nome
# 0        123  Daniel
# 1        567  Amanda

# %%
url = 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/covid19-05-abril-2021.csv'
url
# Out:
# 'https://raw.githubusercontent.com/vladimiralencar/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/master/Python-Para-Analise-de-Dados/covid19-05-abril-2021.csv'

# %%
df = pd.read_csv(url)
len(df)
# Out:
# 5616

# %%
df.head()
# Out:
#    epidemiological_week        date  order_for_place state          city  \
# 0                202114  2021-04-05              373    AC    Acrelândia
# 1                202114  2021-04-05              340    AC  Assis Brasil
# 2                202114  2021-04-05              332    AC     Brasiléia
# 3                202114  2021-04-05              363    AC        Bujari
# 4                202114  2021-04-05              333    AC      Capixaba
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       1200013.0       city                      1341
# 1       1200054.0       city                      1342
# 2       1200104.0       city                      2134
# 3       1200138.0       city                       971
# 4       1200179.0       city                       456
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                     8657.19819              0
# 1                                    17812.58296              0
# 2                                     7991.91072              0
# 3                                     9318.61804              0
# 4                                     3797.46835              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                     22           0                     0.0164
# 1                     18           0                     0.0134
# 2                     29           0                     0.0136
# 3                     12           0                     0.0124
# 4                     13           0                     0.0285
#
#    estimated_population  is_last  is_repeated
# 0               15490.0    False         True
# 1                7534.0    False         True
# 2               26702.0    False         True
# 3               10420.0    False         True
# 4               12008.0    False         True

# %%
df.place_type.unique()
# Out:
# array(['city', 'state'], dtype=object)

# %%
dfe = df[df.place_type ==  'state'].reset_index(drop=True)
len(dfe)
# Out:
# 27

# %%
dfe
# Out:
#     epidemiological_week        date  order_for_place state city  \
# 0                 202114  2021-04-05              385    AC  NaN
# 1                 202114  2021-04-05              394    AL  NaN
# 2                 202114  2021-04-05              389    AM  NaN
# 3                 202114  2021-04-05              382    AP  NaN
# 4                 202114  2021-04-05              396    BA  NaN
# 5                 202114  2021-04-05              386    CE  NaN
# 6                 202114  2021-04-05              395    DF  NaN
# 7                 202114  2021-04-05              397    ES  NaN
# 8                 202114  2021-04-05              390    GO  NaN
# 9                 202114  2021-04-05              382    MA  NaN
# 10                202114  2021-04-05              394    MG  NaN
# 11                202114  2021-04-05              388    MS  NaN
# 12                202114  2021-04-05              382    MT  NaN
# 13                202114  2021-04-05              384    PA  NaN
# 14                202114  2021-04-05              390    PB  NaN
# 15                202114  2021-04-05              390    PE  NaN
# 16                202114  2021-04-05              383    PI  NaN
# 17                202114  2021-04-05              390    PR  NaN
# 18                202114  2021-04-05              397    RJ  NaN
# 19                202114  2021-04-05              390    RN  NaN
# 20                202114  2021-04-05              382    RO  NaN
# 21                202114  2021-04-05              381    RR  NaN
# 22                202114  2021-04-05              392    RS  NaN
# 23                202114  2021-04-05              390    SC  NaN
# 24                202114  2021-04-05              388    SE  NaN
# 25                202114  2021-04-05              406    SP  NaN
# 26                202114  2021-04-05              384    TO  NaN
#
#     city_ibge_code place_type  last_available_confirmed  \
# 0             12.0      state                     71330
# 1             27.0      state                    156522
# 2             13.0      state                    352976
# 3             16.0      state                     99237
# 4             29.0      state                    817722
# 5             23.0      state                    552009
# 6             53.0      state                    351163
# 7             32.0      state                    390884
# 8             52.0      state                    493272
# 9             21.0      state                    244995
# 10            31.0      state                   1159039
# 11            50.0      state                    221725
# 12            51.0      state                    317254
# 13            15.0      state                    426204
# 14            25.0      state                    264640
# 15            26.0      state                    356326
# 16            22.0      state                    212348
# 17            41.0      state                    860424
# 18            33.0      state                    659237
# 19            24.0      state                    201347
# 20            11.0      state                    190995
# 21            14.0      state                     90371
# 22            43.0      state                    860924
# 23            42.0      state                    817884
# 24            28.0      state                    179278
# 25            35.0      state                   2532047
# 26            17.0      state                    143651
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                      7974.55476            173
# 1                                      4670.14745            283
# 2                                      8388.78308            664
# 3                                     11515.44548            339
# 4                                      5476.80695           2073
# 5                                      6008.52086              0
# 6                                     11494.13662           1388
# 7                                      9618.08560           2284
# 8                                      6934.26901           2925
# 9                                      3443.55366            241
# 10                                     5443.37191           2604
# 11                                     7892.27143              0
# 12                                     8996.99962           2167
# 13                                     4904.11351           2513
# 14                                     6551.66754           1059
# 15                                     3705.31396            709
# 16                                     6471.10450           1505
# 17                                     7471.00767           1436
# 18                                     3796.09481            797
# 19                                     5697.15902              0
# 20                                    10631.74243            675
# 21                                    14317.76305              0
# 22                                     7536.77698            788
# 23                                    11277.26680           1344
# 24                                     7731.42570            977
# 25                                     5470.04425           4647
# 26                                     9033.24513              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 0                    1298           7                     0.0182
# 1                    3665          22                     0.0234
# 2                   12107          35                     0.0343
# 3                    1334          11                     0.0134
# 4                   15796          86                     0.0193
# 5                   14407           0                     0.0261
# 6                    6366          78                     0.0181
# 7                    7767          95                     0.0199
# 8                   12069         220                     0.0245
# 9                    6278          42                     0.0256
# 10                  25713          59                     0.0222
# 11                   4513           0                     0.0204
# 12                   8127         128                     0.0256
# 13                  10825          47                     0.0254
# 14                   5949          43                     0.0225
# 15                  12421          44                     0.0349
# 16                   4298          30                     0.0202
# 17                  17405         106                     0.0202
# 18                  37693           6                     0.0572
# 19                   4676           0                     0.0232
# 20                   4327          49                     0.0227
# 21                   1352           0                     0.0150
# 22                  20600         101                     0.0239
# 23                  11324          81                     0.0138
# 24                   3617          25                     0.0202
# 25                  77165         145                     0.0305
# 26                   2113           0                     0.0147
#
#     estimated_population  is_last  is_repeated
# 0               894470.0     True        False
# 1              3351543.0     True        False
# 2              4207714.0     True        False
# 3               861773.0     True        False
# 4             14930634.0     True        False
# 5              9187103.0    False         True
# 6              3055149.0     True        False
# 7              4064052.0     True        False
# 8              7113540.0     True        False
# 9              7114598.0     True        False
# 10            21292666.0     True        False
# 11             2809394.0    False         True
# 12             3526220.0     True        False
# 13             8690745.0     True        False
# 14             4039277.0     True        False
# 15             9616621.0     True        False
# 16             3281480.0     True        False
# 17            11516840.0     True        False
# 18            17366189.0     True        False
# 19             3534165.0    False         True
# 20             1796460.0     True        False
# 21              631181.0    False         True
# 22            11422973.0     True        False
# 23             7252502.0     True        False
# 24             2318822.0     True        False
# 25            46289333.0     True        False
# 26             1590248.0    False         True

# %%
dfc = df[ df.place_type ==  'city' ]
len(dfc)
# Out:
# 5589

# %%
dfc.head(8)
# Out:
#    epidemiological_week        date  order_for_place state             city  \
# 0                202114  2021-04-05              373    AC       Acrelândia
# 1                202114  2021-04-05              340    AC     Assis Brasil
# 2                202114  2021-04-05              332    AC        Brasiléia
# 3                202114  2021-04-05              363    AC           Bujari
# 4                202114  2021-04-05              333    AC         Capixaba
# 5                202114  2021-04-05              358    AC  Cruzeiro do Sul
# 6                202114  2021-04-05              334    AC   Epitaciolândia
# 7                202114  2021-04-05              339    AC            Feijó
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       1200013.0       city                      1341
# 1       1200054.0       city                      1342
# 2       1200104.0       city                      2134
# 3       1200138.0       city                       971
# 4       1200179.0       city                       456
# 5       1200203.0       city                      6951
# 6       1200252.0       city                      1136
# 7       1200302.0       city                      2429
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                     8657.19819              0
# 1                                    17812.58296              0
# 2                                     7991.91072              0
# 3                                     9318.61804              0
# 4                                     3797.46835              0
# 5                                     7803.79917              0
# 6                                     6076.16602              0
# 7                                     6963.07763              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                     22           0                     0.0164
# 1                     18           0                     0.0134
# 2                     29           0                     0.0136
# 3                     12           0                     0.0124
# 4                     13           0                     0.0285
# 5                    128           0                     0.0184
# 6                     24           0                     0.0211
# 7                     44           0                     0.0181
#
#    estimated_population  is_last  is_repeated
# 0               15490.0    False         True
# 1                7534.0    False         True
# 2               26702.0    False         True
# 3               10420.0    False         True
# 4               12008.0    False         True
# 5               89072.0    False         True
# 6               18696.0    False         True
# 7               34884.0    False         True

# %%
dfc.city.unique()
# Out:
# array(['Acrelândia', 'Assis Brasil', 'Brasiléia', ..., 'Tupiratins',
#        'Wanderlândia', 'Xambioá'], dtype=object)

# %%
len(dfc.city.unique())
# Out:
# 5298

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
dfc.describe()
# Out:
#        epidemiological_week  order_for_place  city_ibge_code  \
# count                 5,589            5,589           5,570
# mean                202,114              330       3,253,591
# std                       0               30         984,910
# min                 202,114              185       1,100,015
# 25%                 202,114              311       2,512,126
# 50%                 202,114              332       3,146,280
# 75%                 202,114              352       4,119,190
# max                 202,114              406       5,300,108
#
#        last_available_confirmed  \
# count                     5,589
# mean                      2,295
# std                      12,462
# min                           0
# 25%                         230
# 50%                         530
# 75%                       1,405
# max                     633,097
#
#        last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# count                                          5,570          5,589
# mean                                           5,807              1
# std                                           12,934              7
# min                                               39             -1
# 25%                                            3,212              0
# 50%                                            4,983              0
# 75%                                            7,185              0
# max                                          904,810            364
#
#        last_available_deaths  new_deaths  last_available_death_rate  \
# count                  5,589       5,589                      5,589
# mean                      58           0                          0
# std                      482           1                          0
# min                        0           0                          0
# 25%                        4           0                          0
# 50%                       10           0                          0
# 75%                       27           0                          0
# max                   22,734          40                          1
#
#        estimated_population
# count                 5,570
# mean                 38,017
# std                 222,893
# min                     776
# 25%                   5,442
# 50%                  11,666
# 75%                  25,664
# max              12,325,232

# %%
dfc.describe().T
# Out:
#                                                count      mean     std  \
# epidemiological_week                           5,589   202,114       0
# order_for_place                                5,589       330      30
# city_ibge_code                                 5,570 3,253,591 984,910
# last_available_confirmed                       5,589     2,295  12,462
# last_available_confirmed_per_100k_inhabitants  5,570     5,807  12,934
# new_confirmed                                  5,589         1       7
# last_available_deaths                          5,589        58     482
# new_deaths                                     5,589         0       1
# last_available_death_rate                      5,589         0       0
# estimated_population                           5,570    38,017 222,893
#
#                                                     min       25%       50%  \
# epidemiological_week                            202,114   202,114   202,114
# order_for_place                                     185       311       332
# city_ibge_code                                1,100,015 2,512,126 3,146,280
# last_available_confirmed                              0       230       530
# last_available_confirmed_per_100k_inhabitants        39     3,212     4,983
# new_confirmed                                        -1         0         0
# last_available_deaths                                 0         4        10
# new_deaths                                            0         0         0
# last_available_death_rate                             0         0         0
# estimated_population                                776     5,442    11,666
#
#                                                     75%        max
# epidemiological_week                            202,114    202,114
# order_for_place                                     352        406
# city_ibge_code                                4,119,190  5,300,108
# last_available_confirmed                          1,405    633,097
# last_available_confirmed_per_100k_inhabitants     7,185    904,810
# new_confirmed                                         0        364
# last_available_deaths                                27     22,734
# new_deaths                                            0         40
# last_available_death_rate                             0          1
# estimated_population                             25,664 12,325,232

# %%
df[ df.new_confirmed == -1]
# Out:
#       epidemiological_week        date  order_for_place state       city  \
# 2431                202114  2021-04-05              273    MT  Torixoréu
#
#       city_ibge_code place_type  last_available_confirmed  \
# 2431       5,108,204       city                       288
#
#       last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 2431                                          8,120             -1
#
#       last_available_deaths  new_deaths  last_available_death_rate  \
# 2431                      6           1                          0
#
#       estimated_population  is_last  is_repeated
# 2431                 3,547     True        False

# %%
print(len(df))
df2 = df[ ~ (df.new_confirmed == -1) ] 
len(df2)
# Out:
# 5616
# 5615

# %%
#!pip install seaborn
#!conda install -c anaconda seaborn -y

# %%
import seaborn as sns

sns.distplot(dfc.estimated_population)
# Out:
# /Users/valencar/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='estimated_population', ylabel='Density'>

# %%
sns.distplot(dfe.estimated_population)
# Out:
# /Users/valencar/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='estimated_population', ylabel='Density'>

# %%
dfco = dfc.sort_values(by='last_available_confirmed', ascending=False).reset_index(drop=True)
dfco.head(20)
# Out:
#     epidemiological_week        date  order_for_place state            city  \
# 0                 202114  2021-04-05              406    SP       São Paulo
# 1                 202114  2021-04-05              395    DF        Brasília
# 2                 202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                 202114  2021-04-05              389    BA        Salvador
# 4                 202114  2021-04-05              386    CE       Fortaleza
# 5                 202114  2021-04-05              389    AM          Manaus
# 6                 202114  2021-04-05              390    PR        Curitiba
# 7                 202114  2021-04-05              386    MG  Belo Horizonte
# 8                 202114  2021-04-05              390    GO         Goiânia
# 9                 202114  2021-04-05              391    RS    Porto Alegre
# 10                202114  2021-04-05              390    PE          Recife
# 11                202114  2021-04-05              388    SE         Aracaju
# 12                202114  2021-04-05              384    PA           Belém
# 13                202114  2021-04-05              388    MS    Campo Grande
# 14                202114  2021-04-05              389    SC       Joinville
# 15                202114  2021-04-05              383    PI        Teresina
# 16                202114  2021-04-05              385    MG      Uberlândia
# 17                202114  2021-04-05              384    PB     João Pessoa
# 18                202114  2021-04-05              390    SC   Florianópolis
# 19                202114  2021-04-05              384    SP        Campinas
#
#     city_ibge_code place_type  last_available_confirmed  \
# 0        3,550,308       city                    633097
# 1        5,300,108       city                    306766
# 2        3,304,557       city                    230450
# 3        2,927,408       city                    175965
# 4        2,304,400       city                    164429
# 5        1,302,603       city                    161465
# 6        4,106,902       city                    140575
# 7        3,106,200       city                    131388
# 8        5,208,707       city                    124618
# 9        4,314,902       city                    116145
# 10       2,611,606       city                     90140
# 11       2,800,308       city                     88884
# 12       1,501,402       city                     87266
# 13       5,002,704       city                     85372
# 14       4,209,102       city                     78909
# 15       2,211,001       city                     76548
# 16       3,170,206       city                     76458
# 17       2,507,507       city                     71118
# 18       4,205,407       city                     70012
# 19       3,509,502       city                     68564
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                           5,137              0
# 1                                          10,041              0
# 2                                           3,415              0
# 3                                           6,096              0
# 4                                           6,120              0
# 5                                           7,275              0
# 6                                           7,214             64
# 7                                           5,211              0
# 8                                           8,113              0
# 9                                           7,804              0
# 10                                          5,452              0
# 11                                         13,368              0
# 12                                          5,819              0
# 13                                          9,422              0
# 14                                         13,203              0
# 15                                          8,818              0
# 16                                         10,937              0
# 17                                          8,699              0
# 18                                         13,760              0
# 19                                          5,649              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   22734           0                          0
# 1                    5765           0                          0
# 2                   20987           0                          0
# 3                    5107           0                          0
# 4                    6192           0                          0
# 5                    8444           0                          0
# 6                    3299           1                          0
# 7                    3019           0                          0
# 8                    3683           0                          0
# 9                    3700           0                          0
# 10                   3411           0                          0
# 11                   1388           0                          0
# 12                   3690           0                          0
# 13                   1870           0                          0
# 14                   1025           0                          0
# 15                   1641           0                          0
# 16                   1510           0                          0
# 17                   2002           0                          0
# 18                    795           0                          0
# 19                   2458           0                          0
#
#     estimated_population  is_last  is_repeated
# 0             12,325,232    False         True
# 1              3,055,149    False         True
# 2              6,747,815    False         True
# 3              2,886,698    False         True
# 4              2,686,612    False         True
# 5              2,219,580    False         True
# 6              1,948,626     True        False
# 7              2,521,564    False         True
# 8              1,536,097    False         True
# 9              1,488,252    False         True
# 10             1,653,461    False         True
# 11               664,908    False         True
# 12             1,499,641    False         True
# 13               906,092    False         True
# 14               597,658    False         True
# 15               868,075    False         True
# 16               699,097    False         True
# 17               817,511    False         True
# 18               508,826    False         True
# 19             1,213,792    False         True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
ax = sns.barplot(x='last_available_confirmed', y='city', data=dfco[:20], palette='RdBu')

# %%
sns.distplot(dfc.last_available_confirmed)
# Out:
# /Users/valencar/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='last_available_confirmed', ylabel='Density'>

# %%
sns.distplot(dfe.last_available_confirmed)
# Out:
# /Users/valencar/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='last_available_confirmed', ylabel='Density'>

# %%
dfe.last_available_confirmed.describe()
# Out:
# count          27
# mean      482,363
# std       499,456
# min        71,330
# 25%       196,171
# 50%       351,163
# 75%       605,623
# max     2,532,047
# Name: last_available_confirmed, dtype: float64

# %%
dfc.last_available_confirmed.describe()
# Out:
# count     5,589
# mean      2,295
# std      12,462
# min           0
# 25%         230
# 50%         530
# 75%       1,405
# max     633,097
# Name: last_available_confirmed, dtype: float64

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5589 entries, 0 to 5614
# Data columns (total 16 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   epidemiological_week                           5589 non-null   int64
#  1   date                                           5589 non-null   object
#  2   order_for_place                                5589 non-null   int64
#  3   state                                          5589 non-null   object
#  4   city                                           5589 non-null   object
#  5   city_ibge_code                                 5570 non-null   float64
#  6   place_type                                     5589 non-null   object
#  7   last_available_confirmed                       5589 non-null   int64
#  8   last_available_confirmed_per_100k_inhabitants  5570 non-null   float64
#  9   new_confirmed                                  5589 non-null   int64
#  10  last_available_deaths                          5589 non-null   int64
#  11  new_deaths                                     5589 non-null   int64
#  12  last_available_death_rate                      5589 non-null   float64
#  13  estimated_population                           5570 non-null   float64
#  14  is_last                                        5589 non-null   bool
#  15  is_repeated                                    5589 non-null   bool
# dtypes: bool(2), float64(4), int64(6), object(4)
# memory usage: 665.9+ KB

# %%
dfc.head()
# Out:
#    epidemiological_week        date  order_for_place state          city  \
# 0                202114  2021-04-05              373    AC    Acrelândia
# 1                202114  2021-04-05              340    AC  Assis Brasil
# 2                202114  2021-04-05              332    AC     Brasiléia
# 3                202114  2021-04-05              363    AC        Bujari
# 4                202114  2021-04-05              333    AC      Capixaba
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       1,200,013       city                      1341
# 1       1,200,054       city                      1342
# 2       1,200,104       city                      2134
# 3       1,200,138       city                       971
# 4       1,200,179       city                       456
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          8,657              0
# 1                                         17,813              0
# 2                                          7,992              0
# 3                                          9,319              0
# 4                                          3,797              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                     22           0                          0
# 1                     18           0                          0
# 2                     29           0                          0
# 3                     12           0                          0
# 4                     13           0                          0
#
#    estimated_population  is_last  is_repeated
# 0                15,490    False         True
# 1                 7,534    False         True
# 2                26,702    False         True
# 3                10,420    False         True
# 4                12,008    False         True

# %%
dfc.tail()
# Out:
#       epidemiological_week        date  order_for_place state            city  \
# 5610                202114  2021-04-05              356    TO  Tocantinópolis
# 5611                202114  2021-04-05              318    TO        Tupirama
# 5612                202114  2021-04-05              318    TO      Tupiratins
# 5613                202114  2021-04-05              343    TO    Wanderlândia
# 5614                202114  2021-04-05              332    TO         Xambioá
#
#       city_ibge_code place_type  last_available_confirmed  \
# 5610       1,721,208       city                      1737
# 5611       1,721,257       city                       127
# 5612       1,721,307       city                        51
# 5613       1,722,081       city                       666
# 5614       1,722,107       city                      1619
#
#       last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 5610                                          7,603              0
# 5611                                          6,608              0
# 5612                                          1,869              0
# 5613                                          5,676              0
# 5614                                         14,054              0
#
#       last_available_deaths  new_deaths  last_available_death_rate  \
# 5610                     29           0                          0
# 5611                      2           0                          0
# 5612                      1           0                          0
# 5613                      8           0                          0
# 5614                     19           0                          0
#
#       estimated_population  is_last  is_repeated
# 5610                22,845    False         True
# 5611                 1,922    False         True
# 5612                 2,729    False         True
# 5613                11,734    False         True
# 5614                11,520    False         True

# %%
len(dfc)
# Out:
# 5589

# %%
dfco = dfc.sort_values(by='last_available_confirmed', ascending=False).reset_index(drop=True)
dfco.head(20)
# Out:
#     epidemiological_week        date  order_for_place state            city  \
# 0                 202114  2021-04-05              406    SP       São Paulo
# 1                 202114  2021-04-05              395    DF        Brasília
# 2                 202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                 202114  2021-04-05              389    BA        Salvador
# 4                 202114  2021-04-05              386    CE       Fortaleza
# 5                 202114  2021-04-05              389    AM          Manaus
# 6                 202114  2021-04-05              390    PR        Curitiba
# 7                 202114  2021-04-05              386    MG  Belo Horizonte
# 8                 202114  2021-04-05              390    GO         Goiânia
# 9                 202114  2021-04-05              391    RS    Porto Alegre
# 10                202114  2021-04-05              390    PE          Recife
# 11                202114  2021-04-05              388    SE         Aracaju
# 12                202114  2021-04-05              384    PA           Belém
# 13                202114  2021-04-05              388    MS    Campo Grande
# 14                202114  2021-04-05              389    SC       Joinville
# 15                202114  2021-04-05              383    PI        Teresina
# 16                202114  2021-04-05              385    MG      Uberlândia
# 17                202114  2021-04-05              384    PB     João Pessoa
# 18                202114  2021-04-05              390    SC   Florianópolis
# 19                202114  2021-04-05              384    SP        Campinas
#
#     city_ibge_code place_type  last_available_confirmed  \
# 0        3,550,308       city                    633097
# 1        5,300,108       city                    306766
# 2        3,304,557       city                    230450
# 3        2,927,408       city                    175965
# 4        2,304,400       city                    164429
# 5        1,302,603       city                    161465
# 6        4,106,902       city                    140575
# 7        3,106,200       city                    131388
# 8        5,208,707       city                    124618
# 9        4,314,902       city                    116145
# 10       2,611,606       city                     90140
# 11       2,800,308       city                     88884
# 12       1,501,402       city                     87266
# 13       5,002,704       city                     85372
# 14       4,209,102       city                     78909
# 15       2,211,001       city                     76548
# 16       3,170,206       city                     76458
# 17       2,507,507       city                     71118
# 18       4,205,407       city                     70012
# 19       3,509,502       city                     68564
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                           5,137              0
# 1                                          10,041              0
# 2                                           3,415              0
# 3                                           6,096              0
# 4                                           6,120              0
# 5                                           7,275              0
# 6                                           7,214             64
# 7                                           5,211              0
# 8                                           8,113              0
# 9                                           7,804              0
# 10                                          5,452              0
# 11                                         13,368              0
# 12                                          5,819              0
# 13                                          9,422              0
# 14                                         13,203              0
# 15                                          8,818              0
# 16                                         10,937              0
# 17                                          8,699              0
# 18                                         13,760              0
# 19                                          5,649              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   22734           0                          0
# 1                    5765           0                          0
# 2                   20987           0                          0
# 3                    5107           0                          0
# 4                    6192           0                          0
# 5                    8444           0                          0
# 6                    3299           1                          0
# 7                    3019           0                          0
# 8                    3683           0                          0
# 9                    3700           0                          0
# 10                   3411           0                          0
# 11                   1388           0                          0
# 12                   3690           0                          0
# 13                   1870           0                          0
# 14                   1025           0                          0
# 15                   1641           0                          0
# 16                   1510           0                          0
# 17                   2002           0                          0
# 18                    795           0                          0
# 19                   2458           0                          0
#
#     estimated_population  is_last  is_repeated
# 0             12,325,232    False         True
# 1              3,055,149    False         True
# 2              6,747,815    False         True
# 3              2,886,698    False         True
# 4              2,686,612    False         True
# 5              2,219,580    False         True
# 6              1,948,626     True        False
# 7              2,521,564    False         True
# 8              1,536,097    False         True
# 9              1,488,252    False         True
# 10             1,653,461    False         True
# 11               664,908    False         True
# 12             1,499,641    False         True
# 13               906,092    False         True
# 14               597,658    False         True
# 15               868,075    False         True
# 16               699,097    False         True
# 17               817,511    False         True
# 18               508,826    False         True
# 19             1,213,792    False         True

# %%
dfco.tail(20)
# Out:
#       epidemiological_week        date  order_for_place state  \
# 5569                202114  2021-04-05              283    MG
# 5570                202114  2021-04-05              283    MG
# 5571                202114  2021-04-05              276    MT
# 5572                202114  2021-04-05              283    MG
# 5573                202114  2021-04-05              284    MG
# 5574                202114  2021-04-05              333    MA
# 5575                202114  2021-04-05              281    RS
# 5576                202114  2021-04-05              298    MG
# 5577                202114  2021-04-05              283    MG
# 5578                202114  2021-04-05              283    MG
# 5579                202114  2021-04-05              288    MG
# 5580                202114  2021-04-05              373    AL
# 5581                202114  2021-04-05              377    SC
# 5582                202114  2021-04-05              381    RJ
# 5583                202114  2021-04-05              292    PB
# 5584                202114  2021-04-05              347    RO
# 5585                202114  2021-04-05              251    RS
# 5586                202114  2021-04-05              383    GO
# 5587                202114  2021-04-05              388    PE
# 5588                202114  2021-04-05              351    PA
#
#                         city  city_ibge_code place_type  \
# 5569         Oliveira Fortes       3,145,703       city
# 5570                Monjolos       3,142,502       city
# 5571              Araguainha       5,101,209       city
# 5572       São João do Pacuí       3,162,658       city
# 5573           Córrego Danta       3,119,807       city
# 5574     Boa Vista do Gurupi       2,101,970       city
# 5575   Dezesseis de Novembro       4,306,353       city
# 5576                Serranos       3,167,004       city
# 5577         Cedro do Abaeté       3,115,607       city
# 5578               Miravânia       3,142,254       city
# 5579                  Berilo       3,106,507       city
# 5580  Importados/Indefinidos             NaN       city
# 5581  Importados/Indefinidos             NaN       city
# 5582  Importados/Indefinidos             NaN       city
# 5583  Importados/Indefinidos             NaN       city
# 5584  Importados/Indefinidos             NaN       city
# 5585  Importados/Indefinidos             NaN       city
# 5586  Importados/Indefinidos             NaN       city
# 5587  Importados/Indefinidos             NaN       city
# 5588  Importados/Indefinidos             NaN       city
#
#       last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 5569                        20                                            939
# 5570                        17                                            772
# 5571                        16                                          1,691
# 5572                        15                                            337
# 5573                        15                                            470
# 5574                        14                                            167
# 5575                        14                                            589
# 5576                        13                                            665
# 5577                        12                                          1,037
# 5578                        10                                            204
# 5579                        10                                             84
# 5580                         3                                            NaN
# 5581                         0                                            NaN
# 5582                         0                                            NaN
# 5583                         0                                            NaN
# 5584                         0                                            NaN
# 5585                         0                                            NaN
# 5586                         0                                            NaN
# 5587                         0                                            NaN
# 5588                         0                                            NaN
#
#       new_confirmed  last_available_deaths  new_deaths  \
# 5569              0                      0           0
# 5570              0                      0           0
# 5571              0                      0           0
# 5572              0                      0           0
# 5573              0                      0           0
# 5574              0                      3           0
# 5575              0                      1           0
# 5576              0                      0           0
# 5577              0                      0           0
# 5578              0                      0           0
# 5579              0                      0           0
# 5580              0                      3           0
# 5581              0                      0           0
# 5582              0                      0           0
# 5583              0                      0           0
# 5584              0                      0           0
# 5585              0                      0           0
# 5586              0                      0           0
# 5587              0                      0           0
# 5588              0                      0           0
#
#       last_available_death_rate  estimated_population  is_last  is_repeated
# 5569                          0                 2,130    False         True
# 5570                          0                 2,202    False         True
# 5571                          0                   946     True        False
# 5572                          0                 4,448    False         True
# 5573                          0                 3,191    False         True
# 5574                          0                 8,382    False         True
# 5575                          0                 2,378    False         True
# 5576                          0                 1,956    False         True
# 5577                          0                 1,157    False         True
# 5578                          0                 4,914    False         True
# 5579                          0                11,872    False         True
# 5580                          1                   NaN    False         True
# 5581                          0                   NaN    False         True
# 5582                          0                   NaN    False         True
# 5583                          0                   NaN    False         True
# 5584                          0                   NaN    False         True
# 5585                          0                   NaN    False         True
# 5586                          0                   NaN    False         True
# 5587                          0                   NaN    False         True
# 5588                          0                   NaN    False         True

# %%
dfco[dfco.city == 'Campina Grande']
# Out:
#     epidemiological_week        date  order_for_place state            city  \
# 69                202114  2021-04-05              375    PB  Campina Grande
#
#     city_ibge_code place_type  last_available_confirmed  \
# 69       2,504,009       city                     24011
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 69                                          5,831              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 69                    687           0                          0
#
#     estimated_population  is_last  is_repeated
# 69               411,807    False         True

# %%
dfcg = dfco[dfco.city == 'Campina Grande']
type(dfcg)
# Out:
# pandas.core.frame.DataFrame

# %%
dfcg.last_available_confirmed
# Out:
# 69    24011
# Name: last_available_confirmed, dtype: int64

# %%
dfcg.last_available_confirmed.index
# Out:
# Int64Index([69], dtype='int64')

# %%
dfcg.last_available_confirmed.values
# Out:
# array([24011])

# %%
dfcg.last_available_confirmed.values[0]
# Out:
# 24011

# %%
dfco[dfco.city == 'João Pessoa']
# Out:
#     epidemiological_week        date  order_for_place state         city  \
# 17                202114  2021-04-05              384    PB  João Pessoa
#
#     city_ibge_code place_type  last_available_confirmed  \
# 17       2,507,507       city                     71118
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 17                                          8,699              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 17                   2002           0                          0
#
#     estimated_population  is_last  is_repeated
# 17               817,511    False         True

# %%
71118 / 24011
# Out:
# 2.9618924659531047

# %%
proporcao_cg_jp =  (dfco[dfco.city == 'João Pessoa'].last_available_confirmed.values[0]) / (dfco[dfco.city == 'Campina Grande'].last_available_confirmed.values[0])

proporcao_cg_jp
# Out:
# 2.9618924659531047

# %%
p = (dfco[dfco.city == 'Campina Grande'].last_available_confirmed.values[0])
type(p)
# Out:
# numpy.int64

# %%
p
# Out:
# 24011

# %%
# atributos
dfco.columns
# Out:
# Index(['epidemiological_week', 'date', 'order_for_place', 'state', 'city',
#        'city_ibge_code', 'place_type', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated'],
#       dtype='object')

# %%
dfco[:20]
# Out:
#     epidemiological_week        date  order_for_place state            city  \
# 0                 202114  2021-04-05              406    SP       São Paulo
# 1                 202114  2021-04-05              395    DF        Brasília
# 2                 202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                 202114  2021-04-05              389    BA        Salvador
# 4                 202114  2021-04-05              386    CE       Fortaleza
# 5                 202114  2021-04-05              389    AM          Manaus
# 6                 202114  2021-04-05              390    PR        Curitiba
# 7                 202114  2021-04-05              386    MG  Belo Horizonte
# 8                 202114  2021-04-05              390    GO         Goiânia
# 9                 202114  2021-04-05              391    RS    Porto Alegre
# 10                202114  2021-04-05              390    PE          Recife
# 11                202114  2021-04-05              388    SE         Aracaju
# 12                202114  2021-04-05              384    PA           Belém
# 13                202114  2021-04-05              388    MS    Campo Grande
# 14                202114  2021-04-05              389    SC       Joinville
# 15                202114  2021-04-05              383    PI        Teresina
# 16                202114  2021-04-05              385    MG      Uberlândia
# 17                202114  2021-04-05              384    PB     João Pessoa
# 18                202114  2021-04-05              390    SC   Florianópolis
# 19                202114  2021-04-05              384    SP        Campinas
#
#     city_ibge_code place_type  last_available_confirmed  \
# 0        3,550,308       city                    633097
# 1        5,300,108       city                    306766
# 2        3,304,557       city                    230450
# 3        2,927,408       city                    175965
# 4        2,304,400       city                    164429
# 5        1,302,603       city                    161465
# 6        4,106,902       city                    140575
# 7        3,106,200       city                    131388
# 8        5,208,707       city                    124618
# 9        4,314,902       city                    116145
# 10       2,611,606       city                     90140
# 11       2,800,308       city                     88884
# 12       1,501,402       city                     87266
# 13       5,002,704       city                     85372
# 14       4,209,102       city                     78909
# 15       2,211,001       city                     76548
# 16       3,170,206       city                     76458
# 17       2,507,507       city                     71118
# 18       4,205,407       city                     70012
# 19       3,509,502       city                     68564
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                           5,137              0
# 1                                          10,041              0
# 2                                           3,415              0
# 3                                           6,096              0
# 4                                           6,120              0
# 5                                           7,275              0
# 6                                           7,214             64
# 7                                           5,211              0
# 8                                           8,113              0
# 9                                           7,804              0
# 10                                          5,452              0
# 11                                         13,368              0
# 12                                          5,819              0
# 13                                          9,422              0
# 14                                         13,203              0
# 15                                          8,818              0
# 16                                         10,937              0
# 17                                          8,699              0
# 18                                         13,760              0
# 19                                          5,649              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   22734           0                          0
# 1                    5765           0                          0
# 2                   20987           0                          0
# 3                    5107           0                          0
# 4                    6192           0                          0
# 5                    8444           0                          0
# 6                    3299           1                          0
# 7                    3019           0                          0
# 8                    3683           0                          0
# 9                    3700           0                          0
# 10                   3411           0                          0
# 11                   1388           0                          0
# 12                   3690           0                          0
# 13                   1870           0                          0
# 14                   1025           0                          0
# 15                   1641           0                          0
# 16                   1510           0                          0
# 17                   2002           0                          0
# 18                    795           0                          0
# 19                   2458           0                          0
#
#     estimated_population  is_last  is_repeated
# 0             12,325,232    False         True
# 1              3,055,149    False         True
# 2              6,747,815    False         True
# 3              2,886,698    False         True
# 4              2,686,612    False         True
# 5              2,219,580    False         True
# 6              1,948,626     True        False
# 7              2,521,564    False         True
# 8              1,536,097    False         True
# 9              1,488,252    False         True
# 10             1,653,461    False         True
# 11               664,908    False         True
# 12             1,499,641    False         True
# 13               906,092    False         True
# 14               597,658    False         True
# 15               868,075    False         True
# 16               699,097    False         True
# 17               817,511    False         True
# 18               508,826    False         True
# 19             1,213,792    False         True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

ax = sns.barplot(x='last_available_confirmed', y='city', data=dfco[:20])

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='last_available_confirmed', y='city', data=dfco[:20], palette='RdBu')

# %%
dfc.head()
# Out:
#    epidemiological_week        date  order_for_place state          city  \
# 0                202114  2021-04-05              373    AC    Acrelândia
# 1                202114  2021-04-05              340    AC  Assis Brasil
# 2                202114  2021-04-05              332    AC     Brasiléia
# 3                202114  2021-04-05              363    AC        Bujari
# 4                202114  2021-04-05              333    AC      Capixaba
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       1,200,013       city                      1341
# 1       1,200,054       city                      1342
# 2       1,200,104       city                      2134
# 3       1,200,138       city                       971
# 4       1,200,179       city                       456
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          8,657              0
# 1                                         17,813              0
# 2                                          7,992              0
# 3                                          9,319              0
# 4                                          3,797              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                     22           0                          0
# 1                     18           0                          0
# 2                     29           0                          0
# 3                     12           0                          0
# 4                     13           0                          0
#
#    estimated_population  is_last  is_repeated
# 0                15,490    False         True
# 1                 7,534    False         True
# 2                26,702    False         True
# 3                10,420    False         True
# 4                12,008    False         True

# %%
dfp = dfc.sort_values(by='estimated_population', ascending=False).reset_index(drop=True)
dfp.head(10)
# Out:
#    epidemiological_week        date  order_for_place state            city  \
# 0                202114  2021-04-05              406    SP       São Paulo
# 1                202114  2021-04-05              396    RJ  Rio de Janeiro
# 2                202114  2021-04-05              395    DF        Brasília
# 3                202114  2021-04-05              389    BA        Salvador
# 4                202114  2021-04-05              386    CE       Fortaleza
# 5                202114  2021-04-05              386    MG  Belo Horizonte
# 6                202114  2021-04-05              389    AM          Manaus
# 7                202114  2021-04-05              390    PR        Curitiba
# 8                202114  2021-04-05              390    PE          Recife
# 9                202114  2021-04-05              390    GO         Goiânia
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       3,550,308       city                    633097
# 1       3,304,557       city                    230450
# 2       5,300,108       city                    306766
# 3       2,927,408       city                    175965
# 4       2,304,400       city                    164429
# 5       3,106,200       city                    131388
# 6       1,302,603       city                    161465
# 7       4,106,902       city                    140575
# 8       2,611,606       city                     90140
# 9       5,208,707       city                    124618
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          5,137              0
# 1                                          3,415              0
# 2                                         10,041              0
# 3                                          6,096              0
# 4                                          6,120              0
# 5                                          5,211              0
# 6                                          7,275              0
# 7                                          7,214             64
# 8                                          5,452              0
# 9                                          8,113              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                  22734           0                          0
# 1                  20987           0                          0
# 2                   5765           0                          0
# 3                   5107           0                          0
# 4                   6192           0                          0
# 5                   3019           0                          0
# 6                   8444           0                          0
# 7                   3299           1                          0
# 8                   3411           0                          0
# 9                   3683           0                          0
#
#    estimated_population  is_last  is_repeated
# 0            12,325,232    False         True
# 1             6,747,815    False         True
# 2             3,055,149    False         True
# 3             2,886,698    False         True
# 4             2,686,612    False         True
# 5             2,521,564    False         True
# 6             2,219,580    False         True
# 7             1,948,626     True        False
# 8             1,653,461    False         True
# 9             1,536,097    False         True

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='last_available_confirmed', y='city', data=dfco[:20], palette='RdBu')

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='estimated_population', y='city', data=dfp[:20], palette='RdBu')

# %% [markdown]
# # Tratar Valores Nulos

# %%
print(len(dfco))
dfco.isna().sum()
# Out:
# 5589
# epidemiological_week                              0
# date                                              0
# order_for_place                                   0
# state                                             0
# city                                              0
# city_ibge_code                                   19
# place_type                                        0
# last_available_confirmed                          0
# last_available_confirmed_per_100k_inhabitants    19
# new_confirmed                                     0
# last_available_deaths                             0
# new_deaths                                        0
# last_available_death_rate                         0
# estimated_population                             19
# is_last                                           0
# is_repeated                                       0
# dtype: int64

# %%
dfco [ dfco.city_ibge_code.isna() ]
# Out:
#       epidemiological_week        date  order_for_place state  \
# 36                  202114  2021-04-05              376    DF
# 187                 202114  2021-04-05              378    BA
# 253                 202114  2021-04-05              383    CE
# 399                 202114  2021-04-05              380    PR
# 496                 202114  2021-04-05              381    MG
# 699                 202114  2021-04-05              378    ES
# 813                 202114  2021-04-05              341    RR
# 1103                202114  2021-04-05              365    MT
# 1387                202114  2021-04-05              374    RN
# 3194                202114  2021-04-05              383    SP
# 5580                202114  2021-04-05              373    AL
# 5581                202114  2021-04-05              377    SC
# 5582                202114  2021-04-05              381    RJ
# 5583                202114  2021-04-05              292    PB
# 5584                202114  2021-04-05              347    RO
# 5585                202114  2021-04-05              251    RS
# 5586                202114  2021-04-05              383    GO
# 5587                202114  2021-04-05              388    PE
# 5588                202114  2021-04-05              351    PA
#
#                         city  city_ibge_code place_type  \
# 36    Importados/Indefinidos             NaN       city
# 187   Importados/Indefinidos             NaN       city
# 253   Importados/Indefinidos             NaN       city
# 399   Importados/Indefinidos             NaN       city
# 496   Importados/Indefinidos             NaN       city
# 699   Importados/Indefinidos             NaN       city
# 813   Importados/Indefinidos             NaN       city
# 1103  Importados/Indefinidos             NaN       city
# 1387  Importados/Indefinidos             NaN       city
# 3194  Importados/Indefinidos             NaN       city
# 5580  Importados/Indefinidos             NaN       city
# 5581  Importados/Indefinidos             NaN       city
# 5582  Importados/Indefinidos             NaN       city
# 5583  Importados/Indefinidos             NaN       city
# 5584  Importados/Indefinidos             NaN       city
# 5585  Importados/Indefinidos             NaN       city
# 5586  Importados/Indefinidos             NaN       city
# 5587  Importados/Indefinidos             NaN       city
# 5588  Importados/Indefinidos             NaN       city
#
#       last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 36                       43009                                            NaN
# 187                      10549                                            NaN
# 253                       7922                                            NaN
# 399                       5377                                            NaN
# 496                       4266                                            NaN
# 699                       2933                                            NaN
# 813                       2489                                            NaN
# 1103                      1827                                            NaN
# 1387                      1418                                            NaN
# 3194                       424                                            NaN
# 5580                         3                                            NaN
# 5581                         0                                            NaN
# 5582                         0                                            NaN
# 5583                         0                                            NaN
# 5584                         0                                            NaN
# 5585                         0                                            NaN
# 5586                         0                                            NaN
# 5587                         0                                            NaN
# 5588                         0                                            NaN
#
#       new_confirmed  last_available_deaths  new_deaths  \
# 36                0                    523           0
# 187               0                    135           0
# 253               0                      0           0
# 399               0                    117           0
# 496               0                    181           0
# 699               0                    143           0
# 813               0                     13           0
# 1103              9                    139           3
# 1387              0                     30           0
# 3194              0                      0           0
# 5580              0                      3           0
# 5581              0                      0           0
# 5582              0                      0           0
# 5583              0                      0           0
# 5584              0                      0           0
# 5585              0                      0           0
# 5586              0                      0           0
# 5587              0                      0           0
# 5588              0                      0           0
#
#       last_available_death_rate  estimated_population  is_last  is_repeated
# 36                            0                   NaN    False         True
# 187                           0                   NaN    False         True
# 253                           0                   NaN    False         True
# 399                           0                   NaN     True        False
# 496                           0                   NaN    False         True
# 699                           0                   NaN    False         True
# 813                           0                   NaN    False         True
# 1103                          0                   NaN     True        False
# 1387                          0                   NaN    False         True
# 3194                          0                   NaN    False         True
# 5580                          1                   NaN    False         True
# 5581                          0                   NaN    False         True
# 5582                          0                   NaN    False         True
# 5583                          0                   NaN    False         True
# 5584                          0                   NaN    False         True
# 5585                          0                   NaN    False         True
# 5586                          0                   NaN    False         True
# 5587                          0                   NaN    False         True
# 5588                          0                   NaN    False         True

# %%
print(len(dfco))
dfco = dfco [ ~ dfco.city_ibge_code.isna() ]
print(len(dfco))
# Out:
# 5589
# 5570

# %% [markdown]
# # Tramento de Data - Função Lambda

# %%
dfco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 0 to 5579
# Data columns (total 16 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   epidemiological_week                           5570 non-null   int64
#  1   date                                           5570 non-null   object
#  2   order_for_place                                5570 non-null   int64
#  3   state                                          5570 non-null   object
#  4   city                                           5570 non-null   object
#  5   city_ibge_code                                 5570 non-null   float64
#  6   place_type                                     5570 non-null   object
#  7   last_available_confirmed                       5570 non-null   int64
#  8   last_available_confirmed_per_100k_inhabitants  5570 non-null   float64
#  9   new_confirmed                                  5570 non-null   int64
#  10  last_available_deaths                          5570 non-null   int64
#  11  new_deaths                                     5570 non-null   int64
#  12  last_available_death_rate                      5570 non-null   float64
#  13  estimated_population                           5570 non-null   float64
#  14  is_last                                        5570 non-null   bool
#  15  is_repeated                                    5570 non-null   bool
# dtypes: bool(2), float64(4), int64(6), object(4)
# memory usage: 663.6+ KB

# %%
dfco.head()
# Out:
#    epidemiological_week        date  order_for_place state            city  \
# 0                202114  2021-04-05              406    SP       São Paulo
# 1                202114  2021-04-05              395    DF        Brasília
# 2                202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                202114  2021-04-05              389    BA        Salvador
# 4                202114  2021-04-05              386    CE       Fortaleza
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       3,550,308       city                    633097
# 1       5,300,108       city                    306766
# 2       3,304,557       city                    230450
# 3       2,927,408       city                    175965
# 4       2,304,400       city                    164429
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          5,137              0
# 1                                         10,041              0
# 2                                          3,415              0
# 3                                          6,096              0
# 4                                          6,120              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                  22734           0                          0
# 1                   5765           0                          0
# 2                  20987           0                          0
# 3                   5107           0                          0
# 4                   6192           0                          0
#
#    estimated_population  is_last  is_repeated
# 0            12,325,232    False         True
# 1             3,055,149    False         True
# 2             6,747,815    False         True
# 3             2,886,698    False         True
# 4             2,686,612    False         True

# %%
dfco['Data'] = pd.to_datetime(dfco['date'])
dfco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 0 to 5579
# Data columns (total 17 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   epidemiological_week                           5570 non-null   int64
#  1   date                                           5570 non-null   object
#  2   order_for_place                                5570 non-null   int64
#  3   state                                          5570 non-null   object
#  4   city                                           5570 non-null   object
#  5   city_ibge_code                                 5570 non-null   float64
#  6   place_type                                     5570 non-null   object
#  7   last_available_confirmed                       5570 non-null   int64
#  8   last_available_confirmed_per_100k_inhabitants  5570 non-null   float64
#  9   new_confirmed                                  5570 non-null   int64
#  10  last_available_deaths                          5570 non-null   int64
#  11  new_deaths                                     5570 non-null   int64
#  12  last_available_death_rate                      5570 non-null   float64
#  13  estimated_population                           5570 non-null   float64
#  14  is_last                                        5570 non-null   bool
#  15  is_repeated                                    5570 non-null   bool
#  16  Data                                           5570 non-null   datetime64[ns]
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(6), object(4)
# memory usage: 707.1+ KB

# %%
dfco.head()
# Out:
#    epidemiological_week        date  order_for_place state            city  \
# 0                202114  2021-04-05              406    SP       São Paulo
# 1                202114  2021-04-05              395    DF        Brasília
# 2                202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                202114  2021-04-05              389    BA        Salvador
# 4                202114  2021-04-05              386    CE       Fortaleza
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       3,550,308       city                    633097
# 1       5,300,108       city                    306766
# 2       3,304,557       city                    230450
# 3       2,927,408       city                    175965
# 4       2,304,400       city                    164429
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          5,137              0
# 1                                         10,041              0
# 2                                          3,415              0
# 3                                          6,096              0
# 4                                          6,120              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                  22734           0                          0
# 1                   5765           0                          0
# 2                  20987           0                          0
# 3                   5107           0                          0
# 4                   6192           0                          0
#
#    estimated_population  is_last  is_repeated       Data
# 0            12,325,232    False         True 2021-04-05
# 1             3,055,149    False         True 2021-04-05
# 2             6,747,815    False         True 2021-04-05
# 3             2,886,698    False         True 2021-04-05
# 4             2,686,612    False         True 2021-04-05

# %%
dfco['ano'] = dfco['Data'].apply(lambda  x : x.year)
dfco['dia'] = dfco['Data'].apply(lambda  x : x.day)
dfco.head()
# Out:
#    epidemiological_week        date  order_for_place state            city  \
# 0                202114  2021-04-05              406    SP       São Paulo
# 1                202114  2021-04-05              395    DF        Brasília
# 2                202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                202114  2021-04-05              389    BA        Salvador
# 4                202114  2021-04-05              386    CE       Fortaleza
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0       3,550,308       city                    633097
# 1       5,300,108       city                    306766
# 2       3,304,557       city                    230450
# 3       2,927,408       city                    175965
# 4       2,304,400       city                    164429
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                          5,137              0
# 1                                         10,041              0
# 2                                          3,415              0
# 3                                          6,096              0
# 4                                          6,120              0
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 0                  22734           0                          0
# 1                   5765           0                          0
# 2                  20987           0                          0
# 3                   5107           0                          0
# 4                   6192           0                          0
#
#    estimated_population  is_last  is_repeated       Data   ano  dia
# 0            12,325,232    False         True 2021-04-05  2021    5
# 1             3,055,149    False         True 2021-04-05  2021    5
# 2             6,747,815    False         True 2021-04-05  2021    5
# 3             2,886,698    False         True 2021-04-05  2021    5
# 4             2,686,612    False         True 2021-04-05  2021    5

# %% [markdown]
# # Colocando uma média no lugar de Nan (Nulo)

# %%
media = dfco.estimated_population.mean()
print('Média População Cidades =  {:,.2f}'.format(media) )
# Out:
# Média População Cidades =  38,017.18

# %%
dfco2 = dfco.copy()
dfco2.fillna({'estimated_population': media }, inplace=True)
dfco2.isna().sum()
# Out:
# epidemiological_week                             0
# date                                             0
# order_for_place                                  0
# state                                            0
# city                                             0
# city_ibge_code                                   0
# place_type                                       0
# last_available_confirmed                         0
# last_available_confirmed_per_100k_inhabitants    0
# new_confirmed                                    0
# last_available_deaths                            0
# new_deaths                                       0
# last_available_death_rate                        0
# estimated_population                             0
# is_last                                          0
# is_repeated                                      0
# Data                                             0
# ano                                              0
# dia                                              0
# dtype: int64

# %%
len(dfco), len(dfco2)
# Out:
# (5570, 5570)

# %%
dfco2.head(15)
# Out:
#     epidemiological_week        date  order_for_place state            city  \
# 0                 202114  2021-04-05              406    SP       São Paulo
# 1                 202114  2021-04-05              395    DF        Brasília
# 2                 202114  2021-04-05              396    RJ  Rio de Janeiro
# 3                 202114  2021-04-05              389    BA        Salvador
# 4                 202114  2021-04-05              386    CE       Fortaleza
# 5                 202114  2021-04-05              389    AM          Manaus
# 6                 202114  2021-04-05              390    PR        Curitiba
# 7                 202114  2021-04-05              386    MG  Belo Horizonte
# 8                 202114  2021-04-05              390    GO         Goiânia
# 9                 202114  2021-04-05              391    RS    Porto Alegre
# 10                202114  2021-04-05              390    PE          Recife
# 11                202114  2021-04-05              388    SE         Aracaju
# 12                202114  2021-04-05              384    PA           Belém
# 13                202114  2021-04-05              388    MS    Campo Grande
# 14                202114  2021-04-05              389    SC       Joinville
#
#     city_ibge_code place_type  last_available_confirmed  \
# 0        3,550,308       city                    633097
# 1        5,300,108       city                    306766
# 2        3,304,557       city                    230450
# 3        2,927,408       city                    175965
# 4        2,304,400       city                    164429
# 5        1,302,603       city                    161465
# 6        4,106,902       city                    140575
# 7        3,106,200       city                    131388
# 8        5,208,707       city                    124618
# 9        4,314,902       city                    116145
# 10       2,611,606       city                     90140
# 11       2,800,308       city                     88884
# 12       1,501,402       city                     87266
# 13       5,002,704       city                     85372
# 14       4,209,102       city                     78909
#
#     last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                           5,137              0
# 1                                          10,041              0
# 2                                           3,415              0
# 3                                           6,096              0
# 4                                           6,120              0
# 5                                           7,275              0
# 6                                           7,214             64
# 7                                           5,211              0
# 8                                           8,113              0
# 9                                           7,804              0
# 10                                          5,452              0
# 11                                         13,368              0
# 12                                          5,819              0
# 13                                          9,422              0
# 14                                         13,203              0
#
#     last_available_deaths  new_deaths  last_available_death_rate  \
# 0                   22734           0                          0
# 1                    5765           0                          0
# 2                   20987           0                          0
# 3                    5107           0                          0
# 4                    6192           0                          0
# 5                    8444           0                          0
# 6                    3299           1                          0
# 7                    3019           0                          0
# 8                    3683           0                          0
# 9                    3700           0                          0
# 10                   3411           0                          0
# 11                   1388           0                          0
# 12                   3690           0                          0
# 13                   1870           0                          0
# 14                   1025           0                          0
#
#     estimated_population  is_last  is_repeated       Data   ano  dia
# 0             12,325,232    False         True 2021-04-05  2021    5
# 1              3,055,149    False         True 2021-04-05  2021    5
# 2              6,747,815    False         True 2021-04-05  2021    5
# 3              2,886,698    False         True 2021-04-05  2021    5
# 4              2,686,612    False         True 2021-04-05  2021    5
# 5              2,219,580    False         True 2021-04-05  2021    5
# 6              1,948,626     True        False 2021-04-05  2021    5
# 7              2,521,564    False         True 2021-04-05  2021    5
# 8              1,536,097    False         True 2021-04-05  2021    5
# 9              1,488,252    False         True 2021-04-05  2021    5
# 10             1,653,461    False         True 2021-04-05  2021    5
# 11               664,908    False         True 2021-04-05  2021    5
# 12             1,499,641    False         True 2021-04-05  2021    5
# 13               906,092    False         True 2021-04-05  2021    5
# 14               597,658    False         True 2021-04-05  2021    5

# %%
dg = dfco2.groupby('state').sum().reset_index()
len(dg)
# Out:
# 27

# %%
dg.head(8)
# Out:
#   state  epidemiological_week  order_for_place  city_ibge_code  \
# 0    AC               4446508             7577      26,407,719
# 1    AL              20615628            34329     275,887,914
# 2    AM              12531068            21803      80,734,451
# 3    AP               3233824             5627      25,605,908
# 4    BA              84281538           137820   1,216,451,757
# 5    CE              37188976            64749     424,495,156
# 6    DF                202114              395       5,300,108
# 7    ES              15764892            27699     249,826,710
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                     71062                                        173,364
# 1                    151821                                        336,668
# 2                    352312                                        651,565
# 3                     98898                                        220,427
# 4                    805100                                      1,901,854
# 5                    541345                                      1,029,611
# 6                    306766                                         10,041
# 7                    385667                                        726,983
#
#    new_confirmed  last_available_deaths  new_deaths  \
# 0              0                   1284           0
# 1              0                   3486           0
# 2              0                  12072           0
# 3              0                   1323           0
# 4              0                  15575           0
# 5              0                  14359           0
# 6              0                   5765           0
# 7              0                   7529           0
#
#    last_available_death_rate  estimated_population  is_last  is_repeated  \
# 0                          0               894,470        0           22
# 1                          3             3,351,543        0          102
# 2                          1             4,207,714        0           62
# 3                          0               861,773        0           16
# 4                          7            14,930,634        0          417
# 5                          4             9,187,103        0          184
# 6                          0             3,055,149        0            1
# 7                          2             4,064,052        0           78
#
#       ano   dia
# 0   44462   110
# 1  206142   510
# 2  125302   310
# 3   32336    80
# 4  842757  2085
# 5  371864   920
# 6    2021     5
# 7  157638   390

# %%
dg.columns
# Out:
# Index(['state', 'epidemiological_week', 'order_for_place', 'city_ibge_code',
#        'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated', 'ano', 'dia'],
#       dtype='object')

# %%
dg.columns.values
# Out:
# array(['state', 'epidemiological_week', 'order_for_place',
#        'city_ibge_code', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated', 'ano', 'dia'],
#       dtype=object)

# %%
atributos =  [ 'state', 
       'last_available_confirmed',
        'new_confirmed',
        'new_deaths',
       'estimated_population' ]
dg2 = dg [ atributos  ]
dg2
# Out:
#    state  last_available_confirmed  new_confirmed  new_deaths  \
# 0     AC                     71062              0           0
# 1     AL                    151821              0           0
# 2     AM                    352312              0           0
# 3     AP                     98898              0           0
# 4     BA                    805100              0           0
# 5     CE                    541345              0           0
# 6     DF                    306766              0           0
# 7     ES                    385667              0           0
# 8     GO                    490347              0           0
# 9     MA                    244563              0           0
# 10    MG                   1029296              0           0
# 11    MS                    215598              0           0
# 12    MT                    315427           2158         125
# 13    PA                    423691              0           0
# 14    PB                    262500              0           0
# 15    PE                    355617              0           0
# 16    PI                    210843              0           0
# 17    PR                    855047           1436         106
# 18    RJ                    658440              0           0
# 19    RN                    182399              0           0
# 20    RO                    189349              0           0
# 21    RR                     87364              0           0
# 22    RS                    860136              0           0
# 23    SC                    813871              0           0
# 24    SE                    178301              0           0
# 25    SP                   2519780              0           0
# 26    TO                    143322              0           0
#
#     estimated_population
# 0                894,470
# 1              3,351,543
# 2              4,207,714
# 3                861,773
# 4             14,930,634
# 5              9,187,103
# 6              3,055,149
# 7              4,064,052
# 8              7,113,540
# 9              7,114,598
# 10            21,292,666
# 11             2,809,394
# 12             3,526,220
# 13             8,690,745
# 14             4,039,277
# 15             9,616,621
# 16             3,281,480
# 17            11,516,840
# 18            17,366,189
# 19             3,534,165
# 20             1,796,460
# 21               631,181
# 22            11,422,973
# 23             7,252,502
# 24             2,318,822
# 25            46,289,333
# 26             1,590,248

# %%
dgo = dg2.sort_values(by='last_available_confirmed', ascending=False).reset_index(drop=True)
dgo
# Out:
#    state  last_available_confirmed  new_confirmed  new_deaths  \
# 0     SP                   2519780              0           0
# 1     MG                   1029296              0           0
# 2     RS                    860136              0           0
# 3     PR                    855047           1436         106
# 4     SC                    813871              0           0
# 5     BA                    805100              0           0
# 6     RJ                    658440              0           0
# 7     CE                    541345              0           0
# 8     GO                    490347              0           0
# 9     PA                    423691              0           0
# 10    ES                    385667              0           0
# 11    PE                    355617              0           0
# 12    AM                    352312              0           0
# 13    MT                    315427           2158         125
# 14    DF                    306766              0           0
# 15    PB                    262500              0           0
# 16    MA                    244563              0           0
# 17    MS                    215598              0           0
# 18    PI                    210843              0           0
# 19    RO                    189349              0           0
# 20    RN                    182399              0           0
# 21    SE                    178301              0           0
# 22    AL                    151821              0           0
# 23    TO                    143322              0           0
# 24    AP                     98898              0           0
# 25    RR                     87364              0           0
# 26    AC                     71062              0           0
#
#     estimated_population
# 0             46,289,333
# 1             21,292,666
# 2             11,422,973
# 3             11,516,840
# 4              7,252,502
# 5             14,930,634
# 6             17,366,189
# 7              9,187,103
# 8              7,113,540
# 9              8,690,745
# 10             4,064,052
# 11             9,616,621
# 12             4,207,714
# 13             3,526,220
# 14             3,055,149
# 15             4,039,277
# 16             7,114,598
# 17             2,809,394
# 18             3,281,480
# 19             1,796,460
# 20             3,534,165
# 21             2,318,822
# 22             3,351,543
# 23             1,590,248
# 24               861,773
# 25               631,181
# 26               894,470

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
ax = sns.barplot(x='last_available_confirmed', y='state', data=dgo[:], palette='RdBu')

# %% [markdown]
# # Mapas

# %%
#!pip install geopandas
#!pip install mapclassify

# %%
# !ls estados*
# Out:
# estados_2010.dbf estados_2010.shp estados_2010.shx

# %%
import geopandas as gpd

df = gpd.read_file('estados_2010.shp') 
df2 = gpd.read_file('estados_2010.shp') 
df.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...

# %%
df.geometry
# Out:
# 0     POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...
# 1     POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...
# 2     POLYGON ((-67.32553 2.03012, -67.32234 2.01741...
# 3     POLYGON ((-51.18168 4.00889, -51.17900 3.99812...
# 4     POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...
# 5     MULTIPOLYGON (((-40.01804 -2.83698, -40.00587 ...
# 6     POLYGON ((-47.30861 -16.03549, -47.31095 -16.0...
# 7     MULTIPOLYGON (((-40.72383 -20.84178, -40.72804...
# 8     POLYGON ((-50.15776 -12.41195, -50.15901 -12.4...
# 9     MULTIPOLYGON (((-47.03102 -8.98549, -47.02113 ...
# 10    POLYGON ((-44.20886 -14.24413, -44.20871 -14.2...
# 11    MULTIPOLYGON (((-53.87406 -17.92178, -53.87182...
# 12    MULTIPOLYGON (((-60.36083 -13.29932, -60.36033...
# 13    MULTIPOLYGON (((-46.95145 -0.73406, -46.95624 ...
# 14    MULTIPOLYGON (((-37.22677 -6.03464, -37.22228 ...
# 15    MULTIPOLYGON (((-37.17654 -7.30917, -37.16811 ...
# 16    POLYGON ((-41.73868 -2.80558, -41.73440 -2.807...
# 17    POLYGON ((-52.06416 -22.53384, -52.05556 -22.5...
# 18    MULTIPOLYGON (((-44.51273 -23.29294, -44.51640...
# 19    POLYGON ((-37.15172 -4.93536, -37.13311 -4.937...
# 20    MULTIPOLYGON (((-66.45889 -9.87524, -66.46301 ...
# 21    POLYGON ((-59.91635 3.14591, -59.91256 3.14764...
# 22    MULTIPOLYGON (((-52.04367 -31.57374, -52.03627...
# 23    MULTIPOLYGON (((-53.72045 -26.55991, -53.72407...
# 24    POLYGON ((-37.96006 -9.53282, -37.91674 -9.548...
# 25    MULTIPOLYGON (((-46.13772 -23.85888, -46.13327...
# 26    POLYGON ((-47.03296 -8.98232, -47.03102 -8.985...
# Name: geometry, dtype: geometry

# %%
df.plot(figsize=(14,10))
# Out:
# <AxesSubplot:>

# %%
dgo.head()
# Out:
#   state  last_available_confirmed  new_confirmed  new_deaths  \
# 0    SP                   2519780              0           0
# 1    MG                   1029296              0           0
# 2    RS                    860136              0           0
# 3    PR                    855047           1436         106
# 4    SC                    813871              0           0
#
#    estimated_population
# 0            46,289,333
# 1            21,292,666
# 2            11,422,973
# 3            11,516,840
# 4             7,252,502

# %%
df.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...

# %%
type(df), type(dgo)
# Out:
# (geopandas.geodataframe.GeoDataFrame, pandas.core.frame.DataFrame)

# %%
df.sigla.values
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
dgo.state.values
# Out:
# array(['SP', 'MG', 'RS', 'PR', 'SC', 'BA', 'RJ', 'CE', 'GO', 'PA', 'ES',
#        'PE', 'AM', 'MT', 'DF', 'PB', 'MA', 'MS', 'PI', 'RO', 'RN', 'SE',
#        'AL', 'TO', 'AP', 'RR', 'AC'], dtype=object)

# %%
df2.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...

# %%
dgo.head()
# Out:
#   state  last_available_confirmed  new_confirmed  new_deaths  \
# 0    SP                   2519780              0           0
# 1    MG                   1029296              0           0
# 2    RS                    860136              0           0
# 3    PR                    855047           1436         106
# 4    SC                    813871              0           0
#
#    estimated_population
# 0            46,289,333
# 1            21,292,666
# 2            11,422,973
# 3            11,516,840
# 4             7,252,502

# %%
# Junção
d = df2.merge(dgo, left_on='sigla', right_on='state')
d.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry state  \
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...    AC
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...    AL
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...    AM
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...    AP
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...    BA
#
#    last_available_confirmed  new_confirmed  new_deaths  estimated_population
# 0                     71062              0           0               894,470
# 1                    151821              0           0             3,351,543
# 2                    352312              0           0             4,207,714
# 3                     98898              0           0               861,773
# 4                    805100              0           0            14,930,634

# %%
type(d)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
d.tail()
# Out:
#     id               nome sigla regiao_id codigo_ibg  \
# 22  23  Rio Grande do Sul    RS         1         43
# 23  24     Santa Catarina    SC         1         42
# 24  25            Sergipe    SE         4         28
# 25  26          São Paulo    SP         2         35
# 26  27          Tocantins    TO         3         17
#
#                                              geometry state  \
# 22  MULTIPOLYGON (((-52.04367 -31.57374, -52.03627...    RS
# 23  MULTIPOLYGON (((-53.72045 -26.55991, -53.72407...    SC
# 24  POLYGON ((-37.96006 -9.53282, -37.91674 -9.548...    SE
# 25  MULTIPOLYGON (((-46.13772 -23.85888, -46.13327...    SP
# 26  POLYGON ((-47.03296 -8.98232, -47.03102 -8.985...    TO
#
#     last_available_confirmed  new_confirmed  new_deaths  estimated_population
# 22                    860136              0           0            11,422,973
# 23                    813871              0           0             7,252,502
# 24                    178301              0           0             2,318,822
# 25                   2519780              0           0            46,289,333
# 26                    143322              0           0             1,590,248

# %%
# palettes
pal = ["Reds", 'OrRd', 'cubehelix', 'Greens', 'winter', 'Greens', "RdBu_r", 'Blues', 'OrRd' ]

cmap = pal[0]


fig, ax = plt.subplots(figsize=(14, 10))

d.plot(column='last_available_confirmed', figsize=(14,10), cmap=cmap, legend=True, ax=ax)

ax.set(title='Covid-19 - Últimos Casos Confirmados - 8/Abril/2021')

ax.set_axis_off()
plt.show()

# %%
cmap = pal[1]


fig, ax = plt.subplots(figsize=(14, 10))

d.plot(column='estimated_population', figsize=(14,10), cmap=cmap, legend=True, ax=ax)

ax.set(title='Covid-19 - estimated_population - Abril/2021')

ax.set_axis_off()
plt.show()

# %%
d.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry state  \
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...    AC
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...    AL
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...    AM
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...    AP
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...    BA
#
#    last_available_confirmed  new_confirmed  new_deaths  estimated_population
# 0                     71062              0           0               894,470
# 1                    151821              0           0             3,351,543
# 2                    352312              0           0             4,207,714
# 3                     98898              0           0               861,773
# 4                    805100              0           0            14,930,634

# %%
import numpy as np
d.last_available_confirmed.values.astype(np.float32)
# Out:
# array([  71062.,  151821.,  352312.,   98898.,  805100.,  541345.,
#         306766.,  385667.,  490347.,  244563., 1029296.,  215598.,
#         315427.,  423691.,  262500.,  355617.,  210843.,  855047.,
#         658440.,  182399.,  189349.,   87364.,  860136.,  813871.,
#         178301., 2519780.,  143322.], dtype=float32)

# %%
d.estimated_population.values.astype(np.float32)
# Out:
# array([  894470.,  3351543.,  4207714.,   861773., 14930634.,  9187103.,
#         3055149.,  4064052.,  7113540.,  7114598., 21292666.,  2809394.,
#         3526220.,  8690745.,  4039277.,  9616621.,  3281480., 11516840.,
#        17366188.,  3534165.,  1796460.,   631181., 11422973.,  7252502.,
#         2318822., 46289332.,  1590248.], dtype=float32)

# %%
import numpy as np

d['casos_pop'] = (d.last_available_confirmed.values.astype(np.float32) / d.estimated_population.values.astype(np.float32)) * 100
d.head()
# Out:
#    id      nome sigla regiao_id codigo_ibg  \
# 0   1      Acre    AC         3         12
# 1   2   Alagoas    AL         4         27
# 2   3  Amazonas    AM         3         13
# 3   4     Amapá    AP         3         16
# 4   5     Bahia    BA         4         29
#
#                                             geometry state  \
# 0  POLYGON ((-73.60818 -7.20194, -72.86963 -7.528...    AC
# 1  POLYGON ((-35.46516 -8.82549, -35.46626 -8.827...    AL
# 2  POLYGON ((-67.32553 2.03012, -67.32234 2.01741...    AM
# 3  POLYGON ((-51.18168 4.00889, -51.17900 3.99812...    AP
# 4  POLYGON ((-39.28820 -8.56290, -39.28229 -8.567...    BA
#
#    last_available_confirmed  new_confirmed  new_deaths  estimated_population  \
# 0                     71062              0           0               894,470
# 1                    151821              0           0             3,351,543
# 2                    352312              0           0             4,207,714
# 3                     98898              0           0               861,773
# 4                    805100              0           0            14,930,634
#
#    casos_pop
# 0          8
# 1          5
# 2          8
# 3         11
# 4          5

# %%
cmap = pal[0]


fig, ax = plt.subplots(figsize=(14, 10))

d.plot(column='casos_pop', figsize=(14,10), cmap=cmap, legend=True, ax=ax)

ax.set(title='Covid-19 - casos_pop - Abril/2021')

ax.set_axis_off()
plt.show()

# %%
d.head()

# %%
d.to_csv('mapa_br_covid.csv', index=False)

# %%
# ls
# !ls mapa*.csv

# %%
# !cat mapa_br_covid.csv
