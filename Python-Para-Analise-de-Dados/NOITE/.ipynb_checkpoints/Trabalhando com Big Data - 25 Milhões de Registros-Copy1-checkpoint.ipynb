# %% [markdown]
# ## Trabalhando com Big Data - 25 Milhões de Registros
# fonte: https://grouplens.org/datasets/movielens/

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/valencar/Dropbox/AULAS-REMOTAS/Alunos-UEPB-TopicosEspeciaisEmBancoDeDados/Python-Para-Analise-de-Dados/NOITE

# %%
# !ls -ilah /Users/valencar/Dropbox/AULAS-REMOTAS/BD-ESTATISTICA-MANHA/datasets/ml-20m
# Out:
# total 5212696
# 8852112067 drwxr-xr-x@ 16 valencar  staff   512B Feb  3 04:05 .
# 8753341664 drwxr-xr-x@ 34 valencar  staff   1.1K Feb  3 10:49 ..
# 8852135013 -rw-r--r--@  1 valencar  staff   6.0K Dec 21 16:32 .DS_Store
# 8852112072 -rw-r--r--@  1 valencar  staff    10K Oct 17  2016 README.txt
# 8852115885 -rw-r--r--@  1 valencar  staff   1.1M Dec 20 17:50 filmes-ratings.csv
# 8860047286 -rw-r--r--@  1 valencar  staff   277M Feb  3 01:59 filmes.pbix
# 8852133601 -rw-r--r--@  1 valencar  staff    46K Dec 20 21:38 filmes2.csv
# 8859960005 -rw-r-----@  1 valencar  staff   1.1G Dec 20 22:20 filmes4.csv
# 8852142504 -rw-r--r--@  1 valencar  staff   287M Dec 21 05:20 filmes4.csv.zip
# 8852112073 -rw-r--r--@  1 valencar  staff   309M Oct 17  2016 genome-scores.csv
# 8852112070 -rw-r--r--@  1 valencar  staff    18K Oct 17  2016 genome-tags.csv
# 8852112068 -rw-r--r--@  1 valencar  staff   557K Oct 17  2016 links.csv
# 8852445227 -rw-r--r--@  1 valencar  staff   2.3K Dec 24 23:22 ml-20m.sql
# 8852112074 -rw-r--r--@  1 valencar  staff   1.3M Mar 31  2015 movies.csv
# 8852112071 -rw-r--r--@  1 valencar  staff   509M Mar 31  2015 ratings.csv
# 8852112069 -rw-r--r--@  1 valencar  staff    16M Mar 31  2015 tags.csv

# %%
# !head /Users/valencar/Dropbox/AULAS-REMOTAS/BD-ESTATISTICA-MANHA/datasets/ml-20m/movies.csv
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 5,Father of the Bride Part II (1995),Comedy
# 6,Heat (1995),Action|Crime|Thriller
# 7,Sabrina (1995),Comedy|Romance
# 8,Tom and Huck (1995),Adventure|Children
# 9,Sudden Death (1995),Action

# %%
url = '/Users/valencar/Dropbox/AULAS-REMOTAS/BD-ESTATISTICA-MANHA/datasets/ml-20m' + '/' + 'ratings.csv'
url
# Out:
# '/Users/valencar/Dropbox/AULAS-REMOTAS/BD-ESTATISTICA-MANHA/datasets/ml-20m/ratings.csv'

# %%
# %time

dfratings = pd.read_csv(url)
print('total de registros: {:,d}'.format(len(dfratings)))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.2 µs
# total de registros: 20,000,263

# %%
dfratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
url = '/Users/valencar/Dropbox/AULAS-REMOTAS/BD-ESTATISTICA-MANHA/datasets/ml-20m' + '/' + 'movies.csv'
url
# Out:
# '/Users/valencar/Dropbox/AULAS-REMOTAS/BD-ESTATISTICA-MANHA/datasets/ml-20m/movies.csv'

# %%
# %time

dfmovies = pd.read_csv(url)
print('total de registros: {:,d}'.format(len(dfmovies)))
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# total de registros: 27,278

# %%
dfmovies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# %%time

dfdrama_acao = dfmovies[ dfmovies.genres.str.contains('Drama') |  dfmovies.genres.str.contains('Action') ]
print('total de registros: {:,d}'.format(len(dfdrama_acao)))
dfdrama_acao.head()
# Out:
# total de registros: 15,661
# CPU times: user 24.3 ms, sys: 3.49 ms, total: 27.8 ms
# Wall time: 65.3 ms
#     movieId                           title                     genres
# 3         4        Waiting to Exhale (1995)       Comedy|Drama|Romance
# 5         6                     Heat (1995)      Action|Crime|Thriller
# 8         9             Sudden Death (1995)                     Action
# 9        10                GoldenEye (1995)  Action|Adventure|Thriller
# 10       11  American President, The (1995)       Comedy|Drama|Romance

# %% [markdown]
# # Obter todos os generos

# %%
genres = 'Comedy|Drama|Romance'
generos = genres.split('|')
generos
# Out:
# ['Comedy', 'Drama', 'Romance']

# %%
# %%time

set_generos = set()

for index, row in dfmovies.iterrows(): 
    generos = row['genres'].split('|')
    set_generos.update(generos)
    
generos = list(set_generos)
print('numero de generos',len(generos))
print(generos)
# Out:
# numero de generos 20
# ['Romance', 'Western', 'Crime', 'Comedy', 'War', 'Fantasy', 'Sci-Fi', 'Adventure', 'Thriller', 'Action', 'Animation', 'Documentary', 'Drama', 'IMAX', 'Horror', 'Children', '(no genres listed)', 'Mystery', 'Musical', 'Film-Noir']
# CPU times: user 958 ms, sys: 13.4 ms, total: 972 ms
# Wall time: 1.23 s

# %% [markdown]
# ## Criando colunas Genero - individuais

# %%
# %%time

for genero in generos:
    dfmovies[genero] = False
    
dfmovies.head()
# Out:
# CPU times: user 7.4 ms, sys: 2.73 ms, total: 10.1 ms
# Wall time: 8.88 ms
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  Romance  Western  Crime  \
# 0  Adventure|Animation|Children|Comedy|Fantasy    False    False  False
# 1                   Adventure|Children|Fantasy    False    False  False
# 2                               Comedy|Romance    False    False  False
# 3                         Comedy|Drama|Romance    False    False  False
# 4                                       Comedy    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  ...  Animation  Documentary  Drama   IMAX  \
# 0   False  False    False   False  ...      False        False  False  False
# 1   False  False    False   False  ...      False        False  False  False
# 2   False  False    False   False  ...      False        False  False  False
# 3   False  False    False   False  ...      False        False  False  False
# 4   False  False    False   False  ...      False        False  False  False
#
#    Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir
# 0   False     False               False    False    False      False
# 1   False     False               False    False    False      False
# 2   False     False               False    False    False      False
# 3   False     False               False    False    False      False
# 4   False     False               False    False    False      False
#
# [5 rows x 23 columns]

# %%
# %%time 

for index, row in dfmovies.iterrows(): 
    generos = row['genres'].split('|')
    for genero in generos:
        dfmovies.at[index, genero] = True
    
dfmovies.head()
# Out:
# CPU times: user 1.61 s, sys: 21.8 ms, total: 1.63 s
# Wall time: 1.68 s
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  Romance  Western  Crime  \
# 0  Adventure|Animation|Children|Comedy|Fantasy    False    False  False
# 1                   Adventure|Children|Fantasy    False    False  False
# 2                               Comedy|Romance     True    False  False
# 3                         Comedy|Drama|Romance     True    False  False
# 4                                       Comedy    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  ...  Animation  Documentary  Drama   IMAX  \
# 0    True  False     True   False  ...       True        False  False  False
# 1   False  False     True   False  ...      False        False  False  False
# 2    True  False    False   False  ...      False        False  False  False
# 3    True  False    False   False  ...      False        False   True  False
# 4    True  False    False   False  ...      False        False  False  False
#
#    Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir
# 0   False      True               False    False    False      False
# 1   False      True               False    False    False      False
# 2   False     False               False    False    False      False
# 3   False     False               False    False    False      False
# 4   False     False               False    False    False      False
#
# [5 rows x 23 columns]

# %%
dfmovies.Drama.value_counts()
# Out:
# False    13934
# True     13344
# Name: Drama, dtype: int64

# %%
del dfmovies['genres']
dfmovies.head()
# Out:
#    movieId                               title  Romance  Western  Crime  \
# 0        1                    Toy Story (1995)    False    False  False
# 1        2                      Jumanji (1995)    False    False  False
# 2        3             Grumpier Old Men (1995)     True    False  False
# 3        4            Waiting to Exhale (1995)     True    False  False
# 4        5  Father of the Bride Part II (1995)    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  Adventure  ...  Animation  Documentary  \
# 0    True  False     True   False       True  ...       True        False
# 1   False  False     True   False       True  ...      False        False
# 2    True  False    False   False      False  ...      False        False
# 3    True  False    False   False      False  ...      False        False
# 4    True  False    False   False      False  ...      False        False
#
#    Drama   IMAX  Horror  Children  (no genres listed)  Mystery  Musical  \
# 0  False  False   False      True               False    False    False
# 1  False  False   False      True               False    False    False
# 2  False  False   False     False               False    False    False
# 3   True  False   False     False               False    False    False
# 4  False  False   False     False               False    False    False
#
#    Film-Noir
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 22 columns]

# %% [markdown]
# # criar estatistica de generos

# %%
generos = list(set_generos)
print('numero de generos',len(generos))
print(generos)
# Out:
# numero de generos 20
# ['Romance', 'Western', 'Crime', 'Comedy', 'War', 'Fantasy', 'Sci-Fi', 'Adventure', 'Thriller', 'Action', 'Animation', 'Documentary', 'Drama', 'IMAX', 'Horror', 'Children', '(no genres listed)', 'Mystery', 'Musical', 'Film-Noir']

# %%
dfmovies.Horror.value_counts()
# Out:
# False    24667
# True      2611
# Name: Horror, dtype: int64

# %%
for genero in generos:
    count_genero = dfmovies[genero].sum()
    print(genero, count_genero)
    break
# Out:
# Romance 4127

# %%
dict_genero = {}
for genero in generos:
    count_genero = dfmovies[genero].sum()
    dict_genero[genero] = count_genero

dict_genero
# Out:
# {'Romance': 4127,
#  'Western': 676,
#  'Crime': 2939,
#  'Comedy': 8374,
#  'War': 1194,
#  'Fantasy': 1412,
#  'Sci-Fi': 1743,
#  'Adventure': 2329,
#  'Thriller': 4178,
#  'Action': 3520,
#  'Animation': 1027,
#  'Documentary': 2471,
#  'Drama': 13344,
#  'IMAX': 196,
#  'Horror': 2611,
#  'Children': 1139,
#  '(no genres listed)': 246,
#  'Mystery': 1514,
#  'Musical': 1036,
#  'Film-Noir': 330}

# %%
df_genero_cont = pd.DataFrame.from_dict(dict_genero, orient='index').reset_index()
df_genero_cont
# Out:
#                  index      0
# 0              Romance   4127
# 1              Western    676
# 2                Crime   2939
# 3               Comedy   8374
# 4                  War   1194
# 5              Fantasy   1412
# 6               Sci-Fi   1743
# 7            Adventure   2329
# 8             Thriller   4178
# 9               Action   3520
# 10           Animation   1027
# 11         Documentary   2471
# 12               Drama  13344
# 13                IMAX    196
# 14              Horror   2611
# 15            Children   1139
# 16  (no genres listed)    246
# 17             Mystery   1514
# 18             Musical   1036
# 19           Film-Noir    330

# %%
df_genero_cont.columns = ['genero', 'total']
df_genero_cont
# Out:
#                 genero  total
# 0              Romance   4127
# 1              Western    676
# 2                Crime   2939
# 3               Comedy   8374
# 4                  War   1194
# 5              Fantasy   1412
# 6               Sci-Fi   1743
# 7            Adventure   2329
# 8             Thriller   4178
# 9               Action   3520
# 10           Animation   1027
# 11         Documentary   2471
# 12               Drama  13344
# 13                IMAX    196
# 14              Horror   2611
# 15            Children   1139
# 16  (no genres listed)    246
# 17             Mystery   1514
# 18             Musical   1036
# 19           Film-Noir    330

# %%
dfo = df_genero_cont.sort_values(by='total', ascending=False).reset_index(drop=True)
dfo
# Out:
#                 genero  total
# 0                Drama  13344
# 1               Comedy   8374
# 2             Thriller   4178
# 3              Romance   4127
# 4               Action   3520
# 5                Crime   2939
# 6               Horror   2611
# 7          Documentary   2471
# 8            Adventure   2329
# 9               Sci-Fi   1743
# 10             Mystery   1514
# 11             Fantasy   1412
# 12                 War   1194
# 13            Children   1139
# 14             Musical   1036
# 15           Animation   1027
# 16             Western    676
# 17           Film-Noir    330
# 18  (no genres listed)    246
# 19                IMAX    196

# %% [markdown]
# # Capturando o ano

# %%
dfmovies.head()
# Out:
#    movieId                               title  Romance  Western  Crime  \
# 0        1                    Toy Story (1995)    False    False  False
# 1        2                      Jumanji (1995)    False    False  False
# 2        3             Grumpier Old Men (1995)     True    False  False
# 3        4            Waiting to Exhale (1995)     True    False  False
# 4        5  Father of the Bride Part II (1995)    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  Adventure  ...  Animation  Documentary  \
# 0    True  False     True   False       True  ...       True        False
# 1   False  False     True   False       True  ...      False        False
# 2    True  False    False   False      False  ...      False        False
# 3    True  False    False   False      False  ...      False        False
# 4    True  False    False   False      False  ...      False        False
#
#    Drama   IMAX  Horror  Children  (no genres listed)  Mystery  Musical  \
# 0  False  False   False      True               False    False    False
# 1  False  False   False      True               False    False    False
# 2  False  False   False     False               False    False    False
# 3   True  False   False     False               False    False    False
# 4  False  False   False     False               False    False    False
#
#    Film-Noir
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 22 columns]

# %%
x = 'Father of the Bride Part II (1995)'
x.find(')')
# Out:
# 33

# %%
type(x)
# Out:
# str

# %%
x = 'Father of the Bride Part II'
x.find(')')
# Out:
# -1

# %%
import numpy as np

dfmovies['ano'] = dfmovies.title.apply(lambda x : x.split('(')[1] if x.find(')') != -1  else np.nan)
dfmovies.head()
# Out:
#    movieId                               title  Romance  Western  Crime  \
# 0        1                    Toy Story (1995)    False    False  False
# 1        2                      Jumanji (1995)    False    False  False
# 2        3             Grumpier Old Men (1995)     True    False  False
# 3        4            Waiting to Exhale (1995)     True    False  False
# 4        5  Father of the Bride Part II (1995)    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  Adventure  ...  Documentary  Drama   IMAX  \
# 0    True  False     True   False       True  ...        False  False  False
# 1   False  False     True   False       True  ...        False  False  False
# 2    True  False    False   False      False  ...        False  False  False
# 3    True  False    False   False      False  ...        False   True  False
# 4    True  False    False   False      False  ...        False  False  False
#
#    Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir    ano
# 0   False      True               False    False    False      False  1995)
# 1   False      True               False    False    False      False  1995)
# 2   False     False               False    False    False      False  1995)
# 3   False     False               False    False    False      False  1995)
# 4   False     False               False    False    False      False  1995)
#
# [5 rows x 23 columns]

# %%
dfmovies['ano'] = dfmovies.ano.apply(lambda x : x.replace(')', '') if type(x) == str else x)
dfmovies.head()
# Out:
#    movieId                               title  Romance  Western  Crime  \
# 0        1                    Toy Story (1995)    False    False  False
# 1        2                      Jumanji (1995)    False    False  False
# 2        3             Grumpier Old Men (1995)     True    False  False
# 3        4            Waiting to Exhale (1995)     True    False  False
# 4        5  Father of the Bride Part II (1995)    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  Adventure  ...  Documentary  Drama   IMAX  \
# 0    True  False     True   False       True  ...        False  False  False
# 1   False  False     True   False       True  ...        False  False  False
# 2    True  False    False   False      False  ...        False  False  False
# 3    True  False    False   False      False  ...        False   True  False
# 4    True  False    False   False      False  ...        False  False  False
#
#    Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir   ano
# 0   False      True               False    False    False      False  1995
# 1   False      True               False    False    False      False  1995
# 2   False     False               False    False    False      False  1995
# 3   False     False               False    False    False      False  1995
# 4   False     False               False    False    False      False  1995
#
# [5 rows x 23 columns]

# %%
print(dfmovies.ano.value_counts())
# Out:
# 2013                         888
# 2009                         878
# 2012                         852
# 2011                         831
# 2008                         778
#                             ...
# Bienvenue chez les Rozes       1
# L'horloger de Saint-Paul       1
# Nyfes                          1
# Nikutai no mon                 1
# 1891                           1
# Name: ano, Length: 5341, dtype: int64

# %%
import re

x1 = '19993'
x2 = '1 2 title'
datas = r'^([1-9][0-9][0-9][0-9])'
#re.match(r'\d{4}', x)

if re.match(datas, x1):
    print('ok')
if re.match(datas, x2):
    print('ok nao data')
# Out:
# ok

# %%
datas = r'^([0-9][0-9][0-9][0-9])'

dfmovies['ano'] = dfmovies.title.apply(lambda x : x.split('(')[1] if x.find(')') != -1  else np.nan)
dfmovies['ano'] = dfmovies.ano.apply(lambda x : x.replace(')', '') if type(x) == str else x)

dfmovies['ano'] = dfmovies.ano.apply(lambda x : x[:4] if x is not np.nan and re.match(datas, x[:4]) else np.nan)
dfmovies.head()
# Out:
#    movieId                               title  Romance  Western  Crime  \
# 0        1                    Toy Story (1995)    False    False  False
# 1        2                      Jumanji (1995)    False    False  False
# 2        3             Grumpier Old Men (1995)     True    False  False
# 3        4            Waiting to Exhale (1995)     True    False  False
# 4        5  Father of the Bride Part II (1995)    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  Adventure  ...  Documentary  Drama   IMAX  \
# 0    True  False     True   False       True  ...        False  False  False
# 1   False  False     True   False       True  ...        False  False  False
# 2    True  False    False   False      False  ...        False  False  False
# 3    True  False    False   False      False  ...        False   True  False
# 4    True  False    False   False      False  ...        False  False  False
#
#    Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir   ano
# 0   False      True               False    False    False      False  1995
# 1   False      True               False    False    False      False  1995
# 2   False     False               False    False    False      False  1995
# 3   False     False               False    False    False      False  1995
# 4   False     False               False    False    False      False  1995
#
# [5 rows x 23 columns]

# %%
dfmovies.ano.value_counts()
# Out:
# 2013    902
# 2009    885
# 2012    872
# 2011    850
# 2008    785
#        ...
# 1913      1
# 1893      1
# 1901      1
# 1732      1
# 1891      1
# Name: ano, Length: 118, dtype: int64

# %%
len(dfmovies.ano.unique())
# Out:
# 119

# %%
print(dfmovies.ano.unique())
# Out:
# ['1995' nan '1994' '1996' '1976' '1992' '1993' '1977' '1965' '1982' '1985'
#  '1990' '1991' '1989' '1937' '1940' '1969' '1981' '1970' '1968' '1980'
#  '1988' '1975' '1986' '1948' '1943' '1964' '1950' '1946' '1973' '1997'
#  '1974' '1972' '1998' '1933' '1952' '1951' '1957' '1961' '1958' '1954'
#  '1934' '1944' '1959' '1960' '1963' '1942' '1941' '1953' '1939' '1947'
#  '1945' '1955' '1938' '1935' '1936' '1956' '1926' '1949' '1932' '1971'
#  '1979' '1967' '1987' '1978' '1962' '1983' '1984' '1931' '1999' '1927'
#  '1929' '1930' '1966' '1928' '1925' '1914' '2000' '1919' '1923' '1922'
#  '1920' '1918' '1921' '2001' '1732' '2002' '2003' '1915' '1924' '2004'
#  '1916' '1917' '2005' '2006' '1903' '2007' '2008' '2009' '2010' '1913'
#  '2011' '1894' '1912' '2012' '1910' '1898' '1901' '1893' '2013' '1896'
#  '1000' '2014' '1895' '2015' '1909' '1900' '1905' '1891']

# %%
dfmovies.ano.isnull().sum(), len(dfmovies.ano)
# Out:
# (5214, 27278)

# %%
dfanofilmes = dfmovies.ano.value_counts().to_frame().reset_index()
dfanofilmes.columns = ['ano', 'total_filmes']
dfanofilmes.head()
# Out:
#     ano  total_filmes
# 0  2013           902
# 1  2009           885
# 2  2012           872
# 3  2011           850
# 4  2008           785

# %%
dfanofilmes = dfanofilmes.sort_values(by='total_filmes', ascending=False).reset_index(drop=True)
dfanofilmes.head(10)
# Out:
#     ano  total_filmes
# 0  2013           902
# 1  2009           885
# 2  2012           872
# 3  2011           850
# 4  2008           785
# 5  2010           766
# 6  2007           724
# 7  2014           701
# 8  2006           672
# 9  2005           591

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

sns.barplot(x='total_filmes', y='ano', data=dfanofilmes[:20], palette='Greens_r')
# Out:
# <AxesSubplot:xlabel='total_filmes', ylabel='ano'>

# %% [markdown]
# # Join - inner join

# %%
dfratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
dfmovies.head()
# Out:
#    movieId                               title  Romance  Western  Crime  \
# 0        1                    Toy Story (1995)    False    False  False
# 1        2                      Jumanji (1995)    False    False  False
# 2        3             Grumpier Old Men (1995)     True    False  False
# 3        4            Waiting to Exhale (1995)     True    False  False
# 4        5  Father of the Bride Part II (1995)    False    False  False
#
#    Comedy    War  Fantasy  Sci-Fi  Adventure  ...  Documentary  Drama   IMAX  \
# 0    True  False     True   False       True  ...        False  False  False
# 1   False  False     True   False       True  ...        False  False  False
# 2    True  False    False   False      False  ...        False  False  False
# 3    True  False    False   False      False  ...        False   True  False
# 4    True  False    False   False      False  ...        False  False  False
#
#    Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir   ano
# 0   False      True               False    False    False      False  1995
# 1   False      True               False    False    False      False  1995
# 2   False     False               False    False    False      False  1995
# 3   False     False               False    False    False      False  1995
# 4   False     False               False    False    False      False  1995
#
# [5 rows x 23 columns]

# %%
# %%time

dffilmes =  pd.merge(dfmovies, dfratings, left_on='movieId', right_on='movieId', how="inner")
print('total de registros: {:,d}'.format(len(dffilmes)))
dffilmes.head()
# Out:
# total de registros: 20,000,263
# CPU times: user 3.25 s, sys: 1.55 s, total: 4.8 s
# Wall time: 5.91 s
#    movieId             title  Romance  Western  Crime  Comedy    War  Fantasy  \
# 0        1  Toy Story (1995)    False    False  False    True  False     True
# 1        1  Toy Story (1995)    False    False  False    True  False     True
# 2        1  Toy Story (1995)    False    False  False    True  False     True
# 3        1  Toy Story (1995)    False    False  False    True  False     True
# 4        1  Toy Story (1995)    False    False  False    True  False     True
#
#    Sci-Fi  Adventure  ...  Horror  Children  (no genres listed)  Mystery  \
# 0   False       True  ...   False      True               False    False
# 1   False       True  ...   False      True               False    False
# 2   False       True  ...   False      True               False    False
# 3   False       True  ...   False      True               False    False
# 4   False       True  ...   False      True               False    False
#
#    Musical  Film-Noir   ano  userId  rating   timestamp
# 0    False      False  1995       3     4.0   944919407
# 1    False      False  1995       6     5.0   858275452
# 2    False      False  1995       8     4.0   833981871
# 3    False      False  1995      10     4.0   943497887
# 4    False      False  1995      11     4.5  1230858821
#
# [5 rows x 26 columns]

# %%
dffilmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000263 entries, 0 to 20000262
# Data columns (total 26 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   movieId             int64
#  1   title               object
#  2   Romance             bool
#  3   Western             bool
#  4   Crime               bool
#  5   Comedy              bool
#  6   War                 bool
#  7   Fantasy             bool
#  8   Sci-Fi              bool
#  9   Adventure           bool
#  10  Thriller            bool
#  11  Action              bool
#  12  Animation           bool
#  13  Documentary         bool
#  14  Drama               bool
#  15  IMAX                bool
#  16  Horror              bool
#  17  Children            bool
#  18  (no genres listed)  bool
#  19  Mystery             bool
#  20  Musical             bool
#  21  Film-Noir           bool
#  22  ano                 object
#  23  userId              int64
#  24  rating              float64
#  25  timestamp           int64
# dtypes: bool(20), float64(1), int64(3), object(2)
# memory usage: 1.4+ GB

# %%
dffilmes.sort_values(by='rating', ascending=False)[:15]
# Out:
#           movieId                                              title  Romance  \
# 13420269     3578                                   Gladiator (2000)    False
# 2163019       318                   Shawshank Redemption, The (1994)    False
# 2163010       318                   Shawshank Redemption, The (1994)    False
# 16498925     6539  Pirates of the Caribbean: The Curse of the Bla...    False
# 2163012       318                   Shawshank Redemption, The (1994)    False
# 2163013       318                   Shawshank Redemption, The (1994)    False
# 4034636       593                   Silence of the Lambs, The (1991)    False
# 2163015       318                   Shawshank Redemption, The (1994)    False
# 2163016       318                   Shawshank Redemption, The (1994)    False
# 2163017       318                   Shawshank Redemption, The (1994)    False
# 2163018       318                   Shawshank Redemption, The (1994)    False
# 5994160      1147                          When We Were Kings (1996)    False
# 2163008       318                   Shawshank Redemption, The (1994)    False
# 5994161      1147                          When We Were Kings (1996)    False
# 2163024       318                   Shawshank Redemption, The (1994)    False
#
#           Western  Crime  Comedy    War  Fantasy  Sci-Fi  Adventure  ...  \
# 13420269    False  False   False  False    False   False       True  ...
# 2163019     False   True   False  False    False   False      False  ...
# 2163010     False   True   False  False    False   False      False  ...
# 16498925    False  False    True  False     True   False       True  ...
# 2163012     False   True   False  False    False   False      False  ...
# 2163013     False   True   False  False    False   False      False  ...
# 4034636     False   True   False  False    False   False      False  ...
# 2163015     False   True   False  False    False   False      False  ...
# 2163016     False   True   False  False    False   False      False  ...
# 2163017     False   True   False  False    False   False      False  ...
# 2163018     False   True   False  False    False   False      False  ...
# 5994160     False  False   False  False    False   False      False  ...
# 2163008     False   True   False  False    False   False      False  ...
# 5994161     False  False   False  False    False   False      False  ...
# 2163024     False   True   False  False    False   False      False  ...
#
#           Horror  Children  (no genres listed)  Mystery  Musical  Film-Noir  \
# 13420269   False     False               False    False    False      False
# 2163019    False     False               False    False    False      False
# 2163010    False     False               False    False    False      False
# 16498925   False     False               False    False    False      False
# 2163012    False     False               False    False    False      False
# 2163013    False     False               False    False    False      False
# 4034636     True     False               False    False    False      False
# 2163015    False     False               False    False    False      False
# 2163016    False     False               False    False    False      False
# 2163017    False     False               False    False    False      False
# 2163018    False     False               False    False    False      False
# 5994160    False     False               False    False    False      False
# 2163008    False     False               False    False    False      False
# 5994161    False     False               False    False    False      False
# 2163024    False     False               False    False    False      False
#
#            ano  userId  rating   timestamp
# 13420269  2000   81601     5.0  1019193491
# 2163019   1994   74072     5.0  1005281633
# 2163010   1994   74057     5.0   953993667
# 16498925  2003  117595     5.0  1154219134
# 2163012   1994   74061     5.0  1222905331
# 2163013   1994   74063     5.0   839882316
# 4034636   1991   48516     5.0   969672403
# 2163015   1994   74065     5.0   882160934
# 2163016   1994   74066     5.0  1360187222
# 2163017   1994   74070     5.0  1129959828
# 2163018   1994   74071     5.0   858540549
# 5994160   1996  116835     5.0   944908525
# 2163008   1994   74053     5.0  1193677299
# 5994161   1996  116955     5.0   938653287
# 2163024   1994   74078     5.0   838379449
#
# [15 rows x 26 columns]

# %%
# generos = ['Crime', 'Western', 'Thriller', 'War', 'Sci-Fi', 'Children', 
#             'Documentary', '(no genres listed)', 'Romance', 'Adventure', 'Mystery',
#             'Comedy', 'IMAX', 'Animation', 'Action', 'Horror', 'Film-Noir', 'Fantasy',
#         'Drama', 'Musical']

# %%
# %%time

#dffilmes.to_csv('filmes-2022.csv', index=False)
#!ls -ilah *.csv
# Out:
# 8860071200 -rw-r--r--@ 1 valencar  staff   227K Jan  9 18:42 covid19-23-dezembro-2021.csv
# 8860071211 -rw-r--r--@ 1 valencar  staff   111K Feb  1 20:14 covid19-30-janeiro-2022.csv
# 8860077292 -rw-r--r--  1 valencar  staff   3.2G Feb  3 18:17 filmes-2022.csv
# 8860071197 -rw-r--r--@ 1 valencar  staff   2.7M Feb  1 12:36 mapa_covid_brasil.csv
# CPU times: user 2min 19s, sys: 7.55 s, total: 2min 27s
# Wall time: 2min 58s

# %%
# !rm filmes-2022.csv
# !ls -ilah *.csv
# Out:
# 8860071200 -rw-r--r--@ 1 valencar  staff   227K Jan  9 18:42 covid19-23-dezembro-2021.csv
# 8860071211 -rw-r--r--@ 1 valencar  staff   111K Feb  1 20:14 covid19-30-janeiro-2022.csv
# 8860071197 -rw-r--r--@ 1 valencar  staff   2.7M Feb  1 12:36 mapa_covid_brasil.csv
# 8860078901 -rw-r--r--  1 valencar  staff   242B Feb  3 18:17 ratings_saida.csv

# %%
dffilmes.Action.value_counts()
# Out:
# False    14386055
# True      5614208
# Name: Action, dtype: int64

# %%
acao = dffilmes.Action.value_counts()[1]
acao
# Out:
# 5614208

# %%
dffilmes.Drama.value_counts()
# Out:
# False    11142410
# True      8857853
# Name: Drama, dtype: int64

# %%
drama = dffilmes.Drama.value_counts()[1]
drama
# Out:
# 8857853

# %%
dffilmes.Adventure.value_counts()
# Out:
# False    15619912
# True      4380351
# Name: Adventure, dtype: int64

# %%
aventura = dffilmes.Adventure.value_counts()[1]
aventura
# Out:
# 4380351

# %%
dffilmes.Romance.value_counts()
# Out:
# False    16198261
# True      3802002
# Name: Romance, dtype: int64

# %%
romance = dffilmes.Romance.value_counts()[1]
romance
# Out:
# 3802002

# %%
#outros = len(dfmovies) - aventura - drama - romance - acao
#outros

# %% [markdown]
# # grafico de Pizza - genero

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

plt.rcParams["figure.figsize"] = (9,9)

#define data
data =    [aventura, drama, romance, acao] #f6.percent
labels = ['aventura', 'drama', 'romance', 'acao'] #, 'outros'] #df.rating

#define Seaborn color palette to use
colors = sns.color_palette('pastel')#[0:4]

colors = sns.color_palette("rocket")

colors = sns.color_palette("Blues_r") #, as_cmap=True)

#colors = 'Blues'



fig = plt.figure()

#ax = fig.add_axes([.8, .8, .8, .8], aspect=2)

ax = fig.add_axes([.8, .8, .8, .8], aspect=2)
ax.set_title('Filmes por genero ')
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')


plt.show()

# %%
dfo = dffilmes.rating.value_counts()
dfo
# Out:
# 4.0    5561926
# 3.0    4291193
# 5.0    2898660
# 3.5    2200156
# 4.5    1534824
# 2.0    1430997
# 2.5     883398
# 1.0     680732
# 1.5     279252
# 0.5     239125
# Name: rating, dtype: int64

# %%
type(dfo)
# Out:
# pandas.core.series.Series

# %%
df2 = dfo.to_frame().reset_index()
df2.columns = ['rating', 'quantidade']

# %%
df2
# Out:
#    rating  quantidade
# 0     4.0     5561926
# 1     3.0     4291193
# 2     5.0     2898660
# 3     3.5     2200156
# 4     4.5     1534824
# 5     2.0     1430997
# 6     2.5      883398
# 7     1.0      680732
# 8     1.5      279252
# 9     0.5      239125

# %%
df2['percent'] = df2['quantidade'] / df2['quantidade'].sum() * 100
df2
# Out:
#    rating  quantidade    percent
# 0     4.0     5561926  27.809264
# 1     3.0     4291193  21.455683
# 2     5.0     2898660  14.493109
# 3     3.5     2200156  11.000635
# 4     4.5     1534824   7.674019
# 5     2.0     1430997   7.154891
# 6     2.5      883398   4.416932
# 7     1.0      680732   3.403615
# 8     1.5      279252   1.396242
# 9     0.5      239125   1.195609

# %%
# formatar a saída

df3 = df2.style.format({
    "rating": "{:.1f}",
    "quantidade": "{:,d}",
    "percent": "{:.0f}"
})



df3
# Out:
# <style type="text/css">
# </style>
# <table id="T_20881">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20881_level0_col0" class="col_heading level0 col0" >rating</th>
#       <th id="T_20881_level0_col1" class="col_heading level0 col1" >quantidade</th>
#       <th id="T_20881_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20881_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20881_row0_col0" class="data row0 col0" >4.0</td>
#       <td id="T_20881_row0_col1" class="data row0 col1" >5,561,926</td>
#       <td id="T_20881_row0_col2" class="data row0 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20881_row1_col0" class="data row1 col0" >3.0</td>
#       <td id="T_20881_row1_col1" class="data row1 col1" >4,291,193</td>
#       <td id="T_20881_row1_col2" class="data row1 col2" >21</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20881_row2_col0" class="data row2 col0" >5.0</td>
#       <td id="T_20881_row2_col1" class="data row2 col1" >2,898,660</td>
#       <td id="T_20881_row2_col2" class="data row2 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20881_row3_col0" class="data row3 col0" >3.5</td>
#       <td id="T_20881_row3_col1" class="data row3 col1" >2,200,156</td>
#       <td id="T_20881_row3_col2" class="data row3 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20881_row4_col0" class="data row4 col0" >4.5</td>
#       <td id="T_20881_row4_col1" class="data row4 col1" >1,534,824</td>
#       <td id="T_20881_row4_col2" class="data row4 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20881_row5_col0" class="data row5 col0" >2.0</td>
#       <td id="T_20881_row5_col1" class="data row5 col1" >1,430,997</td>
#       <td id="T_20881_row5_col2" class="data row5 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20881_row6_col0" class="data row6 col0" >2.5</td>
#       <td id="T_20881_row6_col1" class="data row6 col1" >883,398</td>
#       <td id="T_20881_row6_col2" class="data row6 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20881_row7_col0" class="data row7 col0" >1.0</td>
#       <td id="T_20881_row7_col1" class="data row7 col1" >680,732</td>
#       <td id="T_20881_row7_col2" class="data row7 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20881_row8_col0" class="data row8 col0" >1.5</td>
#       <td id="T_20881_row8_col1" class="data row8 col1" >279,252</td>
#       <td id="T_20881_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_20881_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20881_row9_col0" class="data row9 col0" >0.5</td>
#       <td id="T_20881_row9_col1" class="data row9 col1" >239,125</td>
#       <td id="T_20881_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df4 = df2[ df2.percent >= 7]
df4
# Out:
#    rating  quantidade    percent
# 0     4.0     5561926  27.809264
# 1     3.0     4291193  21.455683
# 2     5.0     2898660  14.493109
# 3     3.5     2200156  11.000635
# 4     4.5     1534824   7.674019
# 5     2.0     1430997   7.154891

# %%
df4.percent.sum()
# Out:
# 89.58760192303471

# %%
print('{:,d}'.format(df4.quantidade.sum()))
# Out:
# 17,917,756

# %%
df5 = df2[ df2.percent < 7]
df5
# Out:
#    rating  quantidade   percent
# 6     2.5      883398  4.416932
# 7     1.0      680732  3.403615
# 8     1.5      279252  1.396242
# 9     0.5      239125  1.195609

# %%
print('{:,d}'.format(df5.quantidade.sum()))
# Out:
# 2,082,507

# %%
df5.percent.sum()
# Out:
# 10.412398076965287

# %%
df5
# Out:
#    rating  quantidade   percent
# 6     2.5      883398  4.416932
# 7     1.0      680732  3.403615
# 8     1.5      279252  1.396242
# 9     0.5      239125  1.195609

# %%
row = {'rating': 'outros', 'quantidade': df5.quantidade.sum(), 'percent': df5.percent.sum()  }
row
# Out:
# {'rating': 'outros', 'quantidade': 2082507, 'percent': 10.412398076965287}

# %%
df6 = df4.append(row, ignore_index=True)
df6
# Out:
# /var/folders/wm/w4f0z08s2jn7bhy010p8gtz40000gn/T/ipykernel_6411/3302498886.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df4.append(row, ignore_index=True)
#    rating  quantidade    percent
# 0     4.0     5561926  27.809264
# 1     3.0     4291193  21.455683
# 2     5.0     2898660  14.493109
# 3     3.5     2200156  11.000635
# 4     4.5     1534824   7.674019
# 5     2.0     1430997   7.154891
# 6  outros     2082507  10.412398

# %%
# formatar a saída

dfs = df6.style.format({
    "rating": "{}",
    "quantidade": "{:,d}",
    "percent": "{:.0f}"
})

dfs
# Out:
# <style type="text/css">
# </style>
# <table id="T_27433">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27433_level0_col0" class="col_heading level0 col0" >rating</th>
#       <th id="T_27433_level0_col1" class="col_heading level0 col1" >quantidade</th>
#       <th id="T_27433_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27433_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27433_row0_col0" class="data row0 col0" >4.0</td>
#       <td id="T_27433_row0_col1" class="data row0 col1" >5,561,926</td>
#       <td id="T_27433_row0_col2" class="data row0 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_27433_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27433_row1_col0" class="data row1 col0" >3.0</td>
#       <td id="T_27433_row1_col1" class="data row1 col1" >4,291,193</td>
#       <td id="T_27433_row1_col2" class="data row1 col2" >21</td>
#     </tr>
#     <tr>
#       <th id="T_27433_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27433_row2_col0" class="data row2 col0" >5.0</td>
#       <td id="T_27433_row2_col1" class="data row2 col1" >2,898,660</td>
#       <td id="T_27433_row2_col2" class="data row2 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_27433_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27433_row3_col0" class="data row3 col0" >3.5</td>
#       <td id="T_27433_row3_col1" class="data row3 col1" >2,200,156</td>
#       <td id="T_27433_row3_col2" class="data row3 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_27433_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27433_row4_col0" class="data row4 col0" >4.5</td>
#       <td id="T_27433_row4_col1" class="data row4 col1" >1,534,824</td>
#       <td id="T_27433_row4_col2" class="data row4 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_27433_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27433_row5_col0" class="data row5 col0" >2.0</td>
#       <td id="T_27433_row5_col1" class="data row5 col1" >1,430,997</td>
#       <td id="T_27433_row5_col2" class="data row5 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_27433_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27433_row6_col0" class="data row6 col0" >outros</td>
#       <td id="T_27433_row6_col1" class="data row6 col1" >2,082,507</td>
#       <td id="T_27433_row6_col2" class="data row6 col2" >10</td>
#     </tr>
#   </tbody>
# </table>

# %%
df6.to_csv('ratings_saida.csv', index=False)

# %%
# !cat ratings_saida.csv
# Out:
# rating,quantidade,percent
# 4.0,5561926,27.80926430817435
# 3.0,4291193,21.45568285777042
# 5.0,2898660,14.493109415611185
# 3.5,2200156,11.000635341645257
# 4.5,1534824,7.67401908664901
# 2.0,1430997,7.1548909131844916
# outros,2082507,10.412398076965287

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (9,9)

#define data
data = df6.percent
labels = df6.rating

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:7]

colors = sns.color_palette("Blues_r")

colors = sns.color_palette("Reds_r")[0:7]

colors = sns.color_palette("Blues_r")[0:7]


colors = sns.color_palette("Oranges")[0:10]


colors = sns.color_palette("Blues_r")

fig = plt.figure()

ax = fig.add_axes([0, 0, .8, .8], aspect=1)

ax.set_title('Filmes por avaliação (1-5)')
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')


plt.show()
