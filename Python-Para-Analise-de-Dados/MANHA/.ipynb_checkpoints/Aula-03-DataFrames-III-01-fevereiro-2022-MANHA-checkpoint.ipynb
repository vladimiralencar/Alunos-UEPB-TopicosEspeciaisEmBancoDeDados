# %% [markdown]
# # DataFrames

# %%
# !dir
# Out:
#  O volume na unidade C ‚ Windows10
#  O N£mero de S‚rie do Volume ‚ E699-979D
#
#  Pasta de C:\Users\valen\Dropbox\AULAS-REMOTAS\Alunos-UEPB-TopicosEspeciaisEmBancoDeDados\Python-Para-Analise-de-Dados\MANHA
#
# 01/02/2022  11:20    <DIR>          .
# 01/02/2022  11:20    <DIR>          ..
# 01/02/2022  11:20    <DIR>          .ipynb_checkpoints
# 09/01/2022  18:42          (28.169) Aula-01--16-Dezembro-2021-ConceitosBasicos-Turma-Manha.ipynb
# 01/02/2022  10:55          (37.414) Aula-02-Listas-Tuplas-Dicion rios-DataFrames-21-dezembro-2021-MANHA.ipynb
# 01/02/2022  11:19             9.892 Aula-03-DataFrames-II-23-dezembro-2021-MANHA.ipynb
# 01/02/2022  11:20             9.892 Aula-03-DataFrames-III-01-fevereiro-2022-MANHA.ipynb
# 01/02/2022  11:17           113.281 covid19-22-janeiro-2022.csv
# 09/01/2022  18:42          (92.027) covid19-23-dez-2021.csv
# 01/02/2022  10:40           (2.541) List comprehension .ipynb
# 09/01/2022  18:42             (242) ratings_saida.csv
# ...

# %%
url = 'covid19-22-janeiro-2022.csv'
url
# Out:
# 'covid19-22-janeiro-2022.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(url)
print(len(df))
df.head()
# Out:
# 1137
#    epidemiological_week        date  order_for_place state         city  \
# 0                202205  2022-01-30              685    AC          NaN
# 1                202205  2022-01-30              607    AL  Água Branca
# 2                202205  2022-01-30              648    AL       Anadia
# 3                202205  2022-01-30              653    AL    Arapiraca
# 4                202205  2022-01-30              645    AL      Atalaia
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0            12.0      state                     98149
# 1       2700102.0       city                       695
# 2       2700201.0       city                      1587
# 3       2700300.0       city                     32098
# 4       2700409.0       city                      1522
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                    10972.86661            320
# ...

# %%
df.place_type.unique()
# Out:
# array(['state', 'city'], dtype=object)

# %%
dfe = df[ df.place_type == 'state']
dfe = dfe.reset_index(drop=True)
dfe
# Out:
#     epidemiological_week        date  order_for_place state city  \
# 0                 202205  2022-01-30              685    AC  NaN
# 1                 202205  2022-01-30              694    AL  NaN
# 2                 202205  2022-01-30              689    AM  NaN
# 3                 202205  2022-01-30              682    AP  NaN
# 4                 202205  2022-01-30              696    BA  NaN
# 5                 202205  2022-01-30              686    CE  NaN
# 6                 202205  2022-01-30              697    ES  NaN
# 7                 202205  2022-01-30              682    MA  NaN
# 8                 202205  2022-01-30              694    MG  NaN
# 9                 202205  2022-01-30              688    MS  NaN
# 10                202205  2022-01-30              682    MT  NaN
# 11                202205  2022-01-30              684    PA  NaN
# 12                202205  2022-01-30              690    PB  NaN
# ...

# %%
dfc = df[ df.place_type == 'city']
dfc = dfc.reset_index(drop=True)
print(len(dfc))
dfc.head()
# Out:
# 1112
#    epidemiological_week        date  order_for_place state  \
# 0                202205  2022-01-30              607    AL
# 1                202205  2022-01-30              648    AL
# 2                202205  2022-01-30              653    AL
# 3                202205  2022-01-30              645    AL
# 4                202205  2022-01-30              648    AL
#
#                      city  city_ibge_code place_type  \
# 0             Água Branca       2700102.0       city
# 1                  Anadia       2700201.0       city
# 2               Arapiraca       2700300.0       city
# 3                 Atalaia       2700409.0       city
# 4  Barra de Santo Antônio       2700508.0       city
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                       695                                     3435.49184
# 1                      1587                                     9055.11811
# ...

# %%
dfc.city.unique()
# Out:
# array(['Água Branca', 'Anadia', 'Arapiraca', ..., 'Vitória das Missões',
#        'Westfália', 'Xangri-lá'], dtype=object)

# %%
len(dfc.city.unique())
# Out:
# 1102

# %%
dfc.head()
# Out:
#    epidemiological_week        date  order_for_place state  \
# 0                202205  2022-01-30              607    AL
# 1                202205  2022-01-30              648    AL
# 2                202205  2022-01-30              653    AL
# 3                202205  2022-01-30              645    AL
# 4                202205  2022-01-30              648    AL
#
#                      city  city_ibge_code place_type  \
# 0             Água Branca       2700102.0       city
# 1                  Anadia       2700201.0       city
# 2               Arapiraca       2700300.0       city
# 3                 Atalaia       2700409.0       city
# 4  Barra de Santo Antônio       2700508.0       city
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                       695                                     3435.49184
# 1                      1587                                     9055.11811
# ...

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
dfc.describe()
# Out:
#        epidemiological_week  order_for_place  city_ibge_code  \
# count                 1,112            1,112           1,108
# mean                202,205              624       3,474,232
# std                       0               34       1,240,464
# min                 202,205              485       1,500,107
# 25%                 202,205              606       2,206,666
# 50%                 202,205              629       4,304,659
# 75%                 202,205              647       4,316,715
# max                 202,205              694       5,108,956
#
#        last_available_confirmed  \
# count                     1,112
# mean                      3,323
# std                      11,107
# min                           0
# 25%                         417
# 50%                         894
# 75%                       2,278
# max                     213,482
#
#        last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# ...

# %%
dfc.describe().T
# Out:
#                                                count      mean       std  \
# epidemiological_week                           1,112   202,205         0
# order_for_place                                1,112       624        34
# city_ibge_code                                 1,108 3,474,232 1,240,464
# last_available_confirmed                       1,112     3,323    11,107
# last_available_confirmed_per_100k_inhabitants  1,108    12,082     6,401
# new_confirmed                                  1,112        22       103
# last_available_deaths                          1,112        74       312
# new_deaths                                     1,112         0         1
# last_available_death_rate                      1,112         0         0
# estimated_population                           1,108    27,322    87,562
#
#                                                     min       25%       50%  \
# epidemiological_week                            202,205   202,205   202,205
# ...

# %%
import seaborn as sns
import numpy as np

sns.distplot(dfc.new_confirmed)
# Out:
# C:\Users\valen\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='new_confirmed', ylabel='Density'>

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 16 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   epidemiological_week                           1112 non-null   int64
#  1   date                                           1112 non-null   object
#  2   order_for_place                                1112 non-null   int64
#  3   state                                          1112 non-null   object
#  4   city                                           1112 non-null   object
#  5   city_ibge_code                                 1108 non-null   float64
#  6   place_type                                     1112 non-null   object
#  7   last_available_confirmed                       1112 non-null   int64
#  8   last_available_confirmed_per_100k_inhabitants  1108 non-null   float64
# ...

# %%
dfc.head()
# Out:
#    epidemiological_week        date  order_for_place state  \
# 0                202205  2022-01-30              607    AL
# 1                202205  2022-01-30              648    AL
# 2                202205  2022-01-30              653    AL
# 3                202205  2022-01-30              645    AL
# 4                202205  2022-01-30              648    AL
#
#                      city  city_ibge_code place_type  \
# 0             Água Branca       2,700,102       city
# 1                  Anadia       2,700,201       city
# 2               Arapiraca       2,700,300       city
# 3                 Atalaia       2,700,409       city
# 4  Barra de Santo Antônio       2,700,508       city
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                       695                                          3,435
# 1                      1587                                          9,055
# ...

# %%
dfo = dfc.sort_values(by='new_confirmed', ascending=False).reset_index(drop=True)
dfo.head(12)
# Out:
#     epidemiological_week        date  order_for_place state  \
# 0                 202205  2022-01-30              684    PA
# 1                 202205  2022-01-30              649    PA
# 2                 202205  2022-01-30              670    PA
# 3                 202205  2022-01-30              691    RS
# 4                 202205  2022-01-30              668    PA
# 5                 202205  2022-01-30              676    PA
# 6                 202205  2022-01-30              647    PA
# 7                 202205  2022-01-30              681    RS
# 8                 202205  2022-01-30              676    RS
# 9                 202205  2022-01-30              670    MT
# 10                202205  2022-01-30              674    PA
# 11                202205  2022-01-30              657    PA
#
#                  city  city_ibge_code place_type  last_available_confirmed  \
# 0               Belém       1,501,402       city                    110470
# ...

# %%
dfo.tail(10)
# Out:
#       epidemiological_week        date  order_for_place state  \
# 1102                202205  2022-01-30              606    RS
# 1103                202205  2022-01-30              583    RS
# 1104                202205  2022-01-30              622    PI
# 1105                202205  2022-01-30              656    RS
# 1106                202205  2022-01-30              620    PI
# 1107                202205  2022-01-30              658    PI
# 1108                202205  2022-01-30              576    RS
# 1109                202205  2022-01-30              613    PI
# 1110                202205  2022-01-30              603    PI
# 1111                202205  2022-01-30              601    PI
#
#                            city  city_ibge_code place_type  \
# 1102                  Chiapetta       4,305,405       city
# 1103                    Charrua       4,305,371       city
# 1104          Capitão de Campos       2,202,406       city
# ...

# %%
dfo[dfo.city == 'Campina Grande']
# Out:
# Empty DataFrame
# Columns: [epidemiological_week, date, order_for_place, state, city, city_ibge_code, place_type, last_available_confirmed, last_available_confirmed_per_100k_inhabitants, new_confirmed, last_available_deaths, new_deaths, last_available_death_rate, estimated_population, is_last, is_repeated]
# Index: []

# %%
dfo[dfo.city == 'João Pessoa']
# Out:
# Empty DataFrame
# Columns: [epidemiological_week, date, order_for_place, state, city, city_ibge_code, place_type, last_available_confirmed, last_available_confirmed_per_100k_inhabitants, new_confirmed, last_available_deaths, new_deaths, last_available_death_rate, estimated_population, is_last, is_repeated]
# Index: []

# %%
dfo[dfo.city == 'Belém']
# Out:
#      epidemiological_week        date  order_for_place state   city  \
# 0                  202205  2022-01-30              684    PA  Belém
# 375                202205  2022-01-30              619    AL  Belém
#
#      city_ibge_code place_type  last_available_confirmed  \
# 0         1,501,402       city                    110470
# 375       2,700,805       city                       160
#
#      last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                            7,366           2638
# 375                                          3,735              3
#
#      last_available_deaths  new_deaths  last_available_death_rate  \
# 0                     5167           4                          0
# 375                      8           0                          0
#
#      estimated_population  is_last  is_repeated
# 0               1,499,641     True        False
# 375                 4,284     True        False

# %%
dfo[dfo.city == 'Porto Alegre']
# Out:
#    epidemiological_week        date  order_for_place state          city  \
# 3                202205  2022-01-30              691    RS  Porto Alegre
#
#    city_ibge_code place_type  last_available_confirmed  \
# 3       4,314,902       city                    213482
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 3                                         14,344            601
#
#    last_available_deaths  new_deaths  last_available_death_rate  \
# 3                   5891           3                          0
#
#    estimated_population  is_last  is_repeated
# 3             1,488,252     True        False

# %%
df.columns
# Out:
# Index(['epidemiological_week', 'date', 'order_for_place', 'state', 'city',
#        'city_ibge_code', 'place_type', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated'],
#       dtype='object')

# %%
atributos = df.columns.values

# %%
atributos
# Out:
# array(['epidemiological_week', 'date', 'order_for_place', 'state', 'city',
#        'city_ibge_code', 'place_type', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated'], dtype=object)

# %%
atrib = [ 'city', 'state', 
       'last_available_confirmed',
       'new_confirmed',
       'last_available_deaths', 'new_deaths', 
       'estimated_population']
atrib
# Out:
# ['city',
#  'state',
#  'last_available_confirmed',
#  'new_confirmed',
#  'last_available_deaths',
#  'new_deaths',
#  'estimated_population']

# %%
dfo2 = dfo [ atrib ]

# %%
dfo2[:20]
# Out:
#                    city state  last_available_confirmed  new_confirmed  \
# 0                 Belém    PA                    110470           2638
# 1              Redenção    PA                     18069           1193
# 2              Santarém    PA                     25477            619
# 3          Porto Alegre    RS                    213482            601
# 4              Altamira    PA                     17483            442
# 5             Castanhal    PA                     11434            436
# 6              Tomé-Açu    PA                      3793            427
# 7                Canoas    RS                     54167            407
# 8           Passo Fundo    RS                     47260            375
# 9      Tangará da Serra    MT                     20845            373
# 10          Parauapebas    PA                     56377            351
# 11    Canaã dos Carajás    PA                      9950            341
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

sns.barplot(x='new_confirmed', y='city', data = dfo[:20])
# Out:
# <AxesSubplot:xlabel='new_confirmed', ylabel='city'>

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='new_confirmed', y='city', data = dfo[:20], palette='RdBu')
# Out:
# <AxesSubplot:xlabel='new_confirmed', ylabel='city'>

# %%
dfo3 = dfo2[ dfo2.new_confirmed > 0]

# %%
dfo3.tail(20)
# Out:
#                                  city state  last_available_confirmed  \
# 555         Santo Antônio do Leverger    MT                      1731
# 556                         Brasnorte    MT                      2883
# 557                      Lagoa Alegre    PI                       370
# 558                         Quatipuru    PA                      1002
# 559                      Boca da Mata    AL                      2019
# 560                         Carneiros    AL                       387
# 561                     Monsenhor Gil    PI                      1676
# 562                    Elesbão Veloso    PI                       711
# 563                Colônia Leopoldina    AL                       440
# 564                         Primavera    PA                       888
# 565                           Melgaço    PA                       578
# 566  Vila Bela da Santíssima Trindade    MT                      3343
# ...

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='new_confirmed', y='city', data = dfo3[-15:], palette='RdBu')
# Out:
# <AxesSubplot:xlabel='new_confirmed', ylabel='city'>

# %%
dfo3.head()
# Out:
#            city state  last_available_confirmed  new_confirmed  \
# 0         Belém    PA                    110470           2638
# 1      Redenção    PA                     18069           1193
# 2      Santarém    PA                     25477            619
# 3  Porto Alegre    RS                    213482            601
# 4      Altamira    PA                     17483            442
#
#    last_available_deaths  new_deaths  estimated_population
# 0                   5167           4             1,499,641
# 1                    261           8                85,563
# 2                   1025          10               306,480
# 3                   5891           3             1,488,252
# 4                    344           0               115,969

# %%
pd.options.display.float_format = '{:,.1f}'.format

# %%
dft = dfo3.copy()
dft.head()
# Out:
#            city state  last_available_confirmed  new_confirmed  \
# 0         Belém    PA                    110470           2638
# 1      Redenção    PA                     18069           1193
# 2      Santarém    PA                     25477            619
# 3  Porto Alegre    RS                    213482            601
# 4      Altamira    PA                     17483            442
#
#    last_available_deaths  new_deaths  estimated_population
# 0                   5167           4           1,499,641.0
# 1                    261           8              85,563.0
# 2                   1025          10             306,480.0
# 3                   5891           3           1,488,252.0
# 4                    344           0             115,969.0

# %%
#dft = dfo3.copy()
dft['new_confimados/populacao'] = dft['new_confirmed'] / dft['estimated_population'] * 100
dft.head()
# Out:
#            city state  last_available_confirmed  new_confirmed  \
# 0         Belém    PA                    110470           2638
# 1      Redenção    PA                     18069           1193
# 2      Santarém    PA                     25477            619
# 3  Porto Alegre    RS                    213482            601
# 4      Altamira    PA                     17483            442
#
#    last_available_deaths  new_deaths  estimated_population  \
# 0                   5167           4           1,499,641.0
# 1                    261           8              85,563.0
# 2                   1025          10             306,480.0
# 3                   5891           3           1,488,252.0
# 4                    344           0             115,969.0
#
#    new_confimados/populacao
# 0                       0.2
# 1                       1.4
# 2                       0.2
# 3                       0.0
# 4                       0.4

# %%
atributos
# Out:
# array(['epidemiological_week', 'date', 'order_for_place', 'state', 'city',
#        'city_ibge_code', 'place_type', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'new_confirmed',
#        'last_available_deaths', 'new_deaths', 'last_available_death_rate',
#        'estimated_population', 'is_last', 'is_repeated'], dtype=object)

# %%
#atributos2 = ['city', 'state', 'confirmed', 'deaths',
        'estimated_population', 'city_ibge_code']
#atributos2

# %%
#dft2 = dft[ atributos2 ]
dft2 = dft.copy()

#del dft2

# %%
dfto = dft2.sort_values(by='new_confimados/populacao', ascending=False).reset_index(drop=True)

dfto[:20]
# Out:
#                         city state  last_available_confirmed  new_confirmed  \
# 0                       Faro    PA                      1291            160
# 1                   Belterra    PA                      2094            279
# 2                   Redenção    PA                     18069           1193
# 3            Abel Figueiredo    PA                      1191             81
# 4        Ourilândia do Norte    PA                      6549            302
# 5          Canaã dos Carajás    PA                      9950            341
# 6           Balneário Pinhal    RS                      1765            114
# 7          Conquista D'Oeste    MT                       630             31
# 8                   Tomé-Açu    PA                      3793            427
# 9               Pedras Altas    RS                       251             13
# 10             Porto Estrela    MT                       705             19
# ...

# %%
dfto['new_confimados/populacao'].describe()
# Out:
# count   574.0
# mean      0.1
# std       0.2
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.1
# max       2.3
# Name: new_confimados/populacao, dtype: float64

# %%
media = dfto['new_confimados/populacao'].mean()
media
# Out:
# 0.10351875347203053

# %%
dfm = dfto[ dfto['new_confimados/populacao'] > media]
print(len(dfto), len(dfm))
dfm.head(20)
# Out:
# 575 158
#                         city state  last_available_confirmed  new_confirmed  \
# 0                       Faro    PA                      1291            160
# 1                   Belterra    PA                      2094            279
# 2                   Redenção    PA                     18069           1193
# 3            Abel Figueiredo    PA                      1191             81
# 4        Ourilândia do Norte    PA                      6549            302
# 5          Canaã dos Carajás    PA                      9950            341
# 6           Balneário Pinhal    RS                      1765            114
# 7          Conquista D'Oeste    MT                       630             31
# 8                   Tomé-Açu    PA                      3793            427
# 9               Pedras Altas    RS                       251             13
# 10             Porto Estrela    MT                       705             19
# ...

# %%
len(dfm)
# Out:
# 158

# %%
dfm.isna().sum()
# Out:
# city                        0
# state                       0
# last_available_confirmed    0
# new_confirmed               0
# last_available_deaths       0
# new_deaths                  0
# estimated_population        0
# new_confimados/populacao    0
# dtype: int64

# %%
len(dfm)
# Out:
# 158

# %%
df.isna().sum()
# Out:
# epidemiological_week                              0
# date                                              0
# order_for_place                                   0
# state                                             0
# city                                             25
# city_ibge_code                                    4
# place_type                                        0
# last_available_confirmed                          0
# last_available_confirmed_per_100k_inhabitants     4
# new_confirmed                                     0
# last_available_deaths                             0
# new_deaths                                        0
# last_available_death_rate                         0
# estimated_population                              4
# is_last                                           0
# is_repeated                                       0
# dtype: int64

# %%
df.head()
# Out:
#    epidemiological_week        date  order_for_place state         city  \
# 0                202205  2022-01-30              685    AC          NaN
# 1                202205  2022-01-30              607    AL  Água Branca
# 2                202205  2022-01-30              648    AL       Anadia
# 3                202205  2022-01-30              653    AL    Arapiraca
# 4                202205  2022-01-30              645    AL      Atalaia
#
#    city_ibge_code place_type  last_available_confirmed  \
# 0            12.0      state                     98149
# 1     2,700,102.0       city                       695
# 2     2,700,201.0       city                      1587
# 3     2,700,300.0       city                     32098
# 4     2,700,409.0       city                      1522
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                       10,972.9            320
# 1                                        3,435.5              1
# ...

# %% [markdown]
# # Mapas

# %% [markdown]
# ### Instalar o Geopandas no Windows

# %% [markdown]
#  https://towardsdatascience.com/geopandas-installation-the-easy-way-for-windows-31a666b3610f

# %% [markdown]
# pip install .\GDAL-3.1.1-cp37-cp37m-win_amd64.whl <br>
# pip install .\pyproj-2.6.1.post1-cp37-cp37m-win_amd64.whl <br>
# pip install .\Fiona-1.8.13-cp37-cp37m-win_amd64.whl <br>
# pip install .\Shapely-1.7.0-cp37-cp37m-win_amd64.whl <br>
# pip install .\geopandas-0.8.0-py3-none-any <br>

# %%
#!pip install geopandas

# %%
#!pip install mapclassify

# %%
# !dir estados*
# Out:
#  O volume na unidade C ‚ Windows10
#  O N£mero de S‚rie do Volume ‚ E699-979D
#
#  Pasta de C:\Users\valen\Dropbox\AULAS-REMOTAS\Alunos-UEPB-TopicosEspeciaisEmBancoDeDados\Python-Para-Analise-de-Dados\MANHA
# Arquivo nÆo encontrado
