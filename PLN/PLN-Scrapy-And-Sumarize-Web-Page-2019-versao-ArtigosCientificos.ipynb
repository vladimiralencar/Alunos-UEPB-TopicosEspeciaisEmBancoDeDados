# %% [markdown]
# # <font color='blue'>PLN - Scrapy and Sumarize Web Page -  2019</font>

# %% [markdown]
# ### Carregando um Dataset de um Site de E-commerce (em português)

# %% [markdown]
# ## Gensim - Modelagem de Tópicos (Sumarização, etc)

# %% [markdown]
# https://github.com/RaRe-Technologies/gensim

# %%
#!pip install gensim
#!conda install -c anaconda beautifulsoup4

# %%
import requests

url = 'https://www.saibamais.jor.br/bacurau-sera-mesmo-resistencia/'
page = requests.get(url)
page.text[:300]
# Out:
# '<!DOCTYPE html>\n<html lang="pt-BR">\n\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n\t<meta name="format-detection" content="telephone=no">\n\t<meta name="theme-color" content="#fdb913">\n\t<link rel="profile" href="https://gmpg.org/x'

# %%
page.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html lang="pt-BR">\n\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n\t<meta name="format-detection" content="telephone=no">\n\t<meta name="theme-color" content="#fdb913">\n\t<link rel="profile" href="https://gmpg.org/xfn/11">\n\t<link rel="pingback" href="https://www.saibamais.jor.br/xmlrpc.php">\n\t\t\n\t<title>Bacurau: será mesmo resistência?</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v12.4 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="&quot;Bacurau, para mim, em muitos aspectos, presta um enorme desserviço para a necessária elaboração de um novo imaginário político por parte das forças da esquerda&quot;. Confira a crítica do professor e historiador Durval Muniz de Albuquerque Jr. ao filme Bacurau, dirigido por Kléber Mendonça e Juliano Dornelles."/>\n<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-
# ...

# %% [markdown]
# # Pegar 1 texto na web e resumir usando o gensim

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="#fdb913" name="theme-color"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.saibamais.jor.br/xmlrpc.php" rel="pingback"/>
#   <title>
#    Bacurau: será mesmo resistência?
#   </title>
#   <!-- This site is optimized with the Yoast SEO plugin v12.4 - https://yoast.com/wordpress/plugins/seo/ -->
#   <meta content='"Bacurau, para mim, em muitos aspectos, presta um enorme desserviço para a necessária elaboração de um novo imaginário político por parte das forças da esquerda". Confira a crítica do professor e historiador Durval Muniz de Albuquerque Jr. ao filme Bacurau, dirigido por Kléber Mendonça e Juliano Dornelles.' name="description">
# ...

# %%
paragraphs = soup.find_all('p')
paragraphs[:1]
# Out:
# [<p>Vejo por todo lado um enorme entusiasmo com o filme <em>Bacurau</em>, dos diretores Kleber Mendonça Filho e Juliano Dornelles, até porque o filme recebeu o prêmio do júri do Festival de Cannes (sabemos como nosso complexo de vira-latas valoriza algo nacional quanto e só quando reconhecido internacionalmente, muitos não teriam ido assistir o filme se não fosse o prêmio), e na ocasião atores e diretores se posicionaram publicamente de maneira bastante crítica em relação a situação política e social brasileira. Esses eventos, de cara, prepararam uma recepção bastante favorável ao filme entre os setores mais à esquerda do espectro político. A filmografia anterior de Kleber Mendonça Filho também gerava a expectativa de estarmos diante de um novo trabalho que continuaria o questionamento da violência inerente às relações sociais no Brasil, das desigualdades sociais, dos problemas urbanos do país, como a especulação imobiliária, dos traços, ainda presentes em nossas cidades, de nosso pa
# ...

# %%
text = soup.find_all('p')[0].get_text()
text[:300]
# Out:
# 'Vejo por todo lado um enorme entusiasmo com o filme Bacurau, dos diretores Kleber Mendonça Filho e Juliano Dornelles, até porque o filme recebeu o prêmio do júri do Festival de Cannes (sabemos como nosso complexo de vira-latas valoriza algo nacional quanto e só quando reconhecido internacionalmente,'

# %% [markdown]
# ## Resumir o texto usando o Gensim

# %%
print('Número de parágrafos:', len(soup.find_all('p')))
# Out:
# Número de parágrafos: 22

# %%
import gensim
num_paragraphs = 3
word_count=1000
print (gensim.summarization.summarize(text, word_count=word_count))
# Out:
# Vejo por todo lado um enorme entusiasmo com o filme Bacurau, dos diretores Kleber Mendonça Filho e Juliano Dornelles, até porque o filme recebeu o prêmio do júri do Festival de Cannes (sabemos como nosso complexo de vira-latas valoriza algo nacional quanto e só quando reconhecido internacionalmente, muitos não teriam ido assistir o filme se não fosse o prêmio), e na ocasião atores e diretores se posicionaram publicamente de maneira bastante crítica em relação a situação política e social brasileira.
# Esses eventos, de cara, prepararam uma recepção bastante favorável ao filme entre os setores mais à esquerda do espectro político.
# ...

# %%
# Summary (0.5% of the original content). 
ratio = 0.5
print (gensim.summarization.summarize(text, ratio=ratio))
# Out:
# Vejo por todo lado um enorme entusiasmo com o filme Bacurau, dos diretores Kleber Mendonça Filho e Juliano Dornelles, até porque o filme recebeu o prêmio do júri do Festival de Cannes (sabemos como nosso complexo de vira-latas valoriza algo nacional quanto e só quando reconhecido internacionalmente, muitos não teriam ido assistir o filme se não fosse o prêmio), e na ocasião atores e diretores se posicionaram publicamente de maneira bastante crítica em relação a situação política e social brasileira.
# Todos esses elementos prepararam uma recepção bastante favorável para o filme que, nos dias sombrios em que vive o país, foi enunciado e elevado, por importantes críticos e intelectuais brasileiros, à condição de símbolo de resistência das forças progressistas do país, diante da deliberada perseguição às atividades culturais e, inclusive, da explícita censura a Agência Nacional de Cinema e do desmonte das políticas de apoio a produção audiovisual brasileira.

# %% [markdown]
# # Função para ler e Sumarizar PDF

# %% [markdown]
# # ler pdf

# %%
# !ls *.pdf
# Out:
# Seleçao_texto 2.pdf
# Seleção_texto 4.pdf
# Todas as Coisas Belas - Matthew Quick.pdf

# %%
# pip install tika
import tika
tika.initVM()
from tika import parser

url = 'Todas as Coisas Belas - Matthew Quick.pdf'
parsed = parser.from_file(url)
print(parsed["metadata"])
print(parsed["content"][:300])
# Out:
# 2019-11-10 13:39:32,905 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# ...

# %%
pages = parsed["content"]
len(pages)
# Out:
# 316106

# %% [markdown]
# # Sumarizar o pdf usando o Modelador de Tópicos Gensim

# %%
# %%time
import gensim

text = pages
# sumariza

word_count=300
#print (gensim.summarization.summarize(text, word_count=word_count, split=True))
print (gensim.summarization.summarize(text, word_count=word_count))
# Out:
# ” Ele não pode perguntar a uma das irmãs se era ela no riacho naquele dia,
# na floresta e que não quer falar com ele nunca mais.
# meus pais não se amavam mais, mas sempre acreditei que eles fossem exatamente
# Por que não pode ser apenas uma conversa
# Você não tem mais aula com aquele seu professor que lhe deu o livro que
# Não duvido, ainda mais depois que ele me mandou fotos da sua coleção secreta
# Ele queria que eu lesse um pouco de poesia para você hoje, mas eu  Não
# Por que você não queria vir com seu pai?
# Sinto muito que isso tenha acontecido com você  disse ele, quando
# Não fale assim com seu técnico, Nanette  disse meu pai, muito
# Sua filha jogava por sua causa, Don. Só que ela não é mais uma garotinha.
# dele como escritor, e aí é por isso que ela está com um sorriso ligeiramente
# Por que você não tinha uma namorada antes de a gente se conhecer?
# Você sabe que a gente vai falar com a Sandra  disse Alex quando
# ...

# %%
# %%time

# Summary (0.05% of the original content). 
ratio = 0.05
print (gensim.summarization.summarize(text, ratio=ratio))
# Out:
# i esse livro quando tinha sua idade, e ele mudou minha vida  disse o sr.
# clássico cult e sinto que pode ser a leitura perfeita para você.
# Na época fiquei com raiva, mas tempos depois entendi que era cautela.
# superior, mas tenho minhas dúvidas quanto a isso, porque o narrador não
# ” Ele não pode perguntar a uma das irmãs se era ela no riacho naquele dia,
# rigle  passa meses nesse dilema, torcendo para que a gêmea com quem
# na floresta e que não quer falar com ele nunca mais.
# ele conclui que a gêmea certa é ena, sobretudo porque ela fica nervosa e bate o
# indício é que há pouco tempo ena começou a usar uma bolsa com um patch da
# se ela aceitar, será uma confirmação de que ele acertou.
# conversa com a tartaruga no riacho não amaria o rigle  que vai ao baile,
# Seu lixo de gente  Você é uma vergonha para nosso bairro.
# Agora eu entendo, Ted mprodutivo, por que você fica o dia inteiro
# curiosa para saber o que acontece com rigle  depois que ele sai da água.
# ...
