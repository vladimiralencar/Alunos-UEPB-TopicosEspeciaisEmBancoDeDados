# %% [markdown]
# # Kmeans - Aprendizagem Não-Supervisionada

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# ## Filmes - Segmentação
# Disponível em: https://www.kaggle.com/tmdb <br>
# https://www.imdb.com/chart/top/?ref_=nv_mv_250

# %%
df = pd.read_csv("tmdb_5000_movies.csv")

#df.rename(columns={'budget': 'Custo', 'revenue': 'Receita'}, inplace=True)

df['Custo'] = df.budget
df['Receita'] = df.revenue

df.Custo = df.Custo.apply("{:,}".format)
df.Receita = df.Receita.apply("{:,}".format)

df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...     revenue runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   880674609   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  1084939099   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   284139100   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#          Custo        Receita
# 0  237,000,000  2,787,965,087
# 1  300,000,000    961,000,000
# 2  245,000,000    880,674,609
# 3  250,000,000  1,084,939,099
# 4  260,000,000    284,139,100
#
# [5 rows x 22 columns]

# %%
print("Número de filmes: ",len(df))
# Out:
# Número de filmes:  4803

# %%
len(df.columns)
# Out:
# 22

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'Custo', 'Receita'],
#       dtype='object')

# %% [markdown]
# ### Cenário 1 - Filmes

# %%
# budget - custo do filme
# revenue - receita do filme
df["lucro"] = (df.loc[:, "revenue"] - df.loc[:, "budget"])/1000000

plt.scatter( df.loc[:, "popularity"],  df.loc[:, "lucro"], 
             c="b")
plt.title("Filmes por Lucro/Popularidade")
plt.xlabel("Lucro (em Milhões)")
plt.ylabel("Popularidade")
plt.show()

# %%
# budget - custo do filme
# revenue - receita do filme
df["lucro"] = (df.loc[:, "revenue"] - df.loc[:, "budget"])/1000000
plt.scatter( df.loc[:, "vote_average"],  df.loc[:, "lucro"], 
             c="b")
plt.title("Filmes por Lucro/Popularidade")
plt.xlabel("Lucro (em Milhões)")
plt.ylabel("vote_average")
plt.show()

# %%
# Clusterização
from sklearn.cluster import KMeans
X = df.loc[:, ["popularity", "lucro"]]
X.head()
# Out:
#    popularity        lucro
# 0  150.437577  2550.965087
# 1  139.082615   661.000000
# 2  107.376788   635.674609
# 3  112.312950   834.939099
# 4   43.926995    24.139100

# %%
cluster = y_pred = KMeans(n_clusters=3).fit_predict(X) 
df["cluster"] = cluster
df.loc[ :, ["popularity", "lucro", 'cluster']].head()
# Out:
#    popularity        lucro  cluster
# 0  150.437577  2550.965087        2
# 1  139.082615   661.000000        2
# 2  107.376788   635.674609        2
# 3  112.312950   834.939099        2
# 4   43.926995    24.139100        0

# %%
df.cluster.value_counts()
# Out:
# 0    4098
# 1     593
# 2     112
# Name: cluster, dtype: int64

# %%
matplotlib.style.use("ggplot")

fig = plt.figure()
ax = fig.add_subplot(111)

scatter = ax.scatter( df.loc[:, "popularity"], df.loc[:, "lucro"], c=df["cluster"], s=100)
plt.title("Filmes por Lucro/Popularidade")
plt.xlabel("Lucro (em Milhões)")
plt.ylabel("Popularidade")
plt.colorbar(scatter)
ax.set_aspect('auto')

plt.show()

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#          Custo        Receita        lucro  cluster
# 0  237,000,000  2,787,965,087  2550.965087        2
# 1  300,000,000    961,000,000   661.000000        2
# 2  245,000,000    880,674,609   635.674609        2
# 3  250,000,000  1,084,939,099   834.939099        2
# 4  260,000,000    284,139,100    24.139100        0
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'Custo', 'Receita', 'lucro', 'cluster'],
#       dtype='object')

# %%
df[ df["cluster"] == 2].sort_values(by='lucro', ascending=False ) [:5]
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25  200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 28  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44  190000000                     [{"id": 28, "name": "Action"}]
# 16  220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
#
#                              homepage      id  \
# 0         http://www.avatarmovie.com/   19995
# 25        http://www.titanicmovie.com     597
# 28      http://www.jurassicworld.com/  135397
# 44           http://www.furious7.com/  168259
# 16  http://marvel.com/avengers_movie/   24428
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 28  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 44  [{"id": 830, "name": "car race"}, {"id": 3428,...                en
# 16  [{"id": 242, "name": "new york"}, {"id": 5539,...                en
#
#     original_title                                           overview  \
# 0           Avatar  In the 22nd century, a paraplegic Marine is di...
# 25         Titanic  84 years later, a 101-year-old woman named Ros...
# 28  Jurassic World  Twenty-two years after the events of Jurassic ...
# 44       Furious 7  Deckard Shaw seeks revenge against Dominic Tor...
# 16    The Avengers  When an unexpected enemy emerges and threatens...
#
#     popularity                               production_companies  ...  \
# 0   150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 25  100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 28  418.708552  [{"name": "Universal Studios", "id": 13}, {"na...  ...
# 44  102.322217  [{"name": "Universal Pictures", "id": 33}, {"n...  ...
# 16  144.448633  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
#
#                                      spoken_languages    status  \
# 0   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 25  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 28           [{"iso_639_1": "en", "name": "English"}]  Released
# 44           [{"iso_639_1": "en", "name": "English"}]  Released
# 16           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                       tagline           title vote_average  \
# 0                 Enter the World of Pandora.          Avatar          7.2
# 25  Nothing on Earth could come between them.         Titanic          7.5
# 28                          The park is open.  Jurassic World          6.5
# 44                        Vengeance Hits Home       Furious 7          7.3
# 16                    Some assembly required.    The Avengers          7.4
#
#    vote_count        Custo        Receita        lucro  cluster
# 0       11800  237,000,000  2,787,965,087  2550.965087        2
# 25       7562  200,000,000  1,845,034,188  1645.034188        2
# 28       8662  150,000,000  1,513,528,810  1363.528810        2
# 44       4176  190,000,000  1,506,249,360  1316.249360        2
# 16      11776  220,000,000  1,519,557,910  1299.557910        2
#
# [5 rows x 24 columns]

# %%
df['release_date'].head()
# Out:
# 0    2009-12-10
# 1    2007-05-19
# 2    2015-10-26
# 3    2012-07-16
# 4    2012-03-07
# Name: release_date, dtype: object

# %%
df[ (df["cluster"] == 2) & (df['release_date'] >= '2015-01-01') ].sort_values(by='lucro', ascending=False ) [:5]
# Out:
#         budget                                             genres  \
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                               homepage      id  \
# 28                       http://www.jurassicworld.com/  135397
# 44                            http://www.furious7.com/  168259
# 7    http://marvel.com/movies/movie/193/avengers_ag...   99861
# 546                       http://www.minionsmovie.com/  211672
# 26            http://marvel.com/captainamericapremiere  271110
#
#                                               keywords original_language  \
# 28   [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 44   [{"id": 830, "name": "car race"}, {"id": 3428,...                en
# 7    [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
# 26   [{"id": 393, "name": "civil war"}, {"id": 6091...                en
#
#                  original_title  \
# 28               Jurassic World
# 44                    Furious 7
# 7       Avengers: Age of Ultron
# 546                     Minions
# 26   Captain America: Civil War
#
#                                               overview  popularity  \
# 28   Twenty-two years after the events of Jurassic ...  418.708552
# 44   Deckard Shaw seeks revenge against Dominic Tor...  102.322217
# 7    When Tony Stark tries to jumpstart a dormant p...  134.279229
# 546  Minions Stuart, Kevin and Bob are recruited by...  875.581305
# 26   Following the events of Age of Ultron, the col...  198.372395
#
#                                   production_companies  ...  \
# 28   [{"name": "Universal Studios", "id": 13}, {"na...  ...
# 44   [{"name": "Universal Pictures", "id": 33}, {"n...  ...
# 7    [{"name": "Marvel Studios", "id": 420}, {"name...  ...
# 546  [{"name": "Universal Pictures", "id": 33}, {"n...  ...
# 26   [{"name": "Studio Babelsberg", "id": 264}, {"n...  ...
#
#                                       spoken_languages    status  \
# 28            [{"iso_639_1": "en", "name": "English"}]  Released
# 44            [{"iso_639_1": "en", "name": "English"}]  Released
# 7             [{"iso_639_1": "en", "name": "English"}]  Released
# 546           [{"iso_639_1": "en", "name": "English"}]  Released
# 26   [{"iso_639_1": "ro", "name": "Rom\u00e2n\u0103...  Released
#
#                                           tagline                       title  \
# 28                              The park is open.              Jurassic World
# 44                            Vengeance Hits Home                   Furious 7
# 7                             A New Age Has Come.     Avengers: Age of Ultron
# 546  Before Gru, they had a history of bad bosses                     Minions
# 26                                Divided We Fall  Captain America: Civil War
#
#     vote_average vote_count        Custo        Receita        lucro  cluster
# 28           6.5       8662  150,000,000  1,513,528,810  1363.528810        2
# 44           7.3       4176  190,000,000  1,506,249,360  1316.249360        2
# 7            7.3       6767  280,000,000  1,405,403,694  1125.403694        2
# 546          6.4       4571   74,000,000  1,156,730,962  1082.730962        2
# 26           7.1       7241  250,000,000  1,153,304,495   903.304495        2
#
# [5 rows x 24 columns]

# %%
df[ df["cluster"] == 0].sort_values(by='lucro', ascending=False ) [:10]
# Out:
#          budget                                             genres  \
# 2116   20000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 3446    6000000                [{"id": 99, "name": "Documentary"}]
# 1363   35000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 2090   20000000                     [{"id": 35, "name": "Comedy"}]
# 399    85000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 1156   40000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 2330   17000000                     [{"id": 35, "name": "Comedy"}]
# 296   100000000  [{"id": 28, "name": "Action"}, {"id": 14, "nam...
# 704    60000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 1050   43000000  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
#
#                                             homepage     id  \
# 2116                                             NaN  14873
# 3446                                             NaN   1777
# 1363                                             NaN  10054
# 2090                                             NaN  10678
# 399   http://www.sonypictures.com/movies/openseason/   7484
# 1156                                             NaN   1645
# 2330                       http://www.meangirls.com/  10625
# 296                      http://www.end-of-days.com/   9946
# 704                                              NaN   8916
# 1050                                             NaN   4379
#
#                                                keywords original_language  \
# 2116  [{"id": 1261, "name": "river"}, {"id": 4344, "...                en
# 3446  [{"id": 840, "name": "usa president"}, {"id": ...                en
# 1363  [{"id": 848, "name": "double life"}, {"id": 97...                en
# 2090  [{"id": 378, "name": "prison"}, {"id": 1594, "...                en
# 399   [{"id": 414, "name": "hunter"}, {"id": 1262, "...                en
# 1156  [{"id": 529, "name": "ku klux klan"}, {"id": 5...                en
# 2330  [{"id": 5248, "name": "female friendship"}, {"...                en
# 296   [{"id": 186, "name": "christianity"}, {"id": 5...                en
# 704   [{"id": 1402, "name": "general"}, {"id": 1701,...                en
# 1050  [{"id": 2374, "name": "bad mother-in-law"}, {"...                en
#
#                original_title  \
# 2116        The Jungle Book 2
# 3446          Fahrenheit 9/11
# 1363                 Spy Kids
# 2090  Bringing Down the House
# 399               Open Season
# 1156           A Time to Kill
# 2330               Mean Girls
# 296               End of Days
# 704                      Antz
# 1050           Monster-in-Law
#
#                                                overview  popularity  \
# 2116  Mowgli, missing the jungle and his old friends...   19.819893
# 3446  Michael Moore's view on what happened to the U...   16.209850
# 1363  Carmen and Juni think their parents are boring...   21.543389
# 2090  Straight-laced lawyer, Peter Sanderson (Steve ...    8.351385
# 399   Boog, a domesticated 900lb. Grizzly bear finds...   26.619510
# 1156  A young lawyer defends a black man accused of ...   25.219805
# 2330  Cady Heron is a hit with The Plastics, the A-l...   36.423717
# 296   On December 28th, 1999, the citizens of New Yo...   20.652943
# 704   In this animated hit, a neurotic worker ant in...   41.515702
# 1050  Office temp Charlotte Cantilini thinks she's f...   10.411996
#
#                                    production_companies  ...  \
# 2116  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 3446  [{"name": "BIM Distribuzione", "id": 225}, {"n...  ...
# 1363  [{"name": "Dimension Films", "id": 7405}, {"na...  ...
# 2090  [{"name": "Hyde Park Films", "id": 1172}, {"na...  ...
# 399   [{"name": "Sony Pictures Animation", "id": 2251}]  ...
# 1156  [{"name": "Regency Enterprises", "id": 508}, {...  ...
# 2330  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 296      [{"name": "Beacon Communications", "id": 919}]  ...
# 704   [{"name": "DreamWorks SKG", "id": 27}, {"name"...  ...
# 1050  [{"name": "New Line Cinema", "id": 12}, {"name...  ...
#
#                                        spoken_languages    status  \
# 2116           [{"iso_639_1": "en", "name": "English"}]  Released
# 3446  [{"iso_639_1": "ar", "name": "\u0627\u0644\u06...  Released
# 1363  [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...  Released
# 2090  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 399            [{"iso_639_1": "en", "name": "English"}]  Released
# 1156           [{"iso_639_1": "en", "name": "English"}]  Released
# 2330  [{"iso_639_1": "sw", "name": "Kiswahili"}, {"i...  Released
# 296   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 704            [{"iso_639_1": "en", "name": "English"}]  Released
# 1050  [{"iso_639_1": "cs", "name": "\u010cesk\u00fd"...  Released
#
#                                                 tagline  \
# 2116                               Feel the jungle beat
# 3446                   Controversy... what controversy?
# 1363                          Real spies...only smaller
# 2090  Everything he needed to know about life, she l...
# 399                           One Fur All & All Fur One
# 1156             Experience a time you'll never forget.
# 2330                             Welcome to girl world.
# 296                                Prepare for the end.
# 704                              Every ant has his day.
# 1050    This relationship is going to be a real mother.
#
#                         title vote_average vote_count        Custo  \
# 2116        The Jungle Book 2          5.6        269   20,000,000
# 3446          Fahrenheit 9/11          6.8        397    6,000,000
# 1363                 Spy Kids          5.5        867   35,000,000
# 2090  Bringing Down the House          5.4        183   20,000,000
# 399               Open Season          6.1        656   85,000,000
# 1156           A Time to Kill          7.0        509   40,000,000
# 2330               Mean Girls          6.9       2320   17,000,000
# 296               End of Days          5.5        482  100,000,000
# 704                      Antz          6.0       1272   60,000,000
# 1050           Monster-in-Law          5.6        406   43,000,000
#
#           Receita       lucro  cluster
# 2116  135,680,000  115.680000        0
# 3446  119,114,517  113.114517        0
# 1363  147,934,180  112.934180        0
# 2090  132,675,402  112.675402        0
# 399   197,309,027  112.309027        0
# 1156  152,266,007  112.266007        0
# 2330  129,042,871  112.042871        0
# 296   211,989,043  111.989043        0
# 704   171,757,863  111.757863        0
# 1050  154,749,918  111.749918        0
#
# [10 rows x 24 columns]

# %%
df[ df["cluster"] == 1].sort_values(by='lucro', ascending=False ) [:10]
# Out:
#          budget                                             genres  \
# 243   110000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2809    7000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 185   132000000  [{"id": 12, "name": "Adventure"}, {"id": 53, "...
# 2511   18000000  [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# 509    75000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 120   150000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 254   110000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 558    75000000  [{"id": 16, "name": "Animation"}, {"id": 35, "...
# 234   135000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 277   150000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                                homepage     id  \
# 243                                                 NaN   1593
# 2809                             http://www.jaws25.com/    578
# 185                                                 NaN     74
# 2511       https://www.foxconnect.com/home-alone-4.html    771
# 509                                                 NaN    953
# 120                  http://www.madagascar-themovie.com  10527
# 254                        http://www.smurfhappens.com/  41513
# 558                       http://www.simpsonsmovie.com/     35
# 234                      http://www.thecroodsmovie.com/  49519
# 277   http://www.mgm.com/#/our-titles/233/Casino-Roy...  36557
#
#                                                keywords original_language  \
# 243   [{"id": 2598, "name": "museum"}, {"id": 4062, ...                en
# 2809  [{"id": 1495, "name": "fishing"}, {"id": 1913,...                en
# 185   [{"id": 447, "name": "post traumatic stress  d...                en
# 2511  [{"id": 65, "name": "holiday"}, {"id": 1437, "...                en
# 509   [{"id": 2043, "name": "lion"}, {"id": 2509, "n...                en
# 120   [{"id": 409, "name": "africa"}, {"id": 931, "n...                en
# 254   [{"id": 305, "name": "moon"}, {"id": 2343, "na...                en
# 558   [{"id": 494, "name": "father son relationship"...                en
# 234   [{"id": 4428, "name": "stone age"}, {"id": 560...                en
# 277   [{"id": 131, "name": "italy"}, {"id": 383, "na...                en
#
#                    original_title  \
# 243           Night at the Museum
# 2809                         Jaws
# 185             War of the Worlds
# 2511                   Home Alone
# 509                    Madagascar
# 120   Madagascar: Escape 2 Africa
# 254                    The Smurfs
# 558            The Simpsons Movie
# 234                    The Croods
# 277                 Casino Royale
#
#                                                overview  popularity  \
# 243   Chaos reigns at the natural history museum whe...   48.780039
# 2809  An insatiable great white shark terrorizes the...   50.152327
# 185   Ray Ferrier is a divorced dockworker and less-...   48.572726
# 2511  Eight-year-old Kevin McCallister makes the mos...    2.186927
# 509   Zoo animals leave the comforts of man-made hab...   48.110909
# 120   Alex, Marty, Melman, Gloria, King Julien, Maur...   44.141021
# 254   When the evil wizard Gargamel chases the tiny ...   36.654220
# 558   After Homer accidentally pollutes the town's w...   46.875375
# 234   The Croods is a prehistoric comedy adventure t...   64.183321
# 277   Le Chiffre, a banker to the world's terrorists...   88.935165
#
#                                    production_companies  ...  \
# 243   [{"name": "Ingenious Film Partners", "id": 289...  ...
# 2809  [{"name": "Universal Pictures", "id": 33}, {"n...  ...
# 185   [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 2511  [{"name": "Twentieth Century Fox Film Corporat...  ...
# 509   [{"name": "DreamWorks SKG", "id": 27}, {"name"...  ...
# 120       [{"name": "DreamWorks Animation", "id": 521}]  ...
# 254   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 558   [{"name": "Gracie Films", "id": 18}, {"name": ...  ...
# 234       [{"name": "DreamWorks Animation", "id": 521}]  ...
# 277   [{"name": "Eon Productions", "id": 7576}, {"na...  ...
#
#                                        spoken_languages    status  \
# 243   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2809           [{"iso_639_1": "en", "name": "English"}]  Released
# 185            [{"iso_639_1": "en", "name": "English"}]  Released
# 2511           [{"iso_639_1": "en", "name": "English"}]  Released
# 509   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 120   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 254            [{"iso_639_1": "en", "name": "English"}]  Released
# 558            [{"iso_639_1": "en", "name": "English"}]  Released
# 234            [{"iso_639_1": "en", "name": "English"}]  Released
# 277   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                                                 tagline  \
# 243                         Where History Comes To Life
# 2809                             Don't go in the water.
# 185                               They're already here.
# 2511                A Family Comedy Without the Family.
# 509                          Someone's got a zoo loose.
# 120                         Still together. Still lost!
# 254                                      Smurf Happens.
# 558        See our family. And feel better about yours.
# 234                       Meet the first modern family.
# 277   Everyone has a past. Every legend has a beginn...
#
#                             title vote_average vote_count        Custo  \
# 243           Night at the Museum          6.3       2862  110,000,000
# 2809                         Jaws          7.5       2542    7,000,000
# 185             War of the Worlds          6.2       2322  132,000,000
# 2511                   Home Alone          7.1       2414   18,000,000
# 509                    Madagascar          6.6       3237   75,000,000
# 120   Madagascar: Escape 2 Africa          6.2       1810  150,000,000
# 254                    The Smurfs          5.5       1179  110,000,000
# 558            The Simpsons Movie          6.9       2264   75,000,000
# 234                    The Croods          6.8       2399  135,000,000
# 277                 Casino Royale          7.3       3855  150,000,000
#
#           Receita       lucro  cluster
# 243   574,480,841  464.480841        1
# 2809  470,654,000  463.654000        1
# 185   591,739,379  459.739379        1
# 2511  476,684,675  458.684675        1
# 509   532,680,671  457.680671        1
# 120   603,900,354  453.900354        1
# 254   563,749,323  453.749323        1
# 558   527,068,851  452.068851        1
# 234   585,178,928  450.178928        1
# 277   599,045,960  449.045960        1
#
# [10 rows x 24 columns]

# %%
def plot_cluster(df, centroids, xdata_name, ydata_name, title, xlabel, ylabel):

    # Set style of scatterplot
    sns.set_context("notebook", font_scale=1.1)
    sns.set_style("ticks")
    
    # Create scatterplot of dataframe
    sns.lmplot(xdata_name, # Horizontal axis
               ydata_name, # Vertical axis
               data=df, # Data source
               fit_reg=False, # Don't fix a regression line
               hue="cluster")
    
    plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', 
            linewidths=3,
            color='k',)

    
    # Set title
    plt.title(title)
    # Set x-axis label
    plt.xlabel(xlabel)
    # Set y-axis label
    plt.ylabel(ylabel)
    plt.show()

# %%
n_clusters = 3
kmeans = KMeans(n_clusters).fit(X)
ypred = KMeans(n_clusters).fit_predict(X)
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )
# Out:
# /home/valencar/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
kmeans.cluster_centers_
# Out:
# array([[ 14.93158445,  11.77645564],
#        [117.98346025, 710.10636795],
#        [ 48.95085111, 217.60142042]])

# %%
# budget - custo do filme
# revenue - receita do filme
df2 = df[ df["cluster"] == 2].sort_values(by='lucro', ascending=False ) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(20)
# Out:
#                                              title  popularity     revenue  \
# 0                                           Avatar  150.437577  2787965087
# 25                                         Titanic  100.025899  1845034188
# 28                                  Jurassic World  418.708552  1513528810
# 44                                       Furious 7  102.322217  1506249360
# 16                                    The Avengers  144.448633  1519557910
# 7                          Avengers: Age of Ultron  134.279229  1405403694
# 124                                         Frozen  165.125366  1274219009
# 546                                        Minions  875.581305  1156730962
# 329  The Lord of the Rings: The Return of the King  123.630332  1118888979
# 31                                      Iron Man 3   77.682080  1215439994
# 52                  Transformers: Dark of the Moon   28.529607  1123746996
# 29                                         Skyfall   93.004993  1108561013
# 26                      Captain America: Civil War  198.372395  1153304495
# 506                                Despicable Me 2  136.886704   970761885
# 36                 Transformers: Age of Extinction  116.840296  1091405097
# 42                                     Toy Story 3   59.995418  1066969703
# 12      Pirates of the Caribbean: Dead Man's Chest  145.847379  1065659812
# 675                                  Jurassic Park   40.413191   920100000
# 197       Harry Potter and the Philosopher's Stone  109.984351   976475550
# 330          The Lord of the Rings: The Two Towers  106.914973   926287400
#
#            lucro  cluster
# 0    2550.965087        2
# 25   1645.034188        2
# 28   1363.528810        2
# 44   1316.249360        2
# 16   1299.557910        2
# 7    1125.403694        2
# 124  1124.219009        2
# 546  1082.730962        2
# 329  1024.888979        2
# 31   1015.439994        2
# 52    928.746996        2
# 29    908.561013        2
# 26    903.304495        2
# 506   894.761885        2
# 36    881.405097        2
# 42    866.969703        2
# 12    865.659812        2
# 675   857.100000        2
# 197   851.475550        2
# 330   847.287400        2

# %%
df2 = df[ df["cluster"] == 2].sort_values(by='lucro', ascending=True) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(20)
# Out:
#                                                   title  popularity  \
# 160                          How to Train Your Dragon 2  100.213910
# 118                                         Ratatouille   65.677399
# 115                                             Hancock   56.758411
# 614                                       Despicable Me  113.858273
# 126                                Thor: The Dark World   99.499595
# 1695                                            Aladdin   92.982009
# 2017                                              Ghost   41.967005
# 790                                     American Sniper   87.534370
# 88                                           Big Hero 6  203.734590
# 216                                          Life of Pi   51.328145
# 102               The Hunger Games: Mockingjay - Part 2  127.284427
# 46                           X-Men: Days of Future Past  118.078691
# 903                                                 Ted   68.876910
# 342                                        Men in Black  104.121555
# 204                                           Fast Five    7.255718
# 181                                       Kung Fu Panda   84.689648
# 38                             The Amazing Spider-Man 2   89.270217
# 95                                         Interstellar  724.247784
# 199   Pirates of the Caribbean: The Curse of the Bla...  271.972889
# 137                                     Kung Fu Panda 2   51.247321
#
#         revenue       lucro  cluster
# 160   609123048  464.123048        2
# 118   623722818  473.722818        2
# 115   624029371  474.029371        2
# 614   543513985  474.513985        2
# 126   644571402  474.571402        2
# 1695  504050219  476.050219        2
# 2017  505000000  483.000000        2
# 790   542307423  483.507423        2
# 88    652105443  487.105443        2
# 216   609016565  489.016565        2
# 102   653428261  493.428261        2
# 46    747862775  497.862775        2
# 903   549368315  499.368315        2
# 342   589390539  499.390539        2
# 204   626137675  501.137675        2
# 181   631744560  501.744560        2
# 38    705717432  505.717432        2
# 95    675120017  510.120017        2
# 199   655011224  515.011224        2
# 137   665692281  515.692281        2

# %%
pd.options.display.float_format = '{:,.0f}'.format
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        2
# 1  http://disney.go.com/disneypictures/pirates/         139    661        2
# 2   http://www.sonypictures.com/movies/spectre/         107    636        2
# 3            http://www.thedarkknightrises.com/         112    835        2
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
n_clusters = 4
kmeans = KMeans(n_clusters).fit(X)
y_pred = KMeans(n_clusters=4).fit_predict(X)


df["cluster"] = y_pred


# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )
# Out:
# /home/valencar/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
n_clusters = 5
kmeans = KMeans(n_clusters).fit(X)
y_pred = KMeans(n_clusters).fit_predict(X)
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )
# Out:
# /home/valencar/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# budget - custo do filme
# revenue - receita do filme
df2 = df[ df["cluster"] == 3].sort_values(by='lucro', ascending=False ) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(15)
# Out:
#                        title  popularity     revenue  lucro  cluster
# 0                     Avatar         150  2787965087  2,551        3
# 25                   Titanic         100  1845034188  1,645        3
# 28            Jurassic World         419  1513528810  1,364        3
# 44                 Furious 7         102  1506249360  1,316        3
# 16              The Avengers         144  1519557910  1,300        3
# 7    Avengers: Age of Ultron         134  1405403694  1,125        3
# 124                   Frozen         165  1274219009  1,124        3
# 546                  Minions         876  1156730962  1,083        3

# %%
#df2 = df[ df["title"].apply(lambda x: x is 'furious') ].sort_values(by='revenue', ascending=False ) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(10)
# Out:
#                        title  popularity     revenue  lucro  cluster
# 0                     Avatar         150  2787965087  2,551        3
# 25                   Titanic         100  1845034188  1,645        3
# 28            Jurassic World         419  1513528810  1,364        3
# 44                 Furious 7         102  1506249360  1,316        3
# 16              The Avengers         144  1519557910  1,300        3
# 7    Avengers: Age of Ultron         134  1405403694  1,125        3
# 124                   Frozen         165  1274219009  1,124        3
# 546                  Minions         876  1156730962  1,083        3

# %%
df[df['title'].str.contains('Titanic')]
# Out:
#          budget                                             genres  \
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 1269          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 3103          0                      [{"id": 18, "name": "Drama"}]
#
#                          homepage      id  \
# 25    http://www.titanicmovie.com     597
# 1269                          NaN   24575
# 3103                          NaN  115872
#
#                                                keywords original_language  \
# 25    [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 1269                                                 []                en
# 3103                                                 []                en
#
#                       original_title  \
# 25                           Titanic
# 1269               Raise the Titanic
# 3103  La femme de chambre du Titanic
#
#                                                overview  popularity  \
# 25    84 years later, a 101-year-old woman named Ros...         100
# 1269  To obtain a supply of a rare mineral, a ship r...           2
# 3103  Horty, a French foundry worker, wins a contest...           1
#
#                                    production_companies  ...  \
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 1269        [{"name": "ITC Entertainment", "id": 1584}]  ...
# 3103                                                 []  ...
#
#                                        spoken_languages    status  \
# 25    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1269           [{"iso_639_1": "en", "name": "English"}]  Released
# 3103  [{"iso_639_1": "hu", "name": "Magyar"}, {"iso_...  Released
#
#                                                 tagline  \
# 25            Nothing on Earth could come between them.
# 1269  They've found the Titanic. There's just one th...
# 3103                                                NaN
#
#                                title vote_average vote_count        Custo  \
# 25                           Titanic            8       7562  200,000,000
# 1269               Raise the Titanic            5         21            0
# 3103  The Chambermaid on the Titanic            5          3            0
#
#             Receita  lucro  cluster
# 25    1,845,034,188  1,645        3
# 1269              0      0        0
# 3103              0      0        0
#
# [3 rows x 24 columns]

# %%
df[df['title'].str.contains('Superman')]
# Out:
#          budget                                             genres  \
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 813    55000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 870    54000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1296   39000000  [{"id": 35, "name": "Comedy"}, {"id": 28, "nam...
# 2433   17000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                           homepage      id  \
# 9     http://www.batmanvsupermandawnofjustice.com/  209112
# 10                         http://www.superman.com    1452
# 813                                            NaN    1924
# 870                                            NaN    8536
# 1296                                           NaN    9531
# 2433                                           NaN   11411
#
#                                                keywords original_language  \
# 9     [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
# 10    [{"id": 83, "name": "saving the world"}, {"id"...                en
# 813   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 870   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 1296  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 2433  [{"id": 83, "name": "saving the world"}, {"id"...                en
#
#                           original_title  \
# 9     Batman v Superman: Dawn of Justice
# 10                      Superman Returns
# 813                             Superman
# 870                          Superman II
# 1296                        Superman III
# 2433    Superman IV: The Quest for Peace
#
#                                                overview  popularity  \
# 9     Fearing the actions of a god-like Super Hero l...         156
# 10    Superman returns to discover his 5-year absenc...          58
# 813   Mild-mannered Clark Kent works as a reporter a...          49
# 870   Three escaped criminals from the planet Krypto...          31
# 1296  Aiming to defeat the Man of Steel, wealthy exe...          22
# 2433  With global superpowers engaged in an increasi...          17
#
#                                    production_companies  ...  \
# 9     [{"name": "DC Comics", "id": 429}, {"name": "A...  ...
# 10    [{"name": "DC Comics", "id": 429}, {"name": "L...  ...
# 813   [{"name": "Warner Bros.", "id": 6194}, {"name"...  ...
# 870   [{"name": "Warner Bros.", "id": 6194}, {"name"...  ...
# 1296  [{"name": "Warner Bros.", "id": 6194}, {"name"...  ...
# 2433  [{"name": "Cannon Films", "id": 4110}, {"name"...  ...
#
#                                        spoken_languages    status  \
# 9              [{"iso_639_1": "en", "name": "English"}]  Released
# 10    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 813            [{"iso_639_1": "en", "name": "English"}]  Released
# 870            [{"iso_639_1": "en", "name": "English"}]  Released
# 1296  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2433  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                                                 tagline  \
# 9                                    Justice or revenge
# 10                                                  NaN
# 813                       You'll Believe a Man Can Fly!
# 870                   The Man of Steel meets his match!
# 1296  If the world's most powerful computer can cont...
# 2433  Nuclear Power. In the best hands, it is danger...
#
#                                    title vote_average vote_count        Custo  \
# 9     Batman v Superman: Dawn of Justice            6       7004  250,000,000
# 10                      Superman Returns            5       1400  270,000,000
# 813                             Superman            7       1022   55,000,000
# 870                          Superman II            6        629   54,000,000
# 1296                        Superman III            5        490   39,000,000
# 2433    Superman IV: The Quest for Peace            4        318   17,000,000
#
#           Receita  lucro  cluster
# 9     873,260,194    623        1
# 10    391,081,192    121        2
# 813   300,218,018    245        4
# 870   190,458,706    136        2
# 1296   75,850,624     37        0
# 2433   19,300,000      2        0
#
# [6 rows x 24 columns]

# %%
df[df['title'].str.contains('Woman')]
# Out:
#         budget                                             genres  \
# 1185  40000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 2533  17000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...
# 2668  14000000  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 2896         0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 2942  11000000                      [{"id": 18, "name": "Drama"}]
# 3269   8000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3528         0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3921   3000000                      [{"id": 18, "name": "Drama"}]
# 4694         0                      [{"id": 18, "name": "Drama"}]
# 4705         0                      [{"id": 18, "name": "Drama"}]
# 4719    120000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                           homepage      id  \
# 1185                           NaN  193610
# 2533      http://womaninblack.com/   65086
# 2668                           NaN     114
# 2896                           NaN   44555
# 2942  http://womaningoldmovie.com/  304357
# 3269                           NaN   14629
# 3528                           NaN   16186
# 3921                           NaN   44634
# 4694                           NaN  288927
# 4705                           NaN   28666
# 4719                           NaN   40652
#
#                                                keywords original_language  \
# 1185  [{"id": 1326, "name": "infidelity"}, {"id": 97...                en
# 2533  [{"id": 212, "name": "london england"}, {"id":...                en
# 2668  [{"id": 549, "name": "prostitute"}, {"id": 592...                en
# 2896                                                 []                zh
# 2942  [{"id": 2652, "name": "nazis"}, {"id": 9672, "...                en
# 3269         [{"id": 187056, "name": "woman director"}]                en
# 3528                                                 []                en
# 3921        [{"id": 10183, "name": "independent film"}]                en
# 4694         [{"id": 187056, "name": "woman director"}]                en
# 4705  [{"id": 155700, "name": "charles willeford"}, ...                en
# 4719  [{"id": 1965, "name": "sandstorm"}, {"id": 151...                fr
#
#                                          original_title  \
# 1185                                    The Other Woman
# 2533                                 The Woman in Black
# 2668                                       Pretty Woman
# 2896                                             三枪拍案惊奇
# 2942                                      Woman in Gold
# 3269                                       Woman on Top
# 3528                         Diary of a Mad Black Woman
# 3921                              Woman Thou Art Loosed
# 4694                             Archaeology of a Woman
# 4705                                   The Woman Chaser
# 4719  Une femme mariée: Suite de fragments d'un film...
#
#                                                overview  popularity  \
# 1185  After discovering her boyfriend is married, Ca...          35
# 2533  The story follows a young lawyer, Arthur Kipps...          44
# 2668  When millionaire wheeler-dealer Edward Lewis e...          45
# 2896  Wang is a gloomy, cunning and avaricious noodl...           1
# 2942  Maria Altmann, an octogenarian Jewish refugee,...          21
# 3269  Set to the intoxicating rhythms of Brazil, "Wo...           4
# 3528  Charles McCarter and his wife Helen are about ...           4
# 3921  An adaptation of Bishop T.D. Jakes' self-help ...           0
# 4694  A woman's dementia uncovers secrets of a 30-ye...           0
# 4705  A 1950s used-car salesman (Patrick Warburton) ...           1
# 4719  Charlotte is young and modern, not a hair out ...           1
#
#                                    production_companies  ...  \
# 1185  [{"name": "Twentieth Century Fox Film Corporat...  ...
# 2533  [{"name": "Hammer Film Productions", "id": 131...  ...
# 2668  [{"name": "Touchstone Pictures", "id": 9195}, ...  ...
# 2896  [{"name": "Beijing New Picture Film Co. Ltd.",...  ...
# 2942  [{"name": "BBC Films", "id": 288}, {"name": "O...  ...
# 3269   [{"name": "Fox Searchlight Pictures", "id": 43}]  ...
# 3528           [{"name": "Lions Gate Films", "id": 35}]  ...
# 3921                                                 []  ...
# 4694                                                 []  ...
# 4705                                                 []  ...
# 4719  [{"name": "Orsay Films", "id": 2325}, {"name":...  ...
#
#                                        spoken_languages    status  \
# 1185           [{"iso_639_1": "en", "name": "English"}]  Released
# 2533           [{"iso_639_1": "en", "name": "English"}]  Released
# 2668  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2896  [{"iso_639_1": "zh", "name": "\u666e\u901a\u8b...  Released
# 2942  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3269  [{"iso_639_1": "pt", "name": "Portugu\u00eas"}...  Released
# 3528           [{"iso_639_1": "en", "name": "English"}]  Released
# 3921           [{"iso_639_1": "en", "name": "English"}]  Released
# 4694           [{"iso_639_1": "en", "name": "English"}]  Released
# 4705           [{"iso_639_1": "en", "name": "English"}]  Released
# 4719     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"}]  Released
#
#                                           tagline  \
# 1185     The oddest friends are about to get even
# 2533                           What did they see?
# 2668  Who knew it was so much fun to be a hooker?
# 2896                                          NaN
# 2942                        Justice is priceless.
# 3269              Want to know how she got there?
# 3528  Time heals the heart. Faith heals the rest.
# 3921                                          NaN
# 4694                                          NaN
# 4705                                          NaN
# 4719  She Loves Two Men... She is Married to One!
#
#                                  title vote_average vote_count       Custo  \
# 1185                   The Other Woman            6       1437  40,000,000
# 2533                The Woman in Black            6       1206  17,000,000
# 2668                      Pretty Woman            7       1746  14,000,000
# 2896  A Woman, a Gun and a Noodle Shop            5         13           0
# 2942                     Woman in Gold            7        440  11,000,000
# 3269                      Woman on Top            6         46   8,000,000
# 3528        Diary of a Mad Black Woman            6         71           0
# 3921             Woman Thou Art Loosed            5          3   3,000,000
# 4694            Archaeology of a Woman            0          0           0
# 4705                  The Woman Chaser            5          4           0
# 4719                 The Married Woman            7         20     120,000
#
#           Receita  lucro  cluster
# 1185  196,781,193    157        2
# 2533  127,730,736    111        2
# 2668  463,000,000    449        4
# 2896            0      0        0
# 2942   61,619,773     51        0
# 3269            0     -8        0
# 3528            0      0        0
# 3921    6,804,016      4        0
# 4694            0      0        0
# 4705            0      0        0
# 4719            0     -0        0
#
# [11 rows x 24 columns]

# %%
y_pred[:5]
# Out:
# array([3, 1, 1, 1, 0], dtype=int32)

# %%
df.cluster.value_counts()
# Out:
# 0    3591
# 2     850
# 4     260
# 1      94
# 3       8
# Name: cluster, dtype: int64

# %%
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        3
# 1  http://disney.go.com/disneypictures/pirates/         139    661        1
# 2   http://www.sonypictures.com/movies/spectre/         107    636        1
# 3            http://www.thedarkknightrises.com/         112    835        1
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
# James Cameron lucra US$ 350 milhões com 'Avatar ... 
# Arrecadou US$ 97 milhões com "Titanic"
df.loc[:,["homepage","popularity","lucro", "cluster"]].sort_values(by="lucro", ascending=False).head(15)
# Out:
#                                               homepage  popularity  lucro  \
# 0                          http://www.avatarmovie.com/         150  2,551
# 25                         http://www.titanicmovie.com         100  1,645
# 28                       http://www.jurassicworld.com/         419  1,364
# 44                            http://www.furious7.com/         102  1,316
# 16                   http://marvel.com/avengers_movie/         144  1,300
# 7    http://marvel.com/movies/movie/193/avengers_ag...         134  1,125
# 124                    http://movies.disney.com/frozen         165  1,124
# 546                       http://www.minionsmovie.com/         876  1,083
# 329                      http://www.lordoftherings.net         124  1,025
# 31                          http://marvel.com/ironman3          78  1,015
# 52                   http://www.transformersmovie.com/          29    929
# 29                        http://www.skyfall-movie.com          93    909
# 26            http://marvel.com/captainamericapremiere         198    903
# 506                       http://www.despicableme.com/         137    895
# 36                    http://www.transformersmovie.com         117    881
#
#      cluster
# 0          3
# 25         3
# 28         3
# 44         3
# 16         3
# 7          3
# 124        3
# 546        3
# 329        1
# 31         1
# 52         1
# 29         1
# 26         1
# 506        1
# 36         1

# %% [markdown]
# ### Predição de novos dados

# %%
n_clusters = 6
n_clusters
# Out:
# 6

# %%
y_pred = KMeans(n_clusters, random_state=0).fit(X)
df["cluster"] = y_pred.labels_
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        3
# 1  http://disney.go.com/disneypictures/pirates/         139    661        1
# 2   http://www.sonypictures.com/movies/spectre/         107    636        1
# 3            http://www.thedarkknightrises.com/         112    835        1
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
y_pred = KMeans(n_clusters, random_state=0).fit_predict(X)
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        3
# 1  http://disney.go.com/disneypictures/pirates/         139    661        1
# 2   http://www.sonypictures.com/movies/spectre/         107    636        1
# 3            http://www.thedarkknightrises.com/         112    835        1
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
X.head()
# Out:
#    popularity  lucro
# 0         150  2,551
# 1         139    661
# 2         107    636
# 3         112    835
# 4          44     24

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)

popularity = 150.437577
lucro = 2550.965087
kmeans.predict([[popularity, lucro], [130, 500], [43,24]])
# Out:
# array([1, 1, 0], dtype=int32)

# %%
def plot_new_data_cluster(df, x_new, y_new, centroids, xdata_name, ydata_name, title, xlabel, ylabel):

    # Set style of scatterplot
    sns.set_context("notebook", font_scale=1.1)
    sns.set_style("ticks")
    
    # Create scatterplot of dataframe
    sns.lmplot(xdata_name, # Horizontal axis
               ydata_name, # Vertical axis
               data=df, # Data source
               fit_reg=False, # Don't fix a regression line
               hue="cluster")
    
    plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', 
            linewidths=3,
            color='k',)

    
    plt.scatter(x_new, y_new, c='red', marker='x', s=100)
    
    # Set title
    plt.title(title)
    # Set x-axis label
    plt.xlabel(xlabel)
    # Set y-axis label
    plt.ylabel(ylabel)
    plt.show()

# %%
n_clusters = 5
kmeans = KMeans(n_clusters).fit(X)
y_pred = KMeans(n_clusters).fit_predict(X)
df["cluster"] = y_pred

centroids = kmeans.cluster_centers_

# os novos dados
popularity = 150.437577
lucro = 2550.965087
dados_x = [[popularity, lucro], [130, 500], [43,24]]
x_new = [x[0] for x in dados_x]
y_new = [y[1] for y in dados_x]


plot_new_data_cluster(df, x_new, y_new, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )
# Out:
# /home/valencar/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# centróides
kmeans.cluster_centers_
# Out:
# array([[  12.36801168,    2.13871119],
#        [ 110.70365888,  672.66544345],
#        [  36.31608207,  110.15005281],
#        [  60.70927127,  312.49790486],
#        [ 261.36609725, 1438.4611275 ]])

# %%
kmeans.labels_
# Out:
# array([4, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
len(kmeans.labels_)
# Out:
# 4803

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...         150
# 1  Captain Barbossa, long believed to be dead, ha...         139
# 2  A cryptic message from Bond’s past sends him o...         107
# 3  Following the death of District Attorney Harve...         112
# 4  John Carter is a war-weary, former military ca...          44
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar            7      11800
# 1  Pirates of the Caribbean: At World's End            7       4500
# 2                                   Spectre            6       4466
# 3                     The Dark Knight Rises            8       9106
# 4                               John Carter            6       2124
#
#          Custo        Receita  lucro  cluster
# 0  237,000,000  2,787,965,087  2,551        3
# 1  300,000,000    961,000,000    661        2
# 2  245,000,000    880,674,609    636        2
# 3  250,000,000  1,084,939,099    835        2
# 4  260,000,000    284,139,100     24        1
#
# [5 rows x 24 columns]

# %%
df[df["cluster"]==3].head(7)
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 7    http://marvel.com/movies/movie/193/avengers_ag...   99861
# 16                   http://marvel.com/avengers_movie/   24428
# 25                         http://www.titanicmovie.com     597
# 28                       http://www.jurassicworld.com/  135397
# 44                            http://www.furious7.com/  168259
# 124                    http://movies.disney.com/frozen  109445
#
#                                               keywords original_language  \
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 7    [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 16   [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 25   [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 28   [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 44   [{"id": 830, "name": "car race"}, {"id": 3428,...                en
# 124  [{"id": 2011, "name": "queen"}, {"id": 4344, "...                en
#
#               original_title  \
# 0                     Avatar
# 7    Avengers: Age of Ultron
# 16              The Avengers
# 25                   Titanic
# 28            Jurassic World
# 44                 Furious 7
# 124                   Frozen
#
#                                               overview  popularity  \
# 0    In the 22nd century, a paraplegic Marine is di...         150
# 7    When Tony Stark tries to jumpstart a dormant p...         134
# 16   When an unexpected enemy emerges and threatens...         144
# 25   84 years later, a 101-year-old woman named Ros...         100
# 28   Twenty-two years after the events of Jurassic ...         419
# 44   Deckard Shaw seeks revenge against Dominic Tor...         102
# 124  Young princess Anna of Arendelle dreams about ...         165
#
#                                   production_companies  ...  \
# 0    [{"name": "Ingenious Film Partners", "id": 289...  ...
# 7    [{"name": "Marvel Studios", "id": 420}, {"name...  ...
# 16   [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 25   [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 28   [{"name": "Universal Studios", "id": 13}, {"na...  ...
# 44   [{"name": "Universal Pictures", "id": 33}, {"n...  ...
# 124  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
#
#                                       spoken_languages    status  \
# 0    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 7             [{"iso_639_1": "en", "name": "English"}]  Released
# 16            [{"iso_639_1": "en", "name": "English"}]  Released
# 25   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 28            [{"iso_639_1": "en", "name": "English"}]  Released
# 44            [{"iso_639_1": "en", "name": "English"}]  Released
# 124           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                tagline  \
# 0                          Enter the World of Pandora.
# 7                                  A New Age Has Come.
# 16                             Some assembly required.
# 25           Nothing on Earth could come between them.
# 28                                   The park is open.
# 44                                 Vengeance Hits Home
# 124  Only the act of true love will thaw a frozen h...
#
#                        title vote_average vote_count        Custo  \
# 0                     Avatar            7      11800  237,000,000
# 7    Avengers: Age of Ultron            7       6767  280,000,000
# 16              The Avengers            7      11776  220,000,000
# 25                   Titanic            8       7562  200,000,000
# 28            Jurassic World            6       8662  150,000,000
# 44                 Furious 7            7       4176  190,000,000
# 124                   Frozen            7       5295  150,000,000
#
#            Receita  lucro  cluster
# 0    2,787,965,087  2,551        3
# 7    1,405,403,694  1,125        3
# 16   1,519,557,910  1,300        3
# 25   1,845,034,188  1,645        3
# 28   1,513,528,810  1,364        3
# 44   1,506,249,360  1,316        3
# 124  1,274,219,009  1,124        3
#
# [7 rows x 24 columns]

# %% [markdown]
# ### Cenário 2 - Filmes

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 3
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro" , title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 4
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro", title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 5
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro", title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 6
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro", title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %% [markdown]
# # Determinando o melhor número de Clusters (Elbow Method)

# %%
Xx = Xx
Ks = range(1, 10)
km = [KMeans(n_clusters=i) for i in Ks]
score = [km[i].fit(Xx).score(Xx) for i in range(len(km))]
print(score)

# %%
list(range(1,9))

# %%
score

# %%
plt.style.use('ggplot')
plt.scatter( list(range(1,len(score)+1)), score, c="b")
plt.title("Curva de Elbow")
plt.xlabel("Clusters")
plt.ylabel("Distorção")
plt.show()

# %% [markdown]
# Exercício: Variar o número de clusters (k=7)
