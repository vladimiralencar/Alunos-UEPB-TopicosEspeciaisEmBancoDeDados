# %% [markdown]
# # Kmeans - Aprendizagem Não-Supervisionada

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# ## Filmes - Segmentação
# Disponível em: https://www.kaggle.com/tmdb

# %%
df = pd.read_csv("tmdb_5000_movies.csv")

#df.rename(columns={'budget': 'Custo', 'revenue': 'Receita'}, inplace=True)

df['Custo'] = df.budget
df['Receita'] = df.revenue

df.Custo = df.Custo.apply("{:,}".format)
df.Receita = df.Receita.apply("{:,}".format)

df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...     revenue runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   880674609   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  1084939099   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   284139100   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#          Custo        Receita
# 0  237,000,000  2,787,965,087
# 1  300,000,000    961,000,000
# 2  245,000,000    880,674,609
# 3  250,000,000  1,084,939,099
# 4  260,000,000    284,139,100
#
# [5 rows x 22 columns]

# %%
print("Número de filmes: ",len(df))
# Out:
# Número de filmes:  4803

# %%
len(df.columns)
# Out:
# 22

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'Custo', 'Receita'],
#       dtype='object')

# %% [markdown]
# ### Cenário 1 - Filmes

# %%
# budget - custo do filme
# revenue - receita do filme
df["lucro"] = (df.loc[:, "revenue"] - df.loc[:, "budget"])/1000000
plt.scatter( df.loc[:, "popularity"],  df.loc[:, "lucro"], 
             c="b")
plt.title("Filmes por Lucro/Popularidade")
plt.xlabel("Lucro (em Milhões)")
plt.ylabel("Popularidade")
plt.show()

# %%
# Clusterização
from sklearn.cluster import KMeans
X = df.loc[:, ["popularity", "lucro"]]
X.head()
# Out:
#    popularity        lucro
# 0  150.437577  2550.965087
# 1  139.082615   661.000000
# 2  107.376788   635.674609
# 3  112.312950   834.939099
# 4   43.926995    24.139100

# %%
y_pred = KMeans(n_clusters=3).fit_predict(X) 
df["cluster"] = y_pred
df.loc[ :, ["popularity", "lucro", 'cluster']].head()
# Out:
#    popularity        lucro  cluster
# 0  150.437577  2550.965087        1
# 1  139.082615   661.000000        1
# 2  107.376788   635.674609        1
# 3  112.312950   834.939099        1
# 4   43.926995    24.139100        0

# %%
matplotlib.style.use("ggplot")

fig = plt.figure()
ax = fig.add_subplot(111)

scatter = ax.scatter( df.loc[:, "popularity"], df.loc[:, "lucro"], c=df["cluster"], s=100)
plt.title("Filmes por Lucro/Popularidade")
plt.xlabel("Lucro (em Milhões)")
plt.ylabel("Popularidade")
plt.colorbar(scatter)
ax.set_aspect('auto')
#plt.colorbar(label=y_pred)
#plt.legend()

plt.show()

# %%
df[ df["cluster"] == 2].sort_values(by='revenue', ascending=False ) [:20]
# Out:
#         budget                                             genres  \
# 14   225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 18   225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 79   200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 120  150000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 277  150000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 6    260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 185  132000000  [{"id": 12, "name": "Adventure"}, {"id": 53, "...
# 11   200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 116  150000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...
# 234  135000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 68   140000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 243  110000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 254  110000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 231  115000000  [{"id": 16, "name": "Animation"}, {"id": 35, "...
# 40   200000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 187  130000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 149  140000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 24   207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 213  125000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 212  125000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                               homepage      id  \
# 14                          http://www.manofsteel.com/   49521
# 18     http://www.sonypictures.com/movies/meninblack3/   41154
# 79                        http://www.ironmanmovie.com/   10138
# 120                 http://www.madagascar-themovie.com   10527
# 277  http://www.mgm.com/#/our-titles/233/Casino-Roy...   36557
# 6         http://disney.go.com/disneypictures/tangled/   38757
# 185                                                NaN      74
# 11   http://www.mgm.com/view/movie/234/Quantum-of-S...   10764
# 116                   http://iamlegend.warnerbros.com/    6479
# 234                     http://www.thecroodsmovie.com/   49519
# 68                        http://www.ironmanmovie.com/    1726
# 243                                                NaN    1593
# 254                       http://www.smurfhappens.com/   41513
# 231              http://movies.disney.com/monsters-inc     585
# 40                      http://www.disney.go.com/cars/   49013
# 187                                                NaN  417859
# 149                                                NaN      95
# 24                                                 NaN     254
# 213                  http://www.missionimpossible.com/     955
# 212                http://www.thedayaftertomorrow.com/     435
#
#                                               keywords original_language  \
# 14   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 18   [{"id": 4379, "name": "time travel"}, {"id": 5...                en
# 79   [{"id": 8613, "name": "malibu"}, {"id": 8828, ...                en
# 120  [{"id": 409, "name": "africa"}, {"id": 931, "n...                en
# 277  [{"id": 131, "name": "italy"}, {"id": 383, "na...                en
# 6    [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# 185  [{"id": 447, "name": "post traumatic stress  d...                en
# 11   [{"id": 627, "name": "killing"}, {"id": 1568, ...                en
# 116  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 234  [{"id": 4428, "name": "stone age"}, {"id": 560...                en
# 68   [{"id": 539, "name": "middle east"}, {"id": 61...                en
# 243  [{"id": 2598, "name": "museum"}, {"id": 4062, ...                en
# 254  [{"id": 305, "name": "moon"}, {"id": 2343, "na...                en
# 231  [{"id": 1299, "name": "monster"}, {"id": 3256,...                en
# 40   [{"id": 830, "name": "car race"}, {"id": 9663,...                en
# 187  [{"id": 4414, "name": "adventure"}, {"id": 618...                en
# 149  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 24   [{"id": 774, "name": "film business"}, {"id": ...                en
# 213  [{"id": 321, "name": "terror"}, {"id": 514, "n...                en
# 212  [{"id": 83, "name": "saving the world"}, {"id"...                en
#
#                   original_title  \
# 14                  Man of Steel
# 18                Men in Black 3
# 79                    Iron Man 2
# 120  Madagascar: Escape 2 Africa
# 277                Casino Royale
# 6                        Tangled
# 185            War of the Worlds
# 11             Quantum of Solace
# 116                  I Am Legend
# 234                   The Croods
# 68                      Iron Man
# 243          Night at the Museum
# 254                   The Smurfs
# 231               Monsters, Inc.
# 40                        Cars 2
# 187                Puss in Boots
# 149                   Armageddon
# 24                     King Kong
# 213       Mission: Impossible II
# 212       The Day After Tomorrow
#
#                                               overview  popularity  \
# 14   A young boy learns that he has extraordinary p...   99.398009
# 18   Agents J (Will Smith) and K (Tommy Lee Jones) ...   52.035179
# 79   With the world now aware of his dual life as t...   77.300194
# 120  Alex, Marty, Melman, Gloria, King Julien, Maur...   44.141021
# 277  Le Chiffre, a banker to the world's terrorists...   88.935165
# 6    When the kingdom's most wanted-and most charmi...   48.681969
# 185  Ray Ferrier is a divorced dockworker and less-...   48.572726
# 11   Quantum of Solace continues the adventures of ...  107.928811
# 116  Robert Neville is a scientist who was unable t...   70.867401
# 234  The Croods is a prehistoric comedy adventure t...   64.183321
# 68   After being held captive in an Afghan cave, bi...  120.725053
# 243  Chaos reigns at the natural history museum whe...   48.780039
# 254  When the evil wizard Gargamel chases the tiny ...   36.654220
# 231  James Sullivan and Mike Wazowski are monsters,...  106.815545
# 40   Star race car Lightning McQueen and his pal Ma...   49.986590
# 187  Long before he even met Shrek, the notorious f...   20.678787
# 149  When an asteroid threatens to collide with Ear...   58.485967
# 24   In 1933 New York, an overly ambitious movie pr...   61.226010
# 213  With computer genius Luther Stickell at his si...   54.931334
# 212  After years of increases in the greenhouse eff...   41.380094
#
#                                   production_companies  ...  \
# 14   [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 18   [{"name": "Amblin Entertainment", "id": 56}, {...  ...
# 79             [{"name": "Marvel Studios", "id": 420}]  ...
# 120      [{"name": "DreamWorks Animation", "id": 521}]  ...
# 277  [{"name": "Eon Productions", "id": 7576}, {"na...  ...
# 6    [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 185  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 11           [{"name": "Eon Productions", "id": 7576}]  ...
# 116  [{"name": "Village Roadshow Pictures", "id": 7...  ...
# 234      [{"name": "DreamWorks Animation", "id": 521}]  ...
# 68             [{"name": "Marvel Studios", "id": 420}]  ...
# 243  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 254  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 231  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 40   [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 187                  [{"name": "DreamWorks", "id": 7}]  ...
# 149  [{"name": "Jerry Bruckheimer Films", "id": 130...  ...
# 24   [{"name": "WingNut Films", "id": 11}, {"name":...  ...
# 213  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
# 212  [{"name": "Lions Gate Films", "id": 35}, {"nam...  ...
#
#                                       spoken_languages    status  \
# 14            [{"iso_639_1": "en", "name": "English"}]  Released
# 18            [{"iso_639_1": "en", "name": "English"}]  Released
# 79   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 120  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 277  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 6             [{"iso_639_1": "en", "name": "English"}]  Released
# 185           [{"iso_639_1": "en", "name": "English"}]  Released
# 11   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 116           [{"iso_639_1": "en", "name": "English"}]  Released
# 234           [{"iso_639_1": "en", "name": "English"}]  Released
# 68   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 243  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 254           [{"iso_639_1": "en", "name": "English"}]  Released
# 231           [{"iso_639_1": "en", "name": "English"}]  Released
# 40   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 187  [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...  Released
# 149  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 24            [{"iso_639_1": "en", "name": "English"}]  Released
# 213           [{"iso_639_1": "en", "name": "English"}]  Released
# 212  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                                                tagline  \
# 14                You will believe that a man can fly.
# 18                           They are back... in time.
# 79   It's not the armor that makes the hero, but th...
# 120                        Still together. Still lost!
# 277  Everyone has a past. Every legend has a beginn...
# 6             They're taking adventure to new lengths.
# 185                              They're already here.
# 11       For love, for hate, for justice, for revenge.
# 116                 The last man on Earth is not alone
# 234                      Meet the first modern family.
# 68                  Heroes aren't born. They're built.
# 243                        Where History Comes To Life
# 254                                     Smurf Happens.
# 231                          We Scare Because We Care.
# 40                                            Ka-ciao!
# 187  Live for danger. Fight for justice. Pray for m...
# 149  The Earth's Darkest Day Will Be Man's Finest Hour
# 24                     The eighth wonder of the world.
# 213                       Expect the impossible again.
# 212                                 Where will you be?
#
#                            title vote_average vote_count        Custo  \
# 14                  Man of Steel          6.5       6359  225,000,000
# 18                Men in Black 3          6.2       4160  225,000,000
# 79                    Iron Man 2          6.6       6849  200,000,000
# 120  Madagascar: Escape 2 Africa          6.2       1810  150,000,000
# 277                Casino Royale          7.3       3855  150,000,000
# 6                        Tangled          7.4       3330  260,000,000
# 185            War of the Worlds          6.2       2322  132,000,000
# 11             Quantum of Solace          6.1       2965  200,000,000
# 116                  I Am Legend          6.9       4853  150,000,000
# 234                   The Croods          6.8       2399  135,000,000
# 68                      Iron Man          7.4       8776  140,000,000
# 243          Night at the Museum          6.3       2862  110,000,000
# 254                   The Smurfs          5.5       1179  110,000,000
# 231               Monsters, Inc.          7.5       5996  115,000,000
# 40                        Cars 2          5.8       2033  200,000,000
# 187                Puss in Boots          6.4        451  130,000,000
# 149                   Armageddon          6.4       2482  140,000,000
# 24                     King Kong          6.6       2337  207,000,000
# 213       Mission: Impossible II          5.9       1928  125,000,000
# 212       The Day After Tomorrow          6.2       2392  125,000,000
#
#          Receita       lucro  cluster
# 14   662,845,518  437.845518        2
# 18   624,026,776  399.026776        2
# 79   623,933,331  423.933331        2
# 120  603,900,354  453.900354        2
# 277  599,045,960  449.045960        2
# 6    591,794,936  331.794936        2
# 185  591,739,379  459.739379        2
# 11   586,090,727  386.090727        2
# 116  585,349,010  435.349010        2
# 234  585,178,928  450.178928        2
# 68   585,174,222  445.174222        2
# 243  574,480,841  464.480841        2
# 254  563,749,323  453.749323        2
# 231  562,816,256  447.816256        2
# 40   559,852,396  359.852396        2
# 187  554,987,477  424.987477        2
# 149  553,799,566  413.799566        2
# 24   550,000,000  343.000000        2
# 213  546,388,105  421.388105        2
# 212  544,272,402  419.272402        2
#
# [20 rows x 24 columns]

# %%
def plot_cluster(df, centroids, xdata_name, ydata_name, title, xlabel, ylabel):

    # Set style of scatterplot
    sns.set_context("notebook", font_scale=1.1)
    sns.set_style("ticks")
    
    # Create scatterplot of dataframe
    sns.lmplot(xdata_name, # Horizontal axis
               ydata_name, # Vertical axis
               data=df, # Data source
               fit_reg=False, # Don't fix a regression line
               hue="cluster")
    
    plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', 
            linewidths=3,
            color='k',)

    
    # Set title
    plt.title(title)
    # Set x-axis label
    plt.xlabel(xlabel)
    # Set y-axis label
    plt.ylabel(ylabel)
    plt.show()

# %%
n_clusters = 3
kmeans = KMeans(n_clusters).fit(X)
ypred = KMeans(n_clusters).fit_predict(X)
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )

# %%
# budget - custo do filme
# revenue - receita do filme
df2 = df[ df["cluster"] == 2].sort_values(by='revenue', ascending=False ) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(10)
# Out:
#                            title  popularity    revenue  lucro  cluster
# 14                  Man of Steel          99  662845518    438        2
# 18                Men in Black 3          52  624026776    399        2
# 79                    Iron Man 2          77  623933331    424        2
# 120  Madagascar: Escape 2 Africa          44  603900354    454        2
# 277                Casino Royale          89  599045960    449        2
# 6                        Tangled          49  591794936    332        2
# 185            War of the Worlds          49  591739379    460        2
# 11             Quantum of Solace         108  586090727    386        2
# 116                  I Am Legend          71  585349010    435        2
# 234                   The Croods          64  585178928    450        2

# %%
pd.options.display.float_format = '{:,.0f}'.format
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        1
# 1  http://disney.go.com/disneypictures/pirates/         139    661        1
# 2   http://www.sonypictures.com/movies/spectre/         107    636        1
# 3            http://www.thedarkknightrises.com/         112    835        1
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
n_clusters = 4
kmeans = KMeans(n_clusters).fit(X)
y_pred = KMeans(n_clusters=4).fit_predict(X)
#ypred = KMeans(n_clusters=4).fit_predict(X)

#y_pred = KMeans(n_clusters=2, random_state=100).fit_predict(X)

df["cluster"] = y_pred

#y_pred = KMeans(n_clusters=3).fit_predict(X)
#df["cluster"] = y_pred


# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )

# %%
n_clusters = 5
kmeans = KMeans(n_clusters).fit(X)
y_pred = KMeans(n_clusters).fit_predict(X)
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )

# %%
# budget - custo do filme
# revenue - receita do filme
df2 = df[ df["cluster"] == 2].sort_values(by='revenue', ascending=False ) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(10)
# Out:
#                        title  popularity     revenue  lucro  cluster
# 0                     Avatar         150  2787965087  2,551        2
# 25                   Titanic         100  1845034188  1,645        2
# 16              The Avengers         144  1519557910  1,300        2
# 28            Jurassic World         419  1513528810  1,364        2
# 44                 Furious 7         102  1506249360  1,316        2
# 7    Avengers: Age of Ultron         134  1405403694  1,125        2
# 124                   Frozen         165  1274219009  1,124        2
# 546                  Minions         876  1156730962  1,083        2

# %%
df2 = df[ df["title"].apply(lambda x: x in 'furious') ].sort_values(by='revenue', ascending=False ) [:20]
df2[["title","popularity",'revenue', "lucro", "cluster"]].head(10)
# Out:
# Empty DataFrame
# Columns: [title, popularity, revenue, lucro, cluster]
# Index: []

# %%
y_pred[:5]
# Out:
# array([2, 3, 3, 3, 0], dtype=int32)

# %%
df.cluster.value_counts()
# Out:
# 0    3590
# 4     851
# 1     260
# 3      94
# 2       8
# Name: cluster, dtype: int64

# %%
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        2
# 1  http://disney.go.com/disneypictures/pirates/         139    661        3
# 2   http://www.sonypictures.com/movies/spectre/         107    636        3
# 3            http://www.thedarkknightrises.com/         112    835        3
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
# James Cameron lucra US$ 350 milhões com 'Avatar ... 
# Arrecadou US$ 97 milhões com "Titanic"
df.loc[:,["homepage","popularity","lucro", "cluster"]].sort_values(by="lucro", ascending=False).head(10)
# Out:
#                                               homepage  popularity  lucro  \
# 0                          http://www.avatarmovie.com/         150  2,551
# 25                         http://www.titanicmovie.com         100  1,645
# 28                       http://www.jurassicworld.com/         419  1,364
# 44                            http://www.furious7.com/         102  1,316
# 16                   http://marvel.com/avengers_movie/         144  1,300
# 7    http://marvel.com/movies/movie/193/avengers_ag...         134  1,125
# 124                    http://movies.disney.com/frozen         165  1,124
# 546                       http://www.minionsmovie.com/         876  1,083
# 329                      http://www.lordoftherings.net         124  1,025
# 31                          http://marvel.com/ironman3          78  1,015
#
#      cluster
# 0          2
# 25         2
# 28         2
# 44         2
# 16         2
# 7          2
# 124        2
# 546        2
# 329        3
# 31         3

# %% [markdown]
# ### Predição de novos dados

# %%
y_pred = KMeans(n_clusters, random_state=0).fit(X)
df["cluster"] = y_pred.labels_
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        4
# 1  http://disney.go.com/disneypictures/pirates/         139    661        2
# 2   http://www.sonypictures.com/movies/spectre/         107    636        2
# 3            http://www.thedarkknightrises.com/         112    835        2
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
y_pred = KMeans(n_clusters, random_state=0).fit_predict(X)
df.loc[:,["homepage","popularity","lucro", "cluster"]].head()
# Out:
#                                        homepage  popularity  lucro  cluster
# 0                   http://www.avatarmovie.com/         150  2,551        4
# 1  http://disney.go.com/disneypictures/pirates/         139    661        2
# 2   http://www.sonypictures.com/movies/spectre/         107    636        2
# 3            http://www.thedarkknightrises.com/         112    835        2
# 4          http://movies.disney.com/john-carter          44     24        0

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)

popularity = 150.437577
lucro = 2550.965087
kmeans.predict([[popularity, lucro], [130, 500], [43,24]])
# Out:
# array([4, 2, 0], dtype=int32)

# %%
def plot_new_data_cluster(df, x_new, y_new, centroids, xdata_name, ydata_name, title, xlabel, ylabel):

    # Set style of scatterplot
    sns.set_context("notebook", font_scale=1.1)
    sns.set_style("ticks")
    
    # Create scatterplot of dataframe
    sns.lmplot(xdata_name, # Horizontal axis
               ydata_name, # Vertical axis
               data=df, # Data source
               fit_reg=False, # Don't fix a regression line
               hue="cluster")
    
    plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', 
            linewidths=3,
            color='k',)

    
    plt.scatter(x_new, y_new, c='red', marker='x', s=100)
    
    # Set title
    plt.title(title)
    # Set x-axis label
    plt.xlabel(xlabel)
    # Set y-axis label
    plt.ylabel(ylabel)
    plt.show()

# %%
n_clusters = 5
kmeans = KMeans(n_clusters).fit(X)
y_pred = KMeans(n_clusters).fit_predict(X)
df["cluster"] = y_pred

centroids = kmeans.cluster_centers_

# os novos dados
popularity = 150.437577
lucro = 2550.965087
dados_x = [[popularity, lucro], [130, 500], [43,24]]
x_new = [x[0] for x in dados_x]
y_new = [y[1] for y in dados_x]


plot_new_data_cluster(df, x_new, y_new, centroids, "popularity", "lucro", title = "Filmes por Lucro/Popularidade", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Popularidade" )

# %%
# centróides
kmeans.cluster_centers_
# Out:
# array([[  60.66662593,  312.10668441],
#        [  12.34329368,    2.04934958],
#        [ 110.70365888,  672.66544345],
#        [  36.23545982,  109.6439509 ],
#        [ 261.36609725, 1438.4611275 ]])

# %%
kmeans.labels_
# Out:
# array([4, 2, 2, ..., 1, 1, 1], dtype=int32)

# %%
len(kmeans.labels_)
# Out:
# 4803

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...         150
# 1  Captain Barbossa, long believed to be dead, ha...         139
# 2  A cryptic message from Bond’s past sends him o...         107
# 3  Following the death of District Attorney Harve...         112
# 4  John Carter is a war-weary, former military ca...          44
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar            7      11800
# 1  Pirates of the Caribbean: At World's End            7       4500
# 2                                   Spectre            6       4466
# 3                     The Dark Knight Rises            8       9106
# 4                               John Carter            6       2124
#
#          Custo        Receita  lucro  cluster
# 0  237,000,000  2,787,965,087  2,551        3
# 1  300,000,000    961,000,000    661        4
# 2  245,000,000    880,674,609    636        4
# 3  250,000,000  1,084,939,099    835        4
# 4  260,000,000    284,139,100     24        0
#
# [5 rows x 24 columns]

# %%
df[df["cluster"]==4].head(7)
# Out:
#        budget                                             genres  \
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                              homepage      id  \
# 1        http://disney.go.com/disneypictures/pirates/     285
# 2         http://www.sonypictures.com/movies/spectre/  206647
# 3                  http://www.thedarkknightrises.com/   49026
# 5     http://www.sonypictures.com/movies/spider-man3/     559
# 8   http://harrypotter.warnerbros.com/harrypottera...     767
# 9        http://www.batmanvsupermandawnofjustice.com/  209112
# 12       http://disney.go.com/disneypictures/pirates/      58
#
#                                              keywords original_language  \
# 1   [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2   [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 5   [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 8   [{"id": 616, "name": "witch"}, {"id": 2343, "n...                en
# 9   [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
# 12  [{"id": 616, "name": "witch"}, {"id": 663, "na...                en
#
#                                 original_title  \
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                 Spider-Man 3
# 8       Harry Potter and the Half-Blood Prince
# 9           Batman v Superman: Dawn of Justice
# 12  Pirates of the Caribbean: Dead Man's Chest
#
#                                              overview  popularity  \
# 1   Captain Barbossa, long believed to be dead, ha...         139
# 2   A cryptic message from Bond’s past sends him o...         107
# 3   Following the death of District Attorney Harve...         112
# 5   The seemingly invincible Spider-Man goes up ag...         116
# 8   As Harry begins his sixth year at Hogwarts, he...          99
# 9   Fearing the actions of a god-like Super Hero l...         156
# 12  Captain Jack Sparrow works his way out of a bl...         146
#
#                                  production_companies  ...  \
# 1   [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3   [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 5   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 8   [{"name": "Warner Bros.", "id": 6194}, {"name"...  ...
# 9   [{"name": "DC Comics", "id": 429}, {"name": "A...  ...
# 12  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
#
#                                      spoken_languages    status  \
# 1            [{"iso_639_1": "en", "name": "English"}]  Released
# 2   [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3            [{"iso_639_1": "en", "name": "English"}]  Released
# 5   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 8            [{"iso_639_1": "en", "name": "English"}]  Released
# 9            [{"iso_639_1": "en", "name": "English"}]  Released
# 12  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                                            tagline  \
# 1   At the end of the world, the adventure begins.
# 2                            A Plan No One Escapes
# 3                                  The Legend Ends
# 5                               The battle within.
# 8                            Dark Secrets Revealed
# 9                               Justice or revenge
# 12                                   Jack is back!
#
#                                          title vote_average vote_count  \
# 1     Pirates of the Caribbean: At World's End            7       4500
# 2                                      Spectre            6       4466
# 3                        The Dark Knight Rises            8       9106
# 5                                 Spider-Man 3            6       3576
# 8       Harry Potter and the Half-Blood Prince            7       5293
# 9           Batman v Superman: Dawn of Justice            6       7004
# 12  Pirates of the Caribbean: Dead Man's Chest            7       5246
#
#           Custo        Receita  lucro  cluster
# 1   300,000,000    961,000,000    661        4
# 2   245,000,000    880,674,609    636        4
# 3   250,000,000  1,084,939,099    835        4
# 5   258,000,000    890,871,626    633        4
# 8   250,000,000    933,959,197    684        4
# 9   250,000,000    873,260,194    623        4
# 12  200,000,000  1,065,659,812    866        4
#
# [7 rows x 24 columns]

# %% [markdown]
# ### Cenário 2 - Filmes

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 3
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro" , title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 4
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro", title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 5
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro", title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %%
Xx = df.loc[:, ["vote_average", "lucro"]]
n_clusters = 6
kmeans = KMeans(n_clusters).fit(Xx)
y_pred = kmeans.labels_
df["cluster"] = y_pred
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plot_cluster(df, centroids,   "vote_average", "lucro", title = "Filmes por Lucro/Rating", 
             xlabel =  "Lucro (em Milhões)", ylabel = "Rating" )

# %% [markdown]
# # Determinando o melhor número de Clusters (Elbow Method)

# %%
Ks = range(1, 10)
km = [KMeans(n_clusters=i) for i in Ks]
score = [km[i].fit(Xx).score(Xx) for i in range(len(km))]
print(score)
# Out:
# [-88782462.06841055, -32518151.504649058, -17533503.028597757, -11563853.290383566, -7864374.134904589, -5675525.739411425, -4377596.49527826, -3187275.567796253, -2573440.3451356706]

# %%
list(range(1,9))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
score
# Out:
# [-88782462.06841055,
#  -32518151.504649058,
#  -17533503.028597757,
#  -11563853.290383566,
#  -7864374.134904589,
#  -5675525.739411425,
#  -4377596.49527826,
#  -3187275.567796253,
#  -2573440.3451356706]

# %%
plt.style.use('ggplot')
plt.scatter( list(range(1,len(score)+1)), score, c="b")
plt.title("Curva de Elbow")
plt.xlabel("Clusters")
plt.ylabel("Distorção")
plt.show()
