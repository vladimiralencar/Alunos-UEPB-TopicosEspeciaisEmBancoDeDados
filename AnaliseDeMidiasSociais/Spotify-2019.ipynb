# %% [markdown]
# # Análises de Mídias Sociais - Spotify

# %%
#!pip install spotipy

# %% [markdown]
# Acesse: https://beta.developer.spotify.com/dashboard/applications
# para criar o Client_ID e o Client_Secret

# %%
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import pandas as pd

def login_spotify():
    client_id = "da1effa23714436a93368fff6f869de2"
    client_secret = "b81bb02ba7e3494bbd9d28489f5a7b7f"

    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

# %%
sp = login_spotify()
sp

# %% [markdown]
# ## busca as músicas do artista

# %%
def search_musics_artist(sp,artist):

    results = sp.search(artist, limit=30)
    df = pd.DataFrame(columns=['artist','name', 'popularity', 'release_date'])
    for i, t in enumerate(results['tracks']['items']):
        df.loc[i] = [q, t['name'], t['popularity'], t['album']['release_date'] ]
        #print(' ', i, t['name'] , t['popularity'], t['album']['release_date']) # t['release_date']
    return df.sort_values('popularity', ascending=False)

sp = login_spotify()
q='Anitta'
df = search_musics_artist(sp,q)
df[:15]
# Out:
#     artist                                               name popularity  \
# 0   Anitta              Me Gusta (with Cardi B & Myke Towers)         87
# 6   Anitta                          Desce Pro Play (PA PA PA)         83
# 17  Anitta                              Paloma (feat. Anitta)         77
# 4   Anitta             Tócame (feat. Arcangel & De La Ghetto)         76
# 5   Anitta                                           Downtown         72
# 14  Anitta                   R.I.P. (feat. Rita Ora & Anitta)         71
# 15  Anitta                       Combatchy (feat. MC Rebecca)         71
# 18  Anitta                        Tá com o Papato (feat. BIN)         70
# 21  Anitta                             Some que ele vem atrás         69
# 20  Anitta       Fuego (with Sean Paul & Anitta, feat. Tainy)         69
# 24  Anitta                               Contatinho - Ao Vivo         68
# 25  Anitta                                         Complicado         67
# 23  Anitta                                          Até o céu         67
# 26  Anitta                                            Meu mel         65
# 12  Anitta  Vai malandra (feat. Tropkillaz & DJ Yuri Martins)         65
#
#    release_date
# 0    2020-09-18
# 6    2020-06-26
# 17   2020-07-03
# 4    2020-07-10
# 5    2017-11-19
# 14   2019-03-15
# 15   2019-11-20
# 18   2020-08-28
# 21   2019-10-30
# 20   2019-07-25
# 24   2019-09-06
# 25   2020-01-17
# 23   2019-12-20
# 26   2019-12-13
# 12   2017-12-18

# %%
#sp = login_spotify()
q='ludmilla'
df = search_musics_artist(sp,q)
df
# Out:
#       artist                                               name popularity  \
# 4   ludmilla                                        SEM LIMITES         68
# 7   ludmilla                   Cobra Venenosa (feat. DJ Will22)         68
# 13  ludmilla                                  Não é por maldade         67
# 10  ludmilla  A boba fui eu - Recorded At Mosh Studios, São ...         67
# 11  ludmilla                              Teu Segredo - Ao Vivo         67
# 18  ludmilla                                Já Tentei - Ao Vivo         66
# 3   ludmilla  Invocada (Participação especial de Léo Santana...         66
# 9   ludmilla                                       Amor difícil         65
# 1   ludmilla                                           Verdinha         64
# 15  ludmilla                           Sacanagenzinha (Ao Vivo)         62
# 6   ludmilla                             Um Pôr do Sol Na Praia         62
# 8   ludmilla                                        SEM LIMITES         61
# 16  ludmilla                              Do jeito que tu gosta         59
# 23  ludmilla                              Teu Segredo - Ao Vivo         58
# 5   ludmilla                            Favela chegou - Ao vivo         58
# 20  ludmilla    Clichê (Participação especial de Felipe Araújo)         56
# 14  ludmilla           Malokera (feat. Ludmilla, Ty Dolla $ign)         54
# 17  ludmilla                                  Pulando na pipoca         54
# 12  ludmilla  Din Din Din (Participação especial de MC Pupio...         54
# 25  ludmilla                                     Te amar demais         53
# 19  ludmilla                                            Cheguei         53
# 21  ludmilla  Faz uma loucura por mim - Recorded At Mosh Stu...         53
# 26  ludmilla                        Qualidade De Vida - Ao Vivo         53
# 28  ludmilla                           Cheiro bom do seu cabelo         52
# 29  ludmilla                                Pôr do sol na praia         52
# 24  ludmilla                                      Favela chegou         52
# 22  ludmilla                                  Só Vem! - Ao Vivo         52
# 2   ludmilla                                   Verdinha - Remix         52
# 27  ludmilla                  Ghost in the Shell - Original Mix         31
# 0   ludmilla                                       Jogando sujo          2
#
#    release_date
# 4    2020-05-14
# 7    2020-07-03
# 13   2020-04-24
# 10   2020-03-17
# 11   2019-08-30
# 18   2020-06-19
# 3    2019-05-31
# 9    2020-04-24
# 1    2019-11-29
# 15   2020-01-08
# 6    2019-07-19
# 8    2020-08-20
# 16   2019-08-16
# 23   2019-08-31
# 5    2019-02-27
# 20   2018-11-23
# 14   2019-08-09
# 17   2020-02-07
# 12   2018-06-06
# 25   2020-04-24
# 19   2016-10-21
# 21   2020-03-17
# 26   2019-01-09
# 28   2020-04-24
# 29   2020-04-24
# 24   2019-08-09
# 22   2017-08-04
# 2    2020-10-16
# 27   2006-11-20
# 0    2020-10-16

# %%
#sp = login_spotify()
q='Rihanna'
df = search_musics_artist(sp,q)
df[:15]
# Out:
#      artist                                       name popularity release_date
# 0   Rihanna                                 BELIEVE IT         81   2020-03-27
# 2   Rihanna                       Love The Way You Lie         81   2010-06-18
# 3   Rihanna                          Love On The Brain         80   2016-01-28
# 10  Rihanna                                   Umbrella         80   2008-06-02
# 4   Rihanna                            FourFiveSeconds         79   2015-01-24
# 6   Rihanna  This Is What You Came For (feat. Rihanna)         79   2016-04-29
# 1   Rihanna                                  Needed Me         79   2016-01-28
# 7   Rihanna                              Pon de Replay         78   2005-08-29
# 9   Rihanna                                 Take A Bow         77   2008-06-02
# 19  Rihanna                       Don't Stop The Music         77   2008-06-02
# 8   Rihanna                 Bitch Better Have My Money         76   2015-03-26
# 14  Rihanna                                       Work         76   2016-01-28
# 16  Rihanna                                The Monster         75   2013-11-05
# 11  Rihanna                             Live Your Life         75   2008-09-07
# 13  Rihanna                              We Found Love         75   2011-11-18

# %%
#sp = login_spotify()
q='Mariah Carey'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#           artist                                               name  \
# 1   Mariah Carey                    All I Want for Christmas Is You
# 0   Mariah Carey                                  Always Be My Baby
# 4   Mariah Carey                                               Hero
# 2   Mariah Carey                                            Fantasy
# 10  Mariah Carey  When You Believe (with Mariah Carey) - from Th...
# 9   Mariah Carey                   Endless Love (with Mariah Carey)
# 3   Mariah Carey                                      Touch My Body
# 6   Mariah Carey                                    U Make Me Wanna
# 8   Mariah Carey  All I Want For Christmas Is You (SuperFestive!...
# 5   Mariah Carey                                            Bye Bye
#
#    popularity release_date
# 1          75   1994-11-01
# 0          73   1995-09-26
# 4          72   1993-08-04
# 2          70   1995-09-26
# 10         67   1998-11-17
# 9          61   1994-09-20
# 3          60   2008-01-01
# 6          54   2004-01-01
# 8          52   2011-01-01
# 5          51   2008-01-01

# %%
len(df)
# Out:
# 30

# %%
#sp = login_spotify()
q='Paralamas'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#        artist                                       name popularity  \
# 0   Paralamas                       Aonde Quer Que Eu Vá         66
# 2   Paralamas                           Vital E Sua Moto         56
# 3   Paralamas                      Cuide Bem Do Seu Amor         53
# 4   Paralamas                    Caleidoscópio - Ao Vivo         51
# 5   Paralamas                           Lourinha Bombril         44
# 6   Paralamas                          Seguindo Estrelas         41
# 7   Paralamas                                  O Calibre         41
# 24  Paralamas  Lanterna Dos Afogados - Ao Vivo / Version         40
# 19  Paralamas                                  Trac-Trac         40
# 16  Paralamas                      Tendo A Lua - Ao Vivo         40
#
#    release_date
# 0    2000-01-01
# 2    1983-01-01
# 3    2002-01-01
# 4    1999-08-05
# 5    1996-01-01
# 6    2002-01-01
# 7    2002-01-01
# 24   1995-03-10
# 19   2000-01-01
# 16   1999-08-05

# %%
#sp = login_spotify()
q='Ivete Sangalo'
df = search_musics_artist(sp,q)
df[:5]
# Out:
#            artist                                name popularity release_date
# 6   Ivete Sangalo                       Dura Na Queda         62   2020-10-02
# 2   Ivete Sangalo                            Um Sinal         58   2018-08-03
# 1   Ivete Sangalo                         O Mundo Vai         58   2020-01-24
# 12  Ivete Sangalo  A Mais Pedida - Ao Vivo | Acústico         58   2017-04-28
# 0   Ivete Sangalo     Se Eu Não Te Amasse Tanto Assim         57   1999-01-01

# %%
#sp = login_spotify()
q='Simone e Simaria'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#               artist                                       name popularity  \
# 18  Simone e Simaria                    Os Boys Amam O Ex Chora         70
# 14  Simone e Simaria                                    Amoreco         70
# 24  Simone e Simaria                                 Folha Seca         61
# 16  Simone e Simaria  Raspão (feat. Simone & Simaria) - Ao Vivo         60
# 1   Simone e Simaria                                 Ta Tum Tum         59
# 21  Simone e Simaria                   Regime Fechado - Ao Vivo         59
# 2   Simone e Simaria                           O Que É O Que É?         58
# 8   Simone e Simaria                           La Vida Continuó         58
# 27  Simone e Simaria                    Aperte O Play - Ao Vivo         56
# 23  Simone e Simaria                                       Loka         56
#
#    release_date
# 18   2020-05-08
# 14   2020-02-07
# 24   2019-10-30
# 16   2017-04-07
# 1    2018-01-29
# 21   2016-10-28
# 2    2019-10-01
# 8    2019-05-03
# 27   2019-03-29
# 23   2017-11-17

# %% [markdown]
# ## Obter a musica mais popular de cada cantor/cantora

# %%
cantoras = ['Beyonce', 'Rihanna', 'Anitta', 'Ludmilla', 'Simone e Simaria', 'Ivete Sangalo', 'Claudia Leitte' ]
df = pd.DataFrame(columns=['artist','name', 'popularity', 'release_date'])
linha = 0
for artist in cantoras:
    popularidade = 0
    results = sp.search(artist, limit=30)
    for i, t in enumerate(results['tracks']['items']):
        if t['popularity'] > popularidade:
            musica_mais_popular = [artist, t['name'], t['popularity'], t['album']['release_date'] ]
            popularidade = t['popularity']
    df.loc[linha] = musica_mais_popular
    linha += 1   
df2 = df.sort_values('popularity', ascending=False)
df2
# Out:
#              artist                                               name  \
# 2            Anitta              Me Gusta (with Cardi B & Myke Towers)
# 0           Beyonce                       Savage Remix (feat. Beyoncé)
# 1           Rihanna                                         BELIEVE IT
# 4  Simone e Simaria                                            Amoreco
# 3          Ludmilla                                        SEM LIMITES
# 6    Claudia Leitte  We Are One (Ole Ola) [The Official 2014 FIFA W...
# 5     Ivete Sangalo                                      Dura Na Queda
#
#   popularity release_date
# 2         87   2020-09-18
# 0         83   2020-04-29
# 1         81   2020-03-27
# 4         70   2020-02-07
# 3         68   2020-05-14
# 6         65   2014-11-21
# 5         62   2020-10-02

# %% [markdown]
# ## plota num gráfico

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(10,8))
fig.add_subplot(1,1,1)

ax = sns.barplot(y='artist', x = 'popularity', data=df2, palette="Set3" )

ax.axes.set_title("Best Popular Songs",fontsize=40)
ax.set_xlabel("Popularity",fontsize=26)
ax.set_ylabel("Artist",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()

# %% [markdown]
# ## Banda, Músicas

# %%
import spotipy
sp = login_spotify()

results = sp.search(q='coldplay', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print (' ', i, t['name'])
# Out:
#   0 Viva La Vida
#   1 Yellow
#   2 Something Just Like This
#   3 The Scientist
#   4 Fix You
#   5 Paradise
#   6 Coldplay
#   7 Coldplay
#   8 Coldplay
#   9 Miracles (Someone Special)
#   10 Coldplay - Fix You (Remix)
#   11 Clocks
#   12 Clocks - Coldplay
#   13 Every Teardrop Is A Waterfall (Coldplay Vs. Swedish House Mafia)
#   14 Coldplay Medly
#   15 Clocks/Relojes (Haitian Mix)
#   16 Yellow (Coldplay Cover)
#   17 Yellow (Coldplay) [Fingerstyle]
#   18 Christmas Lights
#   19 I'm Calling Out - No Coldplay On The Beach Dub

# %% [markdown]
# ## Mostra todos os albuns de um cantor/cantora

# %%
import sys
import spotipy

''' shows the albums and tracks for a given artist.
'''

def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set() # to avoid dups
    albums.sort(key=lambda album:album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            print((' ' + name))
            seen.add(name)

if __name__ == '__main__':
    sp = login_spotify()

    name = 'Beyonce'
    name = 'Simone e Simaria'
    name = 'coldplay'
    artist = get_artist(name)
    if artist:
        print('Albuns de: ', name)
        show_artist_albums(artist)
    else:
        print("Can't find that artist")
# Out:
# Albuns de:  coldplay
#  A Head Full of Dreams
#  A Head Full of Dreams Tour Edition
#  A Rush of Blood to the Head
#  Everyday Life
#  Ghost Stories
#  Ghost Stories Live 2014
#  Live in Buenos Aires
#  Love in Tokyo
#  Mylo Xyloto
#  Parachutes
#  Viva La Vida (Prospekt's March Edition)
#  Viva La Vida or Death and All His Friends
#  X&Y

# %% [markdown]
# ## Obtém informações do Artista

# %%
def obter_informacoes(nome_artista):
    from PIL import Image
    from urllib.request import urlopen
    artista = get_artist(nome_artista)
    seguidores = artista['followers']['total']
    genero = artista['genres']
    foto_url = artista['images'][0]['url']
    popularidade = artista['popularity']
    uri = artista['uri']
    url_spotify = artista['external_urls']['spotify']
    print('Artista: ', artista['name'])
    print('Número de Seguidores: ', '{:,d}'.format(seguidores))
    print('Gênero: ', genero)
    print('Popularidade: ', popularidade)
    print('Spotify uri:', uri)
    print('Spotify url:',url_spotify)
    foto = Image.open(urlopen(foto_url))
    return foto #seguidores, genero, popularidade, foto_url, uri, url_spotify

nome_artista = 'Beyonce'
nome_artista = name = 'Simone e Simaria'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Simone & Simaria
# Número de Seguidores:  4,616,740
# Gênero:  ['funk carioca', 'pop nacional', 'sertanejo pop', 'sertanejo universitario']
# Popularidade:  71
# Spotify uri: spotify:artist:0MInKJqZscEeNc5K3K0mkE
# Spotify url: https://open.spotify.com/artist/0MInKJqZscEeNc5K3K0mkE
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FC2CFE183A0>

# %%
nome_artista = 'Anitta'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Anitta
# Número de Seguidores:  9,820,686
# Gênero:  ['funk carioca', 'funk das antigas', 'funk pop', 'pagode baiano', 'pop nacional']
# Popularidade:  86
# Spotify uri: spotify:artist:7FNnA9vBm6EKceENgCGRMb
# Spotify url: https://open.spotify.com/artist/7FNnA9vBm6EKceENgCGRMb
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FC2CFDDF970>

# %%
nome_artista = 'Ludmilla'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Ludmilla
# Número de Seguidores:  3,511,507
# Gênero:  ['funk carioca', 'funk pop', 'pagode baiano', 'pop nacional']
# Popularidade:  75
# Spotify uri: spotify:artist:3CDoRporvSjdzTrm99a3gi
# Spotify url: https://open.spotify.com/artist/3CDoRporvSjdzTrm99a3gi
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FC2CFE182E0>

# %%
nome_artista = 'katy perry'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Katy Perry
# Número de Seguidores:  16,461,928
# Gênero:  ['dance pop', 'pop', 'post-teen pop']
# Popularidade:  88
# Spotify uri: spotify:artist:6jJ0s89eD6GaHleKKya26X
# Spotify url: https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FC2CFE74FD0>

# %%
nome_artista = 'lady gaga'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Lady Gaga
# Número de Seguidores:  14,130,664
# Gênero:  ['dance pop', 'pop']
# Popularidade:  91
# Spotify uri: spotify:artist:1HY2Jd0NmPuamShAr6KMms
# Spotify url: https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FC2CFE186A0>

# %%
#!pip install pillow

# %%
from IPython.display import display
from PIL import Image

nome_artista = 'michael jackson'
foto = obter_informacoes(nome_artista)
im = foto.convert("RGB")

display(im)
# Out:
# Artista:  Michael Jackson
# Número de Seguidores:  16,076,368
# Gênero:  ['pop', 'r&b', 'soul']
# Popularidade:  85
# Spotify uri: spotify:artist:3fMbdgg4jU18AjLCKBhRSm
# Spotify url: https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm
# <PIL.Image.Image image mode=RGB size=640x639 at 0x7FC2D0134400>
