# %% [markdown]
# # Análise de Mídias Sociais - Youtube

# %%
#!pip install google-api-python-client
#!pip install oauth2client

# %% [markdown]
# ## Para autenticar no youtube: https://cloud.google.com/console
# ### Menu API e Serviços -> Credenciais -> Copiar a chave
# ### DEVELOPER_KEY = 'AIzaSyDWVq-dfdfdfdfdfdfdfdfdfdfdfdfdfdfdfdfdfdf'

# %%
from apiclient.discovery import build #pip install google-api-python-client
from apiclient.errors import HttpError #pip install google-api-python-client
from oauth2client.tools import argparser #pip install oauth2client
import pandas as pd #pip install pandas
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %% [markdown]
# ## Acessa métricas do youtube por termo ou nome

# %%
#!echo 'xxxxxxxxxxxx' > dados.txt
#!cat dados.txt

# %%
# ler a chave de acesso
def load_developer_key():
    with open('dados.txt', 'r') as reader:
        #print(reader.read())
        key = reader.read()
    return key

print(load_developer_key())
# Out:
# AIzaSyDfpru8OYmFTjwTkX-hXsXPk4G3Wq9d9nE

# %%
# get youtube data ratings
def get_youtube_data(qr):
    # Set DEVELOPER_KEY to the API key value from the APIs & auth > Registered apps
    # tab of   https://cloud.google.com/console   
    
    DEVELOPER_KEY = load_developer_key()

    YOUTUBE_API_SERVICE_NAME = "youtube"
    YOUTUBE_API_VERSION = "v3"

    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

    # Call the search.list method to retrieve results matching the specified query term.
    search_response = youtube.search().list(
    # q=qr, # if disabled, search all names
        
     q=qr,
     type="video",
     #type="channel",
     #regionCode=regionCode,
     part="id,snippet",
     maxResults=50,
     order='viewCount'
    ).execute()

    datas = []
    videos = {}
    # Add each result to the appropriate list, and then display the lists of matching videos.
    # Filter out channels, and playlists.
    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":
         #videos.append("%s" % (search_result["id"]["videoId"]))
         videos[search_result["id"]["videoId"]] = search_result["snippet"]["title"]
         datas.append(search_result['snippet']['publishedAt'])
    s = ','.join(videos.keys())
    videos_list_response = youtube.videos().list(
     id=s,
     part='id,statistics'
    ).execute()

    res = []
    for i,data in zip(videos_list_response['items'], datas):
        temp_res = dict(v_id = i['id'], v_title = videos[i['id']], date = data)
        temp_res.update(i['statistics'])
        res.append(temp_res)
    return pd.DataFrame.from_dict(res)

# %% [markdown]
# ## Análises do Youtube

# %% [markdown]
# ### manipulação de data

# %%
def data_agora():
    data_hoje = str(datetime.today())
    data_hoje 
    data, hora = data_hoje.split()
    data,hora 
    hora, minuto, segundo = hora.split(':')
    hora, minuto, segundo
    segundo = segundo.split('.')[0]
    segundo
    str_data_hoje = data + ' '+ hora +':' + minuto + ':' + segundo
    return str_data_hoje
data_hoje = data_agora()
data_hoje
# Out:
# '2020-10-09 00:04:19'

# %% [markdown]
# ## Plotagem de gráfico

# %%
def plot_mapa_df(dfdata, name, medida, palette):
    data_hoje = data_agora()
    fig = plt.figure(figsize=(16,14))
    fig.add_subplot(1,1,1)
    plt.style.use('ggplot')
    ax = sns.barplot(y= "v_title" ,x="viewCount", palette=palette,
                    data=dfdata.sort_values(by='viewCount',ascending=False))

    ax.axes.set_title("Visualizações: " + name + ", em "+ data_hoje + ' (' + medida + ')',fontsize=26)
    ax.set_ylabel("Vídeos",fontsize=26)
    ax.set_xlabel("Visualizações"+  ' (' + medida + ')',fontsize=26)
    ax.tick_params(labelsize=15)

    plt.show()

# %% [markdown]
# ## Consultas yotube API

# %%
qr = name = "Rossandro Klinjey"
qr = name = "camila uckers"
qr = name = "kefera"
qr = name = "nerdologia"
qr = name = "jovem nerd"
qr = name = "nerdologia"

# %% [markdown]
# ## Winderson Nunes - Humorista

# %%
qr = name = "whinderssonnunes"
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head()
# Out:
# Vídeos de whinderssonnunes, em 2020-10-09 00:04:21
# Total de Acessos (50 vídeos mais vistos), de whinderssonnunes :  1,608,398,786
#           v_id                                            v_title  \
# 0  IRirqw082XI  WHINDERSSON NUNES em PROPAROXÍTONA (SHOW COMPL...
# 1  eYfFDaPdkWc     WHINDERSSON NUNES em MARMININO (SHOW COMPLETO)
# 2  tWs1E2BfNZE     QUAL É A SENHA DO WIFI - Paródia Adele - Hello
# 3  3Zy6ai9jtgY  PARÓDIA / Haikaiss - RAP LORD part. Jonas Bent...
# 4  UmmXiN93btM  EU CANSEI DE SER POBRE | Paródia Ed Sheeran - ...
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2017-12-21T22:00:00Z  88.479728   4518059        54471             0
# 1  2016-12-21T23:00:01Z  80.625383   3091053        43635             0
# 2  2015-12-05T23:00:00Z  75.433160   3691598        66134             0
# 3  2017-10-22T22:30:00Z  69.486663   4921850        55928             0
# 4  2017-04-09T00:00:01Z  63.784063   2847824        57986             0
#
#   commentCount
# 0        82700
# 1        83728
# 2       158245
# 3       157977
# 4        76610

# %%
plot_mapa_df(dfdata[:15], name, 'Milhões', "RdYlBu_r")  # RdBu

# %% [markdown]
# ## Rossandro Klinjey - Orador, Consultor, Psicólogo global

# %% [markdown]
# #### numero de acessos - Rossandro Klinjey (youtube, maio de 2017): 3,343,916
# #### numero de acessos - Rossandro Klinjey (youtube, 8 outubro de 2020): 29,449,255

# %%
name = 'Rossandro Klinjey'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) #/ 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head()
# Out:
# Vídeos de Rossandro Klinjey, em 2020-10-09 00:04:24
# Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  29,453,760
#           v_id                                            v_title  \
# 0  GmD7vgOi18k  Autoperdão - Um aprendizado necessário - Rossa...
# 1  dbFZ0FksQxE  A doçura da mulher na visão do homem, com o ps...
# 2  ZtHkNCmp8fM  Rossandro Klinjey - Quando os filhos precisam ...
# 3  FCJ7UyO_hCo  Dicas para um casamento feliz, com o psicólogo...
# 4  K7n-9WivIAw       (CON)viver Aula 01 - Se conheça e se aceite!
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2016-07-20T13:58:19Z    1777954     49323         2244             0
# 1  2015-10-19T23:34:33Z    1482082     55888         2045             0
# 2  2016-11-21T13:59:39Z    1390192     71397         1144             0
# 3  2015-10-21T01:23:43Z    1124490     39425         1036             0
# 4  2019-03-26T21:35:40Z    1079270     89354          897             0
#
#   commentCount
# 0         1207
# 1         2022
# 2          993
# 3          583
# 4         1294

# %%
plot_mapa_df(dfdata[:10], name, 'por milhão', "RdYlGn_r")

# %%
len(dfdata)
# Out:
# 50

# %% [markdown]
# ### Laís Martins - Youtuber

# %% [markdown]
# Vídeos de Laís Martins, em 2020-10-08 18:15:15 <br>
# Total de Acessos (50 vídeos mais vistos), de Laís Martins :  75,911

# %%
qr = name = "Laís Martins"
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) #/ 1000000
print("Vídeos de " + name + ", em "+ data_agora())
numAcessosAtual =  dfdata.viewCount.sum()
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head()
# Out:
# Vídeos de Laís Martins, em 2020-10-09 00:04:26
# Total de Acessos (50 vídeos mais vistos), de Laís Martins :  75,918
#           v_id                                            v_title  \
# 0  g9hpa_mEmhs  Casamento cristão/Votos de casamento evangélic...
# 1  qoyX-62PRmQ               Pulsante // Ana Rock // Laís Martins
# 2  a1SU2YGV414          Lais Martins - MC JhoJhow Pula no meu Pal
# 3  u0OYwkXbmFM       Quebra o Silêncio | Emi Sousa | Laís Martins
# 4  z1DNkIuyCUQ                           Cantora Lais Martins.wmv
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2017-03-27T21:23:40Z      33416       616           13             0
# 1  2016-11-16T13:15:08Z       5519       129            3             0
# 2  2015-05-15T18:35:24Z       3381        59            1             0
# 3  2018-02-02T14:32:57Z       2983        92            2             0
# 4  2012-04-27T23:55:52Z       2539        25            0             0
#
#   commentCount
# 0           21
# 1           12
# 2          NaN
# 3            3
# 4            2

# %%
plot_mapa_df(dfdata[:15], name, 'por mil', "RdBu")

# %% [markdown]
# ## Outras consultas

# %%
qr = "5incominutos"
qr = "@Kefera"
qr = "whinderssonnunes"
qr = "Felipe Neto"
qr = "beyonce"
qr = "rihanna"
qr = "Coisa de Nerd"
qr = "PewDiePie"

# %% [markdown]
# ## Beyoncé

# %%
qr = "beyonce"
regionCode="BR"
language='BR'

# %% [markdown]
# ## Winderson Nunes x Kéfera

# %%
qr = "whinderssonnunes"
dfw = get_youtube_data(qr)
dfw.likeCount = dfw.likeCount.fillna(0)
dfw.viewCount = dfw.viewCount.fillna(0)
dfw.viewCount = dfw.viewCount.astype(np.int64)
dfw["viewCountMilion"] = dfw["viewCount"] / 1000000
dfw = dfw.sort_values(by="viewCountMilion", ascending=False)
dfw.head()
# Out:
#           v_id                                            v_title  \
# 0  IRirqw082XI  WHINDERSSON NUNES em PROPAROXÍTONA (SHOW COMPL...
# 1  eYfFDaPdkWc     WHINDERSSON NUNES em MARMININO (SHOW COMPLETO)
# 2  tWs1E2BfNZE     QUAL É A SENHA DO WIFI - Paródia Adele - Hello
# 3  3Zy6ai9jtgY  PARÓDIA / Haikaiss - RAP LORD part. Jonas Bent...
# 4  UmmXiN93btM  EU CANSEI DE SER POBRE | Paródia Ed Sheeran - ...
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2017-12-21T22:00:00Z   88479728   4518059        54471             0
# 1  2016-12-21T23:00:01Z   80625383   3091054        43635             0
# 2  2015-12-05T23:00:00Z   75433160   3691598        66134             0
# 3  2017-10-22T22:30:00Z   69486663   4921850        55928             0
# 4  2017-04-09T00:00:01Z   63784063   2847824        57986             0
#
#   commentCount  viewCountMilion
# 0        82700        88.479728
# 1        83728        80.625383
# 2       158245        75.433160
# 3       157977        69.486663
# 4        76610        63.784063

# %%
qr1 = "5incominutos"
qr = "@Kefera"
dfk = get_youtube_data(qr)
dfk.likeCount = dfk.likeCount.fillna(0)
dfk.viewCount = dfk.viewCount.fillna(0)
dfk.viewCount = dfk.viewCount.astype(np.int64)
dfk["viewCountMilion"] = dfk["viewCount"] / 1000000
dfk = dfk.sort_values(by="viewCountMilion", ascending=False)
dfk.head()
# Out:
#           v_id                                            v_title  \
# 0  YD-mnX6D7Sg  Snaps da Kefera (keferabuchmann) - 13/09/2015 ...
# 1  IfOieMPaMIY  ESPECIAL FESTA DA KEFERA #Festa5incoMinutos [@...
# 2  UMqWXMljBD4  Snaps da Kefera (keferabuchmann) - 26/09/2015 ...
# 3  hwSa-X7mLvY  Snaps da Kefera (keferabuchmann) - 02/09/2015 ...
# 4  VP-UIn5z0gU  KÉFERA BUCHMANN (@Kefera) | Trote de Youtubers...
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2015-09-14T10:45:11Z     478668      8244          228             0
# 1  2015-08-08T09:08:27Z     440339      9183          169             0
# 2  2015-09-27T12:56:19Z     336427      4754          210             0
# 3  2015-09-03T08:51:11Z     160692      3911           69             0
# 4  2016-07-27T21:30:09Z     142608      7503          451             0
#
#   commentCount  viewCountMilion
# 0          365         0.478668
# 1          190         0.440339
# 2          268         0.336427
# 3           67         0.160692
# 4          657         0.142608

# %% [markdown]
# ## Plotagem de gráfico comparativo

# %%
def plot_grafico_comparativo(dfdata1, dfdata2, name1, name2, medida, cor1, cor2):
    data_hoje = data_agora()
    l_num_videos = [x+1 for x in (range(50))] 
    plt.figure(figsize=(16,8))
    plt.style.use('ggplot')
    ax = sns.pointplot(x=l_num_videos, y="viewCountMilion", data=dfdata1, color=cor1)
    sns.pointplot(x=l_num_videos, y="viewCountMilion", data=dfdata2, ax=ax, color=cor2)
    ax.legend(handles=ax.lines[::len(dfdata1)+1], labels=[name1,name2])
    ax.axes.set_title("Visualizações: " + name1 + ' x ' + name2 + ", em "+ data_hoje + ' (' + medida + ')',fontsize=20)
    ax.set_xlabel("Vídeos",fontsize=10)
    ax.set_ylabel("Visualizações"+  ' (' + medida + ')',fontsize=10)
    ax.tick_params(labelsize=12)
    ax.set_xticklabels(range(1,51,1),rotation=0 )
    plt.show()

# %%
plot_grafico_comparativo(dfw, dfk, 'WindersonNunes', 'Kéfera', 'Milhões', 'Green', 'Blue' )

# %% [markdown]
# ### Beyonce X Rihanna

# %%
qr = "Beyonce"
df1 = get_youtube_data(qr)
df1.likeCount = df1.likeCount.fillna(0)
df1.viewCount = df1.viewCount.fillna(0)
df1.viewCount = df1.viewCount.astype(np.int64)
df1["viewCountMilion"] = df1["viewCount"] / 1000000
df1 = df1.sort_values(by="viewCountMilion", ascending=False)
df1.head()
# Out:
#           v_id                                            v_title  \
# 0  YykjpeuMNEk   Coldplay - Hymn For The Weekend (Official Video)
# 1  bnVUHWCynig                                     Beyoncé - Halo
# 2  4m1EFMoRFvY  Beyoncé - Single Ladies (Put a Ring on It) (Vi...
# 3  p1JPKLa-Ofc       Beyoncé - Drunk in Love (Explicit) ft. JAY Z
# 4  k4YRWT_Aldo                                     Beyoncé - 7/11
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2016-01-29T15:00:38Z  1352049284   7990242       232878             0
# 1  2009-10-03T20:59:40Z  1068560672   5014343       169309             0
# 2  2009-10-03T04:53:50Z   782825433   2872284       143850             0
# 3  2013-12-16T17:00:03Z   574294492   2330654       190018             0
# 4  2014-11-22T00:11:08Z   546083749   2964064       257695             0
#
#   commentCount  viewCountMilion
# 0       282718      1352.049284
# 1       169575      1068.560672
# 2       130283       782.825433
# 3       116186       574.294492
# 4       123599       546.083749

# %%
qr = "Rihanna"
df2 = get_youtube_data(qr)
df2.likeCount = df2.likeCount.fillna(0)
df2.viewCount = df2.viewCount.fillna(0)
df2.viewCount = df2.viewCount.astype(np.int64)
df2["viewCountMilion"] = df2["viewCount"] / 1000000
df2 = df2.sort_values(by="viewCountMilion", ascending=False)
df2.head()
# Out:
#           v_id                                            v_title  \
# 0  kOkQ4T5WO9E  Calvin Harris - This Is What You Came For (Off...
# 1  uelHwf8o7_U          Eminem - Love The Way You Lie ft. Rihanna
# 2  lWA2pjMjpBs                                 Rihanna - Diamonds
# 3  HL1UzIK-flA                Rihanna - Work (Explicit) ft. Drake
# 4  o3mP3mJDL2k  Shakira - Can&#39;t Remember to Forget You ft....
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2016-06-17T04:01:00Z  2391310736   8710736       505610             0
# 1  2010-08-05T19:09:46Z  2071789151   9529066       338092             0
# 2  2012-11-09T00:18:50Z  1575457004   7171295       325172             0
# 3  2016-02-22T17:00:00Z  1107859995   6531590       586226             0
# 4  2014-01-31T01:35:01Z  1067019624   4547009       320731             0
#
#   commentCount  viewCountMilion
# 0       297738      2391.310736
# 1       549340      2071.789151
# 2       342832      1575.457004
# 3       383735      1107.859995
# 4       236463      1067.019624

# %%
plot_grafico_comparativo(df1, df2, 'Beyoncé', 'Rihanna', 'Milhões', 'Green', 'Blue' )
