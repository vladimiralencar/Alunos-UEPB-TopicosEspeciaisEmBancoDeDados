# %% [markdown]
# # Análise de Mídias Sociais: Twitter

# %% [markdown]
# Para autenticar no twitter, temos que criar uma conta e accessar: <br />
# http://twitter.com/apps/new <br />
# Gerar as chaves de autenticação, ex:<br />
# CONSUMER_KEY = 'DcPtlOYZ07jilc3PgYJLUPRjJ' <br />
# CONSUMER_SECRET = 'bREXzcIMNLKhRpOhQGFuEKTaJhRhHcjD3dKBe682Yt2MOiNv6b' <br />
# OAUTH_TOKEN = '2904474861-coE0I5LEq8btCC0A18IPjqOp1G24vBgwXKyPi5b' <br />
# OAUTH_TOKEN_SECRET = 'ppDRYIeSXOb6J6qajqXolniwVNgbAkIEYDS9VfIzOboQo'<br />

# %% [markdown]
# ## Modulo para autenticação no twitter

# %%
#!pip install twitter
#!pip install pymongo

# %% [markdown]
# ## Leitura das chaves de acesso

# %%
def ler_tokens_acesso():
    filename = 'tokens.txt'
    with open(filename) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content] 
    
    return content[0], content[1], content[2], content[3]

#CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET = ler_tokens_acesso()
#print(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %% [markdown]
# # Twitter

# %%
import twitter

def oauth_login():
    # XXX: Go to http://twitter.com/apps/new to create an app and get values
    # for these credentials that you'll need to provide in place of these
    # empty string values that are defined as placeholders.
    # See https://dev.twitter.com/docs/auth/oauth for more information 
    # on Twitter's OAuth implementation.
    
    #CONSUMER_KEY = 'DcPtlOYZ07jilc3PgYJLUPRjJ'
    #CONSUMER_SECRET = 'bREXzcIMNLKhRpOhQGFuEKTaJhRhHcjD3dKBe682Yt2MOiNv6b'
    #OAUTH_TOKEN = '2904474861-qPmMjcwisBQWR1cMILoXevC8QeKS3Go3PzN5lBq'
    #OAUTH_TOKEN_SECRET = 'h0iaWqpk7YqsP9MAk5mU472ZOsFOtunfL76fwhEY3x9PA'
    
    CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET = ler_tokens_acesso()
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# Sample usage
twitter_api = oauth_login()    

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print (twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7fb9366cc250>

# %% [markdown]
# ## Módulo para buscar tweets, dado uma palavra

# %%
def twitter_search(twitter_api, q, max_results=1000, **kw):  #max_results=200

    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets and 
    # https://dev.twitter.com/docs/using-search for details on advanced 
    # search criteria that may be useful for keyword arguments
    
    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets    
    search_results = twitter_api.search.tweets(q=q, count=1000, **kw)   # count=100
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval. See
    # https://dev.twitter.com/docs/rate-limiting/1.1/limits
    # for details. A reasonable number of results is ~1000, although
    # that number of results may not exist for all queries.
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses

# %% [markdown]
# ## Salvando/Recuperando no MongoDB

# %%
import json
import pymongo # pip install pymongo


def save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw):
    
    # Connects to the MongoDB server running on 
    # localhost:27017 by default
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    
    # Get a reference to a particular database
    
    db = client[mongo_db]
    
    # Reference a particular collection in the database
    
    coll = db[mongo_db_coll]
    
    # Perform a bulk insert and  return the IDs
    
    return coll.insert_many(data)

def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
                    criteria=None, projection=None, **mongo_conn_kw):
    
    # Optionally, use criteria and projection to limit the data that is 
    # returned as documented in 
    # http://docs.mongodb.org/manual/reference/method/db.collection.find/
    
    # Consider leveraging MongoDB's aggregations framework for more 
    # sophisticated queries.
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    db = client[mongo_db]
    coll = db[mongo_db_coll]
    
    if criteria is None:
        criteria = {}
    
    if projection is None:
        cursor = coll.find(criteria)
    else:
        cursor = coll.find(criteria, projection)

    # Returning a cursor is recommended for large amounts of data
    
    if return_cursor:
        return cursor
    else:
        return [ item for item in cursor ]

# %% [markdown]
# ## Capturando tweets

# %%
q = 'brasil'
q = 'Anitta'
result = twitter_search(twitter_api, q, max_results=1000)
type(result)
# Out:
# list

# %%
result[0]
# Out:
# {'created_at': 'Thu Oct 29 16:14:11 +0000 2020',
#  'id': 1321847808874393601,
#  'id_str': '1321847808874393601',
#  'text': 'RT @ronittando: Anitta tem a melhor videografia do Brasil e uma das melhores do mundo! ✨ https://t.co/O51gTryeQQ',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'ronittando',
#     'name': 'Roni',
#     'id': 1224108397768867841,
#     'id_str': '1224108397768867841',
#     'indices': [3, 14]}],
#   'urls': [],
#   'media': [{'id': 1321847163543003136,
#     'id_str': '1321847163543003136',
#     'indices': [89, 112],
#     'media_url': 'http://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#     'url': 'https://t.co/O51gTryeQQ',
#     'display_url': 'pic.twitter.com/O51gTryeQQ',
#     'expanded_url': 'https://twitter.com/ronittando/status/1321847357865152514/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#      'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}},
#     'source_status_id': 1321847357865152514,
#     'source_status_id_str': '1321847357865152514',
#     'source_user_id': 1224108397768867841,
#     'source_user_id_str': '1224108397768867841'}]},
#  'extended_entities': {'media': [{'id': 1321847163543003136,
#     'id_str': '1321847163543003136',
#     'indices': [89, 112],
#     'media_url': 'http://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#     'url': 'https://t.co/O51gTryeQQ',
#     'display_url': 'pic.twitter.com/O51gTryeQQ',
#     'expanded_url': 'https://twitter.com/ronittando/status/1321847357865152514/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#      'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}},
#     'source_status_id': 1321847357865152514,
#     'source_status_id_str': '1321847357865152514',
#     'source_user_id': 1224108397768867841,
#     'source_user_id_str': '1224108397768867841'},
#    {'id': 1321847209781059584,
#     'id_str': '1321847209781059584',
#     'indices': [89, 112],
#     'media_url': 'http://pbs.twimg.com/media/ElglCKpXYAAnlG2.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/ElglCKpXYAAnlG2.jpg',
#     'url': 'https://t.co/O51gTryeQQ',
#     'display_url': 'pic.twitter.com/O51gTryeQQ',
#     'expanded_url': 'https://twitter.com/ronittando/status/1321847357865152514/photo/1',
#     'type': 'photo',
#     'sizes': {'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#      'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}},
#     'source_status_id': 1321847357865152514,
#     'source_status_id_str': '1321847357865152514',
#     'source_user_id': 1224108397768867841,
#     'source_user_id_str': '1224108397768867841'}]},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1225141179081220096,
#   'id_str': '1225141179081220096',
#   'name': 'Lincoln Nobre',
#   'screen_name': 'lincolnnobre',
#   'location': 'São Paulo, Brasil',
#   'description': 'Este programa é uma obra de ficção inspirada livremente em eventos reais. Personagens, situações e outros elementos foram adaptados para efeito dramático.',
#   'url': 'https://t.co/tqiaABQS5l',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/tqiaABQS5l',
#       'expanded_url': 'http://instagram.com/lincolnobre',
#       'display_url': 'instagram.com/lincolnobre',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 2557,
#   'friends_count': 2777,
#   'listed_count': 2,
#   'created_at': 'Wed Feb 05 19:37:03 +0000 2020',
#   'favourites_count': 31839,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 37620,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1317600055164100609/ERABRKIp_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317600055164100609/ERABRKIp_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1225141179081220096/1601604525',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Thu Oct 29 16:12:23 +0000 2020',
#   'id': 1321847357865152514,
#   'id_str': '1321847357865152514',
#   'text': 'Anitta tem a melhor videografia do Brasil e uma das melhores do mundo! ✨ https://t.co/O51gTryeQQ',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1321847163543003136,
#      'id_str': '1321847163543003136',
#      'indices': [73, 96],
#      'media_url': 'http://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#      'url': 'https://t.co/O51gTryeQQ',
#      'display_url': 'pic.twitter.com/O51gTryeQQ',
#      'expanded_url': 'https://twitter.com/ronittando/status/1321847357865152514/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1321847163543003136,
#      'id_str': '1321847163543003136',
#      'indices': [73, 96],
#      'media_url': 'http://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Elgk_eZWoAALIOU.jpg',
#      'url': 'https://t.co/O51gTryeQQ',
#      'display_url': 'pic.twitter.com/O51gTryeQQ',
#      'expanded_url': 'https://twitter.com/ronittando/status/1321847357865152514/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}}},
#     {'id': 1321847209781059584,
#      'id_str': '1321847209781059584',
#      'indices': [73, 96],
#      'media_url': 'http://pbs.twimg.com/media/ElglCKpXYAAnlG2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/ElglCKpXYAAnlG2.jpg',
#      'url': 'https://t.co/O51gTryeQQ',
#      'display_url': 'pic.twitter.com/O51gTryeQQ',
#      'expanded_url': 'https://twitter.com/ronittando/status/1321847357865152514/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1224108397768867841,
#    'id_str': '1224108397768867841',
#    'name': 'Roni',
#    'screen_name': 'ronittando',
#    'location': '',
#    'description': 'Bem-vindo 💙',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2344,
#    'friends_count': 2247,
#    'listed_count': 18,
#    'created_at': 'Sun Feb 02 23:12:52 +0000 2020',
#    'favourites_count': 38986,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 18858,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1321635133762523137/IYXaRqQp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321635133762523137/IYXaRqQp_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1224108397768867841/1601740589',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 14,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  'is_quote_status': False,
#  'retweet_count': 2,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'pt'}

# %%
len(result)
# Out:
# 1100

# %%
q = 'petrobras'
q = 'sarampo'
q = '#IveteSangaloNoTVZ'
q = '#AbortoÉCrime'
q = 'neymar'
q = 'Anitta'

twitter_api = oauth_login()
results = []
for i in range(1):
    result = twitter_search(twitter_api, q, max_results=1000)
    print ('capturando ', len(result),' tweets...')
    results.extend(result) # junçao de 2 lstas
    #results += result
#print(type(result))
#print(type(results))
print("Numero de tweets capturados: ", len(results))

#results = twitter_search(twitter_api, q, max_results=1000)
#save_to_mongo(results, 'tweets', q)
# Out:
# capturando  1100  tweets...
# Numero de tweets capturados:  1100

# %%
results[2]
# Out:
# {'created_at': 'Thu Oct 29 16:17:27 +0000 2020',
#  'id': 1321848633936019456,
#  'id_str': '1321848633936019456',
#  'text': '@Anittano55 @los40mx @Anitta @iamcardib @myketowerspr Hola @Los40mx, mi voto es por “Me Gusta" de @Anitta,… https://t.co/iQ1p35TQnq',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Anittano55',
#     'name': 'Anitta || Girl from rio',
#     'id': 1281077909525069826,
#     'id_str': '1281077909525069826',
#     'indices': [0, 11]},
#    {'screen_name': 'los40mx',
#     'name': 'LOS40 México®',
#     'id': 163521165,
#     'id_str': '163521165',
#     'indices': [12, 20]},
#    {'screen_name': 'Anitta',
#     'name': 'Anitta',
#     'id': 141817380,
#     'id_str': '141817380',
#     'indices': [21, 28]},
#    {'screen_name': 'iamcardib',
#     'name': 'iamcardib',
#     'id': 866953267,
#     'id_str': '866953267',
#     'indices': [29, 39]},
#    {'screen_name': 'myketowerspr',
#     'name': 'MT',
#     'id': 302856349,
#     'id_str': '302856349',
#     'indices': [40, 53]},
#    {'screen_name': 'los40mx',
#     'name': 'LOS40 México®',
#     'id': 163521165,
#     'id_str': '163521165',
#     'indices': [59, 67]},
#    {'screen_name': 'Anitta',
#     'name': 'Anitta',
#     'id': 141817380,
#     'id_str': '141817380',
#     'indices': [98, 105]}],
#   'urls': [{'url': 'https://t.co/iQ1p35TQnq',
#     'expanded_url': 'https://twitter.com/i/web/status/1321848633936019456',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [108, 131]}]},
#  'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': 1321844188934213634,
#  'in_reply_to_status_id_str': '1321844188934213634',
#  'in_reply_to_user_id': 1281077909525069826,
#  'in_reply_to_user_id_str': '1281077909525069826',
#  'in_reply_to_screen_name': 'Anittano55',
#  'user': {'id': 1296645191357681665,
#   'id_str': '1296645191357681665',
#   'name': 'ME GUSTA ON SPOTIFY',
#   'screen_name': 'anittation1',
#   'location': '',
#   'description': 'FAN ACCOUNT - ANITTA Reserva : @anittation',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 29,
#   'friends_count': 45,
#   'listed_count': 0,
#   'created_at': 'Fri Aug 21 03:08:09 +0000 2020',
#   'favourites_count': 432,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 6105,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1319074135184723969/RWG1VpvD_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319074135184723969/RWG1VpvD_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1296645191357681665/1603326756',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'es'}

# %%
results[1]['created_at']
# Out:
# 'Thu Oct 29 15:54:55 +0000 2020'

# %%
results[1]['metadata']['iso_language_code']
# Out:
# 'pt'

# %%
len(results)
# Out:
# 1100

# %% [markdown]
# ## imprimindo tweets

# %%
#result = results
i = 0
for tweet in results:
    #print(tweet['place'], tweet['created_at'], ' >> ', tweet['text'] , " >> ", )
    print(tweet['text'])
    i += 1
    if i > 10:
          break
# Out:
# quem já foi em festa de aniversário minha que o diga! parece até a festa da Anitta, tu olha pra um lado e vê o Davi… https://t.co/ueC2bs63OS
# RT @M3DUSINHA: as vezes eu fico deitado e pensando, porr@ a Anitta tem feat com Madonna, Snoop Dog, Cardi b, Sean Paul, está no álbum da Ar…
# RT @Anitta: 🎱 https://t.co/5H5XnUabXL
# @Anitta Você tá falando da Venezuela, piranha? Pq não faz showzinho lá, hein?
# RT @porralemos: Anitta chamando bolsonaro de Deus https://t.co/R8sF9Ibvb3
# RT @btarzanitta: a anitta sofre vários ataques e ninguém diz nada as pessoas só se importam quando as coisas chegam no ponto que chegou a s…
# RT @Anitta: A mí me gusta https://t.co/RtqcpnL2BG
# RT @WarnerCanada: #MeGusta 🔥 @Anitta https://t.co/G3pD8rVSOT
# RT @Anitta: "Anitta nem precisa do SUS não sabe"
#
# Uma pesquisa rapidinha no Google vocês vão saber 2 coisas..
#
# 1. De onde eu vim e pq já…
# Aff qnd a @Anitta vai lançar um hit com a @gloriagroove ????😭😭😭😭 não aguento mais esperar por esse feat
# RT @ArielleMacedo: Eu estou tão #tbt
# 🎶 Cachorro eu tenho em casa
# @Anitta
# Quem lembra ? https://t.co/JaYqA0NeSI

# %% [markdown]
# ## Nuvem de Palavras - tweet

# %% [markdown]
# ### Stopwords

# %%
# instalando o módulo de stopwords
#!pip install stop-words
results = result

# %%
from stop_words import get_stop_words
stop_words_english = get_stop_words('en')
#stop_words
stop_words_portugues = get_stop_words('pt')
#stop_words_portugues
stop_words = stop_words_english + stop_words_portugues
print(stop_words[:10])
print(stop_words[-10:])
print(len(stop_words_english))
print(len(stop_words_portugues))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and']
# ['tém', 'tínhamos', 'um', 'uma', 'você', 'vocês', 'vos', 'à', 'às', 'éramos']
# 174
# 203

# %%
#!pip install wordcloud

# %%
# nuvem de palavras
from wordcloud import WordCloud, STOPWORDS
import re

stext = ""
for tweet in result:
    if 'text' in tweet:
        stext = stext + tweet['text']
stext = stext.lower() # colocar para minúsculas

# retirando pontuações e outros caracteres não relevantes
stext = "".join([i for i in stext if ord(i)<128])
stext = stext.replace("http://","")
stext = stext.replace("https://","")
stext = stext.replace("https","")
stext = stext.replace(",","")
stext = stext.replace(".","")
stext = stext.replace("?","")
stext = stext.replace("!","")
stext = stext.replace("#","")
stext = stext.replace("@","")
stext = stext.replace("'","")
stext = stext.replace("-","")
stext = stext.replace("3","")
stext = stext.replace("&amp;","")
stext = stext.replace("|","")



# retirando as stopwords dos tweets
for word in stop_words:
    my_regex = r"\b(?=\w)" + re.escape(word) + r"\b(?!\w)"
    stext = re.sub(my_regex,"" ,stext)

print(len(stext))


# Generate a word cloud image
wordcloud = WordCloud().generate(stext)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(stext)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# 72642

# %% [markdown]
# ## Estatistica de contagem de palavras

# %%
words = stext.split()

# %%
from collections import Counter

c = Counter(words)
#print (c.most_common()[:30])
most_common = c.most_common()[:40]

for i in most_common:
    print (i[0])
#for item in words:  #[words, screen_names, hashtags]:
#    c = Counter(item)
#    print (c.most_common()[:20]) # top 10
#    print
# Out:
# anitta
# gusta
# m
# anitta:
# deus
# bolsonaro
# chamando
# porralemos:
# tco/rtqcpnl2bgrt
# los40mx
# iamcardib
# mi
# pra
# b
# cardi
# tco/r8sf9ibvbrt
# myketowerspr
# voto
# sus
# vai
# ser
# hola
# gusta"
# es
# voc
# est
# rt
# brasil
# feat
# t
# s
# h
# n
# gutocosgrove:
# aqui
# j
# pq
# paz
# tco/rtqcpnl2bganitta
# madonna

# %%
for i in range(15):
    print (c.popitem())
# Out:
# ('kkkkkkkkkkkkkkkkkkkk', 1)
# ('tco/rtqcpnl2bgdontstartfuego', 1)
# ('tco/7z6ciwjedxrt', 1)
# ('vsf', 1)
# ('fofo', 1)
# ('magrelao', 1)
# ('coitada', 1)
# ('kqkwkqkwoqiwkwksjkaiskakskwkskwksjaks', 1)
# ('dantflash', 1)
# ('felipe_exst', 1)
# ('hein', 1)
# ('cuida', 1)
# ('ok', 1)
# ('oie', 1)
# ('tco/vqbvcfp6ljrt', 1)

# %% [markdown]
# ## colocando as palavras e suas frequencias do twitter num dataframe

# %%
import pandas as pd
df = pd.DataFrame(([word, freq] for word, freq in most_common), columns=['Word', 'Frequency'])
df[:25]
# Out:
#                 Word  Frequency
# 0             anitta        714
# 1              gusta        222
# 2                  m        174
# 3            anitta:        167
# 4               deus         94
# 5          bolsonaro         91
# 6           chamando         86
# 7        porralemos:         85
# 8   tco/rtqcpnl2bgrt         80
# 9            los40mx         62
# 10         iamcardib         61
# 11                mi         58
# 12               pra         52
# 13                 b         50
# 14             cardi         49
# 15   tco/r8sf9ibvbrt         48
# 16      myketowerspr         48
# 17              voto         44
# 18               sus         43
# 19               vai         43
# 20               ser         43
# 21              hola         41
# 22            gusta"         35
# 23                es         34
# 24               voc         33

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(15,10))
fig.add_subplot(1,1,1)

df2 = df[:25]

ax = sns.barplot(y='Word', x = 'Frequency', data=df2, palette="Set3" )
#sns.despine()
ax.set(xlabel='Tweets words frequency', ylabel='Word')
#ax.set(xticks=range(1, 9), xticklabels=list([10,20,30,40,50,60,70,80,90]))

#ax.set(xticklabels=list(range(0,90,10)))
#plt.figure(figsize=(20,10))

ax.axes.set_title("Tweets words frequency",fontsize=40)
ax.set_xlabel("Frequency",fontsize=26)
ax.set_ylabel("Word",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()

# %% [markdown]
# ## achar os países de onde foram gerados os tweets

# %%
place = []
for result in results:
    if 'place'in result and result['place']:
        place.append(result['place']['country'])
place = set(place)
print(len(place) )
print(place)
# Out:
# 3
# {'Switzerland', 'Portugal', 'Brazil'}

# %%
# cidades
place = []
for result in results:
    if 'user'  in result:
        place.append(result['user']['location'])
location = set(place)
len(location)
# Out:
# 343

# %%
for i in range(15):
    print(location.pop())
# Out:
# bookstan || go vegan 🌱
# São Paulo, Brasil
#  Cortez
# bauru
# 🇨🇦 | Toronto, Ontario
# BRASIL
# BR 116
# Três Cachoeiras, Brasil
# Maringá, Brasil
# 무ㅤ𝗺.ㅤ🚉ㅤ𓏲
# 🥑
# Vitória, Brasil
# Irajá, Rio de Janeiro
# Ancapistão

# %% [markdown]
# ## contar a ocorrencia de cada cidade

# %%
from collections import Counter

c = Counter(location)
#print(c)
cidades = c.items()

# %% [markdown]
# ## colocando as cidades, frequencia num dataframe e salvando no excel

# %%
import pandas as pd
df = pd.DataFrame(([cidade, freq] for cidade, freq in cidades), columns=['city', 'frequency'])

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('cidades.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
df[:15]
# Out:
#                             city  frequency
# 0                 Marabá, Brasil          1
# 1                         manaós          1
# 2                          Marte          1
# 3               Montréal, Québec          1
# 4            Melbourne, Victoria          1
# 5                        konoha🍃          1
# 6                   Acha ai fia           1
# 7          Cascata, Porto Alegre          1
# 8          Recife/Maceió, Brasil          1
# 9                       salvador          1
# 10  Sócia do Esporte Clube Bahia          1
# 11                 Serra talhada          1
# 12                  fan account           1
# 13                      Hellcife          1
# 14                        konoha          1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(15,10))
fig.add_subplot(1,1,1)

df2 = df[:25]

ax = sns.barplot(y='city', x = 'frequency', data=df2, palette="Set3" )
ax.set(xlabel='Tweets cities frequency', ylabel='cities')
ax.axes.set_title("Tweets cities frequency",fontsize=40)
ax.set_xlabel("frequency",fontsize=26)
ax.set_ylabel("cities",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()
# Out:
# /Users/uepb/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 127811 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/uepb/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 127811 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Capturar tweets com coodenadas de lat, long para cidade

# %%
def captura_tweets_com_coordenadas(tweets):
    tweets_com_coordenadas = []
    for tweet in tweets:
        if tweet['place'] is not None:
            tweets_com_coordenadas.append(tweet)
    return (tweets_com_coordenadas)

# %%
tweets_com_coordenadas = captura_tweets_com_coordenadas(results)
print(len(tweets_com_coordenadas))
# Out:
# 10

# %%
len(tweets_com_coordenadas)/len(results) * 100
# Out:
# 0.9090909090909091

# %%
tweets_com_coordenadas[0]['place']['bounding_box']
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-43.795449, -23.08302],
#    [-43.0877068, -23.08302],
#    [-43.0877068, -22.7398234],
#    [-43.795449, -22.7398234]]]}

# %%
tweets_com_coordenadas[0]['place']['bounding_box']['coordinates']
# Out:
# [[[-43.795449, -23.08302],
#   [-43.0877068, -23.08302],
#   [-43.0877068, -22.7398234],
#   [-43.795449, -22.7398234]]]

# %%
tweets_com_coordenadas[0]['place']['bounding_box']['coordinates'][0][0]
# Out:
# [-43.795449, -23.08302]

# %%
def captura_coordenadas(tweets):
    coordenadas = []
    for tweet in tweets:
        coord = tweet['place']['bounding_box']['coordinates'][0][0]
        coordenadas.append(coord)
    return coordenadas

# %%
tweets_coordenadasXY = captura_coordenadas(tweets_com_coordenadas)
tweets_coordenadasXY[:5]
# Out:
# [[-43.795449, -23.08302],
#  [8.554267, 47.1480459],
#  [-39.549343, -15.0977648],
#  [-49.206993, -27.1325356],
#  [-9.4279855, 38.8624347]]

# %%
len(tweets_com_coordenadas)
# Out:
# 10

# %%
latitudes_tweets =  [ y for x,y in tweets_coordenadasXY]
longitudes_tweets =  [ x for x,y in tweets_coordenadasXY]

# %%
coordenadas_distintas = set(latitudes_tweets)
len(coordenadas_distintas)
# Out:
# 8

# %%
print(list(latitudes_tweets[:15]))
# Out:
# [-23.08302, 47.1480459, -15.0977648, -27.1325356, 38.8624347, -23.08302, -22.98297, -27.8389356, -27.7902274, -27.8389356]

# %%
print(list(longitudes_tweets[:15]))
# Out:
# [-43.795449, 8.554267, -39.549343, -49.206993, -9.4279855, -43.795449, -43.1648112, -48.6103127, -52.3436987, -48.6103127]

# %%
import pandas as pd
df10 = pd.DataFrame({'latitude': latitudes_tweets, 'longitude':longitudes_tweets })
df10.head()
# Out:
#     latitude  longitude
# 0 -23.083020 -43.795449
# 1  47.148046   8.554267
# 2 -15.097765 -39.549343
# 3 -27.132536 -49.206993
# 4  38.862435  -9.427986

# %%
len(df10)
# Out:
# 10

# %%
df11 = df10.drop_duplicates()
df11 = df11.reset_index(drop=True)
len(df11)
# Out:
# 8

# %%
df11.to_csv('coordenadas-tweets-Novembro-2019.csv', index=False)

# %%
import pandas as pd
df11 = pd.read_csv('coordenadas-tweets-Novembro-2019.csv')
df11.head()
# Out:
#     latitude  longitude
# 0 -23.083020 -43.795449
# 1  47.148046   8.554267
# 2 -15.097765 -39.549343
# 3 -27.132536 -49.206993
# 4  38.862435  -9.427986

# %%
for i in range(len(df11)):
    #print(i)
    row = df11.loc[i]
    #print(row)
    print('latitude:', row['latitude'], ', longitude:', row['longitude'] )
# Out:
# latitude: -23.08302 , longitude: -43.795449
# latitude: 47.1480459 , longitude: 8.554267
# latitude: -15.097764800000002 , longitude: -39.549343
# latitude: -27.132535600000004 , longitude: -49.206993
# latitude: 38.8624347 , longitude: -9.4279855
# latitude: -22.98297 , longitude: -43.1648112
# latitude: -27.838935600000003 , longitude: -48.6103127
# latitude: -27.7902274 , longitude: -52.343698700000004

# %%
print(list(latitudes_tweets[:10]))
# Out:
# [-23.08302, 47.1480459, -15.0977648, -27.1325356, 38.8624347, -23.08302, -22.98297, -27.8389356, -27.7902274, -27.8389356]

# %%
print(list(longitudes_tweets[:10]))
# Out:
# [-43.795449, 8.554267, -39.549343, -49.206993, -9.4279855, -43.795449, -43.1648112, -48.6103127, -52.3436987, -48.6103127]

# %% [markdown]
# ## ler coordenadas de um arquivo

# %%
df10 = pd.read_csv('coordenadas-tweets-Novembro-2019.csv')
df10.head()
# Out:
#     latitude  longitude
# 0 -23.083020 -43.795449
# 1  47.148046   8.554267
# 2 -15.097765 -39.549343
# 3 -27.132536 -49.206993
# 4  38.862435  -9.427986

# %%
df12 = df10.copy()
df12.head()
df12 = df12.dropna()
len(df12)
df12.head()
# Out:
#     latitude  longitude
# 0 -23.083020 -43.795449
# 1  47.148046   8.554267
# 2 -15.097765 -39.549343
# 3 -27.132536 -49.206993
# 4  38.862435  -9.427986

# %% [markdown]
# ## remover tuplas duplicadas

# %%
df13 = df12.drop_duplicates()
df13 = df13.reset_index(drop=True)
len(df13)
# Out:
# 8

# %% [markdown]
# # Georeferenciar os tweets no mapa mundi

# %%
#!pip install folium

# %%
import folium
from folium.utilities import write_png

mapit = folium.Map(location=[30, 0], zoom_start=2)
for coord in tweets_coordenadasXY:
    folium.CircleMarker( location=[ coord[1], coord[0] ], radius=2).add_to( mapit ) 
                    # color='#0080bb', fill_color='#0080bb'

#png_str = write_png(mapit. .data())
#of = open('folium_map.png', 'w')
#of.write(png_str)
#of.close()

folium.Map.save(mapit, "index.html")
#import os
#cmd = 'cutycapt --url=file:///index.html --out=folium_map.png'
#os.system(cmd)

mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # twitter trends - assuntos mais comentados do momento

# %%
import json
import twitter

# Acessar os tends da localidade
#http://woeid.rosselliot.co.nz/


def twitter_trends(twitter_api, woe_id):
    # Prefix ID with the underscore for query string parameterization.
    # Without the underscore, the twitter package appends the ID value
    # to the URL itself as a special-case keyword argument.
    return twitter_api.trends.place(_id=woe_id)

# Sample usage

twitter_api = oauth_login()

# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/ for details on
# Yahoo! Where On Earth ID

WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
#print json.dumps(world_trends, indent=1)

US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
#print (json.dumps(us_trends, indent=1))
#us_trends[0]

#for trend in us_trends:
#    print (trend['as_of']['name'])

# %%
def find_trends(country_trends):
    trends = country_trends[0]['trends']
    for trend in trends:
        print (trend['name'])

# %%
from datetime import datetime
WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
print ("topicos mais comentados: Mundo", datetime.now())
find_trends(world_trends)
# Out:
# topicos mais comentados: Mundo 2020-10-29 12:58:00.754211
# Corbyn
# #PartyStarters
# Desmond Elliot
# Labour Party
# #NationalCatDay
# #MaliyedenÖğrt60Bin
# #神宮寺勇太誕生祭
# #佐藤勝利誕生祭
# MAMA's Fan Choice Awards
# giselle
# Guernica
# スパチャ総収益
# SNKRS
# お師さん
# Worldwide Fans
# Jay Cutler
# Ivy Park
# 十二鬼月診断
# taemin
# こーしん
# Zlatan
# Islam
# Jeremy
# DITA GOT THAT BOOM
# Keir Starmer
# OLHA ESSE ABSURDO
# Bahisnow Bedava10TL
# 鬼滅の刃の世界
# Pulwama
# Gillian Anderson
# NAUGHTY LIST TOMORROW
# Lampedusa
# じぐいわ入所10周年
# 海のおばけたち
# Avignon
# ぱしゃこれ
# トリプルカイト
# Ciro
# #แปลรักEP2
# #CazaRenosEnChollometro
# #目黒蓮入所10周年
# #NiceAttack
# #ReadyForTravel
# #WaadaHai
# #LifeStory_Of_NabiMuhammad
# #アウトデラックス
# #斎宮宗誕生祭2020
# #FelizJueves
# #FranceBeheading
# #庭ラジ

# %%
US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
print ("topicos mais comentados: USA", datetime.now())
find_trends(us_trends)
# Out:
# topicos mais comentados: USA 2020-10-29 12:58:11.615292
# #NationalCatDay
# SNKRS
# Jay Cutler
# Ivy Park
# #ThursdayThoughts
# #PitDark
# Corbyn
# #PBPitch
# #TrumpDepression
# Jack Nicklaus
# Desmond Elliot
# Labour Party
# Clive
# Hackers
# MAMA's Fan Choice Awards
# Zlatan
# Purell
# The Economist
# Perdue
# Michael Moore
# Riley Children
# giselle
# Vanity Fair
# 33.1% gdp
# Kevin Warren
# Together We Rise
# taemin
# The GDP
# Tyga
# Hunter
# Will Hernandez
# Best Buy
# U.S. GDP
# 5 Days
# Wine
# Demon's Souls
# Malaysia
# Zeta
# Jon Ossoff
# Miracle Whip
# FFXVI
# UNCLE SUGA
# Cubans
# Rick Bowness
# Pompeos
# Paint It Black
# Seamus Heaney
# Pending
# La Russa
# Worldwide Fans

# %%
BR_WOE_ID = 23424768
br_trends = twitter_trends(twitter_api, BR_WOE_ID)
print ("topicos mais comentados: Brasil", datetime.now())
find_trends(br_trends)
# Out:
# topicos mais comentados: Brasil 2020-10-29 12:58:18.064106
# #Nhonho
# MAMA's Fan Choice Awards
# OLHA ESSE ABSURDO
# #CancelaAProvaRecord
# Ciro
# giselle
# NAUGHTY LIST TOMORROW
# The Crown
# STRAY KIDS MALA TASTE PIONEER
# PRIOR NO PANICO
# girl in red
# França
# #DiaNacionalDoLivro
# Worldwide Fans
# giovanna chaves
# Marie
# Rosa Weber
# #ReadyForTravel
# Adilson Batista
# #OpiniaoNoAr
# Ricardo Salles
# Zlatan
# Gatito
# millie
# Cardi B
# Folha
# Gillian
# Demon's Souls
# MAHIRO
# Tirei 99%
# Rodrigo Maia
# Yetz
# Macron
# Câmara
# Sweet Night
# Smilinguido
# Ivy Park
# Islã
# Black Swan
# Argel
# Seungmin
# mc maneirinho
# São Luís
# cocielo
# Carluxo
# Scarlett Johansson
# Quintou
# Tio Suga
# Malásia
# Haruto

# %%
TM_WOE_ID = 32566
tm_trends = twitter_trends(twitter_api, TM_WOE_ID)
print ("topicos mais comentados: UK")
find_trends(tm_trends)
# Out:
# topicos mais comentados: UK
# Corbyn
# Labour
# Jeremy
# Keir Starmer
# Bobby
# #Antisemitism
# #NationalCatDay
# #EHRCReport
# Islamophobia
# Israel
# #RockOnTommy
# Desmond Elliot
# A-Levels
# Gillian Anderson
# Kier
# Tony Blair
# Solidarity
# Malaysia
# Sir Keir
# Momentum
# giselle
# Cannon and Ball
# Greens
# Socialist
# Semite
# taemin
# Demon's Souls
# Harry Senior
# JJ Williams
# Unite
# Margaret Hodge
# McDonnell
# Zionist
# Islington North
# Livingstone
# Shadow Cabinet
# Shami
# Farage
# Mount Pleasant
# Green Party
# Luciana Berger
# RIP JJ
# Maggie
# RTX 3070
# #NiceAttack
# #jezza
# #HotAndColdSongsAndCelebs
# #WorldStrokeDay
# #ThursdayThoughts

# %%
TM_WOE_ID = 455827
tm_trends = twitter_trends(twitter_api, TM_WOE_ID)
print ("topicos mais comentados: São Paulo")
find_trends(tm_trends)
# Out:
# topicos mais comentados: São Paulo
# #Nhonho
# MAMA's Fan Choice Awards
# Ciro
# França
# girl in red
# Ricardo Salles
# #FicaTays
# Botafogo
# Cássio
# #CancelaAProvaRecord
# giselle
# OLHA ESSE ABSURDO
# NAUGHTY LIST TOMORROW
# STRAY KIDS MALA TASTE PIONEER
# The Crown
# giovanna chaves
# PRIOR NO PANICO
# Worldwide Fans
# #OpiniaoNoAr
# #DiaNacionalDoLivro
# Marie
# Folha
# Rosa Weber
# Rodrigo Maia
# Demon's Souls
# Câmara
# millie
# Hyungwon
# cocielo
# Ivy Park
# Tirei 99%
# Macron
# Sweet Night
# Black Swan
# Cardi B
# Guedes
# kihyun
# Carluxo
# hwasa
# Maranhão
# Hayley
# waverly place
# Procon
# Banco Central
# Mc Brinquedo
# Adilson Batista
# Zlatan
# Gatito
# Gillian
# MAHIRO

# %% [markdown]
# # Análise de Sentimentos - Tweets

# %%
#!pip install textblob

# %%
#!pip install googletrans

# %%
from googletrans import Translator
translator = Translator()
translator.translate('oi, tudo bem', src='pt').text
# Out:
# 'Hello all well'

# %% [markdown]
# ### Testando as polaridades

# %%
from textblob import TextBlob as tb
txt = 'bad girl in NY'
analysis = tb(txt)
analysis.sentiment.polarity
analysis.sentiment
# Out:
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)

# %%
txt = 'neutral'
analysis = tb(txt)
analysis.sentiment.polarity
# Out:
# 0.0

# %%
txt = 'good'
analysis = tb(txt)
analysis.sentiment.polarity
# Out:
# 0.7

# %%
txt = 'péssimo'
tb_txt = tb(txt)
tb_txt.sentiment.polarity
txt = tb_txt.translate(to='en')
txt.sentiment.polarity
# Out:
# -1.0

# %% [markdown]
# # polaridade de tweets em ingles e portugues

# %%
from textblob import TextBlob as tb #NLP module
import numpy as np #for some calculation. You may want to use your favorite module for this, such as statistics

# polaridade de tweets em ingles e portugues
def polarity_tweets_pais(query):
    from googletrans import Translator
    
    translator = Translator() # google tradutor

    twitter_api = oauth_login()
    numero_iteracoes = 1
    results = []
    for i in range(numero_iteracoes):
        max_results = 500 # 1000
        result = twitter_search(twitter_api, query, max_results=max_results)
        print ('capturando ', len(result),' tweets...')
        #results.append(result)
        results += result

    analysis = None
    pos_polarity = 0
    neutral_polarity = 0
    neg_polarity = 0
    sum_polarity = 0
    print("calculando polaridades...")

    for tweet in results:
        text_tweet = tweet['text']
        
        # retirando caracteres malucos
        text_tweet = "".join([i for i in text_tweet if ord(i)<128])
        
        frase = tb(text_tweet)       
        language = tweet['lang'] #frase.detect_language()
        if language == 'br' or language == 'pt' :
            text_en = translator.translate(text_tweet, src='pt').text  
            analysis = tb(text_en)
        elif language == 'en':   
            analysis = frase
        else:
            analysis = ""
            
        if analysis != "": 
            if (analysis.sentiment.polarity > 0):
                pos_polarity += 1
            elif (analysis.sentiment.polarity <= 0):
                neg_polarity += 1
            sum_polarity += analysis.sentiment.polarity

    return sum_polarity, pos_polarity, neg_polarity, neutral_polarity

# %%
q = 'tesla'

"""
mean_polarity, pos_polarity, neg_polarity, neutral_polarity = polarity_tweets_pais(q)
total = pos_polarity + neg_polarity + neutral_polarity 
print('SENTIMENT AVERAGE: ' , mean_polarity/total)
print('Positive: ', pos_polarity, (pos_polarity/total) * 100)
print('Negative: ', neg_polarity, (neg_polarity/total) * 100)
print('neutral: ', neutral_polarity, (neutral_polarity/total) * 100
"""
# Out:
# "\nmean_polarity, pos_polarity, neg_polarity, neutral_polarity = polarity_tweets_pais(q)\ntotal = pos_polarity + neg_polarity + neutral_polarity \nprint('SENTIMENT AVERAGE: ' , mean_polarity/total)\nprint('Positive: ', pos_polarity, (pos_polarity/total) * 100)\nprint('Negative: ', neg_polarity, (neg_polarity/total) * 100)\nprint('neutral: ', neutral_polarity, (neutral_polarity/total) * 100\n"

# %%
import pandas as pd
df = pd.DataFrame(columns=['name', 'pos', 'negative', 'sentiment_avg'])
queries = [ 'tesla', 'facebook', 'apple', 'xiaomi']

for q in queries:
    mean_polarity, pos_polarity, neg_polarity, neutral_polarity = polarity_tweets_pais(q)
    total = pos_polarity + neg_polarity + neutral_polarity 
    print('Query: ', q)
    print('SENTIMENT AVERAGE: ' , mean_polarity/total)
    print('Positive: ', pos_polarity, (pos_polarity/total) * 100)
    print('Negative: ', neg_polarity, (neg_polarity/total) * 100)
    #print('neutral: ', neutral_polarity, (neutral_polarity/total) * 100)
    print('----------------------------------------------')
    
    i = len(df)
    df.loc[i] = [q, pos_polarity, neg_polarity, mean_polarity/total]
df
# Out:
# capturando  600  tweets...
# calculando polaridades...
# Query:  tesla
# SENTIMENT AVERAGE:  0.059459951953613185
# Positive:  140 28.397565922920894
# Negative:  353 71.6024340770791
# neutral:  0 0.0
# ----------------------------------------------
# capturando  600  tweets...
# calculando polaridades...
# Query:  facebook
# SENTIMENT AVERAGE:  0.06690110704655929
# Positive:  139 37.669376693766935
# Negative:  230 62.33062330623306
# neutral:  0 0.0
# ----------------------------------------------
# capturando  600  tweets...
# calculando polaridades...
# Query:  apple
# SENTIMENT AVERAGE:  0.10647666095478597
# Positive:  177 44.25
# Negative:  223 55.75
# neutral:  0 0.0
# ----------------------------------------------
# capturando  600  tweets...
# calculando polaridades...
# Query:  xiaomi
# SENTIMENT AVERAGE:  0.1621054421768709
# Positive:  156 49.523809523809526
# Negative:  159 50.476190476190474
# neutral:  0 0.0
# ----------------------------------------------
#        name  pos negative  sentiment_avg
# 0     tesla  140      353       0.059460
# 1  facebook  139      230       0.066901
# 2     apple  177      223       0.106477
# 3    xiaomi  156      159       0.162105

# %%
df["%pos"] = df.pos / (df.pos + df.negative)
df["%neg"] = df.negative / (df.pos + df.negative)
df["%pos"] = df["%pos"].apply(lambda x: int(round(x,1) * 100))
df["%neg"] = df["%neg"].apply(lambda x: int(round(x,1) * 100))
df.loc[:, ['name', "%pos", "%neg", 'sentiment_avg' ]]
# Out:
#        name  %pos  %neg  sentiment_avg
# 0     tesla    30    70       0.059460
# 1  facebook    40    60       0.066901
# 2     apple    40    60       0.106477
# 3    xiaomi    50    50       0.162105

# %% [markdown]
# ### gravando os dados do dataframe num arquivo .csv

# %%
from datetime import datetime
data_agora = str(datetime.now())
df.to_csv("sentimentos-"+ data_agora +".csv")

# %%
df.loc[:, ['name', "%pos", "%neg" ]]
# Out:
#        name  %pos  %neg
# 0     tesla    30    70
# 1  facebook    40    60
# 2     apple    40    60
# 3    xiaomi    50    50
