# %% [markdown]
# # Análise de Mídias Sociais - Youtube

# %%
#!pip install google-api-python-client
#!pip install oauth2client

# %% [markdown]
# ## Para autenticar no youtube: https://cloud.google.com/console
# ### Menu API e Serviços -> Credenciais -> Copiar a chave
# ### DEVELOPER_KEY = 'AIzaSyCdN7u3Fg00-WfGnU6MUrpe1tIcuYUQ7ik'

# %%
from apiclient.discovery import build #pip install google-api-python-client
from apiclient.errors import HttpError #pip install google-api-python-client
from oauth2client.tools import argparser #pip install oauth2client

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %% [markdown]
# ## Acessa métricas do youtube por termo ou nome

# %%
# get youtube data ratings
def get_youtube_data(qr):
    # Set DEVELOPER_KEY to the API key value from the APIs & auth > Registered apps
    # tab of   https://cloud.google.com/console
    DEVELOPER_KEY =  'AIzaSyDfpru8OYmFTjwTkX-hXsXPk4G3Wq9d9nE'


    YOUTUBE_API_SERVICE_NAME = "youtube"
    YOUTUBE_API_VERSION = "v3"

    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

    # Call the search.list method to retrieve results matching the specified query term.
    search_response = youtube.search().list(
     q=qr, # if disabled, search all names
     type="video",
     #type="channel",
     #regionCode=regionCode,
     part="id,snippet",
     maxResults=50,
     order='viewCount'
    ).execute()

    datas = []
    videos = {}
    # Add each result to the appropriate list, and then display the lists of matching videos.
    # Filter out channels, and playlists.
    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":
         #videos.append("%s" % (search_result["id"]["videoId"]))
         videos[search_result["id"]["videoId"]] = search_result["snippet"]["title"]
         datas.append(search_result['snippet']['publishedAt'])
    s = ','.join(videos.keys())
    videos_list_response = youtube.videos().list(
     id=s,
     part='id,statistics'
    ).execute()

    res = []
    for i,data in zip(videos_list_response['items'], datas):
        temp_res = dict(v_id = i['id'], v_title = videos[i['id']], date = data)
        temp_res.update(i['statistics'])
        res.append(temp_res)
    return pd.DataFrame.from_dict(res)

# %% [markdown]
# ## Análises do Youtube

# %% [markdown]
# ### manipulação de data

# %%
def data_agora():
    data_hoje = str(datetime.today())
    data_hoje 
    data, hora = data_hoje.split()
    data,hora 
    hora, minuto, segundo = hora.split(':')
    hora, minuto, segundo
    segundo = segundo.split('.')[0]
    segundo
    str_data_hoje = data + ' '+ hora +':' + minuto + ':' + segundo
    return str_data_hoje
data_hoje = data_agora()
data_hoje
# Out:
# '2021-09-23 12:02:27'

# %% [markdown]
# ## Plotagem de gráfico

# %%
def plot_mapa_df(dfdata, name, medida, palette):
    data_hoje = data_agora()
    fig = plt.figure(figsize=(16,14))
    fig.add_subplot(1,1,1)
    plt.style.use('ggplot')
    ax = sns.barplot(y= "v_title" ,x="viewCount", palette=palette,
                    data=dfdata.sort_values(by='viewCount',ascending=False))

    ax.axes.set_title("Visualizações: " + name + ", em "+ data_hoje + ' (' + medida + ')',fontsize=26)
    ax.set_ylabel("Vídeos",fontsize=26)
    ax.set_xlabel("Visualizações"+  ' (' + medida + ')',fontsize=26)
    ax.tick_params(labelsize=15)

    plt.show()

# %% [markdown]
# ## Consultas yotube API

# %%
qr = name = "Rossandro Klinjey"
qr = name = "camila uckers"
qr = name = "kefera"
qr = name = "nerdologia"
qr = name = "jovem nerd"
qr = name = "nerdologia"
qr = name = 'Anatomia e etc. com Natalia Reinecke'
qr = name = 'miriam leitao'
qr = name = 'Anitta & Marília Mendonça'
qr = name = 'CANETA AZUL (VERSÃO ARROCHA)'

# %% [markdown]
# # whinderssonnunes

# %%
'''
Vídeos de whinderssonnunes, em 2018-08-02 10:09:55
Total de Acessos (50 vídeos mais vistos), de whinderssonnunes :  1,149,605,639
'''
qr = name = 'whinderssonnunes'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,':', '{:,d}'.format(numAcessosAtual))
dfdata.head(8)
# 1,133,272,561
# 1,133,273,670
# Out:
# Vídeos de whinderssonnunes, em 2021-09-23 12:03:13
# Total de Acessos (50 vídeos mais vistos), de whinderssonnunes : 1,505,007,978
#           v_id                                            v_title  \
# 0  IRirqw082XI  WHINDERSSON NUNES em PROPAROXÍTONA (SHOW COMPL...
# 1  eYfFDaPdkWc     WHINDERSSON NUNES em MARMININO (SHOW COMPLETO)
# 2  f7RS8IEj108  Priscilla Alcantara, Whindersson Nunes - Giras...
# 3  tWs1E2BfNZE     QUAL É A SENHA DO WIFI - Paródia Adele - Hello
# 4  UmmXiN93btM  EU CANSEI DE SER POBRE | Paródia Ed Sheeran - ...
# 5  WhGnY2hTVF0                 CRIANÇA DE RICO E CRIANÇA DE POBRE
# 6  tbNV6EedQhE                                 IMITANDO FUNKEIROS
# 7  BYzC3CLCNaI                    FINAL DE ANO DE RICO E DE POBRE
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2017-12-21T22:00:00Z  119.716026   5206471        69448             0
# 1  2016-12-21T23:00:01Z  102.487293   3529631        53870             0
# 2  2020-01-11T16:00:11Z   79.450899   1296614        21715             0
# 3  2015-12-05T23:00:00Z   77.109448   3801144        67145             0
# 4  2017-04-09T00:00:01Z   67.142205   2964513        60138             0
# 5  2016-06-09T22:46:51Z   64.166289   5590999        51415             0
# 6  2017-04-21T00:00:05Z   47.753080   4754246        75770             0
# 7  2016-12-02T23:00:01Z   42.016412   3982336        35036             0
#
#   commentCount
# 0       102652
# 1        93772
# 2        34107
# 3       160464
# 4        77787
# 5        94435
# 6       128063
# 7        78551

# %%
plot_mapa_df(dfdata[:10], name, 'Milhões', "RdYlBu_r")  # RdBu

# %% [markdown]
# ## Winderson Nunes - Humorista

# %%
acessos_agora = str('1,136,475,235'.replace(',',''))
acessos_antes = str('1,145,485,694'.replace(',',''))
acessos = int(acessos_agora) - int(acessos_antes)
print ("1 dia de acesso:", '{:,d}'.format(acessos))
# Out:
# 1 dia de acesso: -9,010,459

# %%
'''
Vídeos de whinderssonnunes, em 2018-08-02 10:09:55
Total de Acessos (50 vídeos mais vistos), de whinderssonnunes :  1,149,605,639
'''
qr = name = "whinderssonnunes"
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head(20)

# %%
dfdata.head(30)

# %%
plot_mapa_df(dfdata[:15], name, 'Milhões', "RdYlBu_r")  # RdBu

# %% [markdown]
# ## Rossandro Klinjey - Orador, Consultor, Psicólogo global

# %% [markdown]
# #### numero de acessos - Rossandro Klinjey (youtube, maio de 2017): 3,343,916
# #### numero de acessos - Rossandro Klinjey (youtube, dezembro de 2018): 12,846,588
#
# #### Vídeos de Rossandro Klinjey, em 2018-12-29 20:44:01
# #### Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  13,401,050
#
# #### Vídeos de Rossandro Klinjey, em 2018-12-30 13:38:37
# #### Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  13,420,870
#
# ###Vídeos de Rossandro Klinjey, em 2019-06-06 11:27:55
# ###Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  ## ### 17,682,714 # 17,810,775

# %%
''''
Vídeos de Rossandro Klinjey, em 2018-04-08 09:58:39
Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  8,084,679

Vídeos de Rossandro Klinjey, em 2019-06-06 09:33:40
Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  17,681,094

'''

name = 'Rossandro Klinjey'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) #/ 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head()
# Out:
# Vídeos de Rossandro Klinjey, em 2021-09-23 12:05:02
# Total de Acessos (50 vídeos mais vistos), de Rossandro Klinjey :  26,781,046
#           v_id                                            v_title  \
# 0  GmD7vgOi18k  Autoperdão - Um aprendizado necessário - Rossa...
# 1  ZtHkNCmp8fM  Rossandro Klinjey - Quando os filhos precisam ...
# 2  yJpGY7BWH1E  Rossandro Klinjey - &quot;Fugas psicológicas e...
# 3  pdjp9MsImfM  Visão Espírita da Depressão e transtornos Físi...
# 4  8r1ISE6UjLU                     Rossandro Klinjey - Tudo passa
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2016-07-20T13:58:19Z    1999198     56207         2433             0
# 1  2016-11-21T13:59:39Z    1805203    102338         1638             0
# 2  2017-02-02T23:25:10Z    1138853     42905         1430             0
# 3  2017-07-16T20:50:21Z    1034099     35790         1507             0
# 4  2020-04-05T00:07:57Z     944573     54706          946             0
#
#   commentCount
# 0         1359
# 1         1957
# 2          769
# 3          782
# 4         1039

# %%
acessos_agora = str('13,420,870'.replace(',',''))
acessos_antes = str('13,405,286'.replace(',',''))
acessos = int(acessos_agora) - int(acessos_antes)
print ("1 dia de acesso:", '{:,d}'.format(acessos))

# %%
plot_mapa_df(dfdata[:10], name, 'por mil', "RdYlGn_r")

# %%
len(dfdata)

# %% [markdown]
# ### Laís Martins - Youtuber

# %%
qr = name = 'Anatomia e etc. com Natalia Reinecke'
qr = name = "Laís Martins"
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) #/ 1000000
print("Vídeos de " + name + ", em "+ data_agora())
numAcessosAtual =  dfdata.viewCount.sum()
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head()

# %%
plot_mapa_df(dfdata[:25], name, 'por mil', "RdBu")

# %% [markdown]
# ## Outras consultas

# %%
qr = "5incominutos"
qr = "@Kefera"
qr = "whinderssonnunes"
qr = "Felipe Neto"
qr = "beyonce"
qr = "rihanna"
qr = "Coisa de Nerd"
qr = "PewDiePie"

# %% [markdown]
# ## Mc Kevinho - Top 50's of the world

# %%
Vídeos de Mc Kevinho, em 2018-12-29 23:29:09
Total de Acessos (50 vídeos mais vistos), de Mc Kevinho :  7,095,318,400

# %%
qr = name = 'Janis Joplin'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head(10)
# Out:
# Vídeos de Janis Joplin, em 2021-09-23 12:05:56
# Total de Acessos (50 vídeos mais vistos), de Janis Joplin :  790,594,216
#           v_id                                            v_title  \
# 0  d59H0UxhyaY  13 Year Old Singing Like a Lion Earns Howie&#3...
# 1  gPHVLxm8U-0  Courtney Hadwin: 13-Year-Old Golden Buzzer Win...
# 2  cM0T9fumD5k                               Janis Joplin - Maybe
# 3  guKoNCQFAFk                          Janis Joplin - Summertime
# 4  7uG2gYE5KOs                   Janis Joplin - Piece Of My Heart
# 5  UQmFpJ0sB9Q      Wheel of Musical Impressions with Alicia Keys
# 6  nLN72sR9w0M                        Janis Joplin - Kozmic Blues
# 7  AxJxUFoR0Es                    Janis Joplin - To Love Somebody
# 8  N7hk-hI0JKw                  Janis Joplin - Me and Bobby McGee
# 9  3SL0oRcD7t0                  Janis Joplin Piece Of My Heart HQ
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2018-06-13T04:35:45Z  174.867132   2628215        85599             0
# 1  2018-06-13T02:04:30Z   57.967226    505999        23028             0
# 2  2009-02-22T19:32:10Z   40.675578    266102         5884             0
# 3  2011-10-04T14:31:02Z   39.536505    193512         7219             0
# 4  2009-06-11T12:34:47Z   34.409807    195001         5730             0
# 5  2017-03-01T05:23:00Z   32.273534    383049        10711             0
# 6  2009-12-21T11:41:32Z   22.398983    112327         2801             0
# 7  2007-12-31T05:41:31Z   22.131038     63284         1476             0
# 8  2010-01-05T20:50:53Z   21.913305    100326         4033             0
# 9  2009-11-15T20:53:54Z   18.271826    140694         3541             0
#
#   commentCount
# 0        78889
# 1        54359
# 2         6101
# 3         6112
# 4         9240
# 5        10483
# 6         2468
# 7         2699
# 8         3688
# 9         4088

# %%
acessos_agora = str('7,098,687,247'.replace(',',''))
acessos_antes = str('7,095,318,400'.replace(',',''))
acessos = int(acessos_agora) - int(acessos_antes)
print ("1 dia de acesso:", '{:,d}'.format(acessos))

# %%
plot_mapa_df(dfdata[:8], name, 'por Milhões', "RdBu")

# %%
qr = name = 'Michael Jackson'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head(10)
# Out:
# Vídeos de Michael Jackson, em 2021-09-23 12:07:33
# Total de Acessos (50 vídeos mais vistos), de Michael Jackson :  15,108,500,816
#           v_id                                            v_title  \
# 0  OPf0YbXqDm0  Mark Ronson - Uptown Funk (Official Video) ft....
# 1  Zi_XLOBDo_Y     Michael Jackson - Billie Jean (Official Video)
# 2  QNJL6nfu__Q  Michael Jackson - They Don’t Care About Us (Br...
# 3  sOnqjkJTMaA        Michael Jackson - Thriller (Official Video)
# 4  oRdxUFDoQe0         Michael Jackson - Beat It (Official Video)
# 5  h_D3VFfhvs4  Michael Jackson - Smooth Criminal (Official Vi...
# 6  LeiFF0gvqcc  Michael Jackson - Remember The Time (Official ...
# 7  HzZ_urpj4As  Michael Jackson - The Way You Make Me Feel (Of...
# 8  dsUXAEzaC3Q          Michael Jackson - Bad (Shortened Version)
# 9  F2AitTPI5U0  Michael Jackson - Black Or White (Official Vid...
#
#                    date    viewCount likeCount dislikeCount favoriteCount  \
# 0  2014-11-19T14:00:18Z  4300.346469  17384838       976764             0
# 1  2009-10-03T04:44:09Z  1059.883868   7221498       215781             0
# 2  2009-10-03T04:50:06Z   854.081250   6937465       215179             0
# 3  2009-10-03T06:51:49Z   788.373065   5430658       285221             0
# 4  2011-04-11T10:13:33Z   751.624997   4887398       159291             0
# 5  2010-11-19T11:39:43Z   602.903605   6137711       191686             0
# 6  2009-10-03T04:54:19Z   434.259558   2534728       113123             0
# 7  2009-10-03T04:48:18Z   396.662762   2136355        69045             0
# 8  2009-10-03T20:55:06Z   382.059534   2383846        69356             0
# 9  2009-10-03T06:10:38Z   377.145775   2323992        78664             0
#
#   commentCount
# 0       576511
# 1       461936
# 2       304680
# 3       411734
# 4       220709
# 5       378469
# 6       114849
# 7        86851
# 8       124219
# 9        94519

# %%
plot_mapa_df(dfdata[:8], name, 'por Milhões', "RdBu")

# %% [markdown]
# ## Beyoncé

# %%
qr = "beyonce"
regionCode="BR"
language='BR'

# %% [markdown]
# ## Winderson Nunes x Kéfera

# %%
qr = "whinderssonnunes"
dfw = get_youtube_data(qr)
dfw.likeCount = dfw.likeCount.fillna(0)
dfw.viewCount = dfw.viewCount.fillna(0)
dfw.viewCount = dfw.viewCount.astype(np.int64)
dfw["viewCountMilion"] = dfw["viewCount"] / 1000000
dfw = dfw.sort_values(by="viewCountMilion", ascending=False)
dfw.head()

# %%
qr1 = "5incominutos"
qr = "@Kefera"
dfk = get_youtube_data(qr)
dfk.likeCount = dfk.likeCount.fillna(0)
dfk.viewCount = dfk.viewCount.fillna(0)
dfk.viewCount = dfk.viewCount.astype(np.int64)
dfk["viewCountMilion"] = dfk["viewCount"] / 1000000
dfk = dfk.sort_values(by="viewCountMilion", ascending=False)
dfk.head()

# %% [markdown]
# ## Plotagem de gráfico comparativo

# %%
def plot_grafico_comparativo(dfdata1, dfdata2, name1, name2, medida, cor1, cor2):
    data_hoje = data_agora()
    l_num_videos = [x+1 for x in (range(50))] 
    plt.figure(figsize=(16,8))
    plt.style.use('ggplot')
    ax = sns.pointplot(x=l_num_videos, y="viewCountMilion", data=dfdata1, color=cor1)
    sns.pointplot(x=l_num_videos, y="viewCountMilion", data=dfdata2, ax=ax, color=cor2)
    ax.legend(handles=ax.lines[::len(dfdata1)+1], labels=[name1,name2])
    ax.axes.set_title("Visualizações: " + name1 + ' x ' + name2 + ", em "+ data_hoje + ' (' + medida + ')',fontsize=20)
    ax.set_xlabel("Vídeos",fontsize=10)
    ax.set_ylabel("Visualizações"+  ' (' + medida + ')',fontsize=10)
    ax.tick_params(labelsize=12)
    ax.set_xticklabels(range(1,51,1),rotation=0 )
    plt.show()

# %%
plot_grafico_comparativo(dfw, dfk, 'WindersonNunes', 'Kéfera', 'Milhões', 'Green', 'Blue' )

# %% [markdown]
# ### Beyonce X Rihanna

# %%
qr = "Beyonce"
df1 = get_youtube_data(qr)
df1.likeCount = df1.likeCount.fillna(0)
df1.viewCount = df1.viewCount.fillna(0)
df1.viewCount = df1.viewCount.astype(np.int64)
df1["viewCountMilion"] = df1["viewCount"] / 1000000
df1 = df1.sort_values(by="viewCountMilion", ascending=False)
df1.head()
# Out:
#           v_id                                            v_title  \
# 0  lWA2pjMjpBs                                 Rihanna - Diamonds
# 1  YykjpeuMNEk   Coldplay - Hymn For The Weekend (Official Video)
# 2  bnVUHWCynig                                     Beyoncé - Halo
# 3  4m1EFMoRFvY  Beyoncé - Single Ladies (Put a Ring on It) (Vi...
# 4  p1JPKLa-Ofc       Beyoncé - Drunk in Love (Explicit) ft. JAY Z
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2012-11-09T00:18:50Z  1801352063   8659172       367427             0
# 1  2016-01-29T15:00:38Z  1528065874   9954208       261026             0
# 2  2009-10-03T20:59:40Z  1202077608   6009996       196062             0
# 3  2009-10-03T04:53:50Z   836993178   3340306       156824             0
# 4  2013-12-16T17:00:03Z   624795150   2576520       200575             0
#
#   commentCount  viewCountMilion
# 0       375755      1801.352063
# 1       324209      1528.065874
# 2       191475      1202.077608
# 3       141471       836.993178
# 4       122840       624.795150

# %%
qr = "Rihanna"
df2 = get_youtube_data(qr)
df2.likeCount = df2.likeCount.fillna(0)
df2.viewCount = df2.viewCount.fillna(0)
df2.viewCount = df2.viewCount.astype(np.int64)
df2["viewCountMilion"] = df2["viewCount"] / 1000000
df2 = df2.sort_values(by="viewCountMilion", ascending=False)
df2.head()
# Out:
#           v_id                                            v_title  \
# 0  kOkQ4T5WO9E  Calvin Harris - This Is What You Came For (Off...
# 1  5GL9JoH4Sws  Fifth Harmony - Work from Home (Official Video...
# 2  uelHwf8o7_U          Eminem - Love The Way You Lie ft. Rihanna
# 3  lWA2pjMjpBs                                 Rihanna - Diamonds
# 4  HL1UzIK-flA                Rihanna - Work (Explicit) ft. Drake
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2016-06-17T04:01:00Z  2512593574   9780215       529961             0
# 1  2016-02-26T12:05:00Z  2493449610  10711433       635732             0
# 2  2010-08-05T19:09:46Z  2284539453  11068349       376542             0
# 3  2012-11-09T00:18:50Z  1801352063   8659172       367427             0
# 4  2016-02-22T17:00:00Z  1220556328   7209532       609242             0
#
#   commentCount  viewCountMilion
# 0       311696      2512.593574
# 1       469817      2493.449610
# 2       584397      2284.539453
# 3       375755      1801.352063
# 4       389740      1220.556328

# %%
plot_grafico_comparativo(df1, df2, 'Beyoncé', 'Rihanna', 'Milhões', 'Green', 'Blue' )

# %%
qr = name = 'Anitta'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head(10)
# Out:
# Vídeos de Anitta, em 2021-09-23 12:08:58
# Total de Acessos (50 vídeos mais vistos), de Anitta :  10,138,144,050
#           v_id                                            v_title  \
# 0  UrT0zCmsN8c   Simone &amp; Simaria - Loka (Ao Vivo) ft. Anitta
# 1  wlS6Ix7mA0w  Anitta &amp; J Balvin - Downtown [Official Mus...
# 2  omzk3klIy0E  Major Lazer - Sua Cara (Feat. Anitta &amp; Pab...
# 3  Xp-dKdSUuLk  Nego do Borel - Você Partiu Meu Coração ft. An...
# 4  kDhptBT_-VI  Anitta, Mc Zaac, Maejor feat. Tropkillaz &amp;...
# 5  UGov-KH7hkM               Anitta - Bang (Official Music Video)
# 6  7Yrghfw1eNo  Anitta feat. Maluma - Sim Ou Não (Official Mus...
# 7  -73pafJ9RFg          Anitta - Paradinha [Official Music Video]
# 8  wzKL-bQKcgA  Anitta &amp; J Balvin - Downtown (Official Lyr...
# 9  O65FBF9RamQ  Anitta &amp; Kevinho - Terremoto [Official Mus...
#
#                    date   viewCount likeCount dislikeCount favoriteCount  \
# 0  2017-01-06T13:00:03Z  703.249763   3748097       313097             0
# 1  2017-11-20T16:00:30Z  579.440714   3953820       199858             0
# 2  2017-07-30T20:00:23Z  534.540233   4843385       462650             0
# 3  2017-02-19T15:00:03Z  465.756181   2849722       259557             0
# 4  2017-12-18T14:09:13Z  419.358917   4049598       668893             0
# 5  2015-10-09T21:43:33Z  412.493489   2396971       386614             0
# 6  2016-07-27T20:00:16Z  402.860807   2324347       170039             0
# 7  2017-05-31T15:00:05Z  366.916828   2696827       258636             0
# 8  2017-12-14T18:30:08Z  339.884104   3526023       127437             0
# 9  2019-02-01T14:00:07Z  313.658179   2646319       295587             0
#
#   commentCount
# 0       168227
# 1       143652
# 2       321829
# 3        68508
# 4       263850
# 5       172943
# 6       123914
# 7       120448
# 8       129082
# 9       110021

# %%
plot_mapa_df(dfdata[:5], name, 'por Milhões', "RdBu")

# %%
qr = name = 'Wesley Safadão'
name = 'Gabriel Diniz'
dfdata = get_youtube_data(name)
numAcessosAtual =  dfdata.viewCount.astype(int).sum()
dfdata.viewCount =  dfdata.viewCount.astype(int) / 1000000
print("Vídeos de " + name + ", em "+ data_agora())
print('Total de Acessos (50 vídeos mais vistos), de', name,': ', '{:,d}'.format(numAcessosAtual))
dfdata.head(10)

# %%
plot_mapa_df(dfdata[:5], name, 'por Milhões', "RdBu")

# %% [markdown]
# # Os 50 Vídeos mais Vistos do Mundo - Youtube

# %%
qr = name = ""
df2 = get_youtube_data(qr)
df2.likeCount = df2.likeCount.fillna(0)
df2.viewCount = df2.viewCount.fillna(0)
df2.viewCount = df2.viewCount.astype(np.int64)
df2["viewCountMilion"] = df2["viewCount"] / 1000000
df2["viewCountTrilion"] = df2["viewCount"] / 1000000000
df2 = df2.sort_values(by="viewCountMilion", ascending=False)
df2.head()
# Out:
#           v_id                                            v_title  \
# 0  TyYENgVUNyE  Avengers Infinity War 2018 ( Infinito ) - Dubl...
# 1  1YwBaOIqZCk  Lux mudou, Lux agora é Botanicals | Sabonete l...
# 2  _QIdWcUoOpc                   Minecraft: TOM E JERRY - O FILME
# 3  WRWtuJoVGW4  Funny Story about Hairstyles 💈 Pretend Play wi...
# 4  Q42BgGVAO0Q  SANTEE | Glenn Ford | Michael Burns | Full Len...
#
#                    date  viewCount likeCount dislikeCount favoriteCount  \
# 0  2018-04-14T16:09:00Z   18949346     57863        38262             0
# 1  2018-07-18T21:12:21Z   17375375       595          259             0
# 2  2018-01-21T17:30:00Z   10771532     66104        11170             0
# 3  2021-09-08T05:59:52Z    7829882         0          NaN             0
# 4  2019-01-14T15:45:01Z    7051510     31283         4201             0
#
#   commentCount  viewCountMilion  viewCountTrilion
# 0         1433        18.949346          0.018949
# 1           55        17.375375          0.017375
# 2         1365        10.771532          0.010772
# 3            0         7.829882          0.007830
# 4          377         7.051510          0.007052

# %%
plot_mapa_df(df2[:15], name, 'Trilhões', "RdYlBu_r")

# %%
print('Vídeos mais vistos no Youtube, em', data_agora())
df2.loc[:, ['date', 'v_title', 'viewCountTrilion']]
# Out:
# Vídeos mais vistos no Youtube, em 2021-09-23 12:10:42
#                     date                                            v_title  \
# 0   2018-04-14T16:09:00Z  Avengers Infinity War 2018 ( Infinito ) - Dubl...
# 1   2018-07-18T21:12:21Z  Lux mudou, Lux agora é Botanicals | Sabonete l...
# 2   2018-01-21T17:30:00Z                   Minecraft: TOM E JERRY - O FILME
# 3   2021-09-08T05:59:52Z  Funny Story about Hairstyles 💈 Pretend Play wi...
# 4   2019-01-14T15:45:01Z  SANTEE | Glenn Ford | Michael Burns | Full Len...
# 5   2016-02-23T06:11:44Z  Patna Se Pakistan - पटना से पाकिस्तान - Bhojpu...
# 6   2018-06-17T22:33:43Z               ESCOLA DE HERÓIS - MINECRAFT O FILME
# 7   2018-05-15T14:15:01Z  SILENT THUNDER | BONANZA | Dan Blocker | Lorne...
# 8   2021-09-22T13:59:24Z                        Can YOU Fix Climate Change?
# 9   2021-06-14T06:35:58Z  全新Huggies Dry Pants – 采用Dry Xpert分流通道科技，是马来西亚吸...
# 10  2021-03-15T18:12:08Z                Range: SPK - Barretta Bar - Scooter
# 11  2011-04-08T13:19:06Z  Mazha Navra Tujhi Baiko (माझा नवरा तुझी बायको ...
# 12  2018-08-17T14:45:00Z  SANTEE [Glenn Ford] [Full Western Movie] [Engl...
# 13  2021-09-22T21:20:48Z  I Surprised My Girlfriend With A $10,000,000 C...
# 14  2021-09-21T09:59:53Z  JURASSIC WORLD EVOLUTION Scorpius Rex Pink Vel...
# 15  2021-09-22T23:59:24Z  DON OMAR ❌ RESIDENTE | FLOW HP 🦍 ( Official Vi...
# 16  2021-09-21T13:18:50Z  GENIUS SCHOOL HACKS || Colorful Parenting Hack...
# 17  2021-09-23T00:00:12Z  HIGHLIGHTS | Arsenal vs AFC Wimbledon (3-0) | ...
# 19  2021-07-09T21:57:23Z                       TUDO PRETO E BRANCO! #shorts
# 21  2016-05-04T18:08:55Z                    O Escorpião Escarlate - O Filme
# 20  2019-11-18T23:58:29Z                               Argentina vs Uruguay
# 22  2021-09-23T02:26:43Z  Bryan Danielson vs Kenny Omega, A Dream Match ...
# 23  2021-09-22T21:54:41Z  Milan 2-0 Venezia | Milan continue their posit...
# 24  2021-07-26T12:09:44Z  TESTE DA TESOURA! SERÁ QUE CORTA CABELO OU NÃO...
# 25  2021-06-03T08:44:31Z                       3M 스카치브라이트™ 더블액션 플러스 물걸레 청소포
# 26  2021-09-22T07:30:12Z  [단독샷캠] 리사 &#39;LALISA&#39; 단독샷 별도녹화│LISA ONE T...
# 27  2021-09-22T13:00:25Z          Roll Up To The PartyㅣStick TogetherㅣEP. 3
# 30  2021-09-23T11:00:21Z                         *NEW* UGLY Mod in Among Us
# 28  2021-09-23T01:04:05Z  Tucker: Why would Biden do this to his own cou...
# 29  2021-09-21T14:25:16Z  Satisfying Video l How To Make Lollipop Candy ...
# 31  2021-04-06T10:08:22Z  Медзнат - сучасний медичний портал для фахівці...
# 37  2021-09-23T03:50:01Z  Aging Politicians And Meat Eaters Stand In The...
# 32  2019-07-20T13:33:46Z  Маnсhеѕtеr Unіtеd vs Ιntеr Milаn 1-0 Highlight...
# 34  2021-09-22T19:00:00Z     Britney vs Spears | Official Trailer | Netflix
# 33  2021-09-23T01:00:09Z  Sen. Bernie Sanders Takes on Fossil Fuel Lobby...
# 35  2021-09-10T17:01:08Z  FRANCE 24 English – LIVE – International Break...
# 36  2020-12-19T11:13:21Z     ট্রেনের সঙ্গে বাসের ধাক্কা, প্রাণ গেলো ১২ জনের
# 42  2021-09-23T12:32:56Z  Maha Samudram Trailer | 4K | Sharwanand,Siddha...
# 38  2019-02-15T13:00:02Z  🎥 RALPH BREAKS THE INTERNET - Wreck-It Ralph 2...
# 39  2021-09-23T01:21:06Z  Nick Diaz on UFC 266 return, fighting Robbie L...
# 40  2021-05-25T14:59:35Z              DESAFIO DA CANETA | PAPELARIA #shorts
# 48  2021-09-23T04:07:43Z  Gutfeld: Politico confirms Hunter Biden laptop...
# 41  2021-09-22T16:00:01Z           Night Teeth | Official Trailer | Netflix
# 49  2021-09-23T03:45:52Z  NBC Nightly News Full Broadcast - September 22...
# 43  2021-09-23T01:27:42Z   The *RANDOM* BOSS Challenge! (Fortnite Season 8)
# 44  2018-10-18T09:00:01Z  SIMBA REI LEÃO | Episódio 2 | Português | Simb...
# 47  2021-09-22T16:00:04Z      i dont cook i dont clean | Kitchen Nightmares
# 45  2021-07-15T00:40:19Z           CANETA DO CAIO CASTRO! CIS SPIRO #SHORTS
# 46  2018-04-03T09:05:21Z  Lokomoschine | A Short Film by Ulrike Schulz A...
# 18  2018-07-11T12:59:08Z                      G Funk | Official Documentary
#
#     viewCountTrilion
# 0           0.018949
# 1           0.017375
# 2           0.010772
# 3           0.007830
# 4           0.007052
# 5           0.005944
# 6           0.004782
# 7           0.004037
# 8           0.003318
# 9           0.003145
# 10          0.002581
# 11          0.002066
# 12          0.002027
# 13          0.001800
# 14          0.001560
# 15          0.001387
# 16          0.001318
# 17          0.001191
# 19          0.001053
# 21          0.001000
# 20          0.000998
# 22          0.000992
# 23          0.000967
# 24          0.000913
# 25          0.000826
# 26          0.000783
# 27          0.000773
# 30          0.000733
# 28          0.000717
# 29          0.000714
# 31          0.000612
# 37          0.000606
# 32          0.000590
# 34          0.000576
# 33          0.000576
# 35          0.000553
# 36          0.000552
# 42          0.000481
# 38          0.000471
# 39          0.000448
# 40          0.000443
# 48          0.000404
# 41          0.000404
# 49          0.000378
# 43          0.000374
# 44          0.000365
# 47          0.000354
# 45          0.000353
# 46          0.000351
# 18          0.000000

# %%
# procurar 1 cantora
cantora = 'beyoncé'
df2.loc[  df2['v_title'].apply(lambda w : w.lower()).str.contains(cantora) ]
# Out:
# Empty DataFrame
# Columns: [v_id, v_title, date, viewCount, likeCount, dislikeCount, favoriteCount, commentCount, viewCountMilion, viewCountTrilion]
# Index: []

# %%
cantora = 'rihanna'
df2.loc[  df2['v_title'].apply(lambda w : w.lower()).str.contains(cantora) ]
# Out:
# Empty DataFrame
# Columns: [v_id, v_title, date, viewCount, likeCount, dislikeCount, favoriteCount, commentCount, viewCountMilion, viewCountTrilion]
# Index: []
