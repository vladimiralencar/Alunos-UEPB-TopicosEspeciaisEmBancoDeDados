# %% [markdown]
# # Análise de Mídias Sociais: Twitter

# %% [markdown]
# Para autenticar no twitter, temos que criar uma conta e accessar: <br />
# http://twitter.com/apps/ <br />
# Gerar as chaves de autenticação, ex:<br />
# CONSUMER_KEY = 'Riew8e4LKVoEJ51HbeOm6wsYA' <br />
# CONSUMER_SECRET = '3pPE1z3kTJGQiY93yCqgLUTURJO2wOcoQCcMbyMbCj4Gm9Hc6N' <br />
# OAUTH_TOKEN = '2904474861-kdalTd2NVus3q0PdvAiD3gB2IlF9IFZzao01ol7' <br />
# OAUTH_TOKEN_SECRET = '2yHMlMAEUZflpw5swYaLA8EjFyPyPJWnJT84VJoAHDKCU' <br />

# %% [markdown]
# ## Modulo para autenticação no twitter

# %%
#!pip install twitter

# %%
import twitter

def oauth_login():
    # XXX: Go to http://twitter.com/apps/new to create an app and get values
    # for these credentials that you'll need to provide in place of these
    # empty string values that are defined as placeholders.
    # See https://dev.twitter.com/docs/auth/oauth for more information 
    # on Twitter's OAuth implementation.
    
    CONSUMER_KEY = 'ZQ9kvzCwoOhkP3db5nZCuqqME'
    CONSUMER_SECRET = 'z3Zvk1GXmvIajH7XqvCYwQ4fo239C70C2FhHDzSF1STMhXFlQN'
    OAUTH_TOKEN = '2904474861-VhrCBeIPSiN4zhEX5WiqBiMIqjL6Ud87kqMqpEF'
    OAUTH_TOKEN_SECRET = 'c3myFUsxGKeS2QJTWrNQpFYkEg6iDpsBROSSczkJEQY6U'
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# Sample usage
twitter_api = oauth_login()    

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print (twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7fb101470370>

# %% [markdown]
# ## Módulo para buscar tweets, dado uma palavra

# %%
def twitter_search(twitter_api, q, max_results=1000, **kw):  #max_results=200

    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets and 
    # https://dev.twitter.com/docs/using-search for details on advanced 
    # search criteria that may be useful for keyword arguments
    
    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets    
    search_results = twitter_api.search.tweets(q=q, count=1000, **kw)   # count=100
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval. See
    # https://dev.twitter.com/docs/rate-limiting/1.1/limits
    # for details. A reasonable number of results is ~1000, although
    # that number of results may not exist for all queries.
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses

# %% [markdown]
# ## Salvando/Recuperando no MongoDB

# %%
#!pip install pymongo

# %%
import json
import pymongo # pip install pymongo


def save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw):
    
    # Connects to the MongoDB server running on 
    # localhost:27017 by default
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    
    # Get a reference to a particular database
    
    db = client[mongo_db]
    
    # Reference a particular collection in the database
    
    coll = db[mongo_db_coll]
    
    # Perform a bulk insert and  return the IDs
    
    return coll.insert_many(data)

def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
                    criteria=None, projection=None, **mongo_conn_kw):
    
    # Optionally, use criteria and projection to limit the data that is 
    # returned as documented in 
    # http://docs.mongodb.org/manual/reference/method/db.collection.find/
    
    # Consider leveraging MongoDB's aggregations framework for more 
    # sophisticated queries.
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    db = client[mongo_db]
    coll = db[mongo_db_coll]
    
    if criteria is None:
        criteria = {}
    
    if projection is None:
        cursor = coll.find(criteria)
    else:
        cursor = coll.find(criteria, projection)

    # Returning a cursor is recommended for large amounts of data
    
    if return_cursor:
        return cursor
    else:
        return [ item for item in cursor ]

# %% [markdown]
# ## Capturando tweets

# %%
q = 'brasil'
result = twitter_search(twitter_api, q, max_results=1000)
type(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     340         try:
# --> 341             handle = urllib_request.urlopen(req, **kwargs)
#     342             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 401: Authorization Required
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-9-ff201f9c6aff> in <module>
#       1 q = 'brasil'
# ----> 2 result = twitter_search(twitter_api, q, max_results=1000)
#       3 type(result)
#
# <ipython-input-4-046ac1693003> in twitter_search(twitter_api, q, max_results, **kw)
#       6
#       7     # See https://dev.twitter.com/docs/api/1.1/get/search/tweets
# ----> 8     search_results = twitter_api.search.tweets(q=q, count=1000, **kw)   # count=100
#       9
#      10     statuses = search_results['statuses']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/twitter/api.py in __call__(self, **kwargs)
#     332             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     333         else:
# --> 334             return self._handle_response(req, uri, arg_data, _timeout)
#     335
#     336     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     365                 return []
#     366             else:
# --> 367                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     368
#     369     def _handle_response_with_retry(self, req, uri, arg_data, _timeout=None):
#
# TwitterHTTPError: Twitter sent status 401 for URL: 1.1/search/tweets.json using parameters: (count=1000&oauth_consumer_key=ZQ9kvzCwoOhkP3db5nZCuqqME&oauth_nonce=12171050958154235897&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1602190355&oauth_token=2904474861-VhrCBeIPSiN4zhEX5WiqBiMIqjL6Ud87kqMqpEF&oauth_version=1.0&q=brasil&oauth_signature=GMW2g7OcQGEU0LSpGHrgo5LFlfE%3D)
# details: {'errors': [{'code': 89, 'message': 'Invalid or expired token.'}]}

# %%
result[1]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu May 10 14:20:22 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 994582925172727808,
#  'id_str': '994582925172727808',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'pt',
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': '11 de setembro e todo dia no Brasil ✌️',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Aug 05 01:34:27 +0000 2013',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'tudo posso naquele que me fortalece ✌️🙏',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 5784,
#   'follow_request_sent': False,
#   'followers_count': 905,
#   'following': False,
#   'friends_count': 631,
#   'geo_enabled': True,
#   'has_extended_profile': True,
#   'id': 1646600161,
#   'id_str': '1646600161',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'pt',
#   'listed_count': 1,
#   'location': 'dona wanda ',
#   'name': 'guilherme garrozi',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/468778625592860672/GKhWh18R.jpeg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/468778625592860672/GKhWh18R.jpeg',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1646600161/1524491538',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/994164294794215425/4Vv0EoBO_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/994164294794215425/4Vv0EoBO_normal.jpg',
#   'profile_link_color': '89C9FA',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'guigarrozii',
#   'statuses_count': 43883,
#   'time_zone': 'Mid-Atlantic',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -7200,
#   'verified': False}}

# %%
q = 'petrobras'

twitter_api = oauth_login()
results = []
for i in range(10):
    result = twitter_search(twitter_api, q, max_results=1000)
    print ('capturando ', len(result),' tweets...')
    results.extend(result) # junçao de 2 lstas
    #results += result
#print(type(result))
#print(type(results))
print("Numero de tweets capturados: ", len(results))

#results = twitter_search(twitter_api, q, max_results=1000)
#save_to_mongo(results, 'tweets', q)
# Out:
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  1100  tweets...
# capturando  799  tweets...
# Numero de tweets capturados:  10699

# %%
results[2]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu May 10 14:20:14 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#     'expanded_url': 'https://twitter.com/i/web/status/994582890607513601',
#     'indices': [116, 139],
#     'url': 'https://t.co/Knb5WdOZNV'}],
#   'user_mentions': [{'id': 241290841,
#     'id_str': '241290841',
#     'indices': [0, 14],
#     'name': 'Rafael Colling',
#     'screen_name': 'rafaelcolling'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 994582890607513601,
#  'id_str': '994582890607513601',
#  'in_reply_to_screen_name': 'rafaelcolling',
#  'in_reply_to_status_id': 994461364801425408,
#  'in_reply_to_status_id_str': '994461364801425408',
#  'in_reply_to_user_id': 241290841,
#  'in_reply_to_user_id_str': '241290841',
#  'is_quote_status': False,
#  'lang': 'pt',
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': '@rafaelcolling Ah mas o "petróleo é nosso," "tem que manter nas mãos do estado", "viva a Petrobrás",  "não podemos… https://t.co/Knb5WdOZNV',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Jun 11 04:25:06 +0000 2010',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Fulguras, ó Brasil, florão da América\nIluminado ao sol do novo mundo!',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 2208,
#   'follow_request_sent': False,
#   'followers_count': 119,
#   'following': False,
#   'friends_count': 284,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 154405407,
#   'id_str': '154405407',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'pt',
#   'listed_count': 1,
#   'location': 'Umuarama, Brasil',
#   'name': 'J. Roberto',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530190129768329216/BD61LJNi.jpeg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530190129768329216/BD61LJNi.jpeg',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/154405407/1520287941',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/543044382182502400/cldA-PQg_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/543044382182502400/cldA-PQg_normal.jpeg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'JairTetzlaff',
#   'statuses_count': 15099,
#   'time_zone': 'Mid-Atlantic',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -7200,
#   'verified': False}}

# %%
results[1]['created_at']
# Out:
# 'Thu May 10 14:21:52 +0000 2018'

# %%
results[1]['metadata']['iso_language_code']
# Out:
# 'pt'

# %%
len(results)
# Out:
# 10699

# %% [markdown]
# ## imprimindo tweets

# %%
i = 0
for tweet in results:
    print(tweet['place'], tweet['created_at'], ' >> ', tweet['text'] , " >> ", )
    i += 1
    if i > 10:
          break
# Out:
# None Thu May 10 14:21:54 +0000 2018  >>  RT @petrodobrasil: Guilherme Estrela, ex-diretor da @petrobras e um dos maiores lutadores pela soberania energética do Brasil, lê o manifes…  >>
# None Thu May 10 14:21:52 +0000 2018  >>  RT @noahshuster: Depois da Petrobras, Caixa, Correios, mais uma estatal dando resultado no governo do mordomo! https://t.co/ZM5NB6DaL8  >>
# None Thu May 10 14:20:14 +0000 2018  >>  @rafaelcolling Ah mas o "petróleo é nosso," "tem que manter nas mãos do estado", "viva a Petrobrás",  "não podemos… https://t.co/Knb5WdOZNV  >>
# None Thu May 10 14:20:03 +0000 2018  >>  @MichelTemer @petrobras Foi a única indicação que o Senhor acertou.  >>
# None Thu May 10 14:19:39 +0000 2018  >>  RT @ObsoL: "Com uma reportagem absolutamente unilateral , o Jornal Nacional festejou na terça-feira, 8, o lucro da Petrobras.
# O que a Globo…  >>
# None Thu May 10 14:18:31 +0000 2018  >>  RT @MarLoureiroTor: Falta pouco para a Petrobras voltar a ser a empresa mais valiosa da bolsa. Está prestes a recuperar o posto, atualmente…  >>
# None Thu May 10 14:18:14 +0000 2018  >>  RT @ObsoL: "Com uma reportagem absolutamente unilateral , o Jornal Nacional festejou na terça-feira, 8, o lucro da Petrobras.
# O que a Globo…  >>
# None Thu May 10 14:17:50 +0000 2018  >>  RT @ObsoL: "Com uma reportagem absolutamente unilateral , o Jornal Nacional festejou na terça-feira, 8, o lucro da Petrobras.
# O que a Globo…  >>
# {'id': 'd9d978b087a92583', 'url': 'https://api.twitter.com/1.1/geo/id/d9d978b087a92583.json', 'place_type': 'city', 'name': 'Belo Horizonte', 'full_name': 'Belo Horizonte, Brazil', 'country_code': 'BR', 'country': 'Brazil', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-44.062789, -20.059816], [-43.856856, -20.059816], [-43.856856, -19.777568], [-44.062789, -19.777568]]]}, 'attributes': {}} Thu May 10 14:17:47 +0000 2018  >>  @MichelTemer @petrobras Ok, mas continuamos com o combustível carissimo, resolva isso tbm.  >>
# None Thu May 10 14:17:38 +0000 2018  >>  @MichelTemer @petrobras Colocando impostos em cima fica fácil.gasolina a 5 paus  >>
# None Thu May 10 14:17:29 +0000 2018  >>  RT @dasilvabenedita: Eu e o meu amigo Luiz Sérgio em defesa da Petrobras. #OPetroleoédoBrasil https://t.co/THCyuHPKF3  >>

# %% [markdown]
# ## Nuvem de Palavras - tweet

# %% [markdown]
# ### Stopwords

# %%
# instalando o módulo de stopwords
#!pip install stop-words

# %%
from stop_words import get_stop_words
stop_words_english = get_stop_words('en')
#stop_words
stop_words_portugues = get_stop_words('pt')
#stop_words_portugues
stop_words = stop_words_english + stop_words_portugues
print(stop_words[:10])
print(stop_words[-10:])
print(len(stop_words_english))
print(len(stop_words_portugues))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and']
# ['tém', 'tínhamos', 'um', 'uma', 'você', 'vocês', 'vos', 'à', 'às', 'éramos']
# 174
# 203

# %%
#!pip install wordcloud

# %%
# nuvem de palavras
from wordcloud import WordCloud, STOPWORDS
import re

stext = ""
for tweet in results:
    if 'text' in tweet:
        stext = stext + tweet['text']
stext = stext.lower() # colocar para minúsculas

# retirando pontuações e outros caracteres não relevantes
stext = "".join([i for i in stext if ord(i)<128])
stext = stext.replace("http://","")
stext = stext.replace("https://","")
stext = stext.replace("https","")
stext = stext.replace(",","")
stext = stext.replace(".","")
stext = stext.replace("?","")
stext = stext.replace("!","")
stext = stext.replace("#","")
stext = stext.replace("@","")
stext = stext.replace("'","")
stext = stext.replace("-","")
stext = stext.replace("3","")
stext = stext.replace("&amp;","")
stext = stext.replace("|","")



# retirando as stopwords dos tweets
for word in stop_words:
    my_regex = r"\b(?=\w)" + re.escape(word) + r"\b(?!\w)"
    stext = re.sub(my_regex,"" ,stext)

print(len(stext))


# Generate a word cloud image
wordcloud = WordCloud().generate(stext)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(stext)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# 1119495

# %% [markdown]
# ## Estatistica de contagem de palavras

# %%
words = stext.split()

# %%
from collections import Counter

c = Counter(words)
#print (c.most_common()[:30])
most_common = c.most_common()[:40]

for i in most_common:
    print (i[0])
#for item in words:  #[words, screen_names, hashtags]:
#    c = Counter(item)
#    print (c.most_common()[:20]) # top 10
#    print
# Out:
# petrobras
# petrobrs
# bilhes
# brasil
# r$
# aps
# petrleo
# gasolina
# governo
# anos
# pt
# "
# campanha
# tambm
# mercado
# lucro
# lava
# contra
# privatizao
# valor
# ter
# cynaramenezes:
# defesa
# volta
# vamos
# soberania
# 15
# carmeioneto:
# nacional
# 200
# pessoas
# nicos
# riscos
# corremos
# barata
# dia
# est
# processo
# 18
# melhor

# %%
for i in range(15):
    print (c.popitem())
# Out:
# ('tco/dlmqcyimgu', 1)
# ('petro', 1)
# ('usam', 1)
# ('subsolo', 1)
# ('manifesrequiaopmdb', 1)
# ('tco/s4xh8s7wpvrt', 2)
# ('tco/thcyuhpkf', 1)
# ('quemariadorosario', 4)
# ('momariadorosario', 1)
# ('tco/jjlfeduzgart', 6)
# ('contrri', 6)
# ('rendimentos', 6)
# ('puto', 6)
# ('recebi', 6)
# ('pblica', 6)

# %% [markdown]
# ## colocando as palavras e suas frequencias do twitter num dataframe

# %%
import pandas as pd
df = pd.DataFrame(([word, freq] for word, freq in most_common), columns=['Word', 'Frequency'])
df[:25]
# Out:
#               Word  Frequency
# 0        petrobras       5390
# 1         petrobrs       1869
# 2           bilhes       1344
# 3           brasil       1305
# 4               r$       1260
# 5              aps       1186
# 6          petrleo       1046
# 7         gasolina       1011
# 8          governo        958
# 9             anos        949
# 10              pt        927
# 11               "        863
# 12        campanha        849
# 13           tambm        810
# 14         mercado        780
# 15           lucro        757
# 16            lava        741
# 17          contra        739
# 18      privatizao        720
# 19           valor        678
# 20             ter        655
# 21  cynaramenezes:        655
# 22          defesa        631
# 23           volta        613
# 24           vamos        611

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(15,10))
fig.add_subplot(1,1,1)

df2 = df[:25]

ax = sns.barplot(y='Word', x = 'Frequency', data=df2, palette="Set3" )
#sns.despine()
ax.set(xlabel='Tweets words frequency', ylabel='Word')
#ax.set(xticks=range(1, 9), xticklabels=list([10,20,30,40,50,60,70,80,90]))

#ax.set(xticklabels=list(range(0,90,10)))
#plt.figure(figsize=(20,10))

ax.axes.set_title("Tweets words frequency",fontsize=40)
ax.set_xlabel("Frequency",fontsize=26)
ax.set_ylabel("Word",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()

# %% [markdown]
# ## achar os países de onde foram gerados os tweets

# %%
place = []
for result in results:
    if 'place'in result and result['place']:
        place.append(result['place']['country'])
place = set(place)
print(len(place) )
print(place)
# Out:
# 4
# {'Brazil', 'Mexico', 'Argentina', 'Chile'}

# %%
# cidades
place = []
for result in results:
    if 'user'  in result:
        place.append(result['user']['location'])
location = set(place)
len(location)
# Out:
# 397

# %%
for i in range(15):
    print(location.pop())
# Out:
# Curvelo/MG - Brasil
# Rio de Janeiro
# Rio de Janeiro/RJ
# Rio de Janeiro / Brasil
# Rio de Janeiro Brasil
# Gainesville, FL
# SC
# Rio Grande do Sul
# Garibaldi/RS
# República de Curitiba
# Florianópolis - SC
# Ribeirão Preto - SP
# Manaus, Brasil
# Salvador, Bahia, Brasil

# %% [markdown]
# ## contar a ocorrencia de cada cidade

# %%
from collections import Counter

c = Counter(location)
#print(c)
cidades = c.items()

# %% [markdown]
# ## colocando as cidades, frequencia num dataframe e salvando no excel

# %%
import pandas as pd
df = pd.DataFrame(([cidade, freq] for cidade, freq in cidades), columns=['city', 'frequency'])

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('cidades.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
df[:15]
# Out:
#                            city  frequency
# 0                       Goiania          1
# 1                        BRAZIL          1
# 2                 Bahia, Brasil          1
# 3          Fortaleza-Ce, Brasil          1
# 4                     Recife/PE          1
# 5                 Curitiba - PR          1
# 6   mas cerca de lo que piensas          1
# 7                          Сайт          1
# 8                      Curitiba          1
# 9                         021 🌊          1
# 10                   Fortaleza           1
# 11          São Paulo Sp Brazil          1
# 12                  México D.F.          1
# 13         Mossoró, RN, Brasil.          1
# 14         Porto Alegre, Brasil          1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(15,10))
fig.add_subplot(1,1,1)

df2 = df[:25]

ax = sns.barplot(y='city', x = 'frequency', data=df2, palette="Set3" )
ax.set(xlabel='Tweets cities frequency', ylabel='cities')
ax.axes.set_title("Tweets cities frequency",fontsize=40)
ax.set_xlabel("frequency",fontsize=26)
ax.set_ylabel("cities",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()

# %% [markdown]
# ## Capturar tweets com coodenadas de lat, long para cidade

# %%
def captura_tweets_com_coordenadas(tweets):
    tweets_com_coordenadas = []
    for tweet in tweets:
        if tweet['place'] is not None:
            tweets_com_coordenadas.append(tweet)
    return (tweets_com_coordenadas)

# %%
tweets_com_coordenadas = captura_tweets_com_coordenadas(results)
print(len(tweets_com_coordenadas))
# Out:
# 107

# %%
len(tweets_com_coordenadas)/len(results) * 100
# Out:
# 1.0000934666791288

# %%
tweets_com_coordenadas[0]['place']['bounding_box']
# Out:
# {'coordinates': [[[-44.062789, -20.059816],
#    [-43.856856, -20.059816],
#    [-43.856856, -19.777568],
#    [-44.062789, -19.777568]]],
#  'type': 'Polygon'}

# %%
tweets_com_coordenadas[0]['place']['bounding_box']['coordinates']
# Out:
# [[[-44.062789, -20.059816],
#   [-43.856856, -20.059816],
#   [-43.856856, -19.777568],
#   [-44.062789, -19.777568]]]

# %%
tweets_com_coordenadas[0]['place']['bounding_box']['coordinates'][0][0]
# Out:
# [-44.062789, -20.059816]

# %%
def captura_coordenadas(tweets):
    coordenadas = []
    for tweet in tweets:
        coord = tweet['place']['bounding_box']['coordinates'][0][0]
        coordenadas.append(coord)
    return coordenadas

# %%
tweets_coordenadasXY = captura_coordenadas(tweets_com_coordenadas)
tweets_coordenadasXY[:5]
# Out:
# [[-44.062789, -20.059816],
#  [-100.421037, 25.4805381],
#  [-35.2911777, -5.897826],
#  [-42.182626, -22.934128],
#  [-58.5317922, -34.674453]]

# %%
len(tweets_com_coordenadas)
# Out:
# 107

# %%
latitudes_tweets =  [ y for x,y in tweets_coordenadasXY]
longitudes_tweets =  [ x for x,y in tweets_coordenadasXY]

# %%
coordenadas_distintas = set(latitudes_tweets)
len(coordenadas_distintas)
# Out:
# 10

# %%
latitudes_tweets[:5]
# Out:
# [-20.059816, 25.4805381, -5.897826, -22.934128, -34.674453]

# %%
longitudes_tweets[:5]
# Out:
# [-44.062789, -100.421037, -35.2911777, -42.182626, -58.5317922]

# %%
# !pwd

# %% [markdown]
# # Georeferenciar os tweets no mapa mundi

# %%
# !pip install folium

# %%
import folium
from folium.utilities import write_png

mapit = folium.Map(location=[30, 0], zoom_start=2)
for coord in tweets_coordenadasXY:
    folium.CircleMarker( location=[ coord[1], coord[0] ], radius=2).add_to( mapit ) 
                    # color='#0080bb', fill_color='#0080bb'

#png_str = write_png(mapit. .data())
#of = open('folium_map.png', 'w')
#of.write(png_str)
#of.close()

folium.Map.save(mapit, "index.html")
#import os
#cmd = 'cutycapt --url=file:///index.html --out=folium_map.png'
#os.system(cmd)

mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from IPython.display import Image 
Image(filename='index.png')

# %%
# !pip install reverse_geocoder
import reverse_geocoder as rg

#coordinates = (51.5214588,-0.1729636),(9.936033, 76.259952)
coordinates=(37.38605,-122.08385)
coordinates=(0.0,0.0)
results = rg.search(coordinates) # default mode = 2
print (results)
# Out:
# [OrderedDict([('lat', '4.88447'), ('lon', '-1.75536'), ('name', 'Takoradi'), ('admin1', 'Western'), ('admin2', ''), ('cc', 'GH')])]

# %%
import reverse_geocoder as rg

#coordinates = (-23.967967, -47.508358)
#cooordinates = (-8.157554, -35.019805 ), (-8.157554, -34.858893)
#cordinates = (-43.4161389,-22.8132778)
coordinates = (-22.8132778, -43.4161389)
results = rg.search(coordinates) # default mode = 2
print (results)
# Out:
# [OrderedDict([('lat', '-22.8075'), ('lon', '-43.41389'), ('name', 'Nilopolis'), ('admin1', 'Rio de Janeiro'), ('admin2', 'Nilopolis'), ('cc', 'BR')])]

# %% [markdown]
# # twitter trends - assuntos mais comentados do momento

# %%
import json
import twitter

# Acessar os tends da localidade
#http://woeid.rosselliot.co.nz/


def twitter_trends(twitter_api, woe_id):
    # Prefix ID with the underscore for query string parameterization.
    # Without the underscore, the twitter package appends the ID value
    # to the URL itself as a special-case keyword argument.
    return twitter_api.trends.place(_id=woe_id)

# Sample usage

twitter_api = oauth_login()

# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/ for details on
# Yahoo! Where On Earth ID

WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
#print json.dumps(world_trends, indent=1)

US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
#print (json.dumps(us_trends, indent=1))
#us_trends[0]

#for trend in us_trends:
#    print (trend['as_of']['name'])

# %%
def find_trends(country_trends):
    trends = country_trends[0]['trends']
    for trend in trends:
        print (trend['name'])

# %%
WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
print ("topicos mais comentados: Mundo")
find_trends(world_trends)
# Out:
# topicos mais comentados: Mundo
# #FelizDiaDeLasMadres
# #instagramdown
# #صافرات_الانذار
# #ThursdayThoughts
# エルレ
# #10May
# Arda Turan'a 16
# Fábio Koff
# Wayne Rooney
# Tun M
# Suzane Richthofen
# Etna
# Dolly
# Viggo Mortensen
# Gonzalo Feito
# David Goodall
# Mehmet Ekici
# 싱가포르
# #تتكلم_انجليري_او_لا
# #メイドの日
# #나의_공포증
# #BuenJueves
# #DeMamáAprendí
# #EuSouFeioMas
# #andsta
# #CelebrateWomen
# #ItStillAmazesMe
# #BackToYouTODAY
# #DDvSRH
# #EngellilerHaftası
# #HasretBittiGözyaşıDindi
# #emmnec
# #حزب_الي_حاملين_مواد
# #noPAG
# #HakkariTAMAM
# #ممثل_او_ممثله_يشد_انتبهاك
# #AntesDeMorrerEu
# #ConMiraDuquePresidente
# #M5SLega
# #100x100conPetro
# #Yas25Bedel15
# #VotaEquipoErrejón
# #TengoUnMásterEn
# #RenewB99
# #ComoDiceMiMamá
# #ÖzgüveniniKeşfet
# #QuintaDetremuraSDV
# #ElDoradoWorldTour
# #AbortoLegalJusticiaSocial
# #Bienvenidos13

# %%
US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
print ("topicos mais comentados: USA")
find_trends(us_trends)
# Out:
# topicos mais comentados: USA
# #ThursdayThoughts
# #ItStillAmazesMe
# #CelebrateWomen
# The Predator
# Wayne Rooney
# #instagramdown
# Kevin Kamenetz
# #FelizDiaDeLasMadres
# Yale
# George Will
# Nine Inch Nails
# Melvin
# Matt Patricia
# Monday Night Football
# Sheldon Adelson
# ECOT
# David Goodall
# Georgina Chapman
# Russian Facebook
# Kremlin-backed
# Town & Country
# Nike Air Max 98
# Leon Panetta
# Oh Joy Begin
# "Audio"
# #ReasonsIGotGrounded
# #NationalShrimpDay
# #FiscalSummit
# #TUGrad18
# #LessNoteworthyBooks
# #202Live
# #99UConf
# #GoodMorningSGF
# #LessIsMoreWhen
# #FTUSHealth
# #ActForWomen
# #Ascension
# #veteranshealth2018
# #UXPABOS18
# #CABANA
# #SFRC
# #Cullinan
# #RenewB99
# #HoCoDay
# #AM2DM
# #BCPSCIA
# #CapitalExchange
# #MGoPositive
# #BikeToWorkDay
# #DayofCaring

# %%
BR_WOE_ID = 23424768
br_trends = twitter_trends(twitter_api, BR_WOE_ID)
print ("topicos mais comentados: Brasil")
find_trends(br_trends)
# Out:
# topicos mais comentados: Brasil
# Fábio Koff
# #EuSouFeioMas
# Dolly
# Suzane Richthofen
# #BackToYouTODAY
# #AntesDeMorrerEu
# #QuintaDetremuraSDV
# O Instagram
# Urgh
# #Encontro
# Predador
# Gedoz
# Ataque de Israel
# Monitor da Violência
# IPCA
# Lúpus
# Ministério
# HOJE TEM CORINTHIANS
# "Solo"
# Operação Bravata
# Meghan Trainor
# Mané Garrincha
# Barricadas
# HOJE TEM FLAMENGO
# aeroporto santos dumont
# Padre Fábio de Melo
# Gremistas
# Dia D
# Míriam Leitão
# Celso Amorim
# Comitê
# Cientista David Goodall
# Ponte Estaiada
# TRF-4
# Sharapova
# Atos 16
# #Chape45Anos
# #VcNoBemEstar
# #RenewB99
# #Twice
# #FelizDiaDeLasMadres
# #ElDoradoWorldTour
# #diadeflu
# #bomdiafoxquinta
# #AutoEsporte
# #bbbomdia
# #AssociouBrocou
# #MaisVocê
# #BettEducar2018
# #Dreamcatcher

# %%
TM_WOE_ID = 23424968
tm_trends = twitter_trends(twitter_api, TM_WOE_ID)
print ("topicos mais comentados: Timor Leste")
find_trends(tm_trends)

# %%
TM_WOE_ID = 455827
tm_trends = twitter_trends(twitter_api, TM_WOE_ID)
print ("topicos mais comentados: São Paulo")
find_trends(tm_trends)
# Out:
# topicos mais comentados: São Paulo
# Fábio Koff
# #EuSouFeioMas
# Dolly
# Suzane Richthofen
# #BackToYouTODAY
# #AntesDeMorrerEu
# #QuintaDetremuraSDV
# O Instagram
# Urgh
# #Encontro
# Predador
# Gedoz
# Ataque de Israel
# Monitor da Violência
# IPCA
# Lúpus
# Ministério
# HOJE TEM CORINTHIANS
# "Solo"
# Operação Bravata
# Meghan Trainor
# Mané Garrincha
# Barricadas
# HOJE TEM FLAMENGO
# aeroporto santos dumont
# Padre Fábio de Melo
# Gremistas
# Dia D
# Míriam Leitão
# Celso Amorim
# Comitê
# Cientista David Goodall
# Ponte Estaiada
# TRF-4
# Sharapova
# Atos 16
# #Chape45Anos
# #VcNoBemEstar
# #RenewB99
# #Twice
# #FelizDiaDeLasMadres
# #ElDoradoWorldTour
# #diadeflu
# #bomdiafoxquinta
# #AutoEsporte
# #bbbomdia
# #AssociouBrocou
# #MaisVocê
# #BettEducar2018
# #Dreamcatcher

# %% [markdown]
# # Análise de Sentimentos - Tweets

# %%
#!pip install textblob

# %%
#!pip install googletrans

# %%
# googletrans token
from googletrans.gtoken import TokenAcquirer
acquirer = TokenAcquirer()
text = 'test'
tk = acquirer.do(text)
tk
# Out:
# '456517.32898'

# %%
from googletrans import Translator
translator = Translator()
translator.translate('oi, tudo bem', src='pt').text
# Out:
# 'Hello all well'

# %%
from textblob import TextBlob as tb #NLP module
import numpy as np #for some calculation. You may want to use your favorite module for this, such as statistics

# polatidade de tweets em ingles e portugues
def polarity_tweets_pais(query):
    from googletrans import Translator
    
    translator = Translator() # google tradutor

    twitter_api = oauth_login()
    numero_iteracoes = 1
    results = []
    for i in range(numero_iteracoes):
        max_results = 500 # 1000
        result = twitter_search(twitter_api, query, max_results=max_results)
        print ('capturando ', len(result),' tweets...')
        #results.append(result)
        results += result

    analysis = None
    pos_polarity = 0
    neutral_polarity = 0
    neg_polarity = 0
    sum_polarity = 0
    print("calculando polaridades...")

    for tweet in results:
        text_tweet = tweet['text']
        
        # retirando caracteres malucos
        text_tweet = "".join([i for i in text_tweet if ord(i)<128])
        
        frase = tb(text_tweet)       
        language = tweet['lang'] #frase.detect_language()
        if language == 'br' or language == 'pt' :
            text_en = translator.translate(text_tweet, src='pt').text  
            analysis = tb(text_en)
        elif language == 'en':   
            analysis = frase
        else:
            analysis = ""
            
        if analysis != "": 
            if (analysis.sentiment.polarity > 0):
                pos_polarity += 1
            elif (analysis.sentiment.polarity <= 0):
                neg_polarity += 1
            sum_polarity += analysis.sentiment.polarity

    return sum_polarity, pos_polarity, neg_polarity, neutral_polarity

# %%
q = 'tesla'
q = 'lula'

"""
mean_polarity, pos_polarity, neg_polarity, neutral_polarity = polarity_tweets_pais(q)
total = pos_polarity + neg_polarity + neutral_polarity 
print('SENTIMENT AVERAGE: ' , mean_polarity/total)
print('Positive: ', pos_polarity, (pos_polarity/total) * 100)
print('Negative: ', neg_polarity, (neg_polarity/total) * 100)
print('neutral: ', neutral_polarity, (neutral_polarity/total) * 100
"""

# %%
import pandas as pd
df = pd.DataFrame(columns=['name', 'pos', 'negative', 'sentiment_avg'])
queries = [ 'tesla', 'facebook', 'trump', 'china', 'brazil', 'brasil', 'lula', 'sergio moro', 'temer', 'stf', 'stj']

queries = ['Suzane Richthofen', 'CORINTHIANS']
for q in queries:
    mean_polarity, pos_polarity, neg_polarity, neutral_polarity = polarity_tweets_pais(q)
    total = pos_polarity + neg_polarity + neutral_polarity 
    print('Query: ', q)
    print('SENTIMENT AVERAGE: ' , mean_polarity/total)
    print('Positive: ', pos_polarity, (pos_polarity/total) * 100)
    print('Negative: ', neg_polarity, (neg_polarity/total) * 100)
    print('neutral: ', neutral_polarity, (neutral_polarity/total) * 100)
    print('----------------------------------------------')
    
    i = len(df)
    df.loc[i] = [q, pos_polarity, neg_polarity, mean_polarity/total]
df
# Out:
# capturando  200  tweets...
# calculando polaridades...
# Query:  Suzane Richthofen
# SENTIMENT AVERAGE:  -0.030610609628466776
# Positive:  23 11.73469387755102
# Negative:  173 88.26530612244898
# neutral:  0 0.0
# ----------------------------------------------
# capturando  600  tweets...
# calculando polaridades...
# Query:  CORINTHIANS
# SENTIMENT AVERAGE:  0.05477111439010686
# Positive:  161 27.150084317032043
# Negative:  432 72.84991568296796
# neutral:  0 0.0
# ----------------------------------------------
#                 name  pos negative  sentiment_avg
# 0  Suzane Richthofen   23      173      -0.030611
# 1        CORINTHIANS  161      432       0.054771

# %%
df["%pos"] = df.pos / (df.pos + df.negative)
df["%neg"] = df.negative / (df.pos + df.negative)
df["%pos"] = df["%pos"].apply(lambda x: int(round(x,1) * 100))
df["%neg"] = df["%neg"].apply(lambda x: int(round(x,1) * 100))
df.loc[:, ['name', "%pos", "%neg", 'sentiment_avg' ]]
# Out:
#                 name  %pos  %neg  sentiment_avg
# 0  Suzane Richthofen    10    90      -0.030611
# 1        CORINTHIANS    30    70       0.054771

# %% [markdown]
# ### gravando os dados do dataframe num arquivo .csv

# %%
from datetime import datetime
data_agora = str(datetime.now())
df.to_csv("sentimentos-"+ data_agora +".csv")

# %%
df.loc[:, ['name', "%pos", "%neg" ]]
# Out:
#                 name  %pos  %neg
# 0  Suzane Richthofen    10    90
# 1        CORINTHIANS    30    70

# %%
#!ls # lista a pasta

# %% [markdown]
# ### Testando as polaridades

# %%
txt = 'good'
analysis = tb(txt)
analysis.sentiment.polarity
# Out:
# 0.7

# %%
txt = 'bad girl in NY'
analysis = tb(txt)
analysis.sentiment.polarity
analysis.sentiment
# Out:
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)

# %%
txt = 'neutral'
analysis = tb(txt)
analysis.sentiment.polarity
# Out:
# 0.0

# %%
txt = 'péssimo'
tb_txt = tb(txt)
tb_txt.sentiment.polarity
txt = tb_txt.translate(to='en')
txt.sentiment.polarity
# Out:
# -1.0
