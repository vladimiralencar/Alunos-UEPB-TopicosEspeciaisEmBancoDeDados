# %% [markdown]
# # Análises de Mídias Sociais - Spotify

# %%
#!pip install spotipy

# %% [markdown]
# Acesse: https://beta.developer.spotify.com/dashboard/applications
# para criar o Client_ID e o Client_Secret

# %%
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import pandas as pd

def login_spotify():
    client_id = "da1effa23714436a93368fff6f869de2"
    client_secret = "b81bb02ba7e3494bbd9d28489f5a7b7f"

    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

# %%
sp = login_spotify()
sp

# %% [markdown]
# ## busca as músicas do artista

# %%
def search_musics_artist(sp,artist):

    results = sp.search(artist, limit=30)
    df = pd.DataFrame(columns=['artist','name', 'popularity', 'release_date'])
    for i, t in enumerate(results['tracks']['items']):
        df.loc[i] = [q, t['name'], t['popularity'], t['album']['release_date'] ]
        #print(' ', i, t['name'] , t['popularity'], t['album']['release_date']) # t['release_date']
    return df.sort_values('popularity', ascending=False)

sp = login_spotify()
q='beyonce'
df = search_musics_artist(sp,q)
df[:15]
# Out:
#      artist                                 name popularity release_date
# 0   beyonce  Perfect Duet (Ed Sheeran & Beyoncé)         90   2017-11-30
# 5   beyonce                              Top Off         85   2018-03-02
# 4   beyonce                                 Halo         81   2008-11-14
# 11  beyonce                        Crazy In Love         80   2003-06-24
# 9   beyonce                          Love On Top         78         2011
# 10  beyonce                        Irreplaceable         78   2007-05-29
# 14  beyonce                Run the World (Girls)         77         2011
# 2   beyonce                                 7/11         77   2014-11-24
# 7   beyonce                        Drunk in Love         76   2014-11-24
# 18  beyonce               Best Thing I Never Had         74         2011
# 6   beyonce                            Partition         74   2014-11-24
# 1   beyonce             Mi Gente (feat. Beyoncé)         73   2017-09-28
# 15  beyonce                      If I Were a Boy         72   2008-11-14
# 8   beyonce                       Flawless Remix         72   2014-11-24
# 3   beyonce        Walk On Water (feat. Beyoncé)         72   2017-12-15

# %%
#sp = login_spotify()
q='Rihanna'
df = search_musics_artist(sp,q)
df[:15]
# Out:
#      artist                            name popularity release_date
# 1   Rihanna             Lemon - Drake Remix         87   2018-03-18
# 17  Rihanna       This Is What You Came For         82   2016-04-29
# 7   Rihanna                           Lemon         81   2017-12-15
# 0   Rihanna         LOYALTY. FEAT. RIHANNA.         79   2017-04-14
# 5   Rihanna                   Wild Thoughts         78   2017-06-22
# 13  Rihanna                    Lemon - Edit         77   2017-12-06
# 4   Rihanna  Live Your Life (feat. Rihanna)         77   2008-09-08
# 2   Rihanna                       Needed Me         76   2016-01-28
# 19  Rihanna                 FourFiveSeconds         76   2015-01-24
# 9   Rihanna                         Selfish         76   2017-07-27
# 10  Rihanna            Love The Way You Lie         75   2010-06-18
# 3   Rihanna               Love On The Brain         75   2016-01-28
# 25  Rihanna                        Umbrella         74   2008-06-02
# 11  Rihanna                       Take Care         73   2011-11-15
# 12  Rihanna                            Work         73   2016-01-28

# %%
#sp = login_spotify()
q='Mariah Carey'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#           artist                             name popularity release_date
# 0   Mariah Carey               We Belong Together         73   2005-01-01
# 1   Mariah Carey                Always Be My Baby         72   1995-09-26
# 2   Mariah Carey                          Fantasy         69   1995-09-26
# 5   Mariah Carey  All I Want for Christmas Is You         69         1994
# 10  Mariah Carey                      Without You         69   1993-08-04
# 7   Mariah Carey                             Hero         67   1993-08-04
# 9   Mariah Carey             I Know What You Want         67   2002-01-01
# 16  Mariah Carey                    One Sweet Day         66   1995-09-26
# 3   Mariah Carey                         Obsessed         63   2009-01-01
# 4   Mariah Carey                    Touch My Body         62   2008-01-01

# %%
#sp = login_spotify()
q='Anitta'
df = search_musics_artist(sp,q)
df
# Out:
#     artist                                               name popularity  \
# 0   Anitta                                           Downtown         93
# 6   Anitta  Vai malandra (feat. Tropkillaz & DJ Yuri Martins)         86
# 1   Anitta                                            Machika         82
# 2   Anitta                                          Indecente         81
# 17  Anitta                         Coladinha em Mim - Ao Vivo         78
# 4   Anitta                                     Is That For Me         77
# 28  Anitta                         Coladinha em Mim - Ao Vivo         76
# 5   Anitta                                          Paradinha         74
# 15  Anitta                            Você Partiu Meu Coração         71
# 13  Anitta          Sim ou não (Participação especial Maluma)         69
# 11  Anitta                  Movimento da Sanfoninha - Ao Vivo         68
# 8   Anitta                        Is That For Me - 3LAU Remix         66
# 27  Anitta         Tic Nervoso (Participação Especial Anitta)         65
# 12  Anitta                                               Bang         64
# 7   Anitta                       Is That For Me (KO:YU Remix)         64
# 22  Anitta    Essa mina é louca (Participação especial Jhama)         63
# 3   Anitta                     Machika - Dillon Francis Remix         62
# 9   Anitta                                           Sua Cara         61
# 21  Anitta  Vai Malandra (feat. Tropkillaz & DJ Yuri Marti...         60
# 23  Anitta                                   Deixa Ele Sofrer         59
# 19  Anitta                                     Will I See You         59
# 10  Anitta                                             Switch         59
# 18  Anitta                             Sí o no (feat. Maluma)         58
# 16  Anitta                                 Show das Poderosas         58
# 20  Anitta                                    Meiga e Abusada         57
# 29  Anitta                                          Na Batida         57
# 25  Anitta                                           Não Para         54
# 26  Anitta                                         Tá na Mira         53
# 24  Anitta                                               Loka         45
# 14  Anitta                               Ginza - Anitta Remix         41
#
#    release_date
# 0    2017-11-19
# 6    2017-12-18
# 1    2018-01-19
# 2    2018-03-26
# 17   2017-12-22
# 4    2017-10-13
# 28   2017-12-01
# 5    2017-05-31
# 15   2017-01-10
# 13   2016-07-28
# 11   2014-06-03
# 8    2017-12-13
# 27   2017-12-04
# 12   2015-10-13
# 7    2017-12-13
# 22   2015-10-13
# 3    2018-03-30
# 9    2017-06-02
# 21   2018-03-23
# 23   2015-10-13
# 19   2017-09-03
# 10   2017-05-19
# 18   2016-12-09
# 16   2013-02-06
# 20   2013-02-06
# 29   2014-06-03
# 25   2013-02-06
# 26   2013-02-06
# 24   2017-11-17
# 14   2016-02-19

# %%
len(df)
# Out:
# 30

# %%
#sp = login_spotify()
q='Paralamas'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#        artist                     name popularity release_date
# 0   Paralamas     Aonde Quer Que Eu Vá         64         2000
# 2   Paralamas         Vital e Sua Moto         53         1983
# 1   Paralamas          Ela Disse Adeus         47         2000
# 5   Paralamas    Cuide Bem Do Seu Amor         44   2003-01-07
# 13  Paralamas                O Calibre         44   2003-01-07
# 7   Paralamas        Seguindo Estrelas         44   2003-01-07
# 9   Paralamas        Saber Amar - Live         43         2000
# 3   Paralamas  Caleidoscópio - Ao Vivo         42   2006-07-31
# 11  Paralamas                 Meu Erro         42         2004
# 15  Paralamas     Caleidoscópio - Live         41         1996

# %%
#sp = login_spotify()
q='Ivete Sangalo'
df = search_musics_artist(sp,q)
df[:5]
# Out:
#            artist                                name popularity release_date
# 0   Ivete Sangalo      Avisa Que Eu Cheguei - Ao Vivo         67   2017-07-28
# 11  Ivete Sangalo  A Mais Pedida - Ao Vivo | Acústico         61   2017-04-28
# 9   Ivete Sangalo                Avisa Que Eu Cheguei         60   2017-05-12
# 8   Ivete Sangalo                         Estaca Zero         56   2016-11-04
# 3   Ivete Sangalo                      Estar Com Você         55   2016-03-25

# %%
#sp = login_spotify()
q='Marilia Mendonca'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#               artist                          name popularity release_date
# 4   Marilia Mendonca                   Transplante         79   2017-11-14
# 13  Marilia Mendonca                A Culpa É Dele         77   2018-03-08
# 2   Marilia Mendonca  Amante Não Tem Lar - Ao Vivo         73   2017-03-06
# 7   Marilia Mendonca                      Estranho         73   2018-03-23
# 3   Marilia Mendonca  De Quem É a Culpa? - Ao Vivo         72   2017-03-06
# 15  Marilia Mendonca        Coração Mal Assombrado         71   2018-03-16
# 10  Marilia Mendonca                      Ausência         71   2018-03-14
# 22  Marilia Mendonca                     Um Brinde         71   2017-10-06
# 12  Marilia Mendonca            Ninguém É de Ferro         69   2017-02-08
# 0   Marilia Mendonca    Como Faz Com Ela - Ao Vivo         69   2016-03-04

# %% [markdown]
# ## Obter a musica mais popular de cada cantor/cantora

# %%
cantoras = ['Beyonce', 'Rihanna', 'Anitta', 'Marilia Mendonca', 'Ivete Sangalo', 'Claudia Leitte' ]
df = pd.DataFrame(columns=['artist','name', 'popularity', 'release_date'])
linha = 0
for artist in cantoras:
    popularidade = 0
    results = sp.search(artist, limit=30)
    for i, t in enumerate(results['tracks']['items']):
        if t['popularity'] > popularidade:
            musica_mais_popular = [artist, t['name'], t['popularity'], t['album']['release_date'] ]
            popularidade = t['popularity']
    df.loc[linha] = musica_mais_popular
    linha += 1   
df2 = df.sort_values('popularity', ascending=False)
df2
# Out:
#              artist                                               name  \
# 2            Anitta                                           Downtown
# 0           Beyonce                Perfect Duet (Ed Sheeran & Beyoncé)
# 1           Rihanna                                Lemon - Drake Remix
# 3  Marilia Mendonca                                        Transplante
# 4     Ivete Sangalo                     Avisa Que Eu Cheguei - Ao Vivo
# 5    Claudia Leitte  We Are One (Ole Ola) [The Official 2014 FIFA W...
#
#   popularity release_date
# 2         93   2017-11-19
# 0         90   2017-11-30
# 1         87   2018-03-18
# 3         79   2017-11-14
# 4         67   2017-07-28
# 5         60   2014-11-21

# %% [markdown]
# ## plota num gráfico

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(10,8))
fig.add_subplot(1,1,1)

ax = sns.barplot(y='artist', x = 'popularity', data=df2, palette="Set3" )

ax.axes.set_title("Best Popular Songs",fontsize=40)
ax.set_xlabel("Popularity",fontsize=26)
ax.set_ylabel("Artist",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()

# %% [markdown]
# ## Banda, Músicas

# %%
import spotipy
sp = login_spotify()

results = sp.search(q='weezer', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print (' ', i, t['name'])
# Out:
#   0 Island In The Sun
#   1 Say It Ain't So
#   2 Buddy Holly
#   3 Beverly Hills
#   4 Feels Like Summer
#   5 Hash Pipe
#   6 Undone - The Sweater Song
#   7 Happy Hour
#   8 Say It Ain't So
#   9 Thank God For Girls
#   10 Pork And Beans
#   11 My Name Is Jonas
#   12 Undone - The Sweater Song
#   13 Buddy Holly
#   14 Only In Dreams
#   15 My Name Is Jonas
#   16 Jacked Up
#   17 The World Has Turned And Left Me Here
#   18 In The Garage
#   19 King Of The World

# %% [markdown]
# ## Mostra todos os albuns de um cantor/cantora

# %%
import sys
import spotipy

''' shows the albums and tracks for a given artist.
'''

def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set() # to avoid dups
    albums.sort(key=lambda album:album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            print((' ' + name))
            seen.add(name)

if __name__ == '__main__':
    sp = login_spotify()

    name = 'Beyonce'
    artist = get_artist(name)
    if artist:
        print('Albuns de: ', name)
        show_artist_albums(artist)
    else:
        print("Can't find that artist")
# Out:
# Albuns de:  Beyonce
#  4
#  4: The Remix
#  Above And Beyoncé Dance Mixes
#  B'Day
#  B'Day Deluxe Edition
#  BEYONCÉ [Platinum Edition]
#  Dangerously In Love
#  Dangerously In Love (Alben für die Ewigkeit)
#  I AM...SASHA FIERCE
#  I AM...SASHA FIERCE - Platinum Edition
#  I AM...SASHA FIERCE NEW DELUXE EDITION
#  I Am...Tour Instrumentals
#  I Am...World Tour
#  The Beyonce Experience Live Audio

# %% [markdown]
# ## Obtém informações do Artista

# %%
def obter_informacoes(nome_artista):
    from PIL import Image
    from urllib.request import urlopen
    artista = get_artist(nome_artista)
    seguidores = artista['followers']['total']
    genero = artista['genres']
    foto_url = artista['images'][0]['url']
    popularidade = artista['popularity']
    uri = artista['uri']
    url_spotify = artista['external_urls']['spotify']
    print('Artista: ', artista['name'])
    print('Número de Seguidores: ', '{:,d}'.format(seguidores))
    print('Gênero: ', genero)
    print('Popularidade: ', popularidade)
    print('Spotify uri:', uri)
    print('Spotify url:',url_spotify)
    foto = Image.open(urlopen(foto_url))
    return foto #seguidores, genero, popularidade, foto_url, uri, url_spotify

nome_artista = 'Beyonce'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Beyoncé
# Número de Seguidores:  12,337,602
# Gênero:  ['dance pop', 'pop', 'post-teen pop', 'r&b']
# Popularidade:  89
# Spotify uri: spotify:artist:6vWDO969PvNqNYHIOW5v0m
# Spotify url: https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x1A12D87400>

# %%
nome_artista = 'Anitta'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Anitta
# Número de Seguidores:  4,763,156
# Gênero:  ['baile pop']
# Popularidade:  86
# Spotify uri: spotify:artist:7FNnA9vBm6EKceENgCGRMb
# Spotify url: https://open.spotify.com/artist/7FNnA9vBm6EKceENgCGRMb
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x10A482FD0>
