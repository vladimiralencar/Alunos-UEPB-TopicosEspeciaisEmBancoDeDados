# %% [markdown]
# # Análises de Mídias Sociais - Spotify

# %%
#!pip install spotipy

# %% [markdown]
# Acesse: https://beta.developer.spotify.com/dashboard/applications
# para criar o Client_ID e o Client_Secret

# %%
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import pandas as pd

def login_spotify():
    client_id = "da1effa23714436a93368fff6f869de2"
    client_secret = "b81bb02ba7e3494bbd9d28489f5a7b7f"

    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    return sp

# %%
sp = login_spotify()
sp

# %% [markdown]
# ## busca as músicas do artista

# %%
def search_musics_artist(sp,artist):

    results = sp.search(artist, limit=30)
    df = pd.DataFrame(columns=['artist','name', 'popularity', 'release_date'])
    for i, t in enumerate(results['tracks']['items']):
        df.loc[i] = [q, t['name'], t['popularity'], t['album']['release_date'] ]
        #print(' ', i, t['name'] , t['popularity'], t['album']['release_date']) # t['release_date']
    return df.sort_values('popularity', ascending=False)

sp = login_spotify()
q='Anitta'
df = search_musics_artist(sp,q)
df[:15]
# Out:
#     artist                                          name popularity  \
# 0   Anitta                                   TODO O NADA         79
# 10  Anitta                                      Downtown         72
# 18  Anitta                                 Girl From Rio         71
# 15  Anitta         Me Gusta (with Cardi B & Myke Towers)         70
# 23  Anitta                     Desce Pro Play (PA PA PA)         67
# 16  Anitta              R.I.P. (feat. Rita Ora & Anitta)         67
# 12  Anitta                    La Mamá de la Mamá (Remix)         64
# 21  Anitta  Fuego (with Sean Paul & Anitta, feat. Tainy)         63
# 20  Anitta                                     Brazilera         62
# 27  Anitta        Tócame (feat. Arcangel & De La Ghetto)         62
# 22  Anitta                                          Loco         62
# 17  Anitta                         Paloma (feat. Anitta)         61
# 13  Anitta                  Girl From Rio (feat. DaBaby)         61
# 24  Anitta                                        Veneno         59
# 14  Anitta                                     Paradinha         57
#
#    release_date
# 0    2021-05-21
# 10   2017-11-19
# 18   2021-04-29
# 15   2020-09-18
# 23   2020-06-26
# 16   2019-03-15
# 12   2021-07-30
# 21   2019-07-25
# 20   2021-06-25
# 27   2020-07-10
# 22   2021-01-29
# 17   2020-07-03
# 13   2021-05-21
# 24   2018-11-09
# 14   2017-05-31

# %%
#sp = login_spotify()
q='ludmilla'
df = search_musics_artist(sp,q)
df
# Out:
#       artist                                               name popularity  \
# 8   ludmilla                                           Apê 1001         77
# 11  ludmilla                      Deixa de Onda (Porra Nenhuma)         72
# 2   ludmilla  Medley Lud Session - Modo Avião / A Tua Voz / ...         67
# 23  ludmilla                                Já Tentei - Ao Vivo         66
# 6   ludmilla                                   Rainha da Favela         66
# 20  ludmilla                                        Gato Siamês         65
# 26  ludmilla                              Teu Segredo - Ao Vivo         63
# 27  ludmilla                             Amor Difícil - Ao vivo         61
# 15  ludmilla                             Um Pôr do Sol Na Praia         59
# 13  ludmilla  Invocada (Participação especial de Léo Santana...         59
# 29  ludmilla  A boba fui eu - Recorded At Mosh Studios, São ...         58
# 10  ludmilla  Medley Lud Session - Gato Siamês / Poesia Acús...         58
# 12  ludmilla                                           Verdinha         55
# 17  ludmilla                            Favela chegou - Ao vivo         53
# 14  ludmilla                                      Favela chegou         52
# 25  ludmilla  Din Din Din (Participação especial de MC Pupio...         51
# 21  ludmilla                                               Hoje         51
# 5   ludmilla                                            Cheguei         50
# 24  ludmilla                                     Vamos com tudo         48
# 9   ludmilla           Malokera (feat. Ludmilla, Ty Dolla $ign)         47
# 28  ludmilla                                   Verdinha - Remix         47
# 19  ludmilla                                   24 horas por dia         46
# 7   ludmilla                                                Bom         44
# 18  ludmilla   Ready Steady Go! - Beatman & Ludmilla Radio Edit         39
# 16  ludmilla                   Onda diferente (feat. Papatinho)         35
# 22  ludmilla     Pra te Machucar (feat. ÀTTØØXXÁ and Suku Ward)         34
# 4   ludmilla                                             Pegada          0
# 3   ludmilla                                          Meu baile          0
# 1   ludmilla                                  Te ensinei certin          0
# 0   ludmilla                                             Sou eu          0
#
#    release_date
# 8    2021-06-10
# 11   2021-01-21
# 2    2021-07-14
# 23   2020-06-19
# 6    2020-11-12
# 20   2021-04-16
# 26   2019-08-30
# 27   2021-01-29
# 15   2019-07-19
# 13   2019-05-31
# 29   2020-03-17
# 10   2021-07-13
# 12   2019-11-29
# 17   2019-02-27
# 14   2019-08-09
# 25   2018-06-06
# 21   2014-08-11
# 5    2016-10-21
# 24   2021-06-04
# 9    2019-08-09
# 28   2020-10-16
# 19   2014-08-11
# 7    2016-10-21
# 18   2014-06-20
# 16   2019-04-05
# 22   2021-03-26
# 4    2021-09-17
# 3    2021-09-17
# 1    2021-09-17
# 0    2021-09-17

# %%
len(df)
# Out:
# 30

# %%
#sp = login_spotify()
q='Rihanna'
df = search_musics_artist(sp,q)
df[:15]
# Out:
#      artist                                       name popularity release_date
# 2   Rihanna                       Love The Way You Lie         80   2010-06-18
# 19  Rihanna                                   Umbrella         80   2008-06-02
# 3   Rihanna  This Is What You Came For (feat. Rihanna)         79   2016-04-29
# 5   Rihanna                          Love On The Brain         79   2016-01-28
# 0   Rihanna                                  Needed Me         78   2016-01-28
# 8   Rihanna                              Pon de Replay         77   2005-08-29
# 10  Rihanna                            FourFiveSeconds         77   2015-01-24
# 15  Rihanna                                  Disturbia         75   2008-06-02
# 23  Rihanna                             Live Your Life         74   2008-09-07
# 13  Rihanna                                        S&M         74   2010-01-01
# 27  Rihanna                              We Found Love         74   2011-11-18
# 21  Rihanna                   Only Girl (In The World)         73   2010-01-01
# 17  Rihanna                                  Take Care         73   2011-11-15
# 26  Rihanna                              Run This Town         72   2009-09-08
# 28  Rihanna                                Sex With Me         72   2016-01-28

# %%
#sp = login_spotify()
q='Mariah Carey'
df = search_musics_artist(sp,q)
df[:10]

# %%
len(df)

# %%
#sp = login_spotify()
q='Paralamas'
df = search_musics_artist(sp,q)
df[:10]
# Out:
#        artist                     name popularity release_date
# 0   Paralamas     Aonde Quer Que Eu Vá         64   2000-01-01
# 7   Paralamas         Vital E Sua Moto         54   1983-01-01
# 10  Paralamas    Cuide Bem Do Seu Amor         51   2002-01-01
# 14  Paralamas  Caleidoscópio - Ao Vivo         46   1999-08-05
# 21  Paralamas                O Calibre         45   2002-01-01
# 16  Paralamas         Lourinha Bombril         44   1996-01-01
# 19  Paralamas        Seguindo Estrelas         41   2002-01-01
# 23  Paralamas         Lourinha Bombril         40   2000-01-01
# 22  Paralamas                Trac-Trac         39   2000-01-01
# 17  Paralamas    Tendo A Lua - Ao Vivo         38   1999-08-05

# %%
#sp = login_spotify()
q='Ivete Sangalo'
df = search_musics_artist(sp,q)
df[:15]

# %%
#sp = login_spotify()
q='Simone e Simaria'
df = search_musics_artist(sp,q)
df[:10]

# %% [markdown]
# ## Obter a musica mais popular de cada cantor/cantora

# %%
cantoras = ['Beyonce', 'Rihanna', 'Anitta', 'Ludmilla', 'Simone e Simaria', 'Ivete Sangalo', 'Claudia Leitte' ]
df = pd.DataFrame(columns=['artist','name', 'popularity', 'release_date'])
linha = 0
for artist in cantoras:
    popularidade = 0
    results = sp.search(artist, limit=30)
    for i, t in enumerate(results['tracks']['items']):
        if t['popularity'] > popularidade:
            musica_mais_popular = [artist, t['name'], t['popularity'], t['album']['release_date'] ]
            popularidade = t['popularity']
    df.loc[linha] = musica_mais_popular
    linha += 1   
df2 = df.sort_values('popularity', ascending=False)
df2

# %% [markdown]
# ## plota num gráfico

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(10,8))
fig.add_subplot(1,1,1)

ax = sns.barplot(y='artist', x = 'popularity', data=df2, palette="Set3" )

ax.axes.set_title("Best Popular Songs",fontsize=40)
ax.set_xlabel("Popularity",fontsize=26)
ax.set_ylabel("Artist",fontsize=20)
ax.tick_params(labelsize=15)
#sns.plt.show()
plt.show()

# %% [markdown]
# ## Banda, Músicas

# %%
import spotipy
sp = login_spotify()

results = sp.search(q='coldplay', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print (' ', i, t['name'])
# Out:
#   0 Yellow
#   1 Viva La Vida
#   2 Sparks
#   3 Hymn for the Weekend
#   4 Paradise
#   5 Something Just Like This
#   6 The Scientist
#   7 A Sky Full of Stars
#   8 Fix You
#   9 Clocks
#   10 Adventure of a Lifetime
#   11 Higher Power
#   12 Magic
#   13 Something Just Like This
#   14 Coloratura
#   15 Princess of China
#   16 Trouble
#   17 Speed of Sound
#   18 Coldplay
#   19 Coldplay

# %% [markdown]
# ## Mostra todos os albuns de um cantor/cantora

# %%
import sys
import spotipy

''' shows the albums and tracks for a given artist.
'''

def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set() # to avoid dups
    albums.sort(key=lambda album:album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            print((' ' + name))
            seen.add(name)

if __name__ == '__main__':
    sp = login_spotify()

    name = 'Beyonce'
    name = 'Simone e Simaria'
    name = 'coldplay'
    artist = get_artist(name)
    if artist:
        print('Albuns de: ', name)
        show_artist_albums(artist)
    else:
        print("Can't find that artist")
# Out:
# Albuns de:  coldplay
#  A Head Full of Dreams
#  A Head Full of Dreams Tour Edition
#  A Rush of Blood to the Head
#  Everyday Life
#  Ghost Stories
#  Ghost Stories Live 2014
#  LeftRightLeftRightLeft (Live)
#  Live in Buenos Aires
#  Love in Tokyo
#  Mylo Xyloto
#  Parachutes
#  Viva La Vida (Prospekt's March Edition)
#  Viva La Vida or Death and All His Friends
#  X&Y

# %% [markdown]
# ## Obtém informações do Artista

# %%
def obter_informacoes(nome_artista):
    from PIL import Image
    from urllib.request import urlopen
    artista = get_artist(nome_artista)
    seguidores = artista['followers']['total']
    genero = artista['genres']
    foto_url = artista['images'][0]['url']
    popularidade = artista['popularity']
    uri = artista['uri']
    url_spotify = artista['external_urls']['spotify']
    print('Artista: ', artista['name'])
    print('Número de Seguidores: ', '{:,d}'.format(seguidores))
    print('Gênero: ', genero)
    print('Popularidade: ', popularidade)
    print('Spotify uri:', uri)
    print('Spotify url:',url_spotify)
    foto = Image.open(urlopen(foto_url))
    return foto #seguidores, genero, popularidade, foto_url, uri, url_spotify

nome_artista = 'Beyonce'
nome_artista = name = 'Simone e Simaria'

nome_artista = 'Michael Jackson'
foto = obter_informacoes(nome_artista)
im = foto.convert("RGB")

display(im)
# Out:
# Artista:  Michael Jackson
# Número de Seguidores:  19,803,693
# Gênero:  ['pop', 'r&b', 'soul']
# Popularidade:  82
# Spotify uri: spotify:artist:3fMbdgg4jU18AjLCKBhRSm
# Spotify url: https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm
# <PIL.Image.Image image mode=RGB size=640x639 at 0x7F8D711F2100>

# %%
nome_artista = 'Anitta'
foto = obter_informacoes(nome_artista)
foto
# Out:
# Artista:  Anitta
# Número de Seguidores:  10,813,172
# Gênero:  ['funk carioca', 'funk pop', 'pagode baiano', 'pop nacional']
# Popularidade:  80
# Spotify uri: spotify:artist:7FNnA9vBm6EKceENgCGRMb
# Spotify url: https://open.spotify.com/artist/7FNnA9vBm6EKceENgCGRMb
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7F8D711D08B0>

# %%
nome_artista = 'Ludmilla'
foto = obter_informacoes(nome_artista)
foto

# %%
nome_artista = 'katy perry'
foto = obter_informacoes(nome_artista)
foto

# %%
nome_artista = 'lady gaga'
foto = obter_informacoes(nome_artista)
foto

# %%
#!pip install pillow

# %%
from IPython.display import display
from PIL import Image

nome_artista = 'michael jackson'
foto = obter_informacoes(nome_artista)
im = foto.convert("RGB")

display(im)
